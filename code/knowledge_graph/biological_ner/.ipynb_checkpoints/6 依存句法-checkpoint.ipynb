# %% [markdown]
# ## 1 读原文件

# %%
import csv

def remove_quotes(string):
    if string.startswith("'") and string.endswith("'"):
        string = string.strip("'")
    elif string.startswith('"') and string.endswith('"'):
        string = string.strip('"')
    return string

with open('/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/biological_ner/data/original_data/before_translate/biological_strategy.csv', 'r', encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='"')
    # 跳过表头
    next(reader)
    
    # 逐行读取数据, 并将需要叙述存入列表中
    text_list = []
    
    for row in reader:
        doc_dict = {}
        id = '##id:'+ row[0]
        first_fun = row[1]
        second_fun = row[2]
        third_fun = row[3]
        title = row[4]
        URL = row[5]
        introduction = row[6]
        strategy = row[7]
        potential = row[8]
        related_innovation = row[9]
        related_strategy = row[10]
        reference = row[11]
        
        # 删除字符串首尾的‘’符号
        introduction = remove_quotes(introduction)
        strategy = remove_quotes(strategy).replace("', '",", ")
        potential = remove_quotes(potential).replace("', '",". ")
        
        # 将文章编号、标题、introduction、strategy、potential合并，并处理成标注需要的格式
        if len(introduction) > 3 or len(strategy) > 3 or len(potential) > 3:
            doc_dict["id"] = id
            doc_dict["title"] = title
            doc_dict["introduction"] = introduction
            doc_dict["strategy"] = strategy
            doc_dict["potential"] = potential
            text_list.append(doc_dict)

# %%
# print(len(text_list))
# print(text_list[0])

# %% [markdown]
# ## 2. 进行依存句法分析

# %%
import spacy

# 加载spaCy的英文模型
nlp = spacy.load('en_core_web_sm')

# 输入待处理的文本并进行依存句法分析
parse_result_list = []
for doc in text_list:
    parse_result = {}
    text = doc["title"] + doc["introduction"] + doc["strategy"] + doc["potential"]
    
    # 对文章进行依存句法分析
    result = nlp(text)

    # 打印每个词语的依存关系、头部词和词性
    parse_result["id"] = doc["id"]
    parse_result["title"] = doc["title"]
    parse_result["result"] = []
    for token in result:
        parse_result_dict = {}
        parse_result_dict["text"] = token.text
        parse_result_dict["dep_"] = token.dep_
        parse_result_dict["head"] = token.head.text
        parse_result_dict["pos_"] = token.pos_
        parse_result["result"].append(parse_result_dict)
    parse_result_list.append(parse_result)

# %%
print(len(parse_result_list))
parse_result_list[0]
# Out:
# 609
# {'id': '##id:0',
#  'title': 'How Fungi Can Clean Up Pollution',
#  'result': [{'text': 'How',
#    'dep_': 'advmod',
#    'head': 'Clean',
#    'pos_': 'SCONJ'},
#   {'text': 'Fungi', 'dep_': 'nsubj', 'head': 'Clean', 'pos_': 'PROPN'},
#   {'text': 'Can', 'dep_': 'aux', 'head': 'Clean', 'pos_': 'AUX'},
#   {'text': 'Clean',
#    'dep_': 'amod',
#    'head': 'PollutionWhoever',
#    'pos_': 'VERB'},
#   {'text': 'Up', 'dep_': 'prt', 'head': 'Clean', 'pos_': 'ADP'},
#   {'text': 'PollutionWhoever',
#    'dep_': 'nsubj',
#    'head': 'observed',
#    'pos_': 'PROPN'},
#   {'text': 'observed', 'dep_': 'ROOT', 'head': 'observed', 'pos_': 'VERB'},
#   {'text': 'that', 'dep_': 'mark', 'head': 'is', 'pos_': 'SCONJ'},
#   {'text': '“', 'dep_': 'punct', 'head': 'is', 'pos_': 'PUNCT'},
#   {'text': 'one', 'dep_': 'nummod', 'head': 'person', 'pos_': 'NUM'},
#   {'text': 'person', 'dep_': 'poss', 'head': 'trash', 'pos_': 'NOUN'},
#   {'text': '’s', 'dep_': 'case', 'head': 'person', 'pos_': 'PART'},
#   {'text': 'trash', 'dep_': 'nsubj', 'head': 'is', 'pos_': 'NOUN'},
#   {'text': 'is', 'dep_': 'ccomp', 'head': 'observed', 'pos_': 'AUX'},
#   {'text': 'another', 'dep_': 'det', 'head': 'treasure', 'pos_': 'DET'},
#   {'text': '’s', 'dep_': 'case', 'head': 'another', 'pos_': 'PART'},
#   {'text': 'treasure', 'dep_': 'attr', 'head': 'is', 'pos_': 'NOUN'},
#   {'text': '”', 'dep_': 'punct', 'head': 'treasure', 'pos_': 'PUNCT'},
#   {'text': 'could', 'dep_': 'aux', 'head': 'speaking', 'pos_': 'AUX'},
#   {'text': 'easily', 'dep_': 'advmod', 'head': 'speaking', 'pos_': 'ADV'},
#   {'text': 'have', 'dep_': 'aux', 'head': 'speaking', 'pos_': 'AUX'},
#   {'text': 'been', 'dep_': 'aux', 'head': 'speaking', 'pos_': 'AUX'},
#   {'text': 'speaking', 'dep_': 'advcl', 'head': 'observed', 'pos_': 'VERB'},
#   {'text': 'about', 'dep_': 'prep', 'head': 'speaking', 'pos_': 'ADP'},
#   {'text': 'fungi', 'dep_': 'pobj', 'head': 'about', 'pos_': 'NOUN'},
#   {'text': '.', 'dep_': 'punct', 'head': 'observed', 'pos_': 'PUNCT'},
#   {'text': 'These', 'dep_': 'det', 'head': 'organisms', 'pos_': 'DET'},
#   {'text': 'organisms', 'dep_': 'nsubj', 'head': 'come', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'organisms', 'pos_': 'PUNCT'},
#   {'text': 'which', 'dep_': 'nsubj', 'head': 'form', 'pos_': 'PRON'},
#   {'text': 'form', 'dep_': 'relcl', 'head': 'organisms', 'pos_': 'VERB'},
#   {'text': 'a', 'dep_': 'det', 'head': 'kingdom', 'pos_': 'DET'},
#   {'text': 'kingdom', 'dep_': 'dobj', 'head': 'form', 'pos_': 'NOUN'},
#   {'text': 'all', 'dep_': 'advmod', 'head': 'on', 'pos_': 'ADV'},
#   {'text': 'on', 'dep_': 'prep', 'head': 'form', 'pos_': 'ADP'},
#   {'text': 'their', 'dep_': 'poss', 'head': 'own', 'pos_': 'PRON'},
#   {'text': 'own', 'dep_': 'pobj', 'head': 'on', 'pos_': 'ADJ'},
#   {'text': ',', 'dep_': 'punct', 'head': 'organisms', 'pos_': 'PUNCT'},
#   {'text': 'come', 'dep_': 'ROOT', 'head': 'come', 'pos_': 'VERB'},
#   {'text': 'in', 'dep_': 'prep', 'head': 'come', 'pos_': 'ADP'},
#   {'text': 'virtually', 'dep_': 'advmod', 'head': 'endless', 'pos_': 'ADV'},
#   {'text': 'endless', 'dep_': 'amod', 'head': 'sizes', 'pos_': 'ADJ'},
#   {'text': 'sizes', 'dep_': 'pobj', 'head': 'in', 'pos_': 'NOUN'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'sizes', 'pos_': 'CCONJ'},
#   {'text': 'shapes', 'dep_': 'conj', 'head': 'sizes', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'come', 'pos_': 'PUNCT'},
#   {'text': 'from', 'dep_': 'prep', 'head': 'come', 'pos_': 'ADP'},
#   {'text': 'single', 'dep_': 'advmod', 'head': 'celled', 'pos_': 'ADJ'},
#   {'text': '-', 'dep_': 'punct', 'head': 'celled', 'pos_': 'PUNCT'},
#   {'text': 'celled', 'dep_': 'amod', 'head': 'yeasts', 'pos_': 'VERB'},
#   {'text': 'yeasts', 'dep_': 'pobj', 'head': 'from', 'pos_': 'NOUN'},
#   {'text': 'to', 'dep_': 'prep', 'head': 'from', 'pos_': 'ADP'},
#   {'text': 'massive', 'dep_': 'amod', 'head': 'organisms', 'pos_': 'ADJ'},
#   {'text': ',', 'dep_': 'punct', 'head': 'massive', 'pos_': 'PUNCT'},
#   {'text': 'web', 'dep_': 'meta', 'head': ',', 'pos_': 'ADJ'},
#   {'text': '-', 'dep_': 'punct', 'head': 'web', 'pos_': 'ADJ'},
#   {'text': 'like', 'dep_': 'conj', 'head': 'massive', 'pos_': 'ADJ'},
#   {'text': 'organisms', 'dep_': 'pobj', 'head': 'to', 'pos_': 'NOUN'},
#   {'text': 'that', 'dep_': 'nsubj', 'head': 'stretch', 'pos_': 'PRON'},
#   {'text': 'stretch', 'dep_': 'relcl', 'head': 'organisms', 'pos_': 'VERB'},
#   {'text': 'for', 'dep_': 'prep', 'head': 'stretch', 'pos_': 'ADP'},
#   {'text': 'miles', 'dep_': 'pobj', 'head': 'for', 'pos_': 'NOUN'},
#   {'text': 'underground', 'dep_': 'advmod', 'head': 'stretch', 'pos_': 'ADV'},
#   {'text': '.', 'dep_': 'punct', 'head': 'come', 'pos_': 'PUNCT'},
#   {'text': 'They', 'dep_': 'nsubj', 'head': 'make', 'pos_': 'PRON'},
#   {'text': 'make', 'dep_': 'ROOT', 'head': 'make', 'pos_': 'VERB'},
#   {'text': 'their', 'dep_': 'poss', 'head': 'way', 'pos_': 'PRON'},
#   {'text': 'way', 'dep_': 'dobj', 'head': 'make', 'pos_': 'NOUN'},
#   {'text': 'through', 'dep_': 'prep', 'head': 'make', 'pos_': 'ADP'},
#   {'text': 'life', 'dep_': 'pobj', 'head': 'through', 'pos_': 'NOUN'},
#   {'text': 'by', 'dep_': 'prep', 'head': 'make', 'pos_': 'ADP'},
#   {'text': 'tapping', 'dep_': 'pcomp', 'head': 'by', 'pos_': 'VERB'},
#   {'text': 'into', 'dep_': 'prep', 'head': 'tapping', 'pos_': 'ADP'},
#   {'text': 'resources', 'dep_': 'pobj', 'head': 'into', 'pos_': 'NOUN'},
#   {'text': 'few', 'dep_': 'amod', 'head': 'manure', 'pos_': 'ADJ'},
#   {'text': 'if', 'dep_': 'mark', 'head': 'want', 'pos_': 'SCONJ'},
#   {'text': 'any', 'dep_': 'det', 'head': 'others', 'pos_': 'DET'},
#   {'text': 'others', 'dep_': 'nsubj', 'head': 'want', 'pos_': 'NOUN'},
#   {'text': 'want', 'dep_': 'advcl', 'head': 'few', 'pos_': 'VERB'},
#   {'text': '—', 'dep_': 'punct', 'head': 'few', 'pos_': 'PUNCT'},
#   {'text': 'horse', 'dep_': 'compound', 'head': 'manure', 'pos_': 'NOUN'},
#   {'text': 'manure', 'dep_': 'npadvmod', 'head': 'make', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'manure', 'pos_': 'PUNCT'},
#   {'text': 'fallen', 'dep_': 'amod', 'head': 'leaves', 'pos_': 'VERB'},
#   {'text': 'leaves', 'dep_': 'appos', 'head': 'manure', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'leaves', 'pos_': 'PUNCT'},
#   {'text': 'dead', 'dep_': 'amod', 'head': 'animals', 'pos_': 'ADJ'},
#   {'text': 'animals', 'dep_': 'conj', 'head': 'leaves', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'animals', 'pos_': 'PUNCT'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'animals', 'pos_': 'CCONJ'},
#   {'text': 'the', 'dep_': 'det', 'head': 'like', 'pos_': 'DET'},
#   {'text': 'like', 'dep_': 'conj', 'head': 'manure', 'pos_': 'ADJ'},
#   {'text': '—', 'dep_': 'punct', 'head': 'like', 'pos_': 'PUNCT'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'like', 'pos_': 'CCONJ'},
#   {'text': 'breaking', 'dep_': 'conj', 'head': 'like', 'pos_': 'VERB'},
#   {'text': 'down', 'dep_': 'prt', 'head': 'breaking', 'pos_': 'ADP'},
#   {'text': 'the', 'dep_': 'det', 'head': 'chemicals', 'pos_': 'DET'},
#   {'text': 'natural', 'dep_': 'amod', 'head': 'chemicals', 'pos_': 'ADJ'},
#   {'text': 'chemicals', 'dep_': 'dobj', 'head': 'breaking', 'pos_': 'NOUN'},
#   {'text': 'they', 'dep_': 'nsubj', 'head': 'contain', 'pos_': 'PRON'},
#   {'text': 'contain', 'dep_': 'relcl', 'head': 'chemicals', 'pos_': 'VERB'},
#   {'text': 'into', 'dep_': 'prep', 'head': 'contain', 'pos_': 'ADP'},
#   {'text': 'a', 'dep_': 'det', 'head': 'source', 'pos_': 'DET'},
#   {'text': 'source', 'dep_': 'pobj', 'head': 'into', 'pos_': 'NOUN'},
#   {'text': 'of', 'dep_': 'prep', 'head': 'source', 'pos_': 'ADP'},
#   {'text': 'energy', 'dep_': 'pobj', 'head': 'of', 'pos_': 'NOUN'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'energy', 'pos_': 'CCONJ'},
#   {'text': 'molecules', 'dep_': 'conj', 'head': 'energy', 'pos_': 'NOUN'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'nourish', 'pos_': 'PART'},
#   {'text': 'nourish', 'dep_': 'advcl', 'head': 'contain', 'pos_': 'VERB'},
#   {'text': 'themselves', 'dep_': 'dobj', 'head': 'nourish', 'pos_': 'PRON'},
#   {'text': '.', 'dep_': 'punct', 'head': 'make', 'pos_': 'PUNCT'},
#   {'text': 'Some', 'dep_': 'det', 'head': 'fungi', 'pos_': 'DET'},
#   {'text': 'fungi', 'dep_': 'nsubj', 'head': 'use', 'pos_': 'NOUN'},
#   {'text': 'can', 'dep_': 'aux', 'head': 'use', 'pos_': 'AUX'},
#   {'text': 'use', 'dep_': 'ROOT', 'head': 'use', 'pos_': 'VERB'},
#   {'text': 'the', 'dep_': 'det', 'head': 'molecules', 'pos_': 'DET'},
#   {'text': 'same', 'dep_': 'amod', 'head': 'molecules', 'pos_': 'ADJ'},
#   {'text': 'molecules', 'dep_': 'dobj', 'head': 'use', 'pos_': 'NOUN'},
#   {'text': 'that', 'dep_': 'nsubj', 'head': 'help', 'pos_': 'PRON'},
#   {'text': 'help', 'dep_': 'relcl', 'head': 'molecules', 'pos_': 'VERB'},
#   {'text': 'them', 'dep_': 'nsubj', 'head': 'obtain', 'pos_': 'PRON'},
#   {'text': 'obtain', 'dep_': 'ccomp', 'head': 'help', 'pos_': 'VERB'},
#   {'text': 'food', 'dep_': 'dobj', 'head': 'obtain', 'pos_': 'NOUN'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'break', 'pos_': 'PART'},
#   {'text': 'break', 'dep_': 'advcl', 'head': 'obtain', 'pos_': 'VERB'},
#   {'text': 'down', 'dep_': 'prt', 'head': 'break', 'pos_': 'ADP'},
#   {'text': 'artificial', 'dep_': 'amod', 'head': 'chemicals', 'pos_': 'ADJ'},
#   {'text': 'chemicals', 'dep_': 'dobj', 'head': 'break', 'pos_': 'NOUN'},
#   {'text': 'with', 'dep_': 'prep', 'head': 'contaminated', 'pos_': 'ADP'},
#   {'text': 'which', 'dep_': 'pobj', 'head': 'with', 'pos_': 'PRON'},
#   {'text': 'we', 'dep_': 'nmod', 'head': 'humans', 'pos_': 'PRON'},
#   {'text': 'humans', 'dep_': 'nsubj', 'head': 'contaminated', 'pos_': 'NOUN'},
#   {'text': 'have', 'dep_': 'aux', 'head': 'contaminated', 'pos_': 'AUX'},
#   {'text': 'contaminated',
#    'dep_': 'relcl',
#    'head': 'chemicals',
#    'pos_': 'VERB'},
#   {'text': 'the', 'dep_': 'det', 'head': 'environment', 'pos_': 'DET'},
#   {'text': 'environment',
#    'dep_': 'dobj',
#    'head': 'contaminated',
#    'pos_': 'NOUN'},
#   {'text': '.', 'dep_': 'punct', 'head': 'use', 'pos_': 'PUNCT'},
#   {'text': 'All', 'dep_': 'det', 'head': 'things', 'pos_': 'DET'},
#   {'text': 'living', 'dep_': 'amod', 'head': 'things', 'pos_': 'VERB'},
#   {'text': 'things', 'dep_': 'nsubj', 'head': 'contain', 'pos_': 'NOUN'},
#   {'text': 'contain', 'dep_': 'ccomp', 'head': 'proteins', 'pos_': 'VERB'},
#   {'text': 'enzymes', 'dep_': 'dobj', 'head': 'contain', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'proteins', 'pos_': 'PUNCT'},
#   {'text': 'proteins', 'dep_': 'ROOT', 'head': 'proteins', 'pos_': 'NOUN'},
#   {'text': 'they', 'dep_': 'nsubj', 'head': 'use', 'pos_': 'PRON'},
#   {'text': 'use', 'dep_': 'relcl', 'head': 'proteins', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'break', 'pos_': 'PART'},
#   {'text': 'break', 'dep_': 'xcomp', 'head': 'use', 'pos_': 'VERB'},
#   {'text': 'or', 'dep_': 'cc', 'head': 'break', 'pos_': 'CCONJ'},
#   {'text': 'make', 'dep_': 'conj', 'head': 'break', 'pos_': 'VERB'},
#   {'text': 'chemical', 'dep_': 'amod', 'head': 'bonds', 'pos_': 'NOUN'},
#   {'text': 'bonds', 'dep_': 'dobj', 'head': 'make', 'pos_': 'NOUN'},
#   {'text': '.', 'dep_': 'punct', 'head': 'proteins', 'pos_': 'PUNCT'},
#   {'text': 'By', 'dep_': 'prep', 'head': 'allow', 'pos_': 'ADP'},
#   {'text': 'holding', 'dep_': 'pcomp', 'head': 'By', 'pos_': 'VERB'},
#   {'text': 'two', 'dep_': 'nummod', 'head': 'molecules', 'pos_': 'NUM'},
#   {'text': 'or', 'dep_': 'cc', 'head': 'two', 'pos_': 'CCONJ'},
#   {'text': 'more', 'dep_': 'conj', 'head': 'two', 'pos_': 'ADJ'},
#   {'text': 'molecules', 'dep_': 'dobj', 'head': 'holding', 'pos_': 'NOUN'},
#   {'text': 'close', 'dep_': 'amod', 'head': 'molecules', 'pos_': 'ADJ'},
#   {'text': 'to', 'dep_': 'prep', 'head': 'close', 'pos_': 'ADP'},
#   {'text': 'each', 'dep_': 'det', 'head': 'other', 'pos_': 'DET'},
#   {'text': 'other', 'dep_': 'pobj', 'head': 'to', 'pos_': 'ADJ'},
#   {'text': 'in', 'dep_': 'prep', 'head': 'holding', 'pos_': 'ADP'},
#   {'text': 'a', 'dep_': 'det', 'head': 'position', 'pos_': 'DET'},
#   {'text': 'position', 'dep_': 'pobj', 'head': 'in', 'pos_': 'NOUN'},
#   {'text': 'that', 'dep_': 'nsubj', 'head': 'encourages', 'pos_': 'PRON'},
#   {'text': 'encourages', 'dep_': 'relcl', 'head': 'position', 'pos_': 'VERB'},
#   {'text': 'them', 'dep_': 'dobj', 'head': 'encourages', 'pos_': 'PRON'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'react', 'pos_': 'PART'},
#   {'text': 'react', 'dep_': 'xcomp', 'head': 'encourages', 'pos_': 'VERB'},
#   {'text': 'with', 'dep_': 'prep', 'head': 'react', 'pos_': 'ADP'},
#   {'text': 'each', 'dep_': 'det', 'head': 'other', 'pos_': 'DET'},
#   {'text': 'other', 'dep_': 'pobj', 'head': 'with', 'pos_': 'ADJ'},
#   {'text': ',', 'dep_': 'punct', 'head': 'allow', 'pos_': 'PUNCT'},
#   {'text': 'enzymes', 'dep_': 'nsubj', 'head': 'allow', 'pos_': 'NOUN'},
#   {'text': 'allow', 'dep_': 'ROOT', 'head': 'allow', 'pos_': 'VERB'},
#   {'text': 'their', 'dep_': 'poss', 'head': 'owners', 'pos_': 'PRON'},
#   {'text': 'owners', 'dep_': 'nsubj', 'head': 'transform', 'pos_': 'NOUN'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'transform', 'pos_': 'PART'},
#   {'text': 'transform', 'dep_': 'ccomp', 'head': 'allow', 'pos_': 'VERB'},
#   {'text': 'one', 'dep_': 'nummod', 'head': 'substance', 'pos_': 'NUM'},
#   {'text': 'substance', 'dep_': 'dobj', 'head': 'transform', 'pos_': 'NOUN'},
#   {'text': 'into', 'dep_': 'prep', 'head': 'transform', 'pos_': 'ADP'},
#   {'text': 'another', 'dep_': 'pobj', 'head': 'into', 'pos_': 'PRON'},
#   {'text': ',', 'dep_': 'punct', 'head': 'allow', 'pos_': 'PUNCT'},
#   {'text': 'creating', 'dep_': 'advcl', 'head': 'allow', 'pos_': 'VERB'},
#   {'text': 'the', 'dep_': 'det', 'head': 'molecules', 'pos_': 'DET'},
#   {'text': 'molecules', 'dep_': 'dobj', 'head': 'creating', 'pos_': 'NOUN'},
#   {'text': 'they', 'dep_': 'nsubj', 'head': 'need', 'pos_': 'PRON'},
#   {'text': 'need', 'dep_': 'relcl', 'head': 'molecules', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'provide', 'pos_': 'PART'},
#   {'text': 'provide', 'dep_': 'xcomp', 'head': 'need', 'pos_': 'VERB'},
#   {'text': 'structure', 'dep_': 'dobj', 'head': 'provide', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'creating', 'pos_': 'PUNCT'},
#   {'text': 'produce', 'dep_': 'conj', 'head': 'creating', 'pos_': 'VERB'},
#   {'text': 'energy', 'dep_': 'dobj', 'head': 'produce', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'produce', 'pos_': 'PUNCT'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'produce', 'pos_': 'CCONJ'},
#   {'text': 'more', 'dep_': 'conj', 'head': 'produce', 'pos_': 'ADJ'},
#   {'text': '.', 'dep_': 'punct', 'head': 'allow', 'pos_': 'PUNCT'},
#   {'text': ',', 'dep_': 'punct', 'head': 'allow', 'pos_': 'PUNCT'},
#   {'text': 'As', 'dep_': 'prep', 'head': 'have', 'pos_': 'ADP'},
#   {'text': 'organisms', 'dep_': 'pobj', 'head': 'As', 'pos_': 'NOUN'},
#   {'text': 'that', 'dep_': 'nsubj', 'head': 'specialize', 'pos_': 'PRON'},
#   {'text': 'specialize', 'dep_': 'relcl', 'head': 'organisms', 'pos_': 'VERB'},
#   {'text': 'in', 'dep_': 'prep', 'head': 'specialize', 'pos_': 'ADP'},
#   {'text': 'decomposing', 'dep_': 'pcomp', 'head': 'in', 'pos_': 'VERB'},
#   {'text': 'other', 'dep_': 'amod', 'head': 'living', 'pos_': 'ADJ'},
#   {'text': 'living', 'dep_': 'nmod', 'head': 'things', 'pos_': 'NOUN'},
#   {'text': '(', 'dep_': 'punct', 'head': 'living', 'pos_': 'PUNCT'},
#   {'text': 'or', 'dep_': 'cc', 'head': 'living', 'pos_': 'CCONJ'},
#   {'text': 'formerly', 'dep_': 'advmod', 'head': 'living', 'pos_': 'ADV'},
#   {'text': 'living', 'dep_': 'conj', 'head': 'living', 'pos_': 'VERB'},
#   {'text': ')', 'dep_': 'punct', 'head': 'things', 'pos_': 'PUNCT'},
#   {'text': 'things', 'dep_': 'dobj', 'head': 'decomposing', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'have', 'pos_': 'PUNCT'},
#   {'text': 'fungi', 'dep_': 'nsubj', 'head': 'have', 'pos_': 'NOUN'},
#   {'text': 'have', 'dep_': 'advcl', 'head': 'allow', 'pos_': 'VERB'},
#   {'text': 'a', 'dep_': 'det', 'head': 'variety', 'pos_': 'DET'},
#   {'text': 'particularly',
#    'dep_': 'advmod',
#    'head': 'impressive',
#    'pos_': 'ADV'},
#   {'text': 'impressive', 'dep_': 'amod', 'head': 'variety', 'pos_': 'ADJ'},
#   {'text': 'variety', 'dep_': 'dobj', 'head': 'have', 'pos_': 'NOUN'},
#   {'text': 'of', 'dep_': 'prep', 'head': 'variety', 'pos_': 'ADP'},
#   {'text': 'enzymes', 'dep_': 'pobj', 'head': 'of', 'pos_': 'NOUN'},
#   {'text': 'they', 'dep_': 'nsubj', 'head': 'use', 'pos_': 'PRON'},
#   {'text': 'can', 'dep_': 'aux', 'head': 'use', 'pos_': 'AUX'},
#   {'text': 'use', 'dep_': 'relcl', 'head': 'variety', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'break', 'pos_': 'PART'},
#   {'text': 'break', 'dep_': 'xcomp', 'head': 'use', 'pos_': 'VERB'},
#   {'text': 'down', 'dep_': 'prt', 'head': 'break', 'pos_': 'ADP'},
#   {'text': 'a', 'dep_': 'det', 'head': 'variety', 'pos_': 'DET'},
#   {'text': 'wide', 'dep_': 'amod', 'head': 'variety', 'pos_': 'ADJ'},
#   {'text': 'variety', 'dep_': 'dobj', 'head': 'break', 'pos_': 'NOUN'},
#   {'text': 'of', 'dep_': 'prep', 'head': 'variety', 'pos_': 'ADP'},
#   {'text': 'chemicals', 'dep_': 'pobj', 'head': 'of', 'pos_': 'NOUN'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'extract', 'pos_': 'PART'},
#   {'text': 'extract', 'dep_': 'advcl', 'head': 'break', 'pos_': 'VERB'},
#   {'text': 'the', 'dep_': 'det', 'head': 'energy', 'pos_': 'DET'},
#   {'text': 'energy', 'dep_': 'dobj', 'head': 'extract', 'pos_': 'NOUN'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'energy', 'pos_': 'CCONJ'},
#   {'text': 'molecules', 'dep_': 'conj', 'head': 'energy', 'pos_': 'NOUN'},
#   {'text': 'they', 'dep_': 'nsubj', 'head': 'need', 'pos_': 'PRON'},
#   {'text': 'need', 'dep_': 'relcl', 'head': 'energy', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'live', 'pos_': 'PART'},
#   {'text': 'live', 'dep_': 'xcomp', 'head': 'need', 'pos_': 'VERB'},
#   {'text': '.', 'dep_': 'punct', 'head': 'allow', 'pos_': 'PUNCT'},
#   {'text': 'Scientists',
#    'dep_': 'nsubj',
#    'head': 'discovered',
#    'pos_': 'NOUN'},
#   {'text': 'searching', 'dep_': 'acl', 'head': 'Scientists', 'pos_': 'VERB'},
#   {'text': 'for', 'dep_': 'prep', 'head': 'searching', 'pos_': 'ADP'},
#   {'text': 'ways', 'dep_': 'pobj', 'head': 'for', 'pos_': 'NOUN'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'remove', 'pos_': 'PART'},
#   {'text': 'remove', 'dep_': 'relcl', 'head': 'ways', 'pos_': 'VERB'},
#   {'text': 'human', 'dep_': 'npadvmod', 'head': 'made', 'pos_': 'NOUN'},
#   {'text': '-', 'dep_': 'punct', 'head': 'made', 'pos_': 'PUNCT'},
#   {'text': 'made', 'dep_': 'amod', 'head': 'pollutants', 'pos_': 'VERB'},
#   {'text': 'pollutants', 'dep_': 'dobj', 'head': 'remove', 'pos_': 'NOUN'},
#   {'text': 'from', 'dep_': 'prep', 'head': 'remove', 'pos_': 'ADP'},
#   {'text': 'the', 'dep_': 'det', 'head': 'environment', 'pos_': 'DET'},
#   {'text': 'environment', 'dep_': 'pobj', 'head': 'from', 'pos_': 'NOUN'},
#   {'text': 'have', 'dep_': 'aux', 'head': 'discovered', 'pos_': 'AUX'},
#   {'text': 'discovered', 'dep_': 'ccomp', 'head': 'include', 'pos_': 'VERB'},
#   {'text': 'that', 'dep_': 'mark', 'head': 'use', 'pos_': 'SCONJ'},
#   {'text': 'some', 'dep_': 'det', 'head': 'fungi', 'pos_': 'DET'},
#   {'text': 'fungi', 'dep_': 'nsubj', 'head': 'use', 'pos_': 'NOUN'},
#   {'text': 'can', 'dep_': 'aux', 'head': 'use', 'pos_': 'AUX'},
#   {'text': 'use', 'dep_': 'ccomp', 'head': 'discovered', 'pos_': 'VERB'},
#   {'text': 'their', 'dep_': 'poss', 'head': 'enzymes', 'pos_': 'PRON'},
#   {'text': 'enzymes', 'dep_': 'dobj', 'head': 'use', 'pos_': 'NOUN'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'degrade', 'pos_': 'PART'},
#   {'text': 'degrade', 'dep_': 'xcomp', 'head': 'use', 'pos_': 'VERB'},
#   {'text': 'these', 'dep_': 'det', 'head': 'chemicals', 'pos_': 'DET'},
#   {'text': 'undesirable', 'dep_': 'amod', 'head': 'chemicals', 'pos_': 'ADJ'},
#   {'text': 'chemicals', 'dep_': 'dobj', 'head': 'degrade', 'pos_': 'NOUN'},
#   {'text': '.', 'dep_': 'punct', 'head': 'discovered', 'pos_': 'PUNCT'},
#   {'text': ',', 'dep_': 'punct', 'head': 'include', 'pos_': 'PUNCT'},
#   {'text': 'Contaminants', 'dep_': 'nsubj', 'head': 'include', 'pos_': 'NOUN'},
#   {'text': 'that', 'dep_': 'dobj', 'head': 'break', 'pos_': 'SCONJ'},
#   {'text': 'fungi', 'dep_': 'nsubjpass', 'head': 'found', 'pos_': 'NOUN'},
#   {'text': 'have', 'dep_': 'aux', 'head': 'found', 'pos_': 'AUX'},
#   {'text': 'been', 'dep_': 'auxpass', 'head': 'found', 'pos_': 'AUX'},
#   {'text': 'found', 'dep_': 'relcl', 'head': 'Contaminants', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'break', 'pos_': 'PART'},
#   {'text': 'break', 'dep_': 'xcomp', 'head': 'found', 'pos_': 'VERB'},
#   {'text': 'down', 'dep_': 'prt', 'head': 'break', 'pos_': 'ADP'},
#   {'text': 'include', 'dep_': 'ROOT', 'head': 'include', 'pos_': 'VERB'},
#   {'text': 'polyaromatic',
#    'dep_': 'amod',
#    'head': 'hydrocarbons',
#    'pos_': 'ADJ'},
#   {'text': 'hydrocarbons', 'dep_': 'dobj', 'head': 'include', 'pos_': 'NOUN'},
#   {'text': '(', 'dep_': 'punct', 'head': 'hydrocarbons', 'pos_': 'PUNCT'},
#   {'text': 'such', 'dep_': 'amod', 'head': 'as', 'pos_': 'ADJ'},
#   {'text': 'as', 'dep_': 'prep', 'head': 'hydrocarbons', 'pos_': 'ADP'},
#   {'text': 'those', 'dep_': 'pobj', 'head': 'as', 'pos_': 'PRON'},
#   {'text': 'found', 'dep_': 'acl', 'head': 'those', 'pos_': 'VERB'},
#   {'text': 'in', 'dep_': 'prep', 'head': 'found', 'pos_': 'ADP'},
#   {'text': 'crude', 'dep_': 'amod', 'head': 'oil', 'pos_': 'ADJ'},
#   {'text': 'oil', 'dep_': 'pobj', 'head': 'in', 'pos_': 'NOUN'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'oil', 'pos_': 'CCONJ'},
#   {'text': 'gasoline', 'dep_': 'conj', 'head': 'oil', 'pos_': 'NOUN'},
#   {'text': ')', 'dep_': 'punct', 'head': 'those', 'pos_': 'PUNCT'},
#   {'text': ',', 'dep_': 'punct', 'head': 'those', 'pos_': 'PUNCT'},
#   {'text': 'heavy', 'dep_': 'amod', 'head': 'metals', 'pos_': 'ADJ'},
#   {'text': 'metals', 'dep_': 'conj', 'head': 'those', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'metals', 'pos_': 'PUNCT'},
#   {'text': 'herbicides', 'dep_': 'conj', 'head': 'metals', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'herbicides', 'pos_': 'PUNCT'},
#   {'text': 'pesticides', 'dep_': 'conj', 'head': 'herbicides', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'pesticides', 'pos_': 'PUNCT'},
#   {'text': 'cyanotoxins',
#    'dep_': 'conj',
#    'head': 'pesticides',
#    'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'cyanotoxins', 'pos_': 'PUNCT'},
#   {'text': 'pharmaceuticals',
#    'dep_': 'conj',
#    'head': 'cyanotoxins',
#    'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'pharmaceuticals', 'pos_': 'PUNCT'},
#   {'text': 'antibiotics',
#    'dep_': 'conj',
#    'head': 'pharmaceuticals',
#    'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'antibiotics', 'pos_': 'PUNCT'},
#   {'text': 'phthalates',
#    'dep_': 'conj',
#    'head': 'antibiotics',
#    'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'phthalates', 'pos_': 'PUNCT'},
#   {'text': 'dyes', 'dep_': 'conj', 'head': 'phthalates', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'dyes', 'pos_': 'PUNCT'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'dyes', 'pos_': 'CCONJ'},
#   {'text': 'detergents', 'dep_': 'conj', 'head': 'dyes', 'pos_': 'NOUN'},
#   {'text': '.', 'dep_': 'punct', 'head': 'include', 'pos_': 'PUNCT'},
#   {'text': 'Often', 'dep_': 'advmod', 'head': 'are', 'pos_': 'ADV'},
#   {'text': ',', 'dep_': 'punct', 'head': 'are', 'pos_': 'PUNCT'},
#   {'text': 'the', 'dep_': 'det', 'head': 'enzymes', 'pos_': 'DET'},
#   {'text': 'enzymes', 'dep_': 'nsubj', 'head': 'are', 'pos_': 'NOUN'},
#   {'text': 'they', 'dep_': 'nsubj', 'head': 'use', 'pos_': 'PRON'},
#   {'text': 'use', 'dep_': 'relcl', 'head': 'enzymes', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'do', 'pos_': 'PART'},
#   {'text': 'do', 'dep_': 'xcomp', 'head': 'use', 'pos_': 'VERB'},
#   {'text': 'this', 'dep_': 'dobj', 'head': 'do', 'pos_': 'PRON'},
#   {'text': 'are', 'dep_': 'ROOT', 'head': 'are', 'pos_': 'AUX'},
#   {'text': 'also', 'dep_': 'advmod', 'head': 'are', 'pos_': 'ADV'},
#   {'text': 'ones', 'dep_': 'attr', 'head': 'are', 'pos_': 'NOUN'},
#   {'text': 'they', 'dep_': 'nsubj', 'head': 'use', 'pos_': 'PRON'},
#   {'text': 'normally', 'dep_': 'advmod', 'head': 'use', 'pos_': 'ADV'},
#   {'text': 'would', 'dep_': 'aux', 'head': 'use', 'pos_': 'AUX'},
#   {'text': 'use', 'dep_': 'relcl', 'head': 'ones', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'break', 'pos_': 'PART'},
#   {'text': 'break', 'dep_': 'xcomp', 'head': 'use', 'pos_': 'VERB'},
#   {'text': 'down', 'dep_': 'prt', 'head': 'break', 'pos_': 'ADP'},
#   {'text': 'lignin', 'dep_': 'dobj', 'head': 'break', 'pos_': 'PROPN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'lignin', 'pos_': 'PUNCT'},
#   {'text': 'the', 'dep_': 'det', 'head': 'molecule', 'pos_': 'DET'},
#   {'text': 'molecule', 'dep_': 'appos', 'head': 'lignin', 'pos_': 'NOUN'},
#   {'text': 'that', 'dep_': 'nsubj', 'head': 'helps', 'pos_': 'PRON'},
#   {'text': 'helps', 'dep_': 'relcl', 'head': 'molecule', 'pos_': 'VERB'},
#   {'text': 'give', 'dep_': 'xcomp', 'head': 'helps', 'pos_': 'VERB'},
#   {'text': 'plants', 'dep_': 'dative', 'head': 'give', 'pos_': 'NOUN'},
#   {'text': 'their', 'dep_': 'poss', 'head': 'structure', 'pos_': 'PRON'},
#   {'text': 'stiff', 'dep_': 'amod', 'head': 'structure', 'pos_': 'ADJ'},
#   {'text': 'structure', 'dep_': 'dobj', 'head': 'give', 'pos_': 'NOUN'},
#   {'text': '.', 'dep_': 'punct', 'head': 'are', 'pos_': 'PUNCT'},
#   {'text': 'But', 'dep_': 'cc', 'head': 'appear', 'pos_': 'CCONJ'},
#   {'text': 'other', 'dep_': 'amod', 'head': 'enzymes', 'pos_': 'ADJ'},
#   {'text': 'enzymes', 'dep_': 'nsubj', 'head': 'appear', 'pos_': 'NOUN'},
#   {'text': 'appear', 'dep_': 'ROOT', 'head': 'appear', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'involved', 'pos_': 'PART'},
#   {'text': 'be', 'dep_': 'auxpass', 'head': 'involved', 'pos_': 'AUX'},
#   {'text': 'involved', 'dep_': 'xcomp', 'head': 'appear', 'pos_': 'VERB'},
#   {'text': 'as', 'dep_': 'advmod', 'head': 'well', 'pos_': 'ADV'},
#   {'text': 'well', 'dep_': 'advmod', 'head': 'involved', 'pos_': 'ADV'},
#   {'text': '.', 'dep_': 'punct', 'head': 'appear', 'pos_': 'PUNCT'},
#   {'text': 'The', 'dep_': 'det', 'head': 'reactions', 'pos_': 'DET'},
#   {'text': 'chemical',
#    'dep_': 'compound',
#    'head': 'reactions',
#    'pos_': 'NOUN'},
#   {'text': 'reactions', 'dep_': 'nsubj', 'head': 'include', 'pos_': 'NOUN'},
#   {'text': 'include', 'dep_': 'ROOT', 'head': 'include', 'pos_': 'VERB'},
#   {'text': 'removing', 'dep_': 'xcomp', 'head': 'include', 'pos_': 'VERB'},
#   {'text': 'oxygen', 'dep_': 'dobj', 'head': 'removing', 'pos_': 'NOUN'},
#   {'text': 'or', 'dep_': 'cc', 'head': 'oxygen', 'pos_': 'CCONJ'},
#   {'text': 'hydrogen', 'dep_': 'conj', 'head': 'oxygen', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'removing', 'pos_': 'PUNCT'},
#   {'text': 'altering', 'dep_': 'conj', 'head': 'removing', 'pos_': 'VERB'},
#   {'text': 'the', 'dep_': 'det', 'head': 'configuration', 'pos_': 'DET'},
#   {'text': 'configuration',
#    'dep_': 'dobj',
#    'head': 'altering',
#    'pos_': 'NOUN'},
#   {'text': 'of', 'dep_': 'prep', 'head': 'configuration', 'pos_': 'ADP'},
#   {'text': 'chemical', 'dep_': 'compound', 'head': 'bonds', 'pos_': 'NOUN'},
#   {'text': 'bonds', 'dep_': 'pobj', 'head': 'of', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'altering', 'pos_': 'PUNCT'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'altering', 'pos_': 'CCONJ'},
#   {'text': 'more', 'dep_': 'conj', 'head': 'altering', 'pos_': 'ADJ'},
#   {'text': '.', 'dep_': 'punct', 'head': 'include', 'pos_': 'PUNCT'},
#   {'text': 'Such', 'dep_': 'amod', 'head': 'changes', 'pos_': 'ADJ'},
#   {'text': 'changes', 'dep_': 'nsubj', 'head': 'turn', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'turn', 'pos_': 'PUNCT'},
#   {'text': 'in', 'dep_': 'prep', 'head': 'turn', 'pos_': 'ADP'},
#   {'text': 'some', 'dep_': 'det', 'head': 'cases', 'pos_': 'DET'},
#   {'text': 'cases', 'dep_': 'pobj', 'head': 'in', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'turn', 'pos_': 'PUNCT'},
#   {'text': 'can', 'dep_': 'aux', 'head': 'turn', 'pos_': 'AUX'},
#   {'text': 'turn', 'dep_': 'ROOT', 'head': 'turn', 'pos_': 'VERB'},
#   {'text': 'toxic', 'dep_': 'amod', 'head': 'substances', 'pos_': 'ADJ'},
#   {'text': 'substances', 'dep_': 'dobj', 'head': 'turn', 'pos_': 'NOUN'},
#   {'text': 'into', 'dep_': 'prep', 'head': 'turn', 'pos_': 'ADP'},
#   {'text': 'harmless', 'dep_': 'amod', 'head': 'molecules', 'pos_': 'ADJ'},
#   {'text': 'molecules', 'dep_': 'pobj', 'head': 'into', 'pos_': 'NOUN'},
#   {'text': 'such', 'dep_': 'amod', 'head': 'as', 'pos_': 'ADJ'},
#   {'text': 'as', 'dep_': 'prep', 'head': 'molecules', 'pos_': 'ADP'},
#   {'text': 'carbohydrates', 'dep_': 'pobj', 'head': 'as', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'carbohydrates', 'pos_': 'PUNCT'},
#   {'text': 'water', 'dep_': 'conj', 'head': 'carbohydrates', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'water', 'pos_': 'PUNCT'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'water', 'pos_': 'CCONJ'},
#   {'text': 'oxygen', 'dep_': 'conj', 'head': 'water', 'pos_': 'NOUN'},
#   {'text': '.', 'dep_': 'punct', 'head': 'turn', 'pos_': 'PUNCT'},
#   {'text': 'Conventional', 'dep_': 'amod', 'head': 'processes', 'pos_': 'ADJ'},
#   {'text': 'processes', 'dep_': 'nsubj', 'head': 'be', 'pos_': 'NOUN'},
#   {'text': 'for', 'dep_': 'prep', 'head': 'processes', 'pos_': 'ADP'},
#   {'text': 'removing', 'dep_': 'pcomp', 'head': 'for', 'pos_': 'VERB'},
#   {'text': 'pollutants', 'dep_': 'dobj', 'head': 'removing', 'pos_': 'NOUN'},
#   {'text': 'such', 'dep_': 'amod', 'head': 'as', 'pos_': 'ADJ'},
#   {'text': 'as', 'dep_': 'prep', 'head': 'pollutants', 'pos_': 'ADP'},
#   {'text': 'industrial', 'dep_': 'amod', 'head': 'waste', 'pos_': 'ADJ'},
#   {'text': 'waste', 'dep_': 'pobj', 'head': 'as', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'waste', 'pos_': 'PUNCT'},
#   {'text': 'paints', 'dep_': 'conj', 'head': 'waste', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'paints', 'pos_': 'PUNCT'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'paints', 'pos_': 'CCONJ'},
#   {'text': 'pesticides', 'dep_': 'conj', 'head': 'paints', 'pos_': 'NOUN'},
#   {'text': 'from', 'dep_': 'prep', 'head': 'pesticides', 'pos_': 'ADP'},
#   {'text': 'land', 'dep_': 'pobj', 'head': 'from', 'pos_': 'NOUN'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'land', 'pos_': 'CCONJ'},
#   {'text': 'water', 'dep_': 'conj', 'head': 'land', 'pos_': 'NOUN'},
#   {'text': 'can', 'dep_': 'aux', 'head': 'be', 'pos_': 'AUX'},
#   {'text': 'be', 'dep_': 'ROOT', 'head': 'be', 'pos_': 'AUX'},
#   {'text': 'expensive', 'dep_': 'acomp', 'head': 'be', 'pos_': 'ADJ'},
#   {'text': ',', 'dep_': 'punct', 'head': 'expensive', 'pos_': 'PUNCT'},
#   {'text': 'energy', 'dep_': 'npadvmod', 'head': 'demanding', 'pos_': 'NOUN'},
#   {'text': '-', 'dep_': 'punct', 'head': 'demanding', 'pos_': 'PUNCT'},
#   {'text': 'demanding', 'dep_': 'conj', 'head': 'expensive', 'pos_': 'ADJ'},
#   {'text': ',', 'dep_': 'punct', 'head': 'demanding', 'pos_': 'PUNCT'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'demanding', 'pos_': 'CCONJ'},
#   {'text': 'of', 'dep_': 'conj', 'head': 'demanding', 'pos_': 'ADP'},
#   {'text': 'limited', 'dep_': 'amod', 'head': 'effectiveness', 'pos_': 'ADJ'},
#   {'text': 'effectiveness', 'dep_': 'pobj', 'head': 'of', 'pos_': 'NOUN'},
#   {'text': '.', 'dep_': 'punct', 'head': 'be', 'pos_': 'PUNCT'},
#   {'text': 'Sometimes', 'dep_': 'advmod', 'head': 'produce', 'pos_': 'ADV'},
#   {'text': 'they', 'dep_': 'nsubj', 'head': 'produce', 'pos_': 'PRON'},
#   {'text': 'even', 'dep_': 'advmod', 'head': 'produce', 'pos_': 'ADV'},
#   {'text': 'produce', 'dep_': 'ROOT', 'head': 'produce', 'pos_': 'VERB'},
#   {'text': 'other', 'dep_': 'amod', 'head': 'molecules', 'pos_': 'ADJ'},
#   {'text': 'undesirable', 'dep_': 'amod', 'head': 'molecules', 'pos_': 'ADJ'},
#   {'text': 'molecules', 'dep_': 'dobj', 'head': 'produce', 'pos_': 'NOUN'},
#   {'text': 'in', 'dep_': 'prep', 'head': 'produce', 'pos_': 'ADP'},
#   {'text': 'the', 'dep_': 'det', 'head': 'process', 'pos_': 'DET'},
#   {'text': 'process', 'dep_': 'pobj', 'head': 'in', 'pos_': 'NOUN'},
#   {'text': '.', 'dep_': 'punct', 'head': 'produce', 'pos_': 'PUNCT'},
#   {'text': 'The', 'dep_': 'det', 'head': 'kinds', 'pos_': 'DET'},
#   {'text': 'right', 'dep_': 'amod', 'head': 'kinds', 'pos_': 'ADJ'},
#   {'text': 'kinds', 'dep_': 'nsubjpass', 'head': 'introduced', 'pos_': 'NOUN'},
#   {'text': 'of', 'dep_': 'prep', 'head': 'kinds', 'pos_': 'ADP'},
#   {'text': 'fungi', 'dep_': 'pobj', 'head': 'of', 'pos_': 'PROPN'},
#   {'text': 'could', 'dep_': 'aux', 'head': 'introduced', 'pos_': 'AUX'},
#   {'text': 'be', 'dep_': 'auxpass', 'head': 'introduced', 'pos_': 'AUX'},
#   {'text': 'introduced', 'dep_': 'ROOT', 'head': 'introduced', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'prep', 'head': 'introduced', 'pos_': 'ADP'},
#   {'text': 'a', 'dep_': 'det', 'head': 'site', 'pos_': 'DET'},
#   {'text': 'contaminated', 'dep_': 'amod', 'head': 'site', 'pos_': 'ADJ'},
#   {'text': 'site', 'dep_': 'pobj', 'head': 'to', 'pos_': 'NOUN'},
#   {'text': 'though', 'dep_': 'advmod', 'head': 'introduced', 'pos_': 'ADV'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'introduced', 'pos_': 'CCONJ'},
#   {'text': 'begin', 'dep_': 'conj', 'head': 'introduced', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'do', 'pos_': 'PART'},
#   {'text': 'do', 'dep_': 'xcomp', 'head': 'begin', 'pos_': 'VERB'},
#   {'text': 'the', 'dep_': 'det', 'head': 'job', 'pos_': 'DET'},
#   {'text': 'job', 'dep_': 'dobj', 'head': 'do', 'pos_': 'NOUN'},
#   {'text': 'themselves', 'dep_': 'npadvmod', 'head': 'do', 'pos_': 'PRON'},
#   {'text': '?', 'dep_': 'punct', 'head': 'introduced', 'pos_': 'PUNCT'},
#   {'text': 'This', 'dep_': 'det', 'head': 'process', 'pos_': 'DET'},
#   {'text': 'process', 'dep_': 'nsubj', 'head': 'uses', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'process', 'pos_': 'PUNCT'},
#   {'text': 'known', 'dep_': 'acl', 'head': 'process', 'pos_': 'VERB'},
#   {'text': 'as', 'dep_': 'prep', 'head': 'known', 'pos_': 'ADP'},
#   {'text': 'mycoremediation', 'dep_': 'pobj', 'head': 'as', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'process', 'pos_': 'PUNCT'},
#   {'text': 'uses', 'dep_': 'ROOT', 'head': 'uses', 'pos_': 'VERB'},
#   {'text': 'other', 'dep_': 'amod', 'head': 'forms', 'pos_': 'ADJ'},
#   {'text': 'forms', 'dep_': 'dobj', 'head': 'uses', 'pos_': 'NOUN'},
#   {'text': 'of', 'dep_': 'prep', 'head': 'forms', 'pos_': 'ADP'},
#   {'text': 'life', 'dep_': 'pobj', 'head': 'of', 'pos_': 'NOUN'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'accomplish', 'pos_': 'PART'},
#   {'text': 'accomplish', 'dep_': 'xcomp', 'head': 'uses', 'pos_': 'VERB'},
#   {'text': 'tasks', 'dep_': 'dobj', 'head': 'accomplish', 'pos_': 'NOUN'},
#   {'text': 'directly', 'dep_': 'advmod', 'head': 'accomplish', 'pos_': 'ADV'},
#   {'text': '(', 'dep_': 'punct', 'head': 'accomplish', 'pos_': 'PUNCT'},
#   {'text': 'as', 'dep_': 'mark', 'head': 'opposed', 'pos_': 'SCONJ'},
#   {'text': 'opposed', 'dep_': 'dep', 'head': 'accomplish', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'prep', 'head': 'opposed', 'pos_': 'ADP'},
#   {'text': 'adapting', 'dep_': 'pcomp', 'head': 'to', 'pos_': 'VERB'},
#   {'text': 'lessons', 'dep_': 'dobj', 'head': 'adapting', 'pos_': 'NOUN'},
#   {'text': 'from', 'dep_': 'prep', 'head': 'adapting', 'pos_': 'ADP'},
#   {'text': 'them', 'dep_': 'pobj', 'head': 'from', 'pos_': 'PRON'},
#   {'text': 'into', 'dep_': 'prep', 'head': 'adapting', 'pos_': 'ADP'},
#   {'text': 'new', 'dep_': 'amod', 'head': 'innovations', 'pos_': 'ADJ'},
#   {'text': 'innovations', 'dep_': 'pobj', 'head': 'into', 'pos_': 'NOUN'},
#   {'text': ')', 'dep_': 'punct', 'head': 'uses', 'pos_': 'PUNCT'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'uses', 'pos_': 'CCONJ'},
#   {'text': 'so', 'dep_': 'advmod', 'head': 'is', 'pos_': 'ADV'},
#   {'text': 'is', 'dep_': 'conj', 'head': 'uses', 'pos_': 'AUX'},
#   {'text': 'a', 'dep_': 'det', 'head': 'form', 'pos_': 'DET'},
#   {'text': 'form', 'dep_': 'attr', 'head': 'is', 'pos_': 'NOUN'},
#   {'text': 'of', 'dep_': 'prep', 'head': 'form', 'pos_': 'ADP'},
#   {'text': '.', 'dep_': 'punct', 'head': 'is', 'pos_': 'PUNCT'},
#   {'text': '.', 'dep_': 'punct', 'head': 'uses', 'pos_': 'PUNCT'},
#   {'text': 'There', 'dep_': 'expl', 'head': 'is', 'pos_': 'PRON'},
#   {'text': 'is', 'dep_': 'ccomp', 'head': 'is', 'pos_': 'VERB'},
#   {'text': 'a', 'dep_': 'det', 'head': 'reason', 'pos_': 'DET'},
#   {'text': 'very', 'dep_': 'advmod', 'head': 'good', 'pos_': 'ADV'},
#   {'text': 'good', 'dep_': 'amod', 'head': 'reason', 'pos_': 'ADJ'},
#   {'text': 'reason', 'dep_': 'attr', 'head': 'is', 'pos_': 'NOUN'},
#   {'text': 'why', 'dep_': 'advmod', 'head': 'put', 'pos_': 'SCONJ'},
#   {'text': 'we', 'dep_': 'nsubj', 'head': 'put', 'pos_': 'PRON'},
#   {'text': 'do', 'dep_': 'aux', 'head': 'put', 'pos_': 'AUX'},
#   {'text': 'n’t', 'dep_': 'neg', 'head': 'put', 'pos_': 'PART'},
#   {'text': 'generally', 'dep_': 'advmod', 'head': 'put', 'pos_': 'ADV'},
#   {'text': 'just', 'dep_': 'advmod', 'head': 'put', 'pos_': 'ADV'},
#   {'text': 'put', 'dep_': 'relcl', 'head': 'reason', 'pos_': 'VERB'},
#   {'text': 'fungi', 'dep_': 'dobj', 'head': 'put', 'pos_': 'NOUN'},
#   {'text': 'into', 'dep_': 'prep', 'head': 'put', 'pos_': 'ADP'},
#   {'text': 'an', 'dep_': 'det', 'head': 'environment', 'pos_': 'DET'},
#   {'text': 'environment', 'dep_': 'pobj', 'head': 'into', 'pos_': 'NOUN'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'let', 'pos_': 'PART'},
#   {'text': 'let', 'dep_': 'advcl', 'head': 'put', 'pos_': 'VERB'},
#   {'text': 'them', 'dep_': 'nsubj', 'head': 'take', 'pos_': 'PRON'},
#   {'text': 'take', 'dep_': 'ccomp', 'head': 'let', 'pos_': 'VERB'},
#   {'text': 'care', 'dep_': 'dobj', 'head': 'take', 'pos_': 'NOUN'},
#   {'text': 'of', 'dep_': 'prep', 'head': 'take', 'pos_': 'ADP'},
#   {'text': 'our', 'dep_': 'poss', 'head': 'pollution', 'pos_': 'PRON'},
#   {'text': 'pollution', 'dep_': 'pobj', 'head': 'of', 'pos_': 'NOUN'},
#   {'text': ':', 'dep_': 'punct', 'head': 'is', 'pos_': 'PUNCT'},
#   {'text': 'it', 'dep_': 'nsubj', 'head': 'is', 'pos_': 'PRON'},
#   {'text': 'is', 'dep_': 'ROOT', 'head': 'is', 'pos_': 'AUX'},
#   {'text': 'very', 'dep_': 'advmod', 'head': 'difficult', 'pos_': 'ADV'},
#   {'text': 'difficult', 'dep_': 'acomp', 'head': 'is', 'pos_': 'ADJ'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'scale', 'pos_': 'PART'},
#   {'text': 'scale', 'dep_': 'xcomp', 'head': 'difficult', 'pos_': 'VERB'},
#   {'text': '.', 'dep_': 'punct', 'head': 'is', 'pos_': 'PUNCT'},
#   {'text': 'Fungi', 'dep_': 'nsubj', 'head': 'convert', 'pos_': 'PROPN'},
#   {'text': 'convert', 'dep_': 'ROOT', 'head': 'convert', 'pos_': 'VERB'},
#   {'text': 'the', 'dep_': 'det', 'head': 'pollution', 'pos_': 'DET'},
#   {'text': 'pollution', 'dep_': 'dobj', 'head': 'convert', 'pos_': 'NOUN'},
#   {'text': 'we', 'dep_': 'nsubj', 'head': 'created', 'pos_': 'PRON'},
#   {'text': 'have', 'dep_': 'aux', 'head': 'created', 'pos_': 'AUX'},
#   {'text': 'created', 'dep_': 'relcl', 'head': 'pollution', 'pos_': 'VERB'},
#   {'text': 'at', 'dep_': 'prep', 'head': 'created', 'pos_': 'ADP'},
#   {'text': 'a', 'dep_': 'det', 'head': 'rate', 'pos_': 'DET'},
#   {'text': 'much', 'dep_': 'advmod', 'head': 'slower', 'pos_': 'ADV'},
#   {'text': 'slower', 'dep_': 'amod', 'head': 'rate', 'pos_': 'ADJ'},
#   {'text': 'rate', 'dep_': 'pobj', 'head': 'at', 'pos_': 'NOUN'},
#   {'text': 'than', 'dep_': 'mark', 'head': 'create', 'pos_': 'SCONJ'},
#   {'text': 'we', 'dep_': 'nsubj', 'head': 'create', 'pos_': 'PRON'},
#   {'text': 'create', 'dep_': 'advcl', 'head': 'created', 'pos_': 'VERB'},
#   {'text': 'it', 'dep_': 'dobj', 'head': 'create', 'pos_': 'PRON'},
#   {'text': '.', 'dep_': 'punct', 'head': 'convert', 'pos_': 'PUNCT'},
#   {'text': 'Genetic', 'dep_': 'amod', 'head': 'modification', 'pos_': 'ADJ'},
#   {'text': 'modification', 'dep_': 'nsubj', 'head': 'enhance', 'pos_': 'NOUN'},
#   {'text': 'could', 'dep_': 'aux', 'head': 'enhance', 'pos_': 'AUX'},
#   {'text': 'enhance', 'dep_': 'ROOT', 'head': 'enhance', 'pos_': 'VERB'},
#   {'text': 'the', 'dep_': 'det', 'head': 'efficiency', 'pos_': 'DET'},
#   {'text': 'efficiency', 'dep_': 'dobj', 'head': 'enhance', 'pos_': 'NOUN'},
#   {'text': 'of', 'dep_': 'prep', 'head': 'efficiency', 'pos_': 'ADP'},
#   {'text': 'some', 'dep_': 'det', 'head': 'fungi', 'pos_': 'DET'},
#   {'text': 'contaminant', 'dep_': 'amod', 'head': 'degrading', 'pos_': 'ADJ'},
#   {'text': '-', 'dep_': 'punct', 'head': 'degrading', 'pos_': 'PUNCT'},
#   {'text': 'degrading', 'dep_': 'amod', 'head': 'fungi', 'pos_': 'ADJ'},
#   {'text': 'fungi', 'dep_': 'pobj', 'head': 'of', 'pos_': 'NOUN'},
#   {'text': 'though', 'dep_': 'advmod', 'head': 'enhance', 'pos_': 'ADV'},
#   {'text': ',', 'dep_': 'punct', 'head': 'enhance', 'pos_': 'PUNCT'},
#   {'text': 'or', 'dep_': 'cc', 'head': 'enhance', 'pos_': 'CCONJ'},
#   {'text': 'enable', 'dep_': 'conj', 'head': 'enhance', 'pos_': 'VERB'},
#   {'text': 'them', 'dep_': 'dobj', 'head': 'enable', 'pos_': 'PRON'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'specialize', 'pos_': 'PART'},
#   {'text': 'specialize', 'dep_': 'xcomp', 'head': 'enable', 'pos_': 'VERB'},
#   {'text': 'in', 'dep_': 'prep', 'head': 'specialize', 'pos_': 'ADP'},
#   {'text': 'certain', 'dep_': 'amod', 'head': 'pollutants', 'pos_': 'ADJ'},
#   {'text': 'pollutants', 'dep_': 'pobj', 'head': 'in', 'pos_': 'NOUN'},
#   {'text': '.', 'dep_': 'punct', 'head': 'enhance', 'pos_': 'PUNCT'},
#   {'text': 'Scientists', 'dep_': 'nsubj', 'head': 'exploring', 'pos_': 'NOUN'},
#   {'text': 'are', 'dep_': 'aux', 'head': 'exploring', 'pos_': 'AUX'},
#   {'text': 'also', 'dep_': 'advmod', 'head': 'exploring', 'pos_': 'ADV'},
#   {'text': 'exploring', 'dep_': 'ROOT', 'head': 'exploring', 'pos_': 'VERB'},
#   {'text': 'ways', 'dep_': 'dobj', 'head': 'exploring', 'pos_': 'NOUN'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'introduce', 'pos_': 'PART'},
#   {'text': 'introduce', 'dep_': 'relcl', 'head': 'ways', 'pos_': 'VERB'},
#   {'text': 'certain', 'dep_': 'amod', 'head': 'bacteria', 'pos_': 'ADJ'},
#   {'text': 'bacteria', 'dep_': 'dobj', 'head': 'introduce', 'pos_': 'NOUN'},
#   {'text': 'or', 'dep_': 'cc', 'head': 'bacteria', 'pos_': 'CCONJ'},
#   {'text': 'natural', 'dep_': 'amod', 'head': 'chemicals', 'pos_': 'ADJ'},
#   {'text': 'chemicals', 'dep_': 'conj', 'head': 'bacteria', 'pos_': 'NOUN'},
#   {'text': 'such', 'dep_': 'amod', 'head': 'as', 'pos_': 'ADJ'},
#   {'text': 'as', 'dep_': 'prep', 'head': 'bacteria', 'pos_': 'ADP'},
#   {'text': '.', 'dep_': 'punct', 'head': 'exploring', 'pos_': 'PUNCT'},
#   {'text': ' ', 'dep_': 'dep', 'head': '.', 'pos_': 'SPACE'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'make', 'pos_': 'PART'},
#   {'text': 'make', 'dep_': 'advcl', 'head': 'exploring', 'pos_': 'VERB'},
#   {'text': 'fungi', 'dep_': 'poss', 'head': 'abilities', 'pos_': 'PROPN'},
#   {'text': '’s', 'dep_': 'case', 'head': 'fungi', 'pos_': 'PART'},
#   {'text': 'natural', 'dep_': 'amod', 'head': 'abilities', 'pos_': 'ADJ'},
#   {'text': 'abilities', 'dep_': 'nsubj', 'head': 'effective', 'pos_': 'NOUN'},
#   {'text': 'more', 'dep_': 'advmod', 'head': 'effective', 'pos_': 'ADV'},
#   {'text': 'effective', 'dep_': 'ccomp', 'head': 'make', 'pos_': 'ADJ'},
#   {'text': '.', 'dep_': 'punct', 'head': 'exploring', 'pos_': 'PUNCT'},
#   {'text': 'This', 'dep_': 'det', 'head': 'ability', 'pos_': 'DET'},
#   {'text': 'ability', 'dep_': 'nsubjpass', 'head': 'used', 'pos_': 'NOUN'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'take', 'pos_': 'PART'},
#   {'text': 'take', 'dep_': 'acl', 'head': 'ability', 'pos_': 'VERB'},
#   {'text': 'up', 'dep_': 'prt', 'head': 'take', 'pos_': 'ADP'},
#   {'text': 'toxic', 'dep_': 'amod', 'head': 'substances', 'pos_': 'ADJ'},
#   {'text': 'substances', 'dep_': 'dobj', 'head': 'take', 'pos_': 'NOUN'},
#   {'text': 'could', 'dep_': 'aux', 'head': 'used', 'pos_': 'AUX'},
#   {'text': 'also', 'dep_': 'advmod', 'head': 'used', 'pos_': 'ADV'},
#   {'text': 'be', 'dep_': 'auxpass', 'head': 'used', 'pos_': 'AUX'},
#   {'text': 'used', 'dep_': 'ROOT', 'head': 'used', 'pos_': 'VERB'},
#   {'text': 'to', 'dep_': 'aux', 'head': 'improve', 'pos_': 'PART'},
#   {'text': 'improve', 'dep_': 'xcomp', 'head': 'used', 'pos_': 'VERB'},
#   {'text': 'recycling', 'dep_': 'dobj', 'head': 'improve', 'pos_': 'NOUN'},
#   {'text': 'and', 'dep_': 'cc', 'head': 'improve', 'pos_': 'CCONJ'},
#   {'text': 'decrease', 'dep_': 'conj', 'head': 'improve', 'pos_': 'VERB'},
#   {'text': 'mining', 'dep_': 'dobj', 'head': 'decrease', 'pos_': 'NOUN'},
#   {'text': 'by', 'dep_': 'prep', 'head': 'decrease', 'pos_': 'ADP'},
#   {'text': '“', 'dep_': 'punct', 'head': 'by', 'pos_': 'PUNCT'},
#   {'text': 'harvesting', 'dep_': 'nmod', 'head': 'metals', 'pos_': 'NOUN'},
#   {'text': '”', 'dep_': 'punct', 'head': 'harvesting', 'pos_': 'PUNCT'},
#   {'text': 'precious', 'dep_': 'amod', 'head': 'metals', 'pos_': 'ADJ'},
#   {'text': 'metals', 'dep_': 'pobj', 'head': 'by', 'pos_': 'NOUN'},
#   {'text': 'from', 'dep_': 'prep', 'head': 'metals', 'pos_': 'ADP'},
#   {'text': 'e', 'dep_': 'pobj', 'head': 'from', 'pos_': 'NOUN'},
#   {'text': '-', 'dep_': 'pobj', 'head': 'from', 'pos_': 'NOUN'},
#   {'text': 'waste', 'dep_': 'pobj', 'head': 'from', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'waste', 'pos_': 'PUNCT'},
#   {'text': 'wastewater', 'dep_': 'conj', 'head': 'waste', 'pos_': 'NOUN'},
#   {'text': ',', 'dep_': 'punct', 'head': 'wastewater', 'pos_': 'PUNCT'},
#   {'text': 'or', 'dep_': 'cc', 'head': 'wastewater', 'pos_': 'CCONJ'},
#   {'text': 'naturally', 'dep_': 'advmod', 'head': 'occurring', 'pos_': 'ADV'},
#   {'text': 'occurring', 'dep_': 'conj', 'head': 'wastewater', 'pos_': 'VERB'},
#   {'text': 'deposits', 'dep_': 'dobj', 'head': 'occurring', 'pos_': 'NOUN'},
#   {'text': '.', 'dep_': 'punct', 'head': 'used', 'pos_': 'PUNCT'}]}

# %% [markdown]
# ## 3.将句法分析的结果存入csv表格

# %%
# 定义CSV文件路径
csv_file = '/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/biological_ner/dependency_parsing_data/parsing_result.csv'

# 将字典逐行写入CSV文件
with open(csv_file, 'w', newline='', encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    
    # 写入表头
    writer.writeheader('id','title', 'text', 'dep_', 'head', 'pos_' )
    
    # 逐行写入数据
    for i in range(len(parse_result_list)):
        for j in range(len(parse_result_list[i]['result'])):
            writer.writerow(parse_result_list[i]["id"])
            writer(",")
            writer.writerow(parse_result_list[i]["title"])
            writer(",")
            writer.writerow(parse_result_list[i]['result']["text"])
            writer(",")
            writer.writerow(parse_result_list[i]['result']["dep_"])
            writer(",")
            writer.writerow(parse_result_list[i]['result']["head"])
            writer(",")
            writer.writerow(parse_result_list[i]['result']["pos_"])
            writer("\n")
# Out:
#   Input In [16]
#     writer.writeheader('id'，'title', 'text', 'dep_', 'head', 'pos_' )
#                            ^
# SyntaxError: invalid character in identifier
