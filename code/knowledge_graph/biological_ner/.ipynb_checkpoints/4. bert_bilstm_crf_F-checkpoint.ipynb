# %% [markdown]
# ## 1. 模型构建与训练

# %%
import torch
print(torch.__version__)
# Out:
# 1.9.0+cu111

# %%
import torch
device=torch.device('cuda:0')

# %%
# 读取数据
def read_data(file):
    all_token_list = []
    all_label_list = []

    token_list = []
    label_list = []
    with open(file, "r", encoding="utf-8") as f:
        all_data = f.read().split("\n")
    lenth_sentence_list = [] #用于存储句子的长度
    for data in all_data:
        # 这里进行数据处理时，每一句话结束后都会有一个空行，当判断为空行时，说明结束，这一句话存入列表
        # 但是在我重新处理的语料中，根据句号.来对句子进行划分
        if data == ". O":
            # 统计一下大多数的句子的长度，太长或者太短的句子直接丢掉，不要保存在语料列表当中
            lenth_sentence_list.append(len(token_list))
            if len(token_list) > 10 and len(token_list) < 70:
                all_token_list.append(token_list)
                all_label_list.append(label_list)
            token_list = []
            label_list = []
        else:
            print(data)
            token, lable = data.split(" ")
            token_list.append(token)
            label_list.append(lable)
    return all_token_list, all_label_list, lenth_sentence_list


# 以训练集为例构建标签及标签ID映射关系
def build_label(train_label):
    # PAD用于填充，UNK 出现不认识的label,则给一个UNK的标识
    label2idx = {"PAD": 0, "UNK": 1}
    for label_list in train_label:
        for lable in label_list:
            if lable not in label2idx:
                label2idx[lable] = len(label2idx)
    return label2idx, list(label2idx)

# %%
import os
from transformers import BertTokenizer

# train_text, train_label, train_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/fineturn_data/biological_data/bio_data_S_train.txt")
# test_text, test_label, test_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/fineturn_data/biological_data/bio_data_S_dev.txt")
# dev_text, dev_label, dev_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/fineturn_data/biological_data/bio_data_S_dev.txt")

train_text, train_label, train_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/biological_ner/data/original_data/before_translate/biological_strategy_F_train.txt")
test_text, test_label, test_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/biological_ner/data/original_data/before_translate/biological_strategy_F_dev.txt")
dev_text, dev_label, dev_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/biological_ner/data/original_data/before_translate/biological_strategy_F_dev.txt")


# print(test_label, test_text)

# 定义标签和对应的数字ID
# PAD --> padding
# UNK --> unknown
# labels_list = ['PAD', 'UNK', 'O', 'B-BFA', 'I-BFA', 'B-BFO', 'I-BFO', 'B-BOP', 'I-BOP', 'B-BEN', 'I-BEN', 'B-BOR', 'I-BOR']
# FA 功能行为； FO 功能对象； OP 生物行为；OR 器官；EN 生物体
# 将生物器官和生物体合并为生物结构，看看生物行为的数量多不多，不多的话看一下用其他的办法获得吧

label2idx, idx2label = build_label(train_label)

print("label2idx为：", label2idx)
print("idx2label为：", idx2label)
print(len(train_lenth_sentence_list))    # 原本有525句子
print(len(train_text))       # 符合长度要求的只有254句子
print(len(dev_lenth_sentence_list))    # 原本有525句子
print(len(dev_text))       # 符合长度要求的只有254句子
print("train_lenth_sentence_list为：", train_lenth_sentence_list)
# Out:
# ##id:5 O
# Maggots O
# Eat B-BFA
# the O
# Dead B-BFO
# But O
# Heal B-BFA
# the O
# Wounded B-BFO
# An O
# old O
# mule O
# deer O
# stumbles O
# to O
# the O
# ground O
# in O
# a O
# forest O
# and O
# dies B-BFA
# The O
# bacteria B-BFO
# that O
# had O
# been O
# living B-BFA
# harmoniously O
# within O
# the O
# deer O
# immediately O
# set O
# about O
# breaking B-BFA
# its O
# carcass B-BFO
# down I-BFA
# Green O
# bottle O
# flies B-BFA
# which O
# have O
# a O
# nose O
# for O
# the O
# dead B-BFO
# are O
# usually O
# the O
# first O
# wave O
# of O
# insects O
# that O
# dive B-BFA
# into O
# the O
# decay B-BFO
# They O
# lay B-BFA
# their O
# eggs B-BFO
# in O
# dead B-BFO
# flesh O
# to O
# give O
# their O
# soon O
# to O
# hatch B-BFA
# larvae O
# known O
# as O
# maggots O
# immediate O
# food B-BFO
# The O
# thought O
# of O
# squirming O
# maggots O
# devouring B-BFA
# the O
# rotting O
# deer O
# may O
# seem O
# sad O
# or O
# gross O
# but O
# it’s O
# the O
# ultimate O
# form O
# of O
# recycling B-BFA
# One O
# animal O
# dies B-BFA
# and O
# becomes O
# the O
# birthplace O
# and O
# food B-BFO
# source O
# of O
# many O
# others O
# Green O
# bottle O
# flies B-BFA
# are O
# first O
# at O
# the O
# scene O
# of O
# death O
# not O
# because O
# they’re O
# ghoulish O
# but O
# because O
# their O
# maggot O
# offspring B-BFA
# need O
# soft O
# dead B-BFO
# tissue I-BFO
# to O
# eat B-BFA
# Maggots O
# lack B-BFA
# the O
# teeth O
# or O
# beaks O
# that O
# would O
# enable O
# them O
# to O
# tear B-BFA
# into O
# old O
# dried O
# out O
# meat B-BFO
# but O
# the O
# little O
# larvae O
# still O
# have O
# bite B-BFA
# Their O
# mouth O
# hooks B-BFA
# and O
# rough B-BFA
# skin B-BFO
# scrape O
# away O
# dead B-BFO
# flesh I-BFO
# as O
# they O
# crawl B-BFA
# across O
# a O
# carcass O
# Then O
# they O
# secrete B-BFA
# enzymes B-BFO
# that O
# liquefy B-BFA
# the O
# dead B-BFO
# tissue I-BFO
# making O
# it O
# easier O
# to O
# swallow B-BFA
# and O
# digest B-BFA
# Maggot O
# salivary O
# glands O
# guts O
# and O
# other O
# digestive O
# organs O
# secrete B-BFA
# the O
# enzymes B-BFO
# called O
# “peptidases B-BFO
# ” O
# which O
# work O
# by O
# breaking B-BFA
# down I-BFA
# proteins B-BFO
# Maggot O
# secretions B-BFA
# don’t O
# just O
# contain B-BFA
# a O
# pinch O
# of O
# peptidase B-BFO
# they O
# are O
# more O
# like O
# enzyme B-BFO
# stew O
# Scientists O
# used O
# genetic O
# sequencing B-BFA
# of O
# their O
# secretions O
# to O
# identify B-BFA
# 185 O
# individual O
# peptidase B-BFO
# enzymes I-BFO
# For O
# the O
# record O
# all O
# biological O
# organisms O
# including O
# plants O
# viruses O
# and O
# people O
# use B-BFA
# peptidases B-BFO
# These O
# enzymes B-BFO
# play O
# critical O
# roles O
# in O
# metabolism B-BFO
# reproduction B-BFO
# growth B-BFO
# and O
# immune B-BFO
# systems O
# While O
# the O
# functions O
# of O
# some O
# individual O
# peptidases B-BFO
# are O
# known O
# others O
# are O
# not O
# Moreover O
# their O
# actions O
# and O
# mechanisms O
# vary O
# across O
# species O
# There O
# are O
# accounts O
# of O
# caregivers O
# making O
# use O
# of O
# maggots O
# to O
# help O
# heal B-BFA
# wounds B-BFO
# among O
# the O
# Maya O
# Aboriginal O
# Australians O
# and O
# other O
# indigenous O
# cultures O
# In O
# Renaissance O
# Europe O
# the O
# benefits O
# were O
# acknowledged O
# but O
# not O
# cultivated O
# By O
# the O
# time O
# of O
# the O
# U.S O
# Civil O
# War O
# at O
# least O
# one O
# surgeon O
# was O
# intentionally O
# applying B-BFA
# maggots O
# to O
# the O
# wounds B-BFO
# of O
# soldiers O
# saying O
# “In O
# a O
# single O
# day O
# maggots O
# would O
# clean B-BFA
# a O
# wound B-BFO
# much O
# better O
# than O
# any O
# agents O
# we O
# had O
# at O
# our O
# command.” O
# Maggot B-BFO
# wound I-BFO
# therapy I-BFO
# declined O
# with O
# the O
# advent O
# of O
# antibiotics B-BFO
# but O
# rebounded B-BFA
# with O
# the O
# rise O
# of O
# drug B-BFO
# resistant I-BFO
# bacteria. O
# Today O
# “maggot O
# wound B-BFO
# debridement” O
# remains O
# an O
# alternative O
# therapy O
# for O
# treating B-BFO
# persistent B-BFO
# wounds B-BFO
# and O
# infections B-BFO
# in O
# patients O
# with O
# severe O
# burns O
# diabetes O
# and O
# other O
# ailments O
# that O
# hinder O
# healing. B-BFA
# Some O
# researchers O
# are O
# even O
# going O
# beyond O
# “bio O
# utilizing” O
# maggots O
# directly O
# on O
# wounds B-BFO
# Isolating B-BFA
# and O
# reproducing B-BFA
# maggot B-BFO
# enzymes I-BFO
# has O
# already O
# led O
# to O
# gels O
# that O
# mimic B-BFO
# how O
# medicinal O
# maggots O
# help O
# people O
# on O
# the O
# mend O
# In O
# the O
# future O
# understanding O
# maggot O
# secretions O
# may O
# lead O
# to O
# new O
# antibiotics B-BFO
# anti I-BFO
# inflammatory I-BFO
# medicines I-BFO
# and O
# coagulants. B-BFO
# Maggots O
# exemplify O
# why O
# we O
# shouldn’t O
# judge O
# organisms O
# as O
# good O
# or O
# bad O
# based O
# on O
# appearances O
# or O
# habits O
# we O
# find O
# off O
# putting O
# If O
# we O
# look O
# away O
# we O
# may O
# miss O
# a O
# valuable O
# opportunity O
# to O
# learn O
# ##id:20 O
# Hourglass O
# Shaped O
# Molecules O
# Filter B-BFA
# Water B-BFO
# Water B-BFO
# is O
# a O
# basic O
# ingredient B-BFO
# of O
# life O
# Our O
# bodies O
# are O
# more O
# than O
# half O
# water B-BFO
# and O
# other O
# organisms O
# depend B-BFA
# on I-BFA
# it O
# as O
# well O
# for O
# everything O
# from O
# to O
# maintaining O
# their O
# shape O
# to O
# eliminating O
# waste O
# water B-BFO
# is O
# in O
# a O
# living O
# thing O
# is O
# as O
# important O
# as O
# whether O
# water B-BFO
# is O
# available O
# Too O
# much O
# water B-BFO
# inside O
# a O
# cell B-BFO
# and O
# it O
# will O
# burst B-BFA
# like O
# a O
# balloon O
# Too O
# little O
# and O
# it O
# will O
# dry B-BFA
# out O
# and O
# die B-BFA
# How O
# does O
# a O
# cell B-BFO
# keep O
# the O
# amount O
# of O
# water B-BFO
# just O
# right O
# The O
# answer O
# lies B-BFA
# in O
# hourglass O
# shaped O
# molecules O
# with O
# a O
# tunnel B-BFO
# down O
# the O
# middle O
# that O
# are O
# very O
# very O
# picky O
# about O
# what O
# they O
# let O
# through B-BFA
# All O
# living O
# things O
# are O
# made O
# up O
# of O
# cells B-BFO
# All O
# cells B-BFO
# have O
# membranes O
# that O
# separate B-BFA
# them O
# from O
# the O
# rest O
# of O
# the O
# world O
# And O
# all O
# membranes O
# have O
# channels O
# that O
# let O
# molecules B-BFO
# in B-BFA
# and O
# out B-BFA
# One O
# type O
# of O
# channel O
# called O
# aquaporins O
# selectively O
# let O
# water B-BFO
# and O
# in B-BFA
# some O
# cases O
# other O
# molecules B-BFO
# move B-BFA
# across O
# the O
# cell O
# membrane O
# These O
# channels O
# are O
# so O
# important O
# that O
# they O
# are O
# found O
# in O
# organisms O
# belonging O
# to O
# all O
# kingdoms O
# of O
# life O
# How O
# do O
# aquaporins O
# separate B-BFA
# water B-BFO
# from O
# other O
# molecules B-BFO
# The O
# answer O
# lies B-BFA
# in O
# their O
# shape O
# and O
# the O
# way O
# electrical B-BFO
# charge O
# is O
# distributed B-BFA
# across O
# the O
# s O
# they’re O
# made O
# of O
# Aquaporins O
# are O
# proteins B-BFO
# which O
# are O
# made O
# up O
# of O
# long O
# chains O
# of O
# smaller O
# molecules B-BFO
# called O
# s O
# Different O
# kinds O
# of O
# amino B-BFO
# acids I-BFO
# attract B-BFA
# or O
# repel B-BFA
# each O
# other O
# creating O
# stretches O
# of O
# shapes O
# such O
# as O
# sheets O
# and O
# within O
# the O
# molecule B-BFO
# An O
# aquaporin O
# molecule B-BFO
# contains O
# six O
# long O
# stretches O
# of O
# helices O
# that O
# stick B-BFA
# through I-BFA
# a O
# cell B-BFO
# membrane O
# like O
# a O
# peephole O
# through B-BFA
# a O
# door O
# Together O
# they O
# form B-BFA
# a O
# tiny O
# tunnel O
# about O
# the O
# size O
# of O
# a O
# water B-BFO
# molecule I-BFO
# The O
# center O
# of O
# the O
# aquaporin O
# channel O
# carries O
# a O
# positive O
# charge O
# which O
# repels B-BFA
# other O
# positively O
# charged O
# molecules B-BFO
# and O
# prevents B-BFA
# them O
# from O
# passing B-BFA
# through I-BFA
# Thus O
# only O
# small O
# uncharged O
# molecules B-BFO
# such O
# as O
# water B-BFO
# are O
# able O
# to O
# pass B-BFA
# through I-BFA
# the O
# channel O
# Increasing O
# efficiency O
# aquaporin O
# molecules B-BFO
# tend O
# to O
# appear O
# in O
# groups O
# of O
# four O
# arranged O
# together O
# creating O
# a O
# fifth O
# pore O
# in O
# the O
# middle O
# that O
# also O
# moves B-BFA
# water B-BFO
# across O
# the O
# membrane O
# The O
# ability O
# of O
# aquaporins O
# to O
# separate B-BFA
# water B-BFO
# from O
# other O
# molecules B-BFO
# without O
# requiring O
# an O
# active O
# pump B-BFO
# opens O
# the O
# door O
# to O
# an O
# energy O
# efficient O
# way O
# to O
# remove B-BFA
# contaminants B-BFO
# from O
# wastewater B-BFO
# or O
# purify B-BFA
# drinking B-BFO
# water I-BFO
# The O
# concept O
# might O
# also O
# be O
# applied O
# to O
# creating O
# customized O
# channels O
# that O
# selectively O
# filter B-BFA
# other O
# types O
# of O
# small O
# molecules B-BFO
# This O
# would O
# make O
# it O
# possible O
# to O
# increase B-BFA
# the O
# concentration O
# of O
# a O
# desired B-BFA
# substance B-BFO
# or O
# remove B-BFA
# undesired O
# contaminants B-BFO
# from O
# a O
# product O
# ##id:1 O
# Photosynthesis B-BFA
# Converts B-BFA
# Solar B-BFO
# Energy I-BFO
# Into O
# Chemical B-BFO
# Energy I-BFO
# For O
# the O
# first O
# half O
# of O
# Earth’s O
# life O
# to O
# date O
# , O
# oxygen B-BFO
# was O
# all O
# but O
# absent B-BFA
# from I-BFA
# an O
# atmosphere O
# made O
# mostly O
# of O
# nitrogen B-BFO
# carbon B-BFO
# dioxide I-BFO
# and O
# methane B-BFO
# The O
# evolution O
# of O
# animals O
# and O
# life O
# as O
# we O
# now O
# know O
# it O
# owe O
# everything O
# to O
# oxygen B-BFO
# About O
# 2.5 O
# billion O
# years O
# ago O
# the O
# first O
# organisms O
# that O
# used B-BFA
# sunlight B-BFO
# and O
# carbon B-BFO
# dioxide I-BFO
# to O
# produce B-BFA
# oxygen B-BFO
# and O
# sugars B-BFO
# via O
# photosynthesis O
# transformed B-BFA
# our O
# atmosphere O
# Later O
# algae O
# evolved B-BFA
# with O
# this O
# ability O
# , O
# and O
# about O
# 0.5 O
# billion O
# years O
# ago O
# , O
# the O
# first O
# land O
# plants O
# sprouted B-BFA
# Algae B-BFO
# plankton I-BFO
# and O
# land O
# plants O
# now O
# work O
# together O
# to O
# keep B-BFA
# our O
# atmosphere O
# full I-BFA
# of I-BFA
# oxygen B-BFO
# Photosynthesis B-BFA
# occurs O
# in O
# special O
# plant O
# cells B-BFO
# called O
# s O
# which O
# are O
# the O
# type O
# of O
# cells B-BFO
# found O
# in O
# leaves O
# A O
# single O
# chloroplast O
# is O
# like O
# a O
# bag O
# filled B-BFA
# with O
# the O
# main O
# ingredients B-BFO
# needed O
# for O
# photosynthesis B-BFA
# It O
# has O
# water B-BFO
# soaked B-BFA
# up I-BFA
# from O
# the O
# plant’s O
# roots O
# atmospheric O
# carbon B-BFO
# dioxide I-BFO
# absorbed B-BFA
# by O
# the O
# leaves O
# and O
# contained B-BFA
# in O
# folded O
# maze O
# like O
# organelles O
# called O
# s O
# Chlorophyll O
# is O
# the O
# true O
# of O
# photosynthesis B-BFA
# Cyanobacteria O
# plankton O
# and O
# land O
# plants O
# all O
# rely B-BFA
# on I-BFO
# this O
# light B-BFO
# sensitive I-BFO
# molecule I-BFO
# to O
# spark B-BFA
# the O
# process O
# Chlorophyll B-BFO
# molecules I-BFO
# are O
# so O
# bad O
# at O
# absorbing B-BFA
# green B-BFO
# light I-BFO
# that O
# they O
# reflect B-BFA
# it O
# like O
# tiny O
# mirrors O
# causing O
# our O
# eyes O
# to O
# see O
# most O
# leaves B-BFO
# as O
# green O
# It’s O
# usually O
# only O
# in O
# autumn O
# after O
# chlorophyll B-BFO
# degrades B-BFA
# that O
# we O
# peep O
# those O
# infinite O
# shades O
# of O
# yellow O
# and O
# orange O
# produced B-BFA
# by O
# s O
# Nature O
# through O
# photosynthesis B-BFA
# enables O
# plants O
# to O
# convert B-BFA
# the O
# sun’s B-BFO
# energy I-BFO
# into O
# a O
# form O
# that O
# they O
# and O
# other O
# living O
# things O
# can O
# make B-BFA
# use I-BFA
# of I-BFA
# Plants O
# transfer B-BFA
# that O
# energy I-BFA
# directly O
# to O
# most O
# other O
# living O
# things O
# as O
# food B-BFO
# or O
# as O
# food B-BFO
# for O
# animals O
# that O
# other O
# animals O
# eat. B-BFA
# Humans O
# also O
# extract B-BFA
# this O
# energy B-BFO
# indirectly O
# from O
# wood B-BFO
# or O
# from O
# plants O
# that O
# decayed B-BFA
# millions O
# of O
# years O
# ago O
# into O
# oil B-BFO
# coal I-BFO
# and O
# natural B-BFO
# gas I-BFO
# Burning B-BFA
# these O
# materials B-BFO
# to O
# provide B-BFA
# electricity B-BFO
# and O
# heat B-BFO
# has O
# through O
# overexploitation O
# led O
# to O
# dire O
# consequences O
# that O
# have O
# upset O
# the O
# balance B-BFO
# of I-BFO
# life I-BFO
# on O
# Earth. O
# What O
# if O
# humans O
# could O
# harness B-BFA
# this O
# power B-BFO
# in O
# a O
# different O
# way O
# Imagine O
# green B-BFO
# chemistry I-BFO
# that’s O
# catalyzed B-BFA
# by O
# sunlight B-BFO
# instead O
# of O
# having O
# to O
# mine B-BFA
# for O
# heavy B-BFO
# metals I-BFO
# like O
# copper B-BFO
# tin B-BFO
# or O
# platinum B-BFO
# Think O
# of O
# the O
# potential O
# that O
# chemical O
# processes O
# requiring B-BFA
# little O
# heat B-BFO
# have O
# to O
# reduce B-BFA
# energy B-BFO
# consumption B-BFA
# With O
# a O
# better O
# understanding O
# of O
# photosynthesis B-BFA
# we O
# may O
# transform B-BFA
# agriculture B-BFO
# to O
# consume B-BFA
# less O
# water B-BFO
# and O
# preserve B-BFA
# more O
# land O
# for O
# native O
# plants O
# and O
# forests B-BFO
# As O
# we O
# continue O
# to O
# grapple O
# with O
# climate B-BFO
# change I-BFO
# listening B-BFA
# to O
# what O
# plants O
# can O
# teach O
# us O
# can O
# shine O
# a O
# light O
# down O
# a O
# greener O
# path O
# ##id:17 O
# How O
# Cicada O
# Wings O
# Kill B-BFA
# Bacteria I-BFA
# Every O
# summer O
# annual O
# cicadas O
# emerge O
# from O
# underground O
# all O
# over O
# the O
# world O
# thickening B-BFA
# the O
# air B-BFO
# with O
# their O
# distinctive O
# clacking B-BFA
# and O
# rattling B-BFA
# Seventeen O
# year O
# cicadas O
# which O
# exist O
# only O
# in O
# North O
# America O
# slurp B-BFA
# plant B-BFO
# root I-BFO
# sap I-BFO
# beneath O
# the O
# ground O
# for O
# nearly O
# two O
# decades O
# before O
# surfacing O
# and O
# molting B-BFA
# their O
# shells B-BFO
# to O
# become O
# breeding O
# adults O
# The O
# Onondaga O
# nation O
# marks O
# the O
# time O
# a O
# brood O
# of O
# 17 O
# year O
# cicadas O
# sprouted O
# from O
# the O
# ground O
# after O
# George O
# Washington’s O
# 1779 O
# scorched O
# earth O
# campaign O
# left O
# the O
# people O
# with O
# no O
# crops O
# giving O
# them O
# an O
# emergency O
# food B-BFO
# source O
# that O
# enabled O
# them O
# to O
# survive B-BFA
# Now O
# cicadas O
# may O
# provide B-BFA
# another O
# means O
# for O
# human O
# survival B-BFA
# Recent O
# science O
# shows O
# that O
# tiny O
# structures O
# on O
# cicada O
# wings O
# kill B-BFA
# bacteria B-BFO
# which O
# could O
# give O
# us O
# another O
# way O
# to O
# fight B-BFA
# germs B-BFO
# that O
# kill B-BFA
# millions O
# of O
# people O
# each O
# year O
# In O
# 2012 O
# scientists O
# observed O
# that O
# cicada O
# wings O
# kill B-BFA
# several O
# types O
# of O
# harmful O
# bacteria B-BFO
# but O
# it O
# wasn’t O
# immediately O
# clear O
# how O
# it O
# worked O
# Were O
# the O
# wings O
# coated B-BFA
# in O
# an O
# antibiotic B-BFO
# Was O
# there O
# a O
# rapid O
# immune O
# response O
# Using O
# powerful O
# microscopes O
# to O
# get O
# an O
# extremely O
# close O
# view O
# of O
# the O
# wings O
# the O
# scientists O
# observed O
# tiny B-BFO
# cone I-BFO
# shaped I-BFO
# bumps I-BFO
# called O
# nanopillars B-BFO
# covering O
# both O
# sides O
# in O
# a O
# hexagonal O
# arrangement O
# They O
# hypothesized O
# it O
# was O
# actually O
# the O
# cones B-BFO
# themselves O
# that O
# were O
# killing B-BFA
# the O
# bacteria B-BFO
# and O
# they O
# used O
# “the O
# Midas O
# touch” O
# to O
# prove O
# it O
# They O
# coated B-BFA
# cicada O
# wings O
# with O
# a O
# super O
# thin O
# layer O
# of O
# gold B-BFO
# to O
# inhibit B-BFA
# any O
# biochemical B-BFO
# reactions I-BFO
# When O
# exposed O
# to O
# the O
# gold O
# plated O
# cicada O
# wings O
# bacteria B-BFO
# still O
# died O
# proving O
# there O
# was O
# no O
# chemical B-BFO
# killer I-BFO
# the O
# unique O
# nanopillar B-BFO
# structures I-BFO
# were O
# directly O
# responsible O
# To O
# understand O
# how O
# the O
# cones B-BFO
# kill B-BFA
# bacteria B-BFO
# think O
# of O
# a O
# bacterial O
# cell B-BFO
# like O
# a O
# water O
# balloon O
# With O
# a O
# diameter O
# several O
# times O
# larger O
# than O
# the O
# distance O
# between O
# cones B-BFO
# one O
# cell B-BFO
# rests O
# on O
# many O
# nanopillars O
# It’s O
# tempting O
# to O
# think O
# of O
# these O
# nanopillars O
# as O
# a O
# bed O
# of O
# nails O
# that O
# simply O
# pop O
# the O
# water O
# balloon O
# However O
# in O
# 2013 O
# the O
# same O
# group O
# of O
# scientists O
# developed O
# a O
# model O
# that O
# told O
# a O
# different O
# story O
# For O
# centuries O
# the O
# concept O
# of O
# bacterial B-BFO
# infection B-BFA
# went O
# undiscovered O
# postponing O
# the O
# war O
# we’d O
# eventually O
# wage O
# against O
# it O
# In O
# the O
# 1860s O
# French O
# microbiologist O
# Louis O
# Pasteur O
# kicked B-BFA
# the O
# battle O
# off O
# by O
# finally O
# proving O
# that O
# germs B-BFO
# cause O
# infection B-BFA
# Shortly O
# after O
# he O
# invented O
# pasteurization O
# to O
# make O
# some O
# beverages O
# safer O
# to O
# drink. B-BFA
# Joseph O
# Lister O
# a O
# surgeon O
# quickly O
# applied O
# Pasteur’s O
# work O
# to O
# hospitals O
# developing B-BFA
# the O
# first O
# sterilizing B-BFO
# technique I-BFO
# to O
# cleanse B-BFA
# instruments B-BFO
# hands B-BFO
# and O
# wounds B-BFO
# with O
# carbolic B-BFO
# acid I-BFO
# Then O
# in O
# 1928 O
# Scottish O
# researcher O
# Alexander O
# Fleming O
# accidentally O
# discovered B-BFA
# penicillin B-BFO
# sparking O
# decades O
# of O
# antibiotic B-BFO
# research. O
# Now O
# that O
# some O
# bacteria B-BFO
# are O
# developing B-BFA
# resistance B-BFO
# to I-BFO
# antibiotics I-BFO
# we O
# need O
# to O
# look O
# to O
# nature O
# to O
# help O
# us O
# discover B-BFA
# new O
# ways O
# of O
# fighting B-BFA
# infection. B-BFO
# Cicada O
# wing O
# nanopillars O
# may O
# be O
# the O
# next O
# weapon B-BFO
# in O
# our O
# germ O
# arsenal O
# Surgical B-BFO
# instruments I-BFO
# biomedical B-BFO
# implants I-BFO
# door B-BFO
# handles I-BFO
# and O
# food B-BFO
# preparation O
# surfaces O
# might O
# one O
# day O
# be O
# coated B-BFA
# with O
# microscopic B-BFO
# cones I-BFO
# to O
# kill B-BFA
# bacteria B-BFO
# before O
# it O
# can O
# invade B-BFA
# ##id:4 O
# Trees O
# and O
# Peat B-BFO
# Capture B-BFA
# and O
# Store B-BFA
# Carbon B-BFO
# Plants O
# are O
# made O
# of O
# air O
# Absorbing B-BFA
# carbon B-BFO
# dioxide I-BFO
# as O
# a O
# gas O
# they O
# break B-BFA
# the O
# invisible O
# molecules B-BFO
# apart I-BFA
# and O
# knit B-BFA
# the O
# atoms B-BFO
# together O
# into O
# roots O
# stems O
# trunks O
# and O
# leaves O
# Some O
# of O
# these O
# structures O
# are O
# fleeting O
# disintegrating B-BFA
# within O
# weeks O
# or O
# months O
# and O
# sending B-BFA
# their O
# carbon B-BFO
# right O
# back O
# into O
# the O
# atmosphere O
# Other O
# structures O
# are O
# built O
# to O
# last O
# and O
# hold B-BFA
# that O
# carbon B-BFO
# in O
# place O
# for O
# decades O
# or O
# even O
# centuries––even O
# after O
# the O
# death O
# of O
# the O
# plant O
# itself O
# This O
# is O
# what O
# gives O
# plant O
# filled O
# ecosystems O
# like O
# forests O
# and O
# peatlands O
# so O
# much O
# potential O
# for O
# bringing B-BFA
# down I-BFA
# the O
# level O
# of O
# carbon B-BFO
# in O
# the O
# atmosphere O
# Trees O
# are O
# well O
# known O
# for O
# providing B-BFA
# this O
# ecological O
# service O
# but O
# peat––the O
# thick O
# soil B-BFO
# like O
# accumulation O
# of O
# waterlogged O
# partially O
# decomposed B-BFA
# plants––is O
# the O
# largest O
# natural O
# terrestrial O
# carbon B-BFO
# store B-BFA
# In O
# areas O
# where O
# a O
# forest O
# grows B-BFA
# on O
# a O
# bed O
# of O
# peat B-BFO
# we O
# get O
# boons O
# from O
# both O
# worlds O
# Wetland O
# ecosystems O
# High O
# water B-BFO
# levels O
# in O
# wetlands O
# prevent B-BFA
# large O
# amounts O
# of O
# oxygen B-BFO
# from O
# reaching B-BFA
# wetland O
# soil B-BFO
# where O
# it O
# would O
# enable O
# aerobic B-BFA
# bacteria B-BFO
# to O
# decompose B-BFA
# organic B-BFO
# xa0matter I-BFO
# n O
# The O
# forested O
# peatlands O
# of O
# North O
# America’s O
# boreal O
# region O
# can O
# be O
# as O
# dense O
# as O
# other O
# types O
# of O
# forests O
# in O
# these O
# areas O
# This O
# is O
# significant O
# because O
# the O
# less O
# sunlight B-BFO
# there O
# is O
# reaching B-BFA
# the O
# forest O
# floor O
# the O
# longer O
# it O
# takes B-BFA
# for O
# plants O
# to O
# decompose B-BFA
# In O
# this O
# way O
# forested O
# peatlands O
# can O
# protect B-BFA
# their O
# peat B-BFO
# from O
# decomposing B-BFA
# fully O
# and O
# releasing B-BFA
# stored B-BFA
# carbon B-BFO
# back O
# into O
# the O
# atmosphere O
# Within O
# forested O
# peatlands O
# the O
# peat B-BFO
# itself O
# does O
# the O
# heavy O
# lifting O
# storing B-BFA
# much O
# more O
# carbon B-BFO
# than O
# the O
# trees O
# In O
# fact O
# the O
# forested O
# peatlands O
# of O
# boreal O
# regions O
# in O
# eastern O
# Canada O
# can O
# store B-BFA
# as O
# much O
# carbon B-BFO
# as O
# other O
# wetlands O
# like O
# fens O
# and O
# bogs O
# in O
# the O
# same O
# areas O
# The O
# combined O
# storage B-BFA
# capabilities O
# and O
# protection B-BFA
# from O
# decomposition B-BFA
# create O
# a O
# self O
# sufficient O
# system O
# for O
# capturing B-BFA
# and O
# storing B-BFA
# carbon B-BFO
# Nothing O
# lasts O
# forever O
# though O
# and O
# fire O
# can O
# cut B-BFA
# short I-BFA
# the O
# long O
# sleep O
# that O
# carbon B-BFO
# would O
# otherwise O
# undergo O
# locked B-BFA
# up I-BFA
# in O
# the O
# peat O
# Whether O
# natural O
# or O
# man O
# made O
# fires O
# can O
# result O
# in O
# both O
# forests O
# and O
# peatlands O
# releasing B-BFA
# their O
# stored B-BFA
# carbon B-BFO
# and O
# losing O
# some O
# of O
# their O
# ability O
# to O
# continue O
# storing B-BFA
# carbon B-BFO
# Since O
# forested O
# peatlands O
# have O
# such O
# high O
# soil B-BFO
# moisture O
# they O
# are O
# less O
# vulnerable O
# to O
# fires O
# and O
# offer O
# more O
# effective O
# long O
# term O
# carbon B-BFO
# storage I-BFO
# than O
# other O
# forests O
# Only O
# the O
# drier O
# layers O
# of O
# peat O
# at O
# the O
# surface O
# of O
# the O
# soil B-BFO
# are O
# impacted O
# by O
# fires O
# leaving O
# those O
# deeper O
# layers O
# that O
# are O
# storing B-BFA
# carbon B-BFO
# unharmed O
# However O
# rising O
# global O
# temperatures O
# as O
# a O
# result O
# of O
# climate B-BFO
# change O
# are O
# causing O
# drying O
# deeper O
# and O
# deeper O
# into O
# the O
# peat O
# making O
# these O
# areas O
# increasingly O
# vulnerable O
# to O
# fires O
# While O
# unforested O
# wetlands O
# generally O
# have O
# greater O
# carbon B-BFO
# storage I-BFO
# capacity O
# forested O
# peatlands O
# present O
# a O
# compelling B-BFA
# alternate O
# model O
# for O
# a O
# sequestering O
# ecosystem O
# and O
# are O
# worth O
# protecting B-BFA
# for O
# their O
# potential O
# role O
# in O
# reducing B-BFA
# the O
# impacts O
# of O
# climate B-BFO
# change O
# As O
# humans O
# seek O
# to O
# develop B-BFA
# artificial B-BFO
# carbon I-BFO
# sequestration I-BFO
# systems I-BFO
# the O
# diversity O
# of O
# forested O
# peatlands O
# provides B-BFA
# examples O
# and O
# inspiration O
# for O
# how O
# to O
# more O
# effectively O
# pull O
# solutions O
# to O
# climate B-BFO
# challenges I-BFO
# out O
# of O
# thin O
# air. O
# Industrial O
# Lung O
# by O
# Sapiem O
# is O
# a O
# non O
# toxic O
# carbon B-BFO
# capture B-BFA
# process O
# that O
# uses O
# a O
# synthetic O
# form O
# of O
# the O
# enzyme B-BFO
# carbonic O
# anhydrase O
# ##id:10 O
# Mixture O
# Waterproofs B-BFA
# Nests O
# When O
# it O
# comes O
# to O
# building B-BFA
# homes B-BFO
# , O
# people O
# have O
# a O
# lot O
# in O
# common O
# with O
# wasps O
# Both O
# use O
# a O
# variety O
# of O
# materials B-BFO
# wood B-BFO
# stone B-BFO
# straw B-BFO
# grass B-BFO
# leaves B-BFO
# and O
# so O
# on––to O
# construct B-BFA
# shelters B-BFO
# that O
# will O
# protect B-BFA
# them O
# from O
# the O
# elements B-BFO
# And O
# both O
# use O
# some O
# kind O
# of O
# adhesive B-BFO
# to O
# hold B-BFA
# the O
# materials O
# together O
# But O
# there O
# are O
# also O
# some O
# key O
# differences O
# For O
# one O
# wasps O
# don’t O
# have O
# access O
# to O
# store O
# bought B-BFA
# adhesives B-BFO
# like O
# wood B-BFO
# glue I-BFO
# or O
# duct B-BFO
# tape I-BFO
# Instead O
# wasps O
# work O
# with O
# what O
# they O
# have O
# And O
# they O
# have O
# saliva B-BFO
# The O
# sticky B-BFO
# glue I-BFO
# like O
# substance O
# helps O
# them O
# to O
# build B-BFA
# water B-BFO
# resistant B-BFA
# nests O
# by O
# forming B-BFA
# a O
# quick O
# drying O
# glue B-BFO
# like O
# matrix B-BFO
# The O
# saliva B-BFO
# is O
# primarily O
# with O
# a O
# high O
# proline O
# content O
# When O
# mixed B-BFA
# with O
# the O
# in O
# plant B-BFO
# matter I-BFO
# a O
# wasp O
# chews O
# it O
# dries O
# quickly O
# and O
# irreversibly O
# to O
# a O
# water B-BFO
# insoluble O
# water B-BFO
# repellant B-BFA
# surface O
# This O
# allows O
# the O
# wasp O
# to O
# build B-BFA
# a O
# nest B-BFO
# that O
# will O
# stand B-BFA
# up I-BFA
# to O
# the O
# rigors B-BFA
# of O
# weather B-BFO
# and O
# the O
# elements B-BFO
# The O
# quick O
# drying B-BFA
# water B-BFO
# resistant O
# properties O
# of O
# wasp O
# saliva O
# could O
# inspire B-BFA
# the O
# creation O
# of O
# more O
# natural B-BFO
# adhesives I-BFO
# for O
# a O
# variety O
# of O
# applications O
# Furthermore O
# the O
# saliva O
# itself O
# or O
# a O
# similar O
# human O
# developed O
# substance O
# could O
# be O
# mixed B-BFA
# with O
# plant B-BFO
# matter I-BFO
# or O
# other O
# materials O
# to O
# create B-BFA
# lightweight O
# highly O
# adaptable O
# building O
# materials B-BFO
# for O
# human O
# applications O
# ##id:19 O
# How O
# Kidneys O
# Filter B-BFA
# and O
# Recycle B-BFA
# Walking O
# around O
# a O
# wet O
# marsh O
# it O
# might O
# not O
# occur O
# that O
# one O
# of O
# the O
# world’s O
# best O
# water B-BFO
# filters I-BFO
# lies B-BFA
# beneath O
# your O
# feet O
# Soil B-BFO
# itself O
# physically O
# sieves B-BFA
# large O
# particulates B-BFO
# as O
# water B-BFO
# flows B-BFA
# through O
# it O
# Some O
# clay O
# soils B-BFO
# chemically O
# absorb B-BFA
# pesticides B-BFO
# and O
# other O
# compounds O
# Bacteria O
# that O
# live B-BFA
# in I-BFA
# soil B-BFO
# also O
# degrade B-BFA
# some O
# pollutants B-BFO
# absorbed B-BFA
# from O
# the O
# atmosphere O
# as O
# a O
# result O
# of O
# burning B-BFA
# fossil B-BFO
# fuels I-BFO
# Soil’s O
# bulk O
# filtration B-BFA
# isn’t O
# enough O
# to O
# treat B-BFA
# drinking B-BFO
# water I-BFO
# however O
# Before O
# it O
# reaches O
# our O
# taps O
# fine O
# tuned O
# treatment O
# plants O
# make O
# targeted O
# adjustments O
# so O
# that O
# the O
# water B-BFO
# we O
# drink B-BFA
# is O
# safe O
# Kidneys O
# filter B-BFA
# blood B-BFO
# using B-BFA
# a O
# similar O
# two O
# stage O
# process O
# with O
# bulk O
# filtration O
# followed O
# by O
# a O
# selective O
# system O
# that O
# removes B-BFA
# or O
# recycles B-BFA
# specific O
# compounds O
# A O
# ’s O
# primary O
# purpose O
# is O
# to O
# filter B-BFA
# metabolic B-BFO
# waste I-BFO
# products I-BFO
# from O
# our O
# blood O
# To O
# do O
# so O
# effectively O
# it O
# has O
# to O
# process O
# a O
# lot O
# of O
# fluid B-BFO
# which O
# also O
# ends O
# up O
# removing B-BFA
# water B-BFO
# minerals B-BFO
# and O
# from O
# the O
# blood O
# things O
# our O
# bodies O
# need O
# If O
# the O
# kidney O
# didn’t O
# recycle B-BFA
# these O
# useful O
# compounds O
# we O
# would O
# have O
# to O
# consume B-BFA
# gallons O
# of O
# water B-BFO
# and O
# large O
# quantities O
# of O
# minerals B-BFO
# each O
# day O
# The O
# machinery O
# of O
# the O
# kidneys O
# is O
# a O
# collection O
# of O
# over O
# a O
# million O
# independent O
# processing O
# lines O
# the O
# nephrons O
# A O
# nephron O
# has O
# two O
# functional O
# zones O
# the O
# glomerulus O
# and O
# the O
# tubule O
# Learning O
# to O
# better O
# separate B-BFA
# and O
# recycle B-BFA
# compounds O
# could O
# help O
# existing O
# industrial O
# chemical O
# processes O
# become O
# more O
# efficient O
# and O
# reduce B-BFA
# emissions O
# Improved O
# separation B-BFA
# technologies O
# could O
# increase B-BFA
# the O
# amount O
# of O
# particulate O
# bacteria B-BFO
# and O
# chemicals B-BFO
# removed O
# in O
# sewage O
# and O
# water B-BFO
# treatment O
# plants B-BFO
# allowing O
# us O
# to O
# recycle B-BFA
# cleaner O
# water B-BFO
# How O
# else O
# might O
# nephron O
# filtering B-BFA
# inspire O
# human O
# innovation O
# ##id:8 O
# Chemicals O
# in O
# Oregano O
# Act B-BFA
# as O
# Fungicide B-BFA
# If O
# you’ve O
# ever O
# opened O
# your O
# refrigerator O
# to O
# find O
# that O
# your O
# fresh B-BFO
# produce I-BFO
# has O
# turned B-BFA
# into I-BFA
# a O
# mushy O
# moldy O
# mess O
# then O
# you’re O
# familiar O
# with O
# the O
# destructive O
# power O
# of O
# fungi O
# Without O
# some O
# sort O
# of O
# protection B-BFA
# against O
# such O
# microorganisms B-BFO
# , O
# thousands O
# of O
# tons O
# of O
# fruits O
# and O
# vegetables O
# would O
# spoil B-BFA
# and O
# go O
# to O
# waste O
# before O
# they O
# even O
# made O
# it O
# to O
# our O
# grocery O
# stores O
# Oregano O
# has O
# emerged O
# as O
# a O
# source O
# of O
# potent O
# plant O
# protection B-BFA
# molecules B-BFO
# producing B-BFA
# oils B-BFO
# and O
# vapors B-BFO
# that O
# prevent B-BFA
# fungal B-BFO
# infection B-BFA
# and O
# food B-BFO
# spoilage B-BFA
# As O
# it O
# turns O
# out O
# , O
# oregano O
# and O
# a O
# number O
# of O
# other O
# plants O
# eucalyptus O
# rosemary O
# thyme O
# have O
# built O
# in O
# defense O
# mechanisms O
# to O
# fight B-BFA
# off I-BFA
# fungal B-BFO
# attacks B-BFA
# These O
# are O
# usually O
# in O
# the O
# form O
# of O
# messenger B-BFO
# molecules I-BFO
# present O
# in O
# the O
# plant’s O
# fluids O
# that O
# easily O
# evaporate B-BFA
# into O
# the O
# surrounding O
# air O
# If O
# one O
# plant O
# is O
# attacked B-BFA
# by O
# a O
# fungus O
# it O
# will O
# release B-BFA
# these O
# “volatile B-BFA
# organic I-BFO
# compounds” I-BFO
# to O
# alert B-BFA
# surrounding O
# plants B-BFO
# , O
# the O
# reception B-BFA
# of O
# the O
# VOCs B-BFO
# will O
# then O
# initiate B-BFA
# the O
# surrounding O
# plants’ O
# natural O
# defense B-BFA
# responses O
# There O
# is O
# keen O
# interest O
# in O
# using O
# VOCs B-BFO
# from O
# oregano O
# commercially O
# for O
# food B-BFO
# preservation B-BFA
# In O
# previous O
# decades O
# synthetic B-BFO
# fungicides I-BFO
# have O
# been O
# used B-BFA
# to O
# prevent B-BFA
# food B-BFO
# spoilage B-BFA
# However O
# these O
# synthetic B-BFO
# compounds I-BFO
# do O
# not O
# degrade B-BFA
# easily O
# in O
# soil B-BFO
# and O
# groundwater O
# and O
# can O
# be O
# toxic B-BFA
# to O
# a O
# broad O
# range O
# of O
# organisms O
# Furthermore O
# fungi O
# can O
# develop B-BFA
# resistance B-BFO
# to O
# synthetic B-BFO
# fungicides I-BFO
# , O
# requiring O
# even O
# more O
# of O
# the O
# chemicals B-BFO
# to O
# be O
# applied B-BFA
# to O
# be O
# effective O
# which O
# in O
# turn O
# worsens B-BFA
# environmental O
# impacts O
# Essential O
# oils B-BFO
# extracted B-BFA
# from O
# plants O
# on O
# the O
# other O
# hand O
# are O
# much O
# less O
# harmful O
# since O
# they O
# do O
# not O
# remain B-BFA
# in O
# soil B-BFO
# or O
# water B-BFO
# for O
# long O
# and O
# very O
# low O
# amounts O
# are O
# needed O
# to O
# be O
# effective. O
# Several O
# companies O
# are O
# now O
# working O
# on O
# integrating B-BFA
# plant B-BFO
# derived B-BFA
# VOCs B-BFO
# into O
# food B-BFO
# packaging I-BFO
# as O
# an O
# alternative O
# to O
# artificial O
# preservatives O
# Such O
# innovation O
# could O
# radically O
# transform B-BFA
# our O
# food B-BFO
# system O
# making O
# it O
# less O
# wasteful O
# and O
# less O
# harmful O
# for O
# both O
# humans O
# and O
# the O
# environment O
# ##id:7 O
# Microbes O
# Strip B-BFA
# Plant B-BFO
# Fibers I-BFO
# Clean B-BFA
# Where O
# would O
# we O
# be O
# without O
# nature’s O
# recyclers O
# If O
# it O
# weren’t O
# for O
# bacteria B-BFA
# fungi O
# and O
# other O
# organisms O
# that O
# break B-BFA
# once O
# living O
# things O
# into I-BFA
# molecules B-BFO
# new O
# life O
# can O
# use B-BFA
# , O
# we’d O
# be O
# wallowing O
# in O
# mountains O
# of O
# detritus O
# , O
# assuming O
# there O
# were O
# even O
# enough O
# molecules B-BFO
# available O
# for O
# us O
# to O
# exist O
# in O
# the O
# first O
# place O
# But O
# when O
# it O
# comes O
# to O
# breaking B-BFA
# down I-BFA
# fibrous B-BFO
# plants O
# decomposers O
# have O
# their O
# limits O
# Some O
# are O
# able O
# to O
# break B-BFA
# down I-BFA
# one O
# plant O
# part O
# while O
# others O
# specialize O
# in O
# a O
# different O
# component O
# With O
# teamwork O
# they O
# get O
# the O
# job O
# done O
# mostly O
# The O
# stems O
# of O
# fibrous O
# plants O
# such O
# as O
# flax O
# and O
# hemp O
# are O
# made O
# of O
# multiple O
# layers O
# Some O
# of O
# these O
# layers O
# are O
# more O
# susceptible O
# to O
# decomposers O
# than O
# are O
# others O
# The O
# outer O
# part O
# of O
# the O
# stem O
# is O
# made O
# up O
# of O
# gluelike O
# pectin O
# gum O
# chemicals O
# that O
# impart O
# color O
# and O
# bast O
# fibers O
# which O
# surround O
# the O
# inner O
# woody O
# part O
# of O
# the O
# stem O
# and O
# provide B-BFA
# structure O
# to O
# the O
# part O
# of O
# the O
# stem O
# through O
# which O
# water B-BFO
# and O
# nutrients B-BFO
# can O
# flow B-BFA
# When O
# a O
# fibrous O
# plant O
# dies B-BFA
# naturally O
# or O
# is O
# harvested B-BFA
# microbes O
# in O
# the O
# environment O
# around O
# it O
# start O
# gnawing B-BFA
# away I-BFA
# at O
# these O
# softer B-BFO
# tissues I-BFO
# They O
# use O
# specialized O
# enzymes B-BFO
# to O
# break B-BFA
# down I-BFA
# the O
# structures O
# that O
# make O
# up O
# the O
# various O
# components O
# of O
# stems O
# into O
# small O
# molecules B-BFO
# providing B-BFA
# food B-BFO
# for O
# themselves O
# in O
# the O
# process O
# The O
# type O
# of O
# microorganism O
# that O
# does O
# the O
# job O
# depends O
# on O
# the O
# setting O
# On O
# land O
# the O
# decomposers O
# tend O
# to O
# be O
# fungi O
# that O
# require B-BFA
# oxygen B-BFO
# to O
# function O
# In O
# freshwater O
# bacteria B-BFO
# particularly O
# do O
# the O
# job O
# In O
# saltwater O
# scientists O
# have O
# identified O
# two O
# kinds O
# of O
# bacteria B-BFO
# normally O
# found O
# in O
# the O
# soil B-BFO
# and O
# as O
# the O
# primary O
# degraders O
# Degraders O
# use O
# enzymes B-BFO
# called O
# to O
# break B-BFA
# down I-BFA
# the O
# pectin B-BFO
# found O
# in O
# the O
# cell B-BFO
# walls O
# and O
# the O
# matter O
# between O
# cells B-BFO
# They O
# break B-BFA
# down I-BFA
# and O
# hemicellulose B-BFO
# with O
# and O
# Relatively O
# few O
# however O
# are O
# able O
# to O
# make O
# much O
# of O
# a O
# dent O
# in O
# the O
# central O
# woody O
# part O
# of O
# the O
# stem O
# As O
# a O
# result O
# the O
# outer O
# materials O
# essentially O
# get O
# eaten B-BFA
# away O
# leaving B-BFA
# a O
# clean B-BFA
# fiber B-BFO
# in O
# much O
# the O
# same O
# way O
# as O
# a O
# dog O
# gnawing B-BFA
# on O
# a O
# bone B-BFO
# removes B-BFA
# every O
# bit O
# of O
# meat B-BFO
# and O
# gristle B-BFA
# but O
# leaves B-BFA
# the O
# bone B-BFO
# relatively O
# intact O
# That’s O
# good O
# news O
# for O
# those O
# of O
# us O
# who O
# wear B-BFA
# clothes B-BFO
# When O
# manufacturers O
# make O
# textiles B-BFO
# from O
# natural O
# fibers O
# they O
# first O
# need O
# to O
# strip B-BFA
# all O
# of O
# the O
# non O
# fiber B-BFO
# bits O
# away O
# One O
# way O
# to O
# do O
# that O
# is O
# to O
# use B-BFA
# harsh O
# chemicals B-BFO
# but O
# as O
# concern O
# grows B-BFA
# for O
# protecting B-BFA
# the O
# environment B-BFO
# manufacturers O
# are O
# turning O
# to O
# decomposers B-BFO
# instead O
# The O
# right O
# mix O
# can O
# remove B-BFA
# the O
# undesirable O
# part O
# of O
# fiber B-BFO
# plants I-BFO
# freeing B-BFA
# up I-BFA
# the O
# sturdy B-BFO
# insides O
# for O
# use O
# in O
# fashioning O
# fashion O
# ##id:0 O
# How O
# Fungi O
# Can O
# Clean B-BFA
# Up I-BFA
# Pollution B-BFO
# Whoever O
# observed O
# that O
# “one O
# person’s O
# trash O
# is O
# another’s O
# treasure” O
# could O
# easily O
# have O
# been O
# speaking B-BFA
# about O
# fungi O
# These O
# organisms O
# which O
# form O
# a O
# kingdom O
# all O
# on O
# their O
# own O
# come O
# in O
# virtually O
# endless O
# sizes O
# and O
# shapes O
# , O
# from O
# single O
# celled O
# yeasts O
# to O
# massive O
# web O
# like O
# organisms O
# that O
# stretch O
# for O
# miles O
# underground O
# They O
# make B-BFA
# their O
# life B-BFO
# through O
# way O
# by O
# tapping B-BFA
# into O
# resources B-BFO
# few O
# if O
# any O
# others O
# want O
# horse B-BFO
# manure I-BFO
# fallen O
# leaves B-BFO
# dead B-BFO
# animals I-BFO
# and O
# the O
# like O
# and O
# breaking B-BFA
# down I-BFA
# the O
# natural B-BFO
# chemicals I-BFO
# they O
# contain O
# into O
# a O
# source O
# of O
# energy B-BFO
# and O
# molecules B-BFO
# to O
# nourish B-BFA
# themselves O
# Some O
# fungi O
# can O
# use B-BFA
# the O
# same O
# molecules B-BFO
# that O
# help O
# them O
# obtain B-BFA
# food B-BFO
# to O
# break B-BFA
# down I-BFA
# artificial B-BFO
# chemicals I-BFO
# with O
# which O
# we O
# humans O
# have O
# contaminated B-BFA
# the O
# environment O
# All O
# living O
# things O
# contain B-BFA
# enzymes B-BFO
# proteins I-BFO
# they O
# use O
# to O
# break B-BFA
# or O
# make B-BFA
# chemical B-BFO
# bonds I-BFO
# By O
# holding B-BFA
# two O
# or O
# more O
# molecules B-BFO
# close O
# to O
# each O
# other O
# in O
# a O
# position O
# that O
# encourages B-BFA
# them O
# to O
# react B-BFA
# with O
# each O
# other O
# enzymes B-BFO
# allow O
# their O
# owners O
# to O
# transform B-BFA
# one O
# substance O
# into O
# another O
# creating B-BFA
# the O
# molecules B-BFO
# they O
# need O
# to O
# provide B-BFA
# structure O
# produce B-BFA
# energy B-BFO
# and O
# more O
# As O
# organisms O
# that O
# specialize O
# in O
# decomposing B-BFA
# other O
# living O
# or O
# formerly O
# living O
# things O
# , O
# fungi O
# have B-BFA
# a O
# particularly O
# impressive O
# variety O
# of O
# enzymes B-BFO
# they O
# can O
# use O
# to O
# break B-BFA
# down I-BFA
# a O
# wide O
# variety O
# of O
# chemicals B-BFO
# to O
# extract B-BFA
# the O
# energy B-BFO
# and O
# molecules B-BFO
# they O
# need O
# to O
# live B-BFA
# Scientists O
# searching O
# for O
# ways O
# to O
# remove B-BFA
# human O
# made O
# pollutants B-BFO
# from O
# the O
# environment O
# have O
# discovered O
# that O
# some O
# fungi O
# can O
# use O
# their O
# enzymes B-BFO
# to O
# degrade B-BFA
# these O
# undesirable O
# chemicals B-BFO
# Contaminants O
# that O
# fungi O
# have O
# been O
# found O
# to O
# break B-BFA
# down B-BFO
# include O
# polyaromatic B-BFO
# hydrocarbons I-BFO
# such O
# as O
# those O
# found O
# in O
# crude B-BFO
# oil I-BFO
# and O
# gasoline B-BFO
# heavy B-BFO
# metals I-BFO
# herbicides B-BFO
# pesticides B-BFO
# cyanotoxins B-BFO
# pharmaceuticals B-BFO
# antibiotics B-BFO
# phthalates B-BFO
# dyes B-BFO
# and O
# detergents B-BFO
# Often O
# the O
# enzymes B-BFO
# they O
# use B-BFA
# to O
# do O
# this O
# are O
# also O
# ones O
# they O
# normally O
# would O
# use B-BFA
# to O
# break B-BFA
# down I-BFO
# lignin B-BFO
# the O
# molecule B-BFO
# that O
# helps O
# give O
# plants B-BFO
# their O
# stiff B-BFO
# structure I-BFO
# But O
# other O
# enzymes B-BFO
# appear O
# to O
# be O
# involved B-BFA
# as O
# well O
# The O
# chemical B-BFO
# reactions I-BFO
# include O
# removing B-BFA
# oxygen B-BFO
# or O
# hydrogen B-BFO
# , O
# altering B-BFA
# the O
# configuration B-BFO
# of O
# chemical B-BFO
# bonds I-BFO
# and O
# more O
# Such O
# changes O
# in O
# some O
# cases O
# can O
# turn B-BFA
# toxic B-BFO
# substances I-BFO
# into O
# harmless B-BFO
# molecules I-BFO
# such O
# as O
# carbohydrates B-BFO
# water I-BFO
# and O
# oxygen B-BFO
# Conventional O
# processes O
# for O
# removing B-BFA
# pollutants B-BFO
# such O
# as O
# industrial B-BFO
# waste I-BFO
# paints I-BFO
# and O
# pesticides B-BFO
# from O
# land O
# and O
# water O
# can O
# be O
# expensive O
# energy B-BFO
# demanding O
# and O
# of O
# limited O
# effectiveness O
# Sometimes O
# they O
# even O
# produce B-BFA
# other O
# undesirable O
# molecules B-BFO
# in O
# the O
# process O
# The O
# right O
# kinds O
# of O
# fungi O
# could O
# be O
# introduced O
# to O
# a O
# contaminated O
# site O
# though O
# and O
# begin O
# to O
# do O
# the O
# job O
# themselves O
# , O
# This O
# process O
# known O
# as O
# mycoremediation O
# uses B-BFA
# other O
# forms O
# of O
# life O
# to O
# accomplish B-BFA
# tasks O
# directly O
# as O
# opposed O
# to O
# adapting B-BFA
# lessons O
# from O
# them O
# into O
# new O
# innovations O
# and O
# so O
# is O
# a O
# form O
# of O
# There O
# is O
# a O
# very O
# good O
# reason O
# why O
# we O
# don’t O
# generally O
# just O
# put O
# fungi O
# into O
# an O
# environment O
# to O
# let O
# them O
# take B-BFA
# care I-BFA
# of I-BFA
# our O
# pollution B-BFO
# it O
# is O
# very O
# difficult O
# to O
# scale B-BFA
# Fungi O
# convert B-BFA
# the O
# pollution B-BFO
# we O
# have O
# created B-BFA
# at O
# a O
# much O
# slower O
# rate O
# than O
# we O
# create B-BFA
# it O
# Genetic O
# modification O
# could O
# enhance B-BFA
# the O
# efficiency O
# of O
# some O
# contaminant O
# degrading B-BFA
# fungi O
# though O
# or O
# enable O
# them O
# to O
# specialize O
# in O
# certain O
# pollutants B-BFO
# Scientists O
# are O
# also O
# exploring B-BFA
# ways O
# to O
# introduce B-BFA
# certain O
# bacteria B-BFO
# or O
# natural B-BFO
# chemicals I-BFO
# such O
# as O
# to O
# make O
# fungi’s O
# natural O
# abilities O
# more O
# effective O
# This O
# ability O
# to O
# take B-BFA
# up I-BFA
# toxic B-BFO
# substances I-BFO
# could O
# also O
# be O
# used B-BFA
# to O
# improve B-BFA
# recycling B-BFO
# and O
# decrease B-BFA
# mining B-BFO
# by O
# “harvesting” B-BFA
# precious B-BFO
# metals I-BFO
# from O
# e O
# waste O
# wastewater B-BFO
# or O
# naturally B-BFO
# occurring I-BFO
# deposits I-BFO
# ##id:9 O
# Mutualism B-BFA
# Enhances O
# Pollutant B-BFO
# Breakdown B-BFA
# Plants O
# are O
# made O
# up O
# of O
# different O
# parts O
# The O
# stems O
# leaves O
# and O
# any O
# flowers O
# sit O
# above O
# the O
# soil B-BFO
# where O
# the O
# leaves O
# photosynthesize O
# Below O
# the O
# soil B-BFO
# surface O
# the O
# plants’ O
# roots O
# and O
# some O
# important O
# partners O
# are O
# also O
# working O
# hard O
# The O
# roots O
# help O
# anchor B-BFA
# the O
# plants O
# and O
# take B-BFA
# in I-BFA
# water B-BFO
# and O
# nutrients B-BFO
# from O
# the O
# soil B-BFO
# The O
# roots O
# also O
# support B-BFA
# a O
# large O
# variety O
# of O
# bacteria B-BFO
# including O
# ones O
# that O
# live B-BFA
# inside O
# plants’ O
# cells B-BFO
# and O
# others O
# that O
# live B-BFA
# in O
# the O
# spaces O
# in O
# between O
# the O
# cells B-BFO
# Another O
# group O
# of O
# bacteria B-BFO
# called O
# live B-BFA
# outside O
# the O
# plant O
# nestled O
# among O
# the O
# roots O
# This O
# area O
# is O
# known O
# as O
# the O
# Rhizobacteria O
# and O
# plants O
# work O
# together O
# to O
# help O
# each O
# other O
# survive B-BFA
# This O
# is O
# called O
# a O
# The O
# plant O
# gives O
# the O
# bacteria B-BFO
# a O
# place O
# to O
# live B-BFA
# and O
# provides B-BFA
# them O
# with O
# nutrients B-BFO
# through O
# its O
# roots O
# In O
# return O
# bacteria B-BFO
# take B-BFA
# natural B-BFO
# chemicals I-BFO
# in O
# the O
# soil B-BFO
# such O
# as O
# nitrogen B-BFO
# and O
# turn B-BFA
# them O
# into I-BFA
# more O
# useful O
# kinds O
# of O
# chemicals B-BFO
# such O
# as O
# ammonia B-BFO
# nitrates I-BFO
# and O
# nitrites B-BFO
# Some O
# chemicals B-BFO
# the O
# bacteria O
# produce O
# increase B-BFA
# the O
# size O
# and O
# surface O
# area O
# of O
# roots O
# so O
# they O
# have B-BFA
# more O
# contact I-BFA
# with I-BFA
# the O
# soil B-BFO
# This O
# increases O
# nutrient B-BFO
# and O
# water B-BFO
# uptake O
# making O
# the O
# plant O
# stronger O
# Hydrocarbon O
# waste O
# can O
# make O
# people O
# sick O
# and O
# decrease B-BFA
# plant O
# growth B-BFO
# so O
# finding O
# a O
# way O
# to O
# remove B-BFA
# or O
# break B-BFA
# down I-BFA
# these O
# pollutants B-BFO
# is O
# important O
# Using O
# conventional O
# methods O
# such O
# as O
# digging B-BFA
# or O
# incineration B-BFA
# to O
# break B-BFA
# down I-BFA
# hydrocarbons B-BFO
# is O
# very O
# expensive O
# so O
# taking O
# advantage O
# of O
# the O
# mutual O
# relationship O
# that O
# already O
# exists O
# between O
# plants O
# and O
# rhizobacteria O
# could O
# help O
# us O
# develop O
# more O
# economical O
# methods O
# of O
# reducing B-BFA
# ground O
# pollution B-BFO
# ##id:18 O
# Mucus O
# Traps B-BFA
# Carbon B-BFO
# From O
# Seawater O
# The O
# tiny O
# oceanic O
# creatures O
# called O
# giant O
# larvaceans O
# are O
# “giant” O
# only O
# in O
# comparison O
# to O
# their O
# relatives O
# New O
# research O
# shows O
# these O
# strange O
# invertebrates O
# have O
# the O
# greatest O
# capacity O
# for O
# filtering B-BFA
# seawater B-BFO
# of O
# any O
# zooplankton O
# and O
# so O
# may O
# play O
# an O
# important O
# role O
# in O
# trapping B-BFA
# carbon B-BFO
# and O
# keeping B-BFA
# it O
# from I-BFA
# reaching B-BFA
# the O
# atmosphere O
# Zooplankton O
# from O
# the O
# Greek O
# for O
# “drifting O
# animals” O
# are O
# generally O
# microscopic O
# waterborne O
# organisms O
# that O
# feed B-BFA
# on O
# phytoplankton B-BFO
# “drifting B-BFO
# plants” I-BFO
# Larvaceans O
# specifically O
# are O
# simple O
# creatures O
# consisting O
# of O
# a O
# head O
# or O
# trunk O
# and O
# tail O
# somewhat O
# resembling B-BFA
# tadpoles B-BFO
# What O
# aren’t O
# simple O
# are O
# their O
# feeding O
# structures––complex O
# filters B-BFA
# called O
# “houses” O
# made O
# of O
# mucus O
# that O
# extend O
# far O
# past O
# the O
# body O
# For O
# most O
# 2 O
# 8mm O
# larvacean O
# species O
# these O
# “houses” O
# can O
# range O
# from O
# 4 O
# to O
# 38 O
# mm O
# up O
# to O
# 1.5 O
# inches O
# in O
# diameter O
# but O
# for O
# the O
# giants O
# of O
# the O
# family O
# like O
# the O
# seen O
# below O
# at O
# 3 O
# to O
# 10 O
# cm O
# 1 O
# to O
# 4 O
# inches O
# the O
# filtering O
# structures O
# can O
# reach O
# a O
# meter O
# 39 O
# inches O
# in O
# width O
# It’s O
# this O
# house O
# structure O
# that O
# enables O
# giant O
# larvaceans O
# to O
# do O
# such O
# an O
# efficient O
# job O
# straining B-BFA
# sea B-BFO
# water I-BFO
# for O
# their O
# tiny O
# food B-BFA
# The O
# wide O
# meshed O
# outer O
# parts O
# of O
# the O
# filter O
# keep B-BFA
# out I-BFA
# anything O
# too O
# big O
# to O
# consume B-BFA
# and O
# a O
# smaller O
# inner O
# filter B-BFO
# funnels O
# food B-BFO
# particles O
# to O
# the O
# mouth O
# via O
# a O
# tube O
# It’s O
# all O
# powered O
# by O
# the O
# constant O
# motion O
# of O
# the O
# animal’s O
# tail O
# directing O
# water B-BFO
# inside O
# and O
# through O
# the O
# house O
# Understanding O
# how O
# giant O
# larvaceans O
# build O
# such O
# efficient O
# filters B-BFO
# and O
# how O
# they O
# do O
# it O
# so O
# quickly O
# is O
# a O
# promising O
# area O
# of O
# study O
# As O
# our O
# understanding O
# of O
# them O
# improves O
# these O
# amazing O
# structures O
# could O
# inspire O
# designs O
# for O
# new O
# filters B-BFO
# and O
# expandable O
# structures O
# perhaps O
# even O
# opening O
# the O
# doors O
# for O
# easier O
# or O
# more O
# sustained O
# deep B-BFO
# water I-BFO
# or O
# space O
# exploration B-BFA
# ##id:2 O
# Honeybees O
# Detoxify B-BFA
# Insecticide B-BFO
# The O
# next O
# time O
# you O
# eat B-BFA
# a O
# fruit B-BFO
# nut B-BFO
# or O
# vegetable B-BFO
# give O
# a O
# thought O
# to O
# how O
# the O
# wondrous O
# food B-BFO
# in O
# your O
# hand O
# or O
# on O
# your O
# plate O
# was O
# grown B-BFA
# Very O
# likely O
# a O
# honeybee O
# was O
# involved B-BFA
# in O
# a O
# vital O
# way O
# Honeybees O
# are O
# important O
# pollinators B-BFA
# for O
# wild O
# plants O
# and O
# human O
# agricultural O
# systems O
# crucial O
# to O
# the O
# pollination O
# of O
# foods B-BFO
# including O
# apples B-BFO
# cherries B-BFO
# blueberries B-BFO
# broccoli B-BFO
# pumpkins B-BFO
# and O
# almonds B-BFO
# Honeybee O
# populations O
# have O
# been O
# declining B-BFA
# however O
# because O
# of O
# a O
# number O
# of O
# threats B-BFA
# including O
# bacterial B-BFO
# and O
# fungal B-BFO
# diseases I-BFO
# and O
# parasitic B-BFO
# mites I-BFO
# Many O
# insecticides B-BFO
# cannot O
# be O
# used B-BFA
# to O
# control B-BFA
# these O
# threats B-BFA
# though O
# because O
# they O
# also O
# kill B-BFO
# the O
# bees O
# Honeybees O
# have O
# important O
# chemical B-BFO
# abilities O
# that O
# can O
# help O
# them O
# deal B-BFA
# with I-BFA
# some O
# of O
# these O
# threats B-BFO
# however O
# For O
# example O
# the O
# insecticide B-BFO
# tau B-BFO
# fuvalinate I-BFO
# a O
# derivative O
# from O
# pyrethrum O
# daisies O
# successfully O
# controls B-BFA
# parasitic B-BFO
# varroa O
# mites O
# without O
# harming O
# the O
# bees O
# themselves O
# That’s O
# because O
# bees O
# have O
# enzymes B-BFO
# ––special O
# molecules B-BFO
# capable O
# of O
# making O
# changes O
# to O
# other O
# molecules––which O
# can O
# detoxify B-BFA
# certain O
# insecticides B-BFO
# The O
# enzymes B-BFO
# known O
# as O
# P450s B-BFO
# short O
# for O
# cytochrome B-BFA
# P450 B-BFO
# monooxygenases I-BFO
# appear O
# to O
# be O
# especially O
# effective O
# at O
# detoxifying B-BFA
# the O
# insecticide B-BFO
# tau B-BFO
# fuvalinate I-BFO
# Researchers O
# draw O
# this O
# kind O
# of O
# conclusion O
# from O
# studies O
# in O
# which O
# chemicals B-BFO
# known O
# to O
# inhibit B-BFA
# P450 B-BFO
# enzymes B-BFO
# e.g O
# piperonyl B-BFO
# butoxide I-BFO
# or O
# PBO B-BFO
# are O
# added O
# to O
# sugar B-BFO
# water I-BFO
# and O
# fed B-BFA
# to O
# bees O
# and O
# the O
# toxic O
# effects O
# of O
# insecticides B-BFO
# like O
# tau O
# fuvalinate––such O
# as O
# a O
# lack O
# of O
# coordination––become O
# more O
# apparent O
# Remove B-BFA
# the O
# PBO B-BFO
# enzyme I-BFO
# inhibitor O
# and O
# the O
# bees O
# are O
# no O
# longer O
# impacted O
# as O
# strongly O
# by O
# tau B-BFO
# fulvalinate I-BFO
# How O
# does O
# it O
# work O
# P450 B-BFO
# enzymes I-BFO
# are O
# known O
# to O
# be O
# capable O
# of O
# stripping B-BFA
# electrons B-BFO
# away I-BFA
# from O
# i.e O
# oxidizing O
# molecular O
# structures O
# known O
# as O
# aromatic B-BFO
# rings I-BFO
# found O
# in O
# natural O
# toxins B-BFO
# as O
# well O
# as O
# pyrethrum O
# derived B-BFA
# insecticides B-BFO
# A O
# similar O
# process O
# occurs O
# when O
# you O
# cut B-BFA
# an O
# apple O
# and O
# it O
# begins O
# to O
# brown B-BFA
# oxygen I-BFA
# in O
# the O
# air O
# removes B-BFA
# electrons B-BFO
# from O
# now O
# exposed B-BFA
# molecules B-BFO
# in O
# the O
# apple’s O
# flesh O
# and O
# you O
# can O
# see O
# the O
# apple’s B-BFO
# molecules I-BFO
# undergo O
# change O
# The O
# formation O
# of O
# rust O
# from O
# metal O
# in O
# moist O
# air O
# is O
# another O
# similar O
# oxidation O
# degradation O
# process O
# Aromatic B-BFO
# rings I-BFO
# are O
# molecules B-BFO
# or O
# parts O
# of O
# molecules B-BFO
# that O
# form O
# circular B-BFO
# chains I-BFO
# of O
# carbon B-BFO
# atoms I-BFO
# with O
# various O
# side O
# groups O
# When O
# these O
# structures O
# are O
# stripped B-BFA
# of O
# electrons B-BFO
# they O
# become O
# unstable O
# and O
# begin O
# to O
# break B-BFA
# down I-BFA
# Tau B-BFO
# fulvalinate I-BFO
# contains O
# an O
# additional O
# aromatic B-BFO
# ring I-BFO
# which O
# may O
# explain O
# why O
# honeybees O
# with O
# their O
# P450 B-BFO
# enzymes I-BFO
# are O
# especially O
# able O
# to O
# detoxify B-BFA
# it O
# The O
# abilities O
# of O
# enzymes B-BFO
# to O
# change O
# and O
# detoxify B-BFA
# otherwise O
# harmful O
# chemicals B-BFO
# is O
# of O
# great O
# use O
# not O
# only O
# to O
# honeybees O
# but O
# more O
# widely O
# for O
# people O
# in O
# our O
# efforts O
# to O
# cope B-BFA
# with I-BFA
# both O
# human O
# made O
# and O
# natural B-BFO
# toxins I-BFO
# The O
# natural O
# metabolic B-BFO
# adaptations O
# of O
# other O
# species O
# can O
# suggest O
# enzymatic B-BFO
# compounds I-BFO
# and O
# chemical O
# processes O
# which O
# can O
# help O
# us O
# neutralize B-BFA
# toxins B-BFO
# in O
# our O
# own O
# environment O
# P450 B-BFO
# enzymes I-BFO
# similar O
# to O
# those O
# found O
# in O
# honeybees O
# for O
# example O
# are O
# now O
# used O
# to O
# break B-BFA
# down B-BFA
# a O
# variety O
# of O
# chemicals O
# harmful O
# to O
# people O
# and O
# other O
# species O
# alike O
# including O
# carcinogens B-BFO
# steroids B-BFO
# and O
# pesticides B-BFO
# ##id:18 O
# Mucus O
# Traps B-BFA
# Carbon B-BFO
# From O
# Seawater O
# The O
# tiny O
# oceanic O
# creatures O
# called O
# giant O
# larvaceans O
# are O
# “giant” O
# only O
# in O
# comparison O
# to O
# their O
# relatives O
# New O
# research O
# shows O
# these O
# strange O
# invertebrates O
# have O
# the O
# greatest O
# capacity O
# for O
# filtering B-BFA
# seawater B-BFO
# of O
# any O
# zooplankton O
# and O
# so O
# may O
# play O
# an O
# important O
# role O
# in O
# trapping B-BFA
# carbon B-BFO
# and O
# keeping B-BFA
# it O
# from I-BFA
# reaching B-BFA
# the O
# atmosphere O
# Zooplankton O
# from O
# the O
# Greek O
# for O
# “drifting O
# animals” O
# are O
# generally O
# microscopic O
# waterborne O
# organisms O
# that O
# feed B-BFA
# on O
# phytoplankton B-BFO
# “drifting B-BFO
# plants” I-BFO
# Larvaceans O
# specifically O
# are O
# simple O
# creatures O
# consisting O
# of O
# a O
# head O
# or O
# trunk O
# and O
# tail O
# somewhat O
# resembling B-BFA
# tadpoles B-BFO
# What O
# aren’t O
# simple O
# are O
# their O
# feeding O
# structures––complex O
# filters B-BFA
# called O
# “houses” O
# made O
# of O
# mucus O
# that O
# extend O
# far O
# past O
# the O
# body O
# For O
# most O
# 2 O
# 8mm O
# larvacean O
# species O
# these O
# “houses” O
# can O
# range O
# from O
# 4 O
# to O
# 38 O
# mm O
# up O
# to O
# 1.5 O
# inches O
# in O
# diameter O
# but O
# for O
# the O
# giants O
# of O
# the O
# family O
# like O
# the O
# seen O
# below O
# at O
# 3 O
# to O
# 10 O
# cm O
# 1 O
# to O
# 4 O
# inches O
# the O
# filtering O
# structures O
# can O
# reach O
# a O
# meter O
# 39 O
# inches O
# in O
# width O
# It’s O
# this O
# house O
# structure O
# that O
# enables O
# giant O
# larvaceans O
# to O
# do O
# such O
# an O
# efficient O
# job O
# straining B-BFA
# sea B-BFO
# water I-BFO
# for O
# their O
# tiny O
# food B-BFA
# The O
# wide O
# meshed O
# outer O
# parts O
# of O
# the O
# filter O
# keep B-BFA
# out I-BFA
# anything O
# too O
# big O
# to O
# consume B-BFA
# and O
# a O
# smaller O
# inner O
# filter B-BFO
# funnels O
# food B-BFO
# particles O
# to O
# the O
# mouth O
# via O
# a O
# tube O
# It’s O
# all O
# powered O
# by O
# the O
# constant O
# motion O
# of O
# the O
# animal’s O
# tail O
# directing O
# water B-BFO
# inside O
# and O
# through O
# the O
# house O
# Understanding O
# how O
# giant O
# larvaceans O
# build O
# such O
# efficient O
# filters B-BFO
# and O
# how O
# they O
# do O
# it O
# so O
# quickly O
# is O
# a O
# promising O
# area O
# of O
# study O
# As O
# our O
# understanding O
# of O
# them O
# improves O
# these O
# amazing O
# structures O
# could O
# inspire O
# designs O
# for O
# new O
# filters B-BFO
# and O
# expandable O
# structures O
# perhaps O
# even O
# opening O
# the O
# doors O
# for O
# easier O
# or O
# more O
# sustained O
# deep B-BFO
# water I-BFO
# or O
# space O
# exploration B-BFA
# ##id:2 O
# Honeybees O
# Detoxify B-BFA
# Insecticide B-BFO
# The O
# next O
# time O
# you O
# eat B-BFA
# a O
# fruit B-BFO
# nut B-BFO
# or O
# vegetable B-BFO
# give O
# a O
# thought O
# to O
# how O
# the O
# wondrous O
# food B-BFO
# in O
# your O
# hand O
# or O
# on O
# your O
# plate O
# was O
# grown B-BFA
# Very O
# likely O
# a O
# honeybee O
# was O
# involved B-BFA
# in O
# a O
# vital O
# way O
# Honeybees O
# are O
# important O
# pollinators B-BFA
# for O
# wild O
# plants O
# and O
# human O
# agricultural O
# systems O
# crucial O
# to O
# the O
# pollination O
# of O
# foods B-BFO
# including O
# apples B-BFO
# cherries B-BFO
# blueberries B-BFO
# broccoli B-BFO
# pumpkins B-BFO
# and O
# almonds B-BFO
# Honeybee O
# populations O
# have O
# been O
# declining B-BFA
# however O
# because O
# of O
# a O
# number O
# of O
# threats B-BFA
# including O
# bacterial B-BFO
# and O
# fungal B-BFO
# diseases I-BFO
# and O
# parasitic B-BFO
# mites I-BFO
# Many O
# insecticides B-BFO
# cannot O
# be O
# used B-BFA
# to O
# control B-BFA
# these O
# threats B-BFA
# though O
# because O
# they O
# also O
# kill B-BFO
# the O
# bees O
# Honeybees O
# have O
# important O
# chemical B-BFO
# abilities O
# that O
# can O
# help O
# them O
# deal B-BFA
# with I-BFA
# some O
# of O
# these O
# threats B-BFO
# however O
# For O
# example O
# the O
# insecticide B-BFO
# tau B-BFO
# fuvalinate I-BFO
# a O
# derivative O
# from O
# pyrethrum O
# daisies O
# successfully O
# controls B-BFA
# parasitic B-BFO
# varroa O
# mites O
# without O
# harming O
# the O
# bees O
# themselves O
# That’s O
# because O
# bees O
# have O
# enzymes B-BFO
# ––special O
# molecules B-BFO
# capable O
# of O
# making O
# changes O
# to O
# other O
# molecules––which O
# can O
# detoxify B-BFA
# certain O
# insecticides B-BFO
# The O
# enzymes B-BFO
# known O
# as O
# P450s B-BFO
# short O
# for O
# cytochrome B-BFA
# P450 B-BFO
# monooxygenases I-BFO
# appear O
# to O
# be O
# especially O
# effective O
# at O
# detoxifying B-BFA
# the O
# insecticide B-BFO
# tau B-BFO
# fuvalinate I-BFO
# Researchers O
# draw O
# this O
# kind O
# of O
# conclusion O
# from O
# studies O
# in O
# which O
# chemicals B-BFO
# known O
# to O
# inhibit B-BFA
# P450 B-BFO
# enzymes B-BFO
# e.g O
# piperonyl B-BFO
# butoxide I-BFO
# or O
# PBO B-BFO
# are O
# added O
# to O
# sugar B-BFO
# water I-BFO
# and O
# fed B-BFA
# to O
# bees O
# and O
# the O
# toxic O
# effects O
# of O
# insecticides B-BFO
# like O
# tau O
# fuvalinate––such O
# as O
# a O
# lack O
# of O
# coordination––become O
# more O
# apparent O
# Remove B-BFA
# the O
# PBO B-BFO
# enzyme I-BFO
# inhibitor O
# and O
# the O
# bees O
# are O
# no O
# longer O
# impacted O
# as O
# strongly O
# by O
# tau B-BFO
# fulvalinate I-BFO
# How O
# does O
# it O
# work O
# P450 B-BFO
# enzymes I-BFO
# are O
# known O
# to O
# be O
# capable O
# of O
# stripping B-BFA
# electrons B-BFO
# away I-BFA
# from O
# i.e O
# oxidizing O
# molecular O
# structures O
# known O
# as O
# aromatic B-BFO
# rings I-BFO
# found O
# in O
# natural O
# toxins B-BFO
# as O
# well O
# as O
# pyrethrum O
# derived B-BFA
# insecticides B-BFO
# A O
# similar O
# process O
# occurs O
# when O
# you O
# cut B-BFA
# an O
# apple O
# and O
# it O
# begins O
# to O
# brown B-BFA
# oxygen I-BFA
# in O
# the O
# air O
# removes B-BFA
# electrons B-BFO
# from O
# now O
# exposed B-BFA
# molecules B-BFO
# in O
# the O
# apple’s O
# flesh O
# and O
# you O
# can O
# see O
# the O
# apple’s B-BFO
# molecules I-BFO
# undergo O
# change O
# The O
# formation O
# of O
# rust O
# from O
# metal O
# in O
# moist O
# air O
# is O
# another O
# similar O
# oxidation O
# degradation O
# process O
# Aromatic B-BFO
# rings I-BFO
# are O
# molecules B-BFO
# or O
# parts O
# of O
# molecules B-BFO
# that O
# form O
# circular B-BFO
# chains I-BFO
# of O
# carbon B-BFO
# atoms I-BFO
# with O
# various O
# side O
# groups O
# When O
# these O
# structures O
# are O
# stripped B-BFA
# of O
# electrons B-BFO
# they O
# become O
# unstable O
# and O
# begin O
# to O
# break B-BFA
# down I-BFA
# Tau B-BFO
# fulvalinate I-BFO
# contains O
# an O
# additional O
# aromatic B-BFO
# ring I-BFO
# which O
# may O
# explain O
# why O
# honeybees O
# with O
# their O
# P450 B-BFO
# enzymes I-BFO
# are O
# especially O
# able O
# to O
# detoxify B-BFA
# it O
# The O
# abilities O
# of O
# enzymes B-BFO
# to O
# change O
# and O
# detoxify B-BFA
# otherwise O
# harmful O
# chemicals B-BFO
# is O
# of O
# great O
# use O
# not O
# only O
# to O
# honeybees O
# but O
# more O
# widely O
# for O
# people O
# in O
# our O
# efforts O
# to O
# cope B-BFA
# with I-BFA
# both O
# human O
# made O
# and O
# natural B-BFO
# toxins I-BFO
# The O
# natural O
# metabolic B-BFO
# adaptations O
# of O
# other O
# species O
# can O
# suggest O
# enzymatic B-BFO
# compounds I-BFO
# and O
# chemical O
# processes O
# which O
# can O
# help O
# us O
# neutralize B-BFA
# toxins B-BFO
# in O
# our O
# own O
# environment O
# P450 B-BFO
# enzymes I-BFO
# similar O
# to O
# those O
# found O
# in O
# honeybees O
# for O
# example O
# are O
# now O
# used O
# to O
# break B-BFA
# down B-BFA
# a O
# variety O
# of O
# chemicals O
# harmful O
# to O
# people O
# and O
# other O
# species O
# alike O
# including O
# carcinogens B-BFO
# steroids B-BFO
# and O
# pesticides B-BFO
# label2idx为： {'PAD': 0, 'UNK': 1, 'O': 2, 'B-BFA': 3, 'B-BFO': 4, 'I-BFA': 5, 'I-BFO': 6}
# idx2label为： ['PAD', 'UNK', 'O', 'B-BFA', 'B-BFO', 'I-BFA', 'I-BFO']
# 223
# 185
# 35
# 32
# train_lenth_sentence_list为： [9, 13, 17, 22, 19, 21, 13, 25, 24, 16, 16, 20, 15, 13, 13, 12, 12, 8, 22, 10, 6, 53, 26, 12, 20, 16, 20, 12, 6, 7, 25, 14, 13, 9, 11, 23, 8, 13, 11, 20, 17, 8, 19, 15, 21, 21, 13, 22, 15, 27, 32, 18, 20, 8, 26, 15, 24, 34, 17, 15, 25, 6, 16, 25, 21, 23, 21, 23, 24, 11, 20, 15, 23, 23, 6, 20, 30, 40, 9, 27, 21, 41, 22, 16, 24, 16, 17, 18, 16, 17, 18, 12, 24, 15, 24, 12, 25, 8, 5, 23, 20, 24, 24, 26, 17, 26, 21, 21, 20, 17, 27, 18, 22, 27, 25, 25, 26, 35, 53, 4, 15, 23, 12, 7, 16, 7, 4, 20, 9, 22, 20, 22, 29, 6, 21, 11, 9, 20, 10, 20, 23, 13, 27, 23, 17, 11, 19, 25, 15, 28, 31, 22, 25, 21, 34, 13, 12, 22, 27, 33, 19, 21, 6, 7, 44, 13, 16, 8, 15, 12, 45, 22, 27, 12, 13, 7, 19, 19, 26, 39, 10, 19, 24, 21, 7, 16, 32, 42, 25, 14, 43, 42, 26, 32, 28, 9, 17, 18, 25, 10, 51, 30, 16, 20, 14, 7, 29, 5, 7, 14, 15, 15, 27, 13, 6, 10, 4, 17, 27, 21, 10, 23, 40]

# %%
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

# 调用torch中bert的分词器
tokenizer = BertTokenizer.from_pretrained(os.path.join('.', 'model_bin'))

# 构建数据集
class BertDataset(Dataset):
    def __init__(self, all_text, all_label, label2idx, max_len, tokenizer, is_test=False):
        self.all_text = all_text
        self.all_label = all_label
        self.label2idx = label2idx
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.is_test = is_test

    def __getitem__(self, index):
        if self.is_test:
            self.max_len = len(self.all_label[index])

        # 按批次获得数据
        text = self.all_text[index]
        # 0到max_len的词有对应的label,后面的用padding（转换为数字张量之后就是0了）补充
        label = self.all_label[index][:self.max_len]
        
        # 这里的encode函数要做的事：
        # 对词进行编码，将词转换为在词表中对应的数字
        # 对长度大于max_length的语句进行截断（超出了max_length的直接没有了），对长度不足max_length的语句进行padding填充
        # 添加特殊的标记符
        # 返回tensor类型的张量，即将词进行编码为torch张量
        text_index = self.tokenizer.encode(text,
                                           add_special_tokens=True,
                                           max_length=self.max_len + 2,        # 加上两个左右标识符
                                           padding="max_length",
                                           truncation=True,
                                           return_tensors="pt")        # pt 返回pytorch的张量
        label_index = [0] + [self.label2idx.get(l, 1) for l in label] + [0] + [0] * (max_len - len(text))
        # 将编码后的label转换为torch张量
        label_index = torch.tensor(label_index)
        # 统一text_index和label_index的形状和维度
        return text_index.reshape(-1), label_index, len(label)

    def __len__(self):
        return self.all_text.__len__()
# Out:
# 2023-06-16 17:11:53.722207: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-16 17:11:53.846064: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-16 17:11:54.378904: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-06-16 17:11:54.378954: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-06-16 17:11:54.378960: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF


batch_size = 16
max_len = 70

# 训练+测试

train_dataset = BertDataset(train_text,
                            train_label,
                            label2idx,
                            max_len,
                            tokenizer)
# 在处理好的语料中随机获得batch_size个句子，作为一批语料输入模型，shuffle是否要随机获得语料
train_dataloader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=False)

dev_dataset = BertDataset(dev_text,
                          dev_label,
                          label2idx,
                          max_len,
                          tokenizer)
dev_dataloader = DataLoader(dev_dataset,
                            batch_size=batch_size,
                            shuffle=False)

print("train_dataset的数据类型为： ", type(train_dataset))
# Out:
# train_dataset的数据类型为：  <class '__main__.BertDataset'>

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

# 构建基于Bert_LSTM_CRF的模型
class Bert_LSTM_CRF_NerModel(nn.Module):
    def __init__(self, lstm_hidden, class_num, dropout_rate=0.2):
        super().__init__()

        self.bert = BertModel.from_pretrained(os.path.join('.', 'model_bin'))
        
        # 为了省显存做的，如果不想省可以删掉
        for name, param in self.bert.named_parameters():
            param.requires_grad = False
            
        # bidirectional 调成True的时候，Linear层的lstm_hidden需要乘2
        self.lstm = nn.LSTM(768,
                            lstm_hidden,
                            batch_first=True,
                            num_layers=1,
                            bidirectional=True)
        
        self.dropout = nn.Dropout(dropout_rate)
        
        # 线性分类器
        self.classifier = nn.Linear(lstm_hidden*2, class_num)
        
        # 条件随机场
        self.crf = CRF(class_num, batch_first=True)

    # 前馈层
    def forward(self, batch_index, batch_label=None):
        # 按批次传入数据到bert编码层
        bert_out = self.bert(batch_index)
        # bert_out0 字符级别的特征信息 bert_out1 篇章级别的特征信息
        bert_out0, bert_out1 = bert_out[0], bert_out[1]  
        # 命名实体识别是序列标注任务，因此需要bert_out0，字符级别的特征信息
        lstm_out, _ = self.lstm(bert_out0)
        lstm_out, _ = self.dropout(lstm_out)
        # 调用线性分类器完成预测任务
        pre = self.classifier(lstm_out)
        
        # 传了label数据的时候，就是训练，就要看loss,没传label数据的时候，就直接对分类预测的结果pre进行解码
        if batch_label is not None:
            # loss = self.loss_fun(pre.reshape(-1, pre.shape[-1]),batch_label.reshape(-1))
            loss = -self.crf(pre, batch_label)
            return loss
        else:
            pre = self.crf.decode(pre)
            # return torch.argmax(pre, dim=-1)
            return pre
# Out:
#   Input In [7]
#     def __init__(self, lstm_hidden, class_num， dropout_rate=0.2):
#                                              ^
# SyntaxError: invalid character in identifier

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

epoch = 200
lr = 0.0005
lstm_hidden = 128
# 根据“训练+验证” “测试” “输入” 三种状态选择True或False
do_train = True
do_test = False
do_input = False
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# %%
if do_train:
        # 加载模型，并将模型放到cuda上
        model = Bert_LSTM_CRF_NerModel(lstm_hidden, len(label2idx)).cuda()
        
        # opt是优化器，这里采用Adam的优化方式
        opt = AdamW(model.parameters(), lr)

        best_score = -1
        for e in range(epoch):
            model.train()
            batch_index = 1    # 设置该变量记录当前是训练模型的第几批，每一批都有16个句子，所以总共有12批    
            for batch_text_index, batch_label_index, batch_len in train_dataloader:
                # 按批获得数据，数据放入cuda中
                batch_text_index = batch_text_index.cuda()
                batch_label_index = batch_label_index.cuda()
                # 数据读入读入模型中，获得训练的loss
                loss = model.forward(batch_text_index, batch_label_index)
                loss.backward()
                # opt优化器优化
                opt.step()
                # 梯度归0
                opt.zero_grad()
                
                print("当前的批次为：", batch_index)
                print(f'loss{loss:.2f}')
                batch_index = batch_index + 1
            
            print('-----------------------------------------------')
            print('********  have trained ' + str(e+1) + ' epoch!  ********')
            print('-----------------------------------------------')
            
            # 模型训练结束之后，开始进行测试
            model.eval()
            all_pre = []    # 记录所有的预测label
            all_tag = []    # 记录所有的真实label
            for batch_text_index, batch_label_index, batch_len in dev_dataloader:
                batch_text_index = batch_text_index.cuda()
                batch_label_index = batch_label_index.cuda()
                # 获得模型预测的结果
                pre = model.forward(batch_text_index)
                # 加载真实的label
                tag = batch_label_index.tolist()

                for p, t, l in zip(pre, tag, batch_len):
                    p = p[1:1 + l]
                    t = t[1:1 + l]

                    p = [idx2label[i] for i in p]
                    t = [idx2label[i] for i in t]

                    all_pre.append(p)
                    all_tag.append(t)

                # 获得f1_score
                f1_score = seqeval_f1_score(all_tag, all_pre)
                # 记录最好的f1_score结果，并将得到该结果的模型文件.pt保存下来
                if f1_score > best_score:
                    torch.save(model, 'best_modelBio.pt')
                    best_score = f1_score
                    
                print(f'********  best_score:{best_score}  ********')
                print('-----------------------------------------------')
                print(f'********  f1_score:{f1_score}  ********')
                print('-----------------------------------------------')

# %%
print(best_score)
print(len(all_pre))

# %%
all_pre

# %%
all_tag

# %% [markdown]
# ## 2 使用新的模型预测数据

# %%
# 读取数据
def read_data(file):
    all_token_list = []
    all_label_list = []

    token_list = []
    label_list = []
    with open(file, "r", encoding="utf-8") as f:
        all_data = f.read().split("\n")
    lenth_sentence_list = [] #用于存储句子的长度
    for data in all_data:
        # 但是在我重新处理的语料中，根据句号.来对句子进行划分
        if len(data) > 0:
            if data == ". O":
                # 统计一下大多数的句子的长度，太长或者太短的句子直接丢掉，不要保存在语料列表当中
                if len(token_list) > 0: 
                    lenth_sentence_list.append(len(token_list))
                    all_token_list.append(token_list)
                    all_label_list.append(label_list)
                token_list = []
                label_list = []
            else:
                token, lable = data.split(" ")
                token_list.append(token)
                label_list.append(lable)
    return all_token_list, all_label_list, lenth_sentence_list
dev_text, dev_label, dev_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/original_data/biological/bio_dev_data.txt")
print("最长的句子为：", max(dev_lenth_sentence_list))
print("有多少条句子：", len(dev_lenth_sentence_list))

# %%
import os
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

# 调用torch中bert的分词器
tokenizer = BertTokenizer.from_pretrained(os.path.join('.', 'model_bin'))

# 构建数据集
class BertDataset(Dataset):
    def __init__(self, all_text, all_label, label2idx, max_len, tokenizer, is_test=False):
        self.all_text = all_text
        self.all_label = all_label
        self.label2idx = label2idx
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.is_test = is_test

    def __getitem__(self, index):
        if self.is_test:
            self.max_len = len(self.all_label[index])

        # 按批次获得数据
        text = self.all_text[index]
        # 0到max_len的词有对应的label,后面的用padding（转换为数字张量之后就是0了）补充
        label = self.all_label[index][:self.max_len]
        
        # 这里的encode函数要做的事：
        # 对词进行编码，将词转换为在词表中对应的数字
        # 对长度大于max_length的语句进行截断（超出了max_length的直接没有了），对长度不足max_length的语句进行padding填充
        # 添加特殊的标记符
        # 返回tensor类型的张量，即将词进行编码为torch张量
        text_index = self.tokenizer.encode(text,
                                           add_special_tokens=True,
                                           max_length=self.max_len + 2,        # 加上两个左右标识符
                                           padding="max_length",
                                           truncation=True,
                                           return_tensors="pt")        # pt 返回pytorch的张量
        label_index = [0] + [self.label2idx.get(l, 1) for l in label] + [0] + [0] * (max_len - len(text))
        # 将编码后的label转换为torch张量
        label_index = torch.tensor(label_index)
        # 统一text_index和label_index的形状和维度
        return text_index.reshape(-1), label_index, len(label)

    def __len__(self):
        return self.all_text.__len__()

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF


batch_size = 16
max_len = max(dev_lenth_sentence_list)

dev_dataset = BertDataset(dev_text,
                          dev_label,
                          label2idx,
                          max_len,
                          tokenizer)
dev_dataloader = DataLoader(dev_dataset,
                            batch_size=batch_size,
                            shuffle=False)

print("train_dataset的数据类型为： ", type(train_dataset))

# %%
model.eval()
all_pre = []    # 记录所有的预测label
all_tag = []    # 记录所有的真实label
batch_index = 1
for batch_text_index, batch_label_index, batch_len in dev_dataloader:
    batch_text_index = batch_text_index.cuda()
    batch_label_index = batch_label_index.cuda()
    # 获得模型预测的结果(这里是一个批次的数据)
    pre = model.forward(batch_text_index)
    # 加载真实的label
    tag = batch_label_index.tolist()

    for p, t, l in zip(pre, tag, batch_len):
        p = p[1:1 + l]
        t = t[1:1 + l]

        p = [idx2label[i] for i in p]
        t = [idx2label[i] for i in t]

        all_pre.append(p)
        all_tag.append(t)

    batch_index = batch_index + 1

# %%
print("语料的总批次为：", batch_index)
print("label的总个数为：", len(all_pre))
print("字符的总个数为：", len(dev_text))

# %% [markdown]
# ## 3 将模型预测的结果写入文件

# %%
word2label_list = []
for i in range(len(dev_text)):
    word2label_dic = {}
    for j in range(len(dev_text[i])):
        word2label_dic[dev_text[i][j]] = all_pre[i][j]
    word2label_list.append(word2label_dic)
print("字符-label对的总个数为：", len(word2label_list))

# %%
word2label_list

# %%
with open("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/result_data/biological_data/1.txt", "w", encoding="utf-8") as file:
    for i in range(len(word2label_list)):
        for key, value in word2label_list[i].items():
            file.write(f"{key} {value}\n")
        file.write(". O\n")

# %% [markdown]
# ## 4 将预测的结果转换格式（有预处理的格式转换为一篇文章下属的实体及label的格式）

# %%
def parse_predict_results(file_path):
    """
    Parse results from predicted file.
    """
    with open(file_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
    id2results = {}
    category = ""
    category_set = set()
    for line in lines:
        try:
            category = line.split(' ')[1].split('-')[1].strip()
        except:
            pass
        if category in ('BFA', 'BFO', 'BOR', 'BEN', 'BOP'):
            category_set.add(category)

    cur_id = ""
    extracted_cnt = 0
    category = ""
    for line in lines:
        if line.startswith('##id:'):
            new_id = line[5:].split(" ")[0].strip()
            if cur_id != new_id:
                if extracted_cnt > 0 :
                    id2results[cur_id] = result_dict
                result_dict = {}
                for category in category_set:
                    result_dict[category] = set()
                cur_id = new_id
                extracted_cnt += 1
            label_word = ''

        else:
            label = line.split(' ')[1].strip()
            if line.split(' ')[0].startswith('##'):
                token = line.split(' ')[0][2:]
            else:
                token = line.split(' ')[0]
            if (label == 'O') or (len(label) == 0):
                if len(label_word) != 0:
                    result_dict[category].add(label_word)
                    category = ""
                    label_word = ""
            elif label.startswith('B-'):
                if len(label_word) != 0:
                    result_dict[category].add(label_word)
                    category = ""
                label_word = token
                category = label.split('-')[1].strip()
            elif label.startswith('I-'):
                if len(category) > 0:
                    label_word += " " + token
    id2results[cur_id] = result_dict
    return id2results

# %%
doc_word_dict = parse_predict_results("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/result_data/biological_data/标注后的数据/1.txt")

# %%
doc_word_dict

# %% [markdown]
# ## 5.将最终格式写入csv文件，这里包括了文章和关键词实体，以及文章和关键词实体之间的关系

# %%
import json
with open("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/original_data/biological/id和标题的对应关系.jsonl", "r", encoding="utf-8") as file:
    for line in file:
        id2doc_dict = json.loads(line)
print("文章的篇数为：", len(id2doc_dict))

# 获得 id2doc_dict中的所有键，也就是所有的文章id
id_list = list(id2doc_dict.keys())

with open("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/result_data/biological_data/格式转换后的数据/doc_BEN.csv", "w", encoding="utf-8") as file:
    file.write("文章,BEN,LABEL\n")
    for key, value in doc_word_dict.items():
        id = key
        for i in range(len(id_list)):
            if id == id_list[i][5:]:
                title = id2doc_dict[id_list[i]]    
        try:
            # BEN的实体类别是集合
            BEN_set = value["BEN"]
            for ele in BEN_set:
                file.write(title)
                file.write(",")
                file.write(ele)
                file.write(",")
                file.write("has_BEN")
                file.write("\n")
        except:
            continue
