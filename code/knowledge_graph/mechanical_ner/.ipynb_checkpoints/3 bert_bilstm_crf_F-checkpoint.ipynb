# %% [markdown]
# ## 1 模型构建与训练

# %%
import torch
print(torch.__version__)
# Out:
# 1.9.0+cu111

# %%
import torch
device=torch.device('cuda:0')

# %%
# 读取数据
def read_data(file):
    all_token_list = []
    all_label_list = []

    token_list = []
    label_list = []
    with open(file, "r", encoding="utf-8") as f:
        all_data = f.read().split("\n")
    lenth_sentence_list = [] #用于存储句子的长度
    for data in all_data:
        # 这里进行数据处理时，每一句话结束后都会有一个空行，当判断为空行时，说明结束，这一句话存入列表
        # 但是在我重新处理的语料中，根据句号.来对句子进行划分
        if data == ". O":
            # 统计一下大多数的句子的长度，太长或者太短的句子直接丢掉，不要保存在语料列表当中
            lenth_sentence_list.append(len(token_list))
            if len(token_list) > 10 and len(token_list) < 70:
                all_token_list.append(token_list)
                all_label_list.append(label_list)
            token_list = []
            label_list = []
        else:
            # print(data)
            token, label = data.split(" ")
            token_list.append(token)
            if label == '':
                print(data)
            label_list.append(label)
    return all_token_list, all_label_list, lenth_sentence_list


# 以训练集为例构建标签及标签ID映射关系
def build_label(train_label):
    # PAD用于填充，UNK 出现不认识的label,则给一个UNK的标识
    label2idx = {"PAD": 0, "UNK": 1}
    for label_list in train_label:
        for label in label_list:
            if label not in label2idx:
                label2idx[label] = len(label2idx)
    return label2idx, list(label2idx)

# %%
train_text, train_label, train_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/fineturn_data/mechanical_data/mechine_train.txt")
test_text, test_label, test_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/fineturn_data/mechanical_data/mechine_dev.txt")
dev_text, dev_label, dev_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/fineturn_data/mechanical_data/mechine_dev.txt")

# 定义标签和对应的数字ID
# PAD --> padding
# UNK --> unknown
# labels_list = ['PAD', 'UNK', 'O', 'B-EFA', 'B-EST', 'I-EST', 'B-EFO', 'I-EFO', 'I-EFA', '', 'B-EEF', 'I-EEF']
# FA 功能行为； FO 功能对象； ST 结构； EF 物理技术 

label2idx, idx2label = build_label(train_label)

print("label2idx为：", label2idx)
print("idx2label为：", idx2label)
print(len(train_lenth_sentence_list))    # 原本有525句子
print(len(train_text))       # 符合长度要求的只有254句子
print(len(dev_lenth_sentence_list))    # 原本有525句子
print(len(dev_text))       # 符合长度要求的只有254句子
print("train_lenth_sentence_list为：", train_lenth_sentence_list)
# Out:
# ##id:205 O
# These O
# operations O
# have O
# high O
# energy O
# needs O
# that O
# significantly O
# limit O
# the O
# endurance O
# of O
# the O
# activation O
# system O
# and O
# therefore O
# the O
# inflatable B-EFO
# safety I-EFO
# vest I-EFO
# and O
# require O
# frequent O
# recharging O
# that O
# immobilises O
# the O
# vest O
# ##id:911 O
# One O
# of O
# the O
# main O
# problems O
# encountered O
# during O
# the O
# development O
# of O
# these O
# active O
# protections O
# is O
# the O
# development O
# of O
# systems O
# for O
# activation O
# of O
# deployment O
# of O
# said O
# inflatable B-EFO
# safety I-EFO
# vest I-EFO
# ##id:668 O
# The O
# upper B-EST
# part I-EST
# of O
# the O
# aforementioned O
# first B-EST
# opening I-EST
# 21 O
# is O
# provided O
# with O
# a O
# housing B-EST
# 22 O
# which O
# is O
# equipped O
# on O
# the O
# base B-EST
# and O
# connected O
# to O
# the O
# case B-EST
# 2 O
# and O
# into O
# which O
# at O
# least O
# the O
# upper B-EST
# part I-EST
# 31 O
# of O
# the O
# box B-EST
# 3 O
# can O
# be O
# inserted O
# so O
# that O
# it O
# is O
# hermetically O
# connected O
# to O
# the O
# case B-EST
# 2 O
# ##id:954 O
# wherein O
# the O
# microcontroller B-EST
# module I-EST
# is O
# a O
# multi B-EST
# core I-EST
# or I-EST
# a I-EST
# single I-EST
# core I-EST
# processor I-EST
# and O
# is O
# configured O
# to O
# be O
# operated O
# in O
# sequential O
# processing O
# ##id:361 O
# wherein O
# the O
# case B-EST
# is O
# fixed O
# to O
# a O
# dorsal B-EST
# protection I-EST
# made O
# of O
# an O
# absorbent O
# material O
# arranged O
# to O
# be O
# fixed O
# on O
# said O
# inflatable B-EFO
# safety I-EFO
# vest I-EFO
# behind O
# the O
# lumbar O
# vertebrae O
# of O
# a O
# skier O
# when O
# the O
# skier O
# is O
# wearing O
# said O
# safety O
# vest O
# ##id:746 O
# a O
# system O
# is O
# disclosed O
# for O
# activating B-EFA
# the O
# deployment O
# of O
# an O
# inflatable B-EFO
# safety I-EFO
# vest I-EFO
# ##id:316 O
# the O
# connection O
# means O
# of O
# the O
# case O
# 2 O
# remain O
# protected O
# ##id:419 O
# wherein O
# every O
# single O
# AC O
# heating O
# pulse O
# signal O
# requires O
# the O
# execution O
# of O
# distinct O
# code O
# steps O
# by O
# the O
# microcontroller B-EST
# module I-EST
# ##id:406 O
# System O
# and O
# method O
# for O
# controlling B-EFA
# a O
# temperature B-EFO
# The O
# present O
# invention O
# relates O
# to O
# a O
# system B-EST
# 100 O
# for O
# controlling B-EFA
# a O
# temperature B-EFO
# ##id:972 O
# wherein O
# the O
# microcontroller B-EST
# module I-EST
# is O
# configured O
# to O
# calculate B-EFA
# an O
# amount O
# of O
# requested B-EFO
# thermal I-EFO
# energy I-EFO
# based O
# on O
# the O
# temperature O
# comparison O
# ##id:599 O
# wherein O
# the O
# biosensor B-EST
# includes O
# a O
# photoplethysmogram B-EST
# PPG I-EST
# sensor I-EST
# ##id:220 O
# Therefore O
# according O
# to O
# the O
# first O
# purpose O
# of O
# the O
# invention O
# ##id:1004 O
# for O
# absorbing B-EFA
# electromagnetic B-EFO
# radiation I-EFO
# ##id:533 O
# 30 O
# which O
# is O
# coupled O
# to O
# the O
# microcontroller B-EST
# module I-EST
# 20 O
# and O
# which O
# is O
# configured O
# to O
# transform O
# the O
# generated B-EFA
# AC B-EFO
# heating I-EFO
# pulse I-EFO
# signals I-EFO
# into O
# transformed O
# AC O
# heating O
# pulse O
# signals O
# using O
# a O
# transfer O
# function O
# which O
# is O
# substantially O
# zero O
# for O
# DC O
# signal O
# components O
# ##id:620 O
# a O
# movable B-EST
# sheave I-EST
# movable O
# along O
# the O
# axis O
# line O
# and O
# non O
# rotatable O
# around O
# the O
# axis O
# line O
# a O
# parallelepiped O
# is O
# nevertheless O
# made O
# asymmetric O
# in O
# its O
# top O
# part O
# 31 O
# ##id:650 O
# and O
# a O
# first B-EST
# personal I-EST
# area I-EST
# network I-EST
# transceiver I-EST
# ##id:854 O
# said O
# box O
# comprising O
# at O
# least O
# an O
# electronic B-EST
# card I-EST
# ##id:1049 O
# The O
# tattoo B-EST
# machine I-EST
# camera I-EST
# assembly O
# of O
# claim O
# ##id:989 O
# to O
# which O
# the O
# temperature B-EST
# sensor I-EST
# module I-EST
# is O
# coupled O
# to O
# ##id:941 O
# which O
# is O
# configured O
# to O
# measure B-EFA
# a O
# temperature B-EFO
# value I-EFO
# of I-EFO
# the I-EFO
# skin I-EFO
# to O
# be O
# heated O
# ##id:225 O
# the O
# upper B-EST
# part I-EST
# of O
# said O
# first B-EST
# opening I-EST
# being O
# provided O
# with O
# a O
# housing B-EST
# on O
# the O
# bottom O
# of O
# which O
# there O
# are O
# means O
# for O
# connecting O
# the O
# case B-EST
# and O
# into O
# which O
# at O
# least O
# the O
# upper B-EST
# part I-EST
# of O
# the O
# box B-EST
# can O
# be O
# inserted O
# so O
# that O
# it O
# is O
# hermetically O
# connected O
# to O
# said O
# case B-EST
# ##id:957 O
# wherein O
# the O
# coupling B-EST
# module I-EST
# is O
# configured O
# to O
# attenuate O
# the O
# DC O
# signal O
# components O
# to O
# a O
# value O
# of O
# less O
# than O
# 4 O
# of O
# an O
# input O
# DC O
# signal O
# component O
# ##id:80 O
# and O
# the O
# control B-EST
# unit I-EST
# are O
# mounted O
# on O
# a O
# removable B-EST
# steering I-EST
# wheel I-EST
# cover O
# that O
# is O
# mounted O
# on O
# a O
# steering B-EST
# wheel I-EST
# of O
# the O
# motor B-EST
# vehicle I-EST
# ##id:11 O
# which O
# is O
# coupled O
# to O
# the O
# coupling B-EST
# module I-EST
# and O
# which O
# is O
# configured O
# to O
# generate O
# heat O
# according O
# to O
# the O
# transformed O
# AC O
# heating O
# pulse O
# signals O
# in O
# the O
# form O
# of O
# heating O
# pulses O
# of O
# a O
# time O
# interval O
# between O
# 1 O
# μs O
# and O
# 500 O
# ms O
# ##id:159 O
# wherein O
# the O
# first B-EST
# opening I-EST
# comprises O
# support O
# rails O
# on O
# each O
# side O
# of O
# the O
# first B-EST
# opening I-EST
# ##id:393 O
# must O
# measure O
# the O
# user O
# s O
# movements O
# in O
# real O
# time O
# using O
# an O
# algorithm O
# and O
# decide O
# to O
# activate O
# deployment O
# of O
# the O
# safety O
# vest O
# under O
# identified O
# situations O
# ##id:1043 O
# a O
# camera O
# mount O
# coupled O
# to O
# the O
# tattoo B-EST
# machine I-EST
# frame O
# ##id:738 O
# taking O
# account O
# of O
# severe O
# usage O
# conditions O
# ##id:767 O
# with O
# reference O
# to O
# the O
# drawings O
# in O
# which O
# FIGS O
# ##id:558 O
# and O
# at O
# least O
# one O
# computer B-EST
# readable O
# memory B-EST
# of O
# the O
# computer O
# system O
# in O
# communication O
# with O
# the O
# set O
# of O
# processors B-EST
# and O
# having O
# stored O
# thereon O
# i O
# a O
# model O
# of O
# a O
# luminal O
# network O
# of O
# a O
# patient O
# ##id:652 O
# Devices O
# can O
# be O
# integrated O
# into O
# items O
# of O
# jewelry B-EST
# ##id:696 O
# The O
# displacement O
# activation O
# system O
# according O
# to O
# claim O
# 1 O
# ##id
# module I-EST
# is O
# a O
# capacitor B-EST
# or O
# an O
# inductor B-EST
# or O
# a O
# transformer B-EST
# ##id:291 O
# The O
# box B-EST
# 3 O
# comprises O
# an O
# electronic B-EST
# card I-EST
# ##id:194 O
# This O
# type O
# of O
# protection O
# is O
# conventionally O
# composed O
# of O
# a O
# very O
# compact O
# inflatable B-EST
# vest I-EST
# that O
# can O
# very O
# quickly O
# be O
# inflated O
# by O
# a O
# gas O
# as O
# a O
# skier O
# is O
# falling O
# ##id:103 O
# in O
# cooperation O
# with O
# the O
# fixed B-EST
# sheave I-EST
# side I-EST
# engagement I-EST
# surface O
# ##id:517 O
# a O
# tattoo B-EST
# machine I-EST
# frame O
# ##id:155 O
# The O
# displacement O
# activation O
# system O
# according O
# to O
# claim O
# 2 O
# ##id:487 O
# placing B-EFA
# an O
# emitting B-EFO
# element I-EFO
# configured O
# for O
# at O
# least O
# one O
# of O
# emitting B-EFA
# or I-EFA
# capturing I-EFA
# EM B-EFO
# radiation I-EFO
# ##id:243 O
# 1 O
# to
# to
# 3 O
# are O
# partial O
# perspective O
# views O
# showing O
# different O
# steps O
# in O
# the O
# assembly O
# of O
# two O
# main O
# elements O
# forming O
# the O
# activation O
# system O
# for O
# deployment O
# of O
# an O
# inflatable B-EFO
# safety I-EFO
# vest I-EFO
# for O
# a O
# skier O
# according O
# to O
# the O
# invention O
# ##id:821 O
# Said O
# electronic O
# board O
# also O
# comprises O
# connection O
# means O
# and O
# wireless O
# communication O
# means O
# ##id:462 O
# The O
# system O
# according O
# to O
# claim O
# 1 O
# ##id:274 O
# At O
# the O
# bottom O
# of O
# the O
# housing B-EST
# 22 O
# ##id:453 O
# The O
# system O
# according O
# to O
# claim O
# 1 O
# ##id:929 O
# the O
# skier O
# can O
# carry O
# several O
# boxes O
# and O
# replace O
# then O
# when O
# the O
# energy B-EST
# storage I-EST
# device I-EST
# of O
# the O
# box O
# connected O
# inside O
# the O
# case B-EST
# 2 O
# is O
# discharged O
# ##id:149 O
# an O
# upper B-EST
# part I-EST
# of O
# said O
# first B-EST
# opening I-EST
# being O
# provided O
# with O
# a O
# housing B-EST
# within O
# which O
# is O
# disposed O
# a O
# case B-EST
# connection I-EST
# mechanism I-EST
# for O
# connecting O
# the O
# case B-EST
# and O
# the O
# box B-EST
# ##id:88 O
# wherein O
# the O
# movable B-EST
# sleeve I-EST
# includes O
# a O
# tubular O
# portion O
# inserted O
# around O
# the O
# axis O
# line O
# direction O
# fixed O
# member O
# and O
# a O
# flange B-EST
# portion I-EST
# extending O
# outward O
# in O
# a O
# radial O
# direction O
# from O
# the O
# tubular B-EST
# portion I-EST
# ##id:283 O
# According O
# to O
# one O
# preferred O
# embodiment O
# ##id:158 O
# The O
# displacement O
# activation O
# system O
# according O
# to O
# claim O
# 1 O
# ##id:163 O
# wherein O
# the O
# box B-EST
# comprises O
# attachment B-EST
# elements I-EST
# designed O
# to O
# cooperate O
# with O
# and O
# to O
# be O
# inserted O
# in O
# the O
# support B-EST
# rails I-EST
# of O
# the O
# case B-EST
# ##id:411 O
# a O
# coupling O
# module O
# 30 O
# which O
# is O
# coupled O
# to O
# the O
# microcontroller B-EST
# module I-EST
# 20 O
# and O
# which O
# is O
# configured O
# to O
# transform B-EFA
# the O
# generated B-EFO
# AC I-EFO
# heating I-EFO
# pulse I-EFO
# signals I-EFO
# the O
# bottom O
# part O
# of O
# the O
# first B-EST
# opening I-EST
# and O
# locking O
# said O
# box O
# in O
# the O
# inserted O
# position O
# ##id:1038 O
# The O
# tattoo B-EST
# machine I-EST
# camera I-EST
# assembly O
# may O
# be O
# formed O
# so O
# that O
# the O
# camera B-EST
# is O
# resistant O
# to O
# vibration O
# created O
# by O
# the O
# operation O
# of O
# the O
# tattoo B-EST
# machine I-EST
# ##id:282 O
# without O
# going O
# outside O
# the O
# framework O
# of O
# the O
# invention O
# ##id:589 O
# transferring B-EFA
# the O
# imaging B-EFO
# data I-EFO
# to I-EFO
# a I-EFO
# central I-EFO
# processing I-EFO
# unit I-EFO
# wherein O
# the O
# central B-EST
# processing I-EST
# unit I-EST
# obtains O
# measurements O
# associated O
# with O
# selected O
# points O
# in O
# the O
# mouth O
# of O
# the O
# patient O
# and O
# predicts O
# future O
# orthodontic O
# conditions O
# of O
# the O
# patient O
# based O
# upon O
# the O
# measurements O
# ##id:773 O
# comprising O
# a O
# case O
# 2 O
# fixed O
# to O
# said O
# inflatable B-EFO
# vest I-EFO
# and O
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 train_text, train_label, train_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/fineturn_data/mechanical_data/mechine_train.txt")
# ----> 2 test_text, test_label, test_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/fineturn_data/mechanical_data/mechine_dev.txt")
#       3 dev_text, dev_label, dev_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/fineturn_data/mechanical_data/mechine_dev.txt")
#       5 # 定义标签和对应的数字ID
#       6 # PAD --> padding
#       7 # UNK --> unknown
#       8 # labels_list = ['PAD', 'UNK', 'O', 'B-EFA', 'B-EST', 'I-EST', 'B-EFO', 'I-EFO', 'I-EFA', '', 'B-EEF', 'I-EEF']
#       9 # FA 功能行为； FO 功能对象； ST 结构； EF 物理技术
#
# Input In [3], in read_data(file)
#      22 else:
#      23     print(data)
# ---> 24     token, label = data.split(" ")
#      25     token_list.append(token)
#      26     if label == '':
#
# ValueError: too many values to unpack (expected 2)

# %%
import os
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

# 调用torch中bert的分词器
tokenizer = BertTokenizer.from_pretrained(os.path.join('.', 'model_bin'))

# 构建数据集
class BertDataset(Dataset):
    def __init__(self, all_text, all_label, label2idx, max_len, tokenizer, is_test=False):
        self.all_text = all_text
        self.all_label = all_label
        self.label2idx = label2idx
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.is_test = is_test

    def __getitem__(self, index):
        if self.is_test:
            self.max_len = len(self.all_label[index])

        # 按批次获得数据
        text = self.all_text[index]
        # 0到max_len的词有对应的label,后面的用padding（转换为数字张量之后就是0了）补充
        label = self.all_label[index][:self.max_len]
        
        # 这里的encode函数要做的事：
        # 对词进行编码，将词转换为在词表中对应的数字
        # 对长度大于max_length的语句进行截断（超出了max_length的直接没有了），对长度不足max_length的语句进行padding填充
        # 添加特殊的标记符
        # 返回tensor类型的张量，即将词进行编码为torch张量
        text_index = self.tokenizer.encode(text,
                                           add_special_tokens=True,
                                           max_length=self.max_len + 2,        # 加上两个左右标识符
                                           padding="max_length",
                                           truncation=True,
                                           return_tensors="pt")        # pt 返回pytorch的张量
        label_index = [0] + [self.label2idx.get(l, 1) for l in label] + [0] + [0] * (max_len - len(text))
        # 将编码后的label转换为torch张量
        label_index = torch.tensor(label_index)
        # 统一text_index和label_index的形状和维度
        return text_index.reshape(-1), label_index, len(label)

    def __len__(self):
        return self.all_text.__len__()

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF


batch_size = 16
max_len = 70

# 训练+测试

train_dataset = BertDataset(train_text,
                            train_label,
                            label2idx,
                            max_len,
                            tokenizer)
# 在处理好的语料中随机获得batch_size个句子，作为一批语料输入模型，shuffle是否要随机获得语料
train_dataloader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=False)

dev_dataset = BertDataset(dev_text,
                          dev_label,
                          label2idx,
                          max_len,
                          tokenizer)
dev_dataloader = DataLoader(dev_dataset,
                            batch_size=batch_size,
                            shuffle=False)

print("train_dataset的数据类型为： ", type(train_dataset))

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

# 构建基于Bert_LSTM_CRF的模型
class Bert_LSTM_CRF_NerModel(nn.Module):
    def __init__(self, lstm_hidden, class_num):
        super().__init__()

        self.bert = BertModel.from_pretrained(os.path.join('.', 'model_bin'))
        
        # 为了省显存做的，如果不想省可以删掉
        for name, param in self.bert.named_parameters():
            param.requires_grad = False
            
        # bidirectional 调成True的时候，Linear层的lstm_hidden需要乘2
        self.lstm = nn.LSTM(768,
                            lstm_hidden,
                            batch_first=True,
                            num_layers=1,
                            bidirectional=True)
        # 线性分类器
        self.classifier = nn.Linear(lstm_hidden*2, class_num)
        
        # 条件随机场
        self.crf = CRF(class_num, batch_first=True)

    # 前馈层
    def forward(self, batch_index, batch_label=None):
        # 按批次传入数据到bert编码层
        bert_out = self.bert(batch_index)
        # bert_out0 字符级别的特征信息 bert_out1 篇章级别的特征信息
        bert_out0, bert_out1 = bert_out[0], bert_out[1]  
        # 命名实体识别是序列标注任务，因此需要bert_out0，字符级别的特征信息
        lstm_out, _ = self.lstm(bert_out0)
        # 调用线性分类器完成预测任务
        pre = self.classifier(lstm_out)
        
        # 传了label数据的时候，就是训练，就要看loss,没传label数据的时候，就直接对分类预测的结果pre进行解码
        if batch_label is not None:
            # loss = self.loss_fun(pre.reshape(-1, pre.shape[-1]),batch_label.reshape(-1))
            loss = -self.crf(pre, batch_label)
            return loss
        else:
            pre = self.crf.decode(pre)
            # return torch.argmax(pre, dim=-1)
            return pre

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

epoch = 200
lr = 0.0005
lstm_hidden = 128
# 根据“训练+验证” “测试” “输入” 三种状态选择True或False
do_train = True
do_test = False
do_input = False
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# %%
if do_train:
        # 加载模型，并将模型放到cuda上
        model = Bert_LSTM_CRF_NerModel(lstm_hidden, len(label2idx)).cuda()
        
        # opt是优化器，这里采用Adam的优化方式
        opt = AdamW(model.parameters(), lr)

        best_score = -1
        for e in range(epoch):
            model.train()
            batch_index = 1    # 设置该变量记录当前是训练模型的第几批，每一批都有16个句子，所以总共有12批    
            for batch_text_index, batch_label_index, batch_len in train_dataloader:
                # 按批获得数据，数据放入cuda中
                batch_text_index = batch_text_index.cuda()
                batch_label_index = batch_label_index.cuda()
                # 数据读入读入模型中，获得训练的loss
                loss = model.forward(batch_text_index, batch_label_index)
                loss.backward()
                # opt优化器优化
                opt.step()
                # 梯度归0
                opt.zero_grad()
                
                print("当前的批次为：", batch_index)
                print(f'loss{loss:.2f}')
                batch_index = batch_index + 1
            
            print('-----------------------------------------------')
            print('********  have trained ' + str(e+1) + ' epoch!  ********')
            print('-----------------------------------------------')
            
            # 模型训练结束之后，开始进行测试
            model.eval()
            all_pre = []    # 记录所有的预测label
            all_tag = []    # 记录所有的真实label
            for batch_text_index, batch_label_index, batch_len in dev_dataloader:
                batch_text_index = batch_text_index.cuda()
                batch_label_index = batch_label_index.cuda()
                # 获得模型预测的结果
                pre = model.forward(batch_text_index)
                # 加载真实的label
                tag = batch_label_index.tolist()

                for p, t, l in zip(pre, tag, batch_len):
                    p = p[1:1 + l]
                    t = t[1:1 + l]

                    p = [idx2label[i] for i in p]
                    t = [idx2label[i] for i in t]

                    all_pre.append(p)
                    all_tag.append(t)
                print(len(all_pre[0]))
                print(len(all_tag[0]))
                # 获得f1_score
                f1_score = seqeval_f1_score(all_tag, all_pre)
                # 记录最好的f1_score结果，并将得到该结果的模型文件.pt保存下来
                if f1_score > best_score:
                    torch.save(model, 'best_modelEng.pt')
                    best_score = f1_score
                    
                print(f'********  best_score:{best_score}  ********')
                print('-----------------------------------------------')
                print(f'********  f1_score:{f1_score}  ********')
                print('-----------------------------------------------')

# %%
print(best_score)
print(len(all_pre))

# %%
print(all_pre)
print(all_tag)

# %% [markdown]
# ## 2 使用训练后的模型预测数据

# %%
# 读取数据
def read_data(file):
    all_token_list = []
    all_label_list = []

    token_list = []
    label_list = []
    with open(file, "r", encoding="utf-8") as f:
        all_data = f.read().split("\n")
    lenth_sentence_list = [] #用于存储句子的长度
    for data in all_data:
        # 但是在我重新处理的语料中，根据句号.来对句子进行划分
        if len(data) > 0:
            if data == ". O":
                # 统计一下大多数的句子的长度，太长或者太短的句子直接丢掉，不要保存在语料列表当中
                if len(token_list) > 0 and len(token_list) < 500: 
                    lenth_sentence_list.append(len(token_list))
                    all_token_list.append(token_list)
                    all_label_list.append(label_list)
                token_list = []
                label_list = []
            else:
                # print(data)
                token, lable = data.split(" ")
                token_list.append(token)
                label_list.append(lable)
    return all_token_list, all_label_list, lenth_sentence_list
dev_text, dev_label, dev_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/original_data/machine/machine_data1/patent_1_dev.txt")
print("最长的句子为：", max(dev_lenth_sentence_list))
print("有多少条句子：", len(dev_lenth_sentence_list))

# %%
import os
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

# 调用torch中bert的分词器
tokenizer = BertTokenizer.from_pretrained(os.path.join('.', 'model_bin'))

# 构建数据集
class BertDataset(Dataset):
    def __init__(self, all_text, all_label, label2idx, max_len, tokenizer, is_test=False):
        self.all_text = all_text
        self.all_label = all_label
        self.label2idx = label2idx
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.is_test = is_test

    def __getitem__(self, index):
        if self.is_test:
            self.max_len = len(self.all_label[index])

        # 按批次获得数据
        text = self.all_text[index]
        # 0到max_len的词有对应的label,后面的用padding（转换为数字张量之后就是0了）补充
        label = self.all_label[index][:self.max_len]
        
        # 这里的encode函数要做的事：
        # 对词进行编码，将词转换为在词表中对应的数字
        # 对长度大于max_length的语句进行截断（超出了max_length的直接没有了），对长度不足max_length的语句进行padding填充
        # 添加特殊的标记符
        # 返回tensor类型的张量，即将词进行编码为torch张量
        text_index = self.tokenizer.encode(text,
                                           add_special_tokens=True,
                                           max_length=self.max_len + 2,        # 加上两个左右标识符
                                           padding="max_length",
                                           truncation=True,
                                           return_tensors="pt")        # pt 返回pytorch的张量
        label_index = [0] + [self.label2idx.get(l, 1) for l in label] + [0] + [0] * (max_len - len(text))
        # 将编码后的label转换为torch张量
        label_index = torch.tensor(label_index)
        # 统一text_index和label_index的形状和维度
        return text_index.reshape(-1), label_index, len(label)

    def __len__(self):
        return self.all_text.__len__()

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF


batch_size = 16
max_len = max(dev_lenth_sentence_list)

dev_dataset = BertDataset(dev_text,
                          dev_label,
                          label2idx,
                          max_len,
                          tokenizer)
dev_dataloader = DataLoader(dev_dataset,
                            batch_size=batch_size,
                            shuffle=False)

print("train_dataset的数据类型为： ", type(train_dataset))

# %%
model.eval()
all_pre = []    # 记录所有的预测label
all_tag = []    # 记录所有的真实label
batch_index = 1
for batch_text_index, batch_label_index, batch_len in dev_dataloader:
    batch_text_index = batch_text_index.cuda()
    batch_label_index = batch_label_index.cuda()
    # 获得模型预测的结果(这里是一个批次的数据)
    pre = model.forward(batch_text_index)
    # 加载真实的label
    tag = batch_label_index.tolist()

    for p, t, l in zip(pre, tag, batch_len):
        p = p[1:1 + l]
        t = t[1:1 + l]

        p = [idx2label[i] for i in p]
        t = [idx2label[i] for i in t]

        all_pre.append(p)
        all_tag.append(t)

    batch_index = batch_index + 1

# %%
print("语料的总批次为：", batch_index)
print("label的总个数为：", len(all_pre))
print("字符的总个数为：", len(dev_text))

# %% [markdown]
# ## 3 将预测的结果转换格式并写入文件（有预处理的格式转换为一篇文章下属的实体及label的格式）

# %%
word2label_list = []
for i in range(len(dev_text)):
    word2label_dic = {}
    for j in range(len(dev_text[i])):
        word2label_dic[dev_text[i][j]] = all_pre[i][j]
    word2label_list.append(word2label_dic)
print("字符-label对的总个数为：", len(word2label_list))

# %%
word2label_list

# %%
with open("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/result_data/mechanical_data/patent_data1//标注后的数据/1.txt", "w", encoding="utf-8") as file:
    for i in range(len(word2label_list)):
        for key, value in word2label_list[i].items():
            file.write(f"{key} {value}\n")
        file.write(". O\n")

# %% [markdown]
# ## 4 将预测的结果转换格式（有预处理的格式转换为一篇文章下属的实体及label的格式）

# %%
def parse_predict_results(file_path):
    """
    Parse results from predicted file.
    """
    with open(file_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
    id2results = {}
    category = ""
    category_set = set()
    for line in lines:
        try:
            category = line.split(' ')[1].split('-')[1].strip()
        except:
            pass
        if category in ('EFA', 'EFO', 'EST', 'EEF'):
            category_set.add(category)

    cur_id = ""
    extracted_cnt = 0
    category = ""
    for line in lines:
        if line.startswith('##id:'):
            new_id = line[5:].split(" ")[0].strip()
            if cur_id != new_id:
                if extracted_cnt > 0 :
                    id2results[cur_id] = result_dict
                result_dict = {}
                for category in category_set:
                    result_dict[category] = set()
                cur_id = new_id
                extracted_cnt += 1
            label_word = ''

        else:
            label = line.split(' ')[1].strip()
            if line.split(' ')[0].startswith('##'):
                token = line.split(' ')[0][2:]
            else:
                token = line.split(' ')[0]
            if (label == 'O') or (len(label) == 0):
                if len(label_word) != 0:
                    result_dict[category].add(label_word)
                    category = ""
                    label_word = ""
            elif label.startswith('B-'):
                if len(label_word) != 0:
                    result_dict[category].add(label_word)
                    category = ""
                label_word = token
                category = label.split('-')[1].strip()
            elif label.startswith('I-'):
                if len(category) > 0:
                    label_word += " " + token
    id2results[cur_id] = result_dict
    return id2results

# %%
doc_word_dict = parse_predict_results("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/result_data/mechanical_data/patent_data1//标注后的数据/1.txt")

# %%
doc_word_dict

# %% [markdown]
# ## 5.将最终格式写入csv文件，这里包括了文章和关键词实体，以及文章和关键词实体之间的关系

# %%
import json
with open("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/original_data/machine/id和标题的对应关系.jsonl", "r", encoding="utf-8") as file:
    for line in file:
        id2doc_dict = json.loads(line)
print("文章的篇数为：", len(id2doc_dict))

# 获得 id2doc_dict中的所有键，也就是所有的文章id
id_list = list(id2doc_dict.keys())

with open("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/datas/result_data/mechanical_data/patent_data1//格式转换后的数据/1.txt", "w", encoding="utf-8") as file:
    file.write("文章,BEN,LABEL\n")
    for key, value in doc_word_dict.items():
        id = key
        for i in range(len(id_list)):
            if id == id_list[i][5:]:
                title = id2doc_dict[id_list[i]]
                print(title)
        try:
            # BEN的实体类别是集合
            BEN_set = value["EFA"]
            for ele in BEN_set:
                file.write(title)
                file.write(",")
                file.write(ele)
                file.write(",")
                file.write("has_EFA")
                file.write("\n")
        except:
            continue
