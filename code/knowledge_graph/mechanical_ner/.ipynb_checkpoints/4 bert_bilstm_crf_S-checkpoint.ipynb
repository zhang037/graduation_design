# %% [markdown]
# ## 1 模型构建与训练

# %%
import torch
print(torch.__version__)
# Out:
# 1.9.0+cu111

# %%
import torch
device=torch.device('cuda:0')

# %%
# 读取数据
def read_data(file):
    all_token_list = []
    all_label_list = []

    token_list = []
    label_list = []
    with open(file, "r", encoding="utf-8") as f:
        all_data = f.read().split("\n")
    lenth_sentence_list = [] #用于存储句子的长度
    for data in all_data:
        # 这里进行数据处理时，每一句话结束后都会有一个空行，当判断为空行时，说明结束，这一句话存入列表
        # 但是在我重新处理的语料中，根据句号.来对句子进行划分
        if data == ". O":
            # 统计一下大多数的句子的长度，太长或者太短的句子直接丢掉，不要保存在语料列表当中
            lenth_sentence_list.append(len(token_list))
            if len(token_list) > 10 and len(token_list) < 70:
                all_token_list.append(token_list)
                all_label_list.append(label_list)
            token_list = []
            label_list = []
        else:
            # print(data)
            token, label = data.split(" ")
            token_list.append(token)
            if label == '':
                print(token_list)
            label_list.append(label)
    return all_token_list, all_label_list, lenth_sentence_list


# 以训练集为例构建标签及标签ID映射关系
def build_label(train_label):
    # PAD用于填充，UNK 出现不认识的label,则给一个UNK的标识
    label2idx = {"PAD": 0, "UNK": 1}
    for label_list in train_label:
        for label in label_list:
            if label not in label2idx:
                label2idx[label] = len(label2idx)
    return label2idx, list(label2idx)

# %%
train_text, train_label, train_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/mechanical_ner/data/fineturn_data/mechine_train.txt")
test_text, test_label, test_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/mechanical_ner/data/fineturn_data/mechine_dev.txt")
dev_text, dev_label, dev_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/mechanical_ner/data/fineturn_data/mechine_dev.txt")

# 定义标签和对应的数字ID
# PAD --> padding
# UNK --> unknown
# labels_list = ['PAD', 'UNK', 'O', 'B-EFA', 'B-EST', 'I-EST', 'B-EFO', 'I-EFO', 'I-EFA', '', 'B-EEF', 'I-EEF']
# FA 功能行为； FO 功能对象； ST 结构； EF 物理技术 

label2idx, idx2label = build_label(train_label)

print("label2idx为：", label2idx)
print("idx2label为：", idx2label)
print(len(train_lenth_sentence_list))    # 原本有525句子
print(len(train_text))       # 符合长度要求的只有254句子
print(len(dev_lenth_sentence_list))    # 原本有525句子
print(len(dev_text))       # 符合长度要求的只有254句子
print("train_lenth_sentence_list为：", train_lenth_sentence_list)
# Out:
# label2idx为： {'PAD': 0, 'UNK': 1, 'O': 2, 'B-EFO': 3, 'I-EFO': 4, 'B-EFA': 5, 'B-EST': 6, 'I-EST': 7, 'I-EFA': 8}
# idx2label为： ['PAD', 'UNK', 'O', 'B-EFO', 'I-EFO', 'B-EFA', 'B-EST', 'I-EST', 'I-EFA']
# 607
# 408
# 151
# 111
# train_lenth_sentence_list为： [30, 28, 20, 22, 25, 4, 9, 31, 25, 7, 43, 19, 31, 29, 10, 14, 14, 7, 14, 9, 26, 9, 23, 20, 38, 4, 11, 24, 19, 7, 23, 35, 35, 20, 5, 39, 36, 9, 7, 9, 46, 25, 10, 9, 37, 10, 5, 8, 53, 18, 28, 31, 40, 26, 29, 10, 33, 25, 12, 27, 14, 21, 19, 20, 51, 7, 15, 26, 15, 17, 24, 8, 19, 9, 10, 22, 15, 12, 23, 9, 9, 9, 10, 10, 40, 21, 28, 8, 17, 25, 29, 15, 71, 28, 15, 14, 38, 28, 32, 54, 23, 39, 14, 10, 19, 20, 20, 9, 10, 5, 40, 22, 10, 24, 8, 8, 29, 9, 17, 10, 28, 29, 7, 8, 23, 14, 23, 21, 20, 21, 30, 29, 13, 10, 10, 13, 23, 8, 28, 31, 24, 40, 19, 11, 9, 9, 35, 14, 8, 39, 29, 8, 21, 20, 13, 23, 7, 24, 21, 8, 9, 18, 15, 48, 26, 24, 39, 15, 25, 10, 7, 9, 33, 9, 9, 12, 19, 40, 9, 14, 20, 16, 27, 5, 29, 38, 24, 14, 8, 28, 10, 5, 9, 16, 36, 12, 7, 8, 7, 25, 28, 31, 6, 9, 22, 43, 11, 17, 24, 22, 13, 25, 19, 9, 36, 54, 16, 9, 24, 8, 9, 6, 9, 25, 12, 7, 10, 33, 16, 20, 28, 17, 10, 10, 27, 19, 23, 7, 10, 9, 27, 9, 23, 14, 20, 21, 36, 10, 9, 16, 15, 34, 9, 30, 29, 8, 51, 31, 26, 31, 9, 10, 19, 14, 9, 29, 20, 10, 9, 26, 19, 23, 42, 29, 9, 10, 40, 39, 10, 14, 7, 18, 19, 40, 30, 8, 71, 8, 9, 28, 8, 46, 10, 20, 10, 13, 15, 28, 7, 15, 12, 21, 53, 16, 54, 19, 8, 14, 20, 6, 26, 31, 8, 17, 12, 26, 9, 32, 14, 36, 14, 16, 17, 13, 23, 40, 21, 23, 8, 54, 7, 9, 34, 27, 36, 21, 8, 8, 10, 34, 24, 4, 8, 16, 12, 14, 14, 7, 25, 8, 39, 10, 21, 10, 22, 32, 39, 38, 13, 5, 27, 10, 36, 17, 10, 26, 40, 9, 21, 10, 42, 8, 21, 24, 22, 15, 22, 34, 10, 25, 9, 16, 31, 14, 27, 20, 6, 32, 28, 23, 16, 26, 10, 20, 8, 9, 23, 40, 29, 25, 9, 15, 18, 12, 24, 31, 15, 11, 20, 14, 16, 20, 10, 25, 9, 36, 13, 19, 5, 6, 10, 19, 17, 9, 22, 20, 19, 9, 9, 10, 8, 26, 9, 7, 5, 47, 9, 23, 10, 19, 7, 20, 20, 30, 14, 9, 14, 23, 7, 17, 25, 21, 8, 14, 21, 10, 16, 9, 7, 9, 5, 9, 54, 31, 16, 47, 26, 9, 10, 24, 38, 7, 31, 17, 14, 21, 14, 19, 16, 27, 14, 27, 36, 35, 27, 14, 31, 27, 13, 38, 9, 8, 27, 8, 18, 20, 27, 20, 40, 7, 15, 26, 10, 30, 24, 7, 7, 27, 25, 17, 24, 9, 28, 47, 23, 9, 34, 28, 14, 9, 8, 14, 9, 46, 9, 25, 18, 17, 20, 11, 9, 7, 16, 31, 14, 15, 27, 20, 40, 21, 9, 5, 10, 8, 28, 11, 5, 21, 19, 8, 20, 10, 7, 7, 19, 28, 10, 14, 54, 39, 17, 47, 24, 10, 29, 39, 6, 22, 29, 12, 9, 8, 13, 36, 28, 38, 19, 11, 8, 7, 17, 18, 34, 11, 8, 31, 38, 37, 19, 10, 8, 9, 17, 7, 9, 25, 39, 9, 33, 19, 31, 19, 27, 9, 26, 7, 14]

# %%
import os
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

# 调用torch中bert的分词器
tokenizer = BertTokenizer.from_pretrained(os.path.join('.', 'model_bin'))

# 构建数据集
class BertDataset(Dataset):
    def __init__(self, all_text, all_label, label2idx, max_len, tokenizer, is_test=False):
        self.all_text = all_text
        self.all_label = all_label
        self.label2idx = label2idx
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.is_test = is_test

    def __getitem__(self, index):
        if self.is_test:
            self.max_len = len(self.all_label[index])

        # 按批次获得数据
        text = self.all_text[index]
        # 0到max_len的词有对应的label,后面的用padding（转换为数字张量之后就是0了）补充
        label = self.all_label[index][:self.max_len]
        
        # 这里的encode函数要做的事：
        # 对词进行编码，将词转换为在词表中对应的数字
        # 对长度大于max_length的语句进行截断（超出了max_length的直接没有了），对长度不足max_length的语句进行padding填充
        # 添加特殊的标记符
        # 返回tensor类型的张量，即将词进行编码为torch张量
        text_index = self.tokenizer.encode(text,
                                           add_special_tokens=True,
                                           max_length=self.max_len + 2,        # 加上两个左右标识符
                                           padding="max_length",
                                           truncation=True,
                                           return_tensors="pt")        # pt 返回pytorch的张量
        label_index = [0] + [self.label2idx.get(l, 1) for l in label] + [0] + [0] * (max_len - len(text))
        # 将编码后的label转换为torch张量
        label_index = torch.tensor(label_index)
        # 统一text_index和label_index的形状和维度
        return text_index.reshape(-1), label_index, len(label)

    def __len__(self):
        return self.all_text.__len__()
# Out:
# 2023-06-15 23:03:33.561586: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-15 23:03:33.679844: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-15 23:03:34.243809: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-06-15 23:03:34.243859: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-06-15 23:03:34.243864: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF


batch_size = 16
max_len = 70

# 训练+测试

train_dataset = BertDataset(train_text,
                            train_label,
                            label2idx,
                            max_len,
                            tokenizer)
# 在处理好的语料中随机获得batch_size个句子，作为一批语料输入模型，shuffle是否要随机获得语料
train_dataloader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=False)

dev_dataset = BertDataset(dev_text,
                          dev_label,
                          label2idx,
                          max_len,
                          tokenizer)
dev_dataloader = DataLoader(dev_dataset,
                            batch_size=batch_size,
                            shuffle=False)

print("train_dataset的数据类型为： ", type(train_dataset))
# Out:
# train_dataset的数据类型为：  <class '__main__.BertDataset'>

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

# 构建基于Bert_LSTM_CRF的模型
class Bert_LSTM_CRF_NerModel(nn.Module):
    def __init__(self, lstm_hidden, class_num):
        super().__init__()

        self.bert = BertModel.from_pretrained(os.path.join('.', 'model_bin'))
        
        # 为了省显存做的，如果不想省可以删掉
        for name, param in self.bert.named_parameters():
            param.requires_grad = False
            
        # bidirectional 调成True的时候，Linear层的lstm_hidden需要乘2
        self.lstm = nn.LSTM(768,
                            lstm_hidden,
                            batch_first=True,
                            num_layers=1,
                            bidirectional=True)
        # 线性分类器
        self.classifier = nn.Linear(lstm_hidden*2, class_num)
        
        # 条件随机场
        self.crf = CRF(class_num, batch_first=True)

    # 前馈层
    def forward(self, batch_index, batch_label=None):
        # 按批次传入数据到bert编码层
        bert_out = self.bert(batch_index)
        # bert_out0 字符级别的特征信息 bert_out1 篇章级别的特征信息
        bert_out0, bert_out1 = bert_out[0], bert_out[1]  
        # 命名实体识别是序列标注任务，因此需要bert_out0，字符级别的特征信息
        lstm_out, _ = self.lstm(bert_out0)
        # 调用线性分类器完成预测任务
        pre = self.classifier(lstm_out)
        
        # 传了label数据的时候，就是训练，就要看loss,没传label数据的时候，就直接对分类预测的结果pre进行解码
        if batch_label is not None:
            # loss = self.loss_fun(pre.reshape(-1, pre.shape[-1]),batch_label.reshape(-1))
            loss = -self.crf(pre, batch_label)
            return loss
        else:
            pre = self.crf.decode(pre)
            # return torch.argmax(pre, dim=-1)
            return pre

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

epoch = 200
lr = 0.0005
lstm_hidden = 128
# 根据“训练+验证” “测试” “输入” 三种状态选择True或False
do_train = True
do_test = False
do_input = False
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda:0

# %%
if do_train:
        # 加载模型，并将模型放到cuda上
        model = Bert_LSTM_CRF_NerModel(lstm_hidden, len(label2idx)).cuda()
        
        # opt是优化器，这里采用Adam的优化方式
        opt = AdamW(model.parameters(), lr)

        best_score = -1
        for e in range(epoch):
            model.train()
            batch_index = 1    # 设置该变量记录当前是训练模型的第几批，每一批都有16个句子，所以总共有12批    
            for batch_text_index, batch_label_index, batch_len in train_dataloader:
                # 按批获得数据，数据放入cuda中
                batch_text_index = batch_text_index.cuda()
                batch_label_index = batch_label_index.cuda()
                # 数据读入读入模型中，获得训练的loss
                loss = model.forward(batch_text_index, batch_label_index)
                loss.backward()
                # opt优化器优化
                opt.step()
                # 梯度归0
                opt.zero_grad()
                
                print("当前的批次为：", batch_index)
                print(f'loss{loss:.2f}')
                batch_index = batch_index + 1
            
            print('-----------------------------------------------')
            print('********  have trained ' + str(e+1) + ' epoch!  ********')
            print('-----------------------------------------------')
            
            # 模型训练结束之后，开始进行测试
            model.eval()
            all_pre = []    # 记录所有的预测label
            all_tag = []    # 记录所有的真实label
            for batch_text_index, batch_label_index, batch_len in dev_dataloader:
                batch_text_index = batch_text_index.cuda()
                batch_label_index = batch_label_index.cuda()
                # 获得模型预测的结果
                pre = model.forward(batch_text_index)
                # 加载真实的label
                tag = batch_label_index.tolist()

                for p, t, l in zip(pre, tag, batch_len):
                    p = p[1:1 + l]
                    t = t[1:1 + l]

                    p = [idx2label[i] for i in p]
                    t = [idx2label[i] for i in t]

                    all_pre.append(p)
                    all_tag.append(t)
                # 获得f1_score
                f1_score = seqeval_f1_score(all_tag, all_pre)
                # 记录最好的f1_score结果，并将得到该结果的模型文件.pt保存下来
                if f1_score > best_score:
                    torch.save(model, 'best_modelEng.pt')
                    best_score = f1_score
                    
                print(f'********  best_score:{best_score}  ********')
                print('-----------------------------------------------')
                print(f'********  f1_score:{f1_score}  ********')
                print('-----------------------------------------------')
# Out:
# Some weights of the model checkpoint at ./model_bin were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /ssd01/Codes/PersonalCodes/ZhangXianpeng/zhangxianpeng_env/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /ssd01/Codes/PersonalCodes/ZhangXianpeng/zhangxianpeng_env/lib/python3.8/site-packages/torchcrf/__init__.py:249: UserWarning: where received a uint8 condition tensor. This behavior is deprecated and will be removed in a future version of PyTorch. Use a boolean condition instead. (Triggered internally at  /pytorch/aten/src/ATen/native/TensorCompare.cpp:255.)
#   score = torch.where(mask[i].unsqueeze(1), next_score, score)
# 当前的批次为： 1
# loss2732.86
# 当前的批次为： 2
# loss2256.72
# 当前的批次为： 3
# loss1804.69
# 当前的批次为： 4
# loss1413.43
# 当前的批次为： 5
# loss1235.84
# 当前的批次为： 6
# loss939.26
# 当前的批次为： 7
# loss833.95
# 当前的批次为： 8
# loss741.94
# 当前的批次为： 9
# loss686.80
# 当前的批次为： 10
# loss584.26
# 当前的批次为： 11
# loss545.63
# 当前的批次为： 12
# loss527.72
# 当前的批次为： 13
# loss512.30
# 当前的批次为： 14
# loss446.21
# 当前的批次为： 15
# loss491.72
# 当前的批次为： 16
# loss418.48
# 当前的批次为： 17
# loss426.20
# 当前的批次为： 18
# loss302.99
# 当前的批次为： 19
# loss334.75
# 当前的批次为： 20
# loss469.03
# 当前的批次为： 21
# loss413.99
# 当前的批次为： 22
# loss333.16
# 当前的批次为： 23
# loss481.48
# 当前的批次为： 24
# loss387.31
# 当前的批次为： 25
# loss342.16
# 当前的批次为： 26
# loss176.91
# -----------------------------------------------
# ********  have trained 1 epoch!  ********
# -----------------------------------------------
# /ssd01/Codes/PersonalCodes/ZhangXianpeng/zhangxianpeng_env/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PAD seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss285.53
# 当前的批次为： 2
# loss524.05
# 当前的批次为： 3
# loss346.51
# 当前的批次为： 4
# loss271.78
# 当前的批次为： 5
# loss418.41
# 当前的批次为： 6
# loss237.91
# 当前的批次为： 7
# loss364.79
# 当前的批次为： 8
# loss325.72
# 当前的批次为： 9
# loss392.47
# 当前的批次为： 10
# loss302.13
# 当前的批次为： 11
# loss315.74
# 当前的批次为： 12
# loss341.40
# 当前的批次为： 13
# loss323.64
# 当前的批次为： 14
# loss289.93
# 当前的批次为： 15
# loss332.70
# 当前的批次为： 16
# loss312.39
# 当前的批次为： 17
# loss284.44
# 当前的批次为： 18
# loss191.67
# 当前的批次为： 19
# loss219.69
# 当前的批次为： 20
# loss330.20
# 当前的批次为： 21
# loss294.22
# 当前的批次为： 22
# loss248.63
# 当前的批次为： 23
# loss345.06
# 当前的批次为： 24
# loss291.14
# 当前的批次为： 25
# loss256.12
# 当前的批次为： 26
# loss129.63
# -----------------------------------------------
# ********  have trained 2 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss224.22
# 当前的批次为： 2
# loss407.27
# 当前的批次为： 3
# loss274.50
# 当前的批次为： 4
# loss222.50
# 当前的批次为： 5
# loss346.42
# 当前的批次为： 6
# loss187.57
# 当前的批次为： 7
# loss304.53
# 当前的批次为： 8
# loss272.89
# 当前的批次为： 9
# loss341.06
# 当前的批次为： 10
# loss254.23
# 当前的批次为： 11
# loss269.39
# 当前的批次为： 12
# loss291.38
# 当前的批次为： 13
# loss278.32
# 当前的批次为： 14
# loss250.35
# 当前的批次为： 15
# loss291.07
# 当前的批次为： 16
# loss283.65
# 当前的批次为： 17
# loss243.05
# 当前的批次为： 18
# loss163.82
# 当前的批次为： 19
# loss193.02
# 当前的批次为： 20
# loss326.72
# 当前的批次为： 21
# loss256.21
# 当前的批次为： 22
# loss215.28
# 当前的批次为： 23
# loss309.42
# 当前的批次为： 24
# loss252.73
# 当前的批次为： 25
# loss225.75
# 当前的批次为： 26
# loss112.95
# -----------------------------------------------
# ********  have trained 3 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# ********  best_score:0.0  ********
# -----------------------------------------------
# ********  f1_score:0.0  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss195.36
# 当前的批次为： 2
# loss357.31
# 当前的批次为： 3
# loss244.75
# 当前的批次为： 4
# loss210.98
# 当前的批次为： 5
# loss294.74
# 当前的批次为： 6
# loss161.48
# 当前的批次为： 7
# loss274.67
# 当前的批次为： 8
# loss238.62
# 当前的批次为： 9
# loss305.01
# 当前的批次为： 10
# loss227.99
# 当前的批次为： 11
# loss236.53
# 当前的批次为： 12
# loss268.67
# 当前的批次为： 13
# loss250.24
# 当前的批次为： 14
# loss220.99
# 当前的批次为： 15
# loss261.67
# 当前的批次为： 16
# loss261.06
# 当前的批次为： 17
# loss210.51
# 当前的批次为： 18
# loss139.06
# 当前的批次为： 19
# loss173.35
# 当前的批次为： 20
# loss271.46
# 当前的批次为： 21
# loss226.94
# 当前的批次为： 22
# loss186.00
# 当前的批次为： 23
# loss276.50
# 当前的批次为： 24
# loss223.98
# 当前的批次为： 25
# loss201.34
# 当前的批次为： 26
# loss96.71
# -----------------------------------------------
# ********  have trained 4 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.1276595744680851  ********
# -----------------------------------------------
# ********  f1_score:0.1276595744680851  ********
# -----------------------------------------------
# ********  best_score:0.1276595744680851  ********
# -----------------------------------------------
# ********  f1_score:0.1111111111111111  ********
# -----------------------------------------------
# ********  best_score:0.1276595744680851  ********
# -----------------------------------------------
# ********  f1_score:0.07936507936507936  ********
# -----------------------------------------------
# ********  best_score:0.1276595744680851  ********
# -----------------------------------------------
# ********  f1_score:0.058479532163742694  ********
# -----------------------------------------------
# ********  best_score:0.1276595744680851  ********
# -----------------------------------------------
# ********  f1_score:0.06796116504854369  ********
# -----------------------------------------------
# ********  best_score:0.1276595744680851  ********
# -----------------------------------------------
# ********  f1_score:0.07563025210084034  ********
# -----------------------------------------------
# ********  best_score:0.1276595744680851  ********
# -----------------------------------------------
# ********  f1_score:0.08571428571428573  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss178.39
# 当前的批次为： 2
# loss311.92
# 当前的批次为： 3
# loss222.77
# 当前的批次为： 4
# loss196.07
# 当前的批次为： 5
# loss263.89
# 当前的批次为： 6
# loss135.14
# 当前的批次为： 7
# loss251.14
# 当前的批次为： 8
# loss215.93
# 当前的批次为： 9
# loss291.40
# 当前的批次为： 10
# loss206.27
# 当前的批次为： 11
# loss216.56
# 当前的批次为： 12
# loss243.00
# 当前的批次为： 13
# loss230.62
# 当前的批次为： 14
# loss202.75
# 当前的批次为： 15
# loss236.90
# 当前的批次为： 16
# loss238.29
# 当前的批次为： 17
# loss197.71
# 当前的批次为： 18
# loss132.81
# 当前的批次为： 19
# loss163.33
# 当前的批次为： 20
# loss254.81
# 当前的批次为： 21
# loss201.50
# 当前的批次为： 22
# loss164.60
# 当前的批次为： 23
# loss258.38
# 当前的批次为： 24
# loss199.42
# 当前的批次为： 25
# loss184.84
# 当前的批次为： 26
# loss89.06
# -----------------------------------------------
# ********  have trained 5 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.18181818181818182  ********
# -----------------------------------------------
# ********  f1_score:0.18181818181818182  ********
# -----------------------------------------------
# ********  best_score:0.18181818181818182  ********
# -----------------------------------------------
# ********  f1_score:0.1764705882352941  ********
# -----------------------------------------------
# ********  best_score:0.18181818181818182  ********
# -----------------------------------------------
# ********  f1_score:0.136986301369863  ********
# -----------------------------------------------
# ********  best_score:0.18181818181818182  ********
# -----------------------------------------------
# ********  f1_score:0.09950248756218906  ********
# -----------------------------------------------
# ********  best_score:0.18181818181818182  ********
# -----------------------------------------------
# ********  f1_score:0.1306122448979592  ********
# -----------------------------------------------
# ********  best_score:0.18181818181818182  ********
# -----------------------------------------------
# ********  f1_score:0.1408450704225352  ********
# -----------------------------------------------
# ********  best_score:0.18181818181818182  ********
# -----------------------------------------------
# ********  f1_score:0.16568047337278105  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss166.84
# 当前的批次为： 2
# loss285.11
# 当前的批次为： 3
# loss204.57
# 当前的批次为： 4
# loss182.25
# 当前的批次为： 5
# loss250.34
# 当前的批次为： 6
# loss115.40
# 当前的批次为： 7
# loss236.47
# 当前的批次为： 8
# loss193.97
# 当前的批次为： 9
# loss271.89
# 当前的批次为： 10
# loss190.89
# 当前的批次为： 11
# loss196.92
# 当前的批次为： 12
# loss225.89
# 当前的批次为： 13
# loss215.56
# 当前的批次为： 14
# loss183.98
# 当前的批次为： 15
# loss215.02
# 当前的批次为： 16
# loss218.46
# 当前的批次为： 17
# loss174.95
# 当前的批次为： 18
# loss117.19
# 当前的批次为： 19
# loss154.34
# 当前的批次为： 20
# loss241.16
# 当前的批次为： 21
# loss194.58
# 当前的批次为： 22
# loss153.64
# 当前的批次为： 23
# loss240.89
# 当前的批次为： 24
# loss184.86
# 当前的批次为： 25
# loss168.05
# 当前的批次为： 26
# loss80.82
# -----------------------------------------------
# ********  have trained 6 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.40579710144927533  ********
# -----------------------------------------------
# ********  f1_score:0.40579710144927533  ********
# -----------------------------------------------
# ********  best_score:0.40579710144927533  ********
# -----------------------------------------------
# ********  f1_score:0.3252032520325203  ********
# -----------------------------------------------
# ********  best_score:0.40579710144927533  ********
# -----------------------------------------------
# ********  f1_score:0.29050279329608936  ********
# -----------------------------------------------
# ********  best_score:0.40579710144927533  ********
# -----------------------------------------------
# ********  f1_score:0.2698412698412698  ********
# -----------------------------------------------
# ********  best_score:0.40579710144927533  ********
# -----------------------------------------------
# ********  f1_score:0.28664495114006516  ********
# -----------------------------------------------
# ********  best_score:0.40579710144927533  ********
# -----------------------------------------------
# ********  f1_score:0.27920227920227925  ********
# -----------------------------------------------
# ********  best_score:0.40579710144927533  ********
# -----------------------------------------------
# ********  f1_score:0.3  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss157.67
# 当前的批次为： 2
# loss257.41
# 当前的批次为： 3
# loss187.17
# 当前的批次为： 4
# loss173.85
# 当前的批次为： 5
# loss221.12
# 当前的批次为： 6
# loss104.35
# 当前的批次为： 7
# loss218.52
# 当前的批次为： 8
# loss179.66
# 当前的批次为： 9
# loss253.12
# 当前的批次为： 10
# loss180.84
# 当前的批次为： 11
# loss186.61
# 当前的批次为： 12
# loss209.65
# 当前的批次为： 13
# loss198.62
# 当前的批次为： 14
# loss172.01
# 当前的批次为： 15
# loss207.58
# 当前的批次为： 16
# loss207.75
# 当前的批次为： 17
# loss167.68
# 当前的批次为： 18
# loss109.13
# 当前的批次为： 19
# loss145.45
# 当前的批次为： 20
# loss227.18
# 当前的批次为： 21
# loss176.06
# 当前的批次为： 22
# loss145.81
# 当前的批次为： 23
# loss221.71
# 当前的批次为： 24
# loss163.72
# 当前的批次为： 25
# loss156.57
# 当前的批次为： 26
# loss74.01
# -----------------------------------------------
# ********  have trained 7 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.5  ********
# -----------------------------------------------
# ********  f1_score:0.5  ********
# -----------------------------------------------
# ********  best_score:0.5  ********
# -----------------------------------------------
# ********  f1_score:0.38759689922480617  ********
# -----------------------------------------------
# ********  best_score:0.5  ********
# -----------------------------------------------
# ********  f1_score:0.3473684210526316  ********
# -----------------------------------------------
# ********  best_score:0.5  ********
# -----------------------------------------------
# ********  f1_score:0.30711610486891383  ********
# -----------------------------------------------
# ********  best_score:0.5  ********
# -----------------------------------------------
# ********  f1_score:0.32515337423312884  ********
# -----------------------------------------------
# ********  best_score:0.5  ********
# -----------------------------------------------
# ********  f1_score:0.3270777479892762  ********
# -----------------------------------------------
# ********  best_score:0.5  ********
# -----------------------------------------------
# ********  f1_score:0.3438914027149322  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss147.48
# 当前的批次为： 2
# loss229.68
# 当前的批次为： 3
# loss175.04
# 当前的批次为： 4
# loss168.40
# 当前的批次为： 5
# loss208.46
# 当前的批次为： 6
# loss100.23
# 当前的批次为： 7
# loss202.91
# 当前的批次为： 8
# loss172.26
# 当前的批次为： 9
# loss247.25
# 当前的批次为： 10
# loss167.75
# 当前的批次为： 11
# loss167.47
# 当前的批次为： 12
# loss194.58
# 当前的批次为： 13
# loss189.33
# 当前的批次为： 14
# loss157.44
# 当前的批次为： 15
# loss189.26
# 当前的批次为： 16
# loss204.32
# 当前的批次为： 17
# loss158.18
# 当前的批次为： 18
# loss101.41
# 当前的批次为： 19
# loss140.29
# 当前的批次为： 20
# loss215.88
# 当前的批次为： 21
# loss166.62
# 当前的批次为： 22
# loss138.40
# 当前的批次为： 23
# loss209.24
# 当前的批次为： 24
# loss155.05
# 当前的批次为： 25
# loss147.24
# 当前的批次为： 26
# loss72.09
# -----------------------------------------------
# ********  have trained 8 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.4393939393939394  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.383419689119171  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.35424354243542433  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3558282208588957  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.35200000000000004  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.36486486486486486  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss136.90
# 当前的批次为： 2
# loss223.15
# 当前的批次为： 3
# loss169.03
# 当前的批次为： 4
# loss158.44
# 当前的批次为： 5
# loss187.92
# 当前的批次为： 6
# loss97.34
# 当前的批次为： 7
# loss199.04
# 当前的批次为： 8
# loss169.64
# 当前的批次为： 9
# loss239.37
# 当前的批次为： 10
# loss160.56
# 当前的批次为： 11
# loss168.45
# 当前的批次为： 12
# loss198.15
# 当前的批次为： 13
# loss184.08
# 当前的批次为： 14
# loss153.53
# 当前的批次为： 15
# loss189.38
# 当前的批次为： 16
# loss189.14
# 当前的批次为： 17
# loss153.43
# 当前的批次为： 18
# loss100.18
# 当前的批次为： 19
# loss138.11
# 当前的批次为： 20
# loss207.03
# 当前的批次为： 21
# loss154.06
# 当前的批次为： 22
# loss128.82
# 当前的批次为： 23
# loss199.39
# 当前的批次为： 24
# loss148.29
# 当前的批次为： 25
# loss146.95
# 当前的批次为： 26
# loss67.24
# -----------------------------------------------
# ********  have trained 9 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.4533333333333333  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3703703703703704  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3553299492385787  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3345454545454546  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.33132530120481923  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3419689119170985  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3604395604395604  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss128.33
# 当前的批次为： 2
# loss205.27
# 当前的批次为： 3
# loss154.30
# 当前的批次为： 4
# loss149.31
# 当前的批次为： 5
# loss176.98
# 当前的批次为： 6
# loss85.16
# 当前的批次为： 7
# loss189.41
# 当前的批次为： 8
# loss158.29
# 当前的批次为： 9
# loss228.58
# 当前的批次为： 10
# loss154.40
# 当前的批次为： 11
# loss151.34
# 当前的批次为： 12
# loss192.50
# 当前的批次为： 13
# loss169.72
# 当前的批次为： 14
# loss148.26
# 当前的批次为： 15
# loss180.40
# 当前的批次为： 16
# loss184.40
# 当前的批次为： 17
# loss147.99
# 当前的批次为： 18
# loss92.25
# 当前的批次为： 19
# loss124.08
# 当前的批次为： 20
# loss187.65
# 当前的批次为： 21
# loss145.12
# 当前的批次为： 22
# loss126.12
# 当前的批次为： 23
# loss190.48
# 当前的批次为： 24
# loss134.85
# 当前的批次为： 25
# loss133.19
# 当前的批次为： 26
# loss61.02
# -----------------------------------------------
# ********  have trained 10 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.49350649350649345  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.39705882352941174  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3718592964824121  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3610108303249097  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3723723723723724  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.37823834196891193  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.38681318681318677  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss124.07
# 当前的批次为： 2
# loss189.80
# 当前的批次为： 3
# loss140.31
# 当前的批次为： 4
# loss149.81
# 当前的批次为： 5
# loss169.74
# 当前的批次为： 6
# loss80.37
# 当前的批次为： 7
# loss180.12
# 当前的批次为： 8
# loss150.69
# 当前的批次为： 9
# loss208.81
# 当前的批次为： 10
# loss149.37
# 当前的批次为： 11
# loss147.32
# 当前的批次为： 12
# loss175.14
# 当前的批次为： 13
# loss167.85
# 当前的批次为： 14
# loss145.70
# 当前的批次为： 15
# loss168.82
# 当前的批次为： 16
# loss174.74
# 当前的批次为： 17
# loss135.49
# 当前的批次为： 18
# loss89.76
# 当前的批次为： 19
# loss124.58
# 当前的批次为： 20
# loss175.51
# 当前的批次为： 21
# loss141.87
# 当前的批次为： 22
# loss119.31
# 当前的批次为： 23
# loss185.80
# 当前的批次为： 24
# loss114.98
# 当前的批次为： 25
# loss128.17
# 当前的批次为： 26
# loss61.02
# -----------------------------------------------
# ********  have trained 11 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.4533333333333333  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.37878787878787873  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.37305699481865284  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3568773234200743  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3641975308641976  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3660477453580902  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3783783783783784  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss115.89
# 当前的批次为： 2
# loss177.88
# 当前的批次为： 3
# loss131.97
# 当前的批次为： 4
# loss138.76
# 当前的批次为： 5
# loss149.25
# 当前的批次为： 6
# loss83.13
# 当前的批次为： 7
# loss162.73
# 当前的批次为： 8
# loss147.60
# 当前的批次为： 9
# loss205.98
# 当前的批次为： 10
# loss138.24
# 当前的批次为： 11
# loss147.81
# 当前的批次为： 12
# loss171.73
# 当前的批次为： 13
# loss161.51
# 当前的批次为： 14
# loss134.28
# 当前的批次为： 15
# loss179.54
# 当前的批次为： 16
# loss170.37
# 当前的批次为： 17
# loss148.14
# 当前的批次为： 18
# loss83.80
# 当前的批次为： 19
# loss117.21
# 当前的批次为： 20
# loss161.28
# 当前的批次为： 21
# loss133.91
# 当前的批次为： 22
# loss113.75
# 当前的批次为： 23
# loss173.94
# 当前的批次为： 24
# loss117.92
# 当前的批次为： 25
# loss130.23
# 当前的批次为： 26
# loss52.19
# -----------------------------------------------
# ********  have trained 12 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.47500000000000003  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3802816901408451  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3827751196172249  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3793103448275862  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.39541547277936967  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.40594059405940597  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.40756302521008403  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss116.14
# 当前的批次为： 2
# loss164.12
# 当前的批次为： 3
# loss122.15
# 当前的批次为： 4
# loss139.38
# 当前的批次为： 5
# loss146.28
# 当前的批次为： 6
# loss75.65
# 当前的批次为： 7
# loss154.13
# 当前的批次为： 8
# loss139.79
# 当前的批次为： 9
# loss192.82
# 当前的批次为： 10
# loss135.01
# 当前的批次为： 11
# loss137.71
# 当前的批次为： 12
# loss168.06
# 当前的批次为： 13
# loss158.74
# 当前的批次为： 14
# loss129.81
# 当前的批次为： 15
# loss166.64
# 当前的批次为： 16
# loss169.36
# 当前的批次为： 17
# loss126.45
# 当前的批次为： 18
# loss83.16
# 当前的批次为： 19
# loss119.81
# 当前的批次为： 20
# loss163.60
# 当前的批次为： 21
# loss132.01
# 当前的批次为： 22
# loss114.98
# 当前的批次为： 23
# loss162.67
# 当前的批次为： 24
# loss104.74
# 当前的批次为： 25
# loss120.02
# 当前的批次为： 26
# loss54.01
# -----------------------------------------------
# ********  have trained 13 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.49350649350649345  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.39416058394160586  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3980099502487562  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3785714285714285  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.37611940298507457  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3865979381443299  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.39651416122004357  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss112.17
# 当前的批次为： 2
# loss149.65
# 当前的批次为： 3
# loss124.85
# 当前的批次为： 4
# loss135.48
# 当前的批次为： 5
# loss133.64
# 当前的批次为： 6
# loss71.80
# 当前的批次为： 7
# loss144.20
# 当前的批次为： 8
# loss129.63
# 当前的批次为： 9
# loss194.00
# 当前的批次为： 10
# loss123.43
# 当前的批次为： 11
# loss125.59
# 当前的批次为： 12
# loss151.13
# 当前的批次为： 13
# loss145.05
# 当前的批次为： 14
# loss123.26
# 当前的批次为： 15
# loss158.12
# 当前的批次为： 16
# loss161.94
# 当前的批次为： 17
# loss123.96
# 当前的批次为： 18
# loss81.86
# 当前的批次为： 19
# loss114.88
# 当前的批次为： 20
# loss158.44
# 当前的批次为： 21
# loss131.04
# 当前的批次为： 22
# loss107.23
# 当前的批次为： 23
# loss148.91
# 当前的批次为： 24
# loss101.10
# 当前的批次为： 25
# loss112.23
# 当前的批次为： 26
# loss56.40
# -----------------------------------------------
# ********  have trained 14 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.5  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.3724137931034483  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.39622641509433965  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.40816326530612246  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.4180790960451977  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.4313725490196079  ********
# -----------------------------------------------
# ********  best_score:0.5066666666666667  ********
# -----------------------------------------------
# ********  f1_score:0.42650103519668736  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss103.82
# 当前的批次为： 2
# loss137.10
# 当前的批次为： 3
# loss111.52
# 当前的批次为： 4
# loss130.54
# 当前的批次为： 5
# loss128.46
# 当前的批次为： 6
# loss67.74
# 当前的批次为： 7
# loss137.23
# 当前的批次为： 8
# loss132.29
# 当前的批次为： 9
# loss173.00
# 当前的批次为： 10
# loss119.73
# 当前的批次为： 11
# loss126.06
# 当前的批次为： 12
# loss151.10
# 当前的批次为： 13
# loss141.59
# 当前的批次为： 14
# loss115.51
# 当前的批次为： 15
# loss147.11
# 当前的批次为： 16
# loss153.66
# 当前的批次为： 17
# loss118.38
# 当前的批次为： 18
# loss71.83
# 当前的批次为： 19
# loss115.40
# 当前的批次为： 20
# loss141.25
# 当前的批次为： 21
# loss115.69
# 当前的批次为： 22
# loss112.13
# 当前的批次为： 23
# loss149.18
# 当前的批次为： 24
# loss97.26
# 当前的批次为： 25
# loss104.42
# 当前的批次为： 26
# loss46.61
# -----------------------------------------------
# ********  have trained 15 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.605263157894737  ********
# -----------------------------------------------
# ********  f1_score:0.605263157894737  ********
# -----------------------------------------------
# ********  best_score:0.605263157894737  ********
# -----------------------------------------------
# ********  f1_score:0.437956204379562  ********
# -----------------------------------------------
# ********  best_score:0.605263157894737  ********
# -----------------------------------------------
# ********  f1_score:0.4623115577889447  ********
# -----------------------------------------------
# ********  best_score:0.605263157894737  ********
# -----------------------------------------------
# ********  f1_score:0.44927536231884063  ********
# -----------------------------------------------
# ********  best_score:0.605263157894737  ********
# -----------------------------------------------
# ********  f1_score:0.4537313432835821  ********
# -----------------------------------------------
# ********  best_score:0.605263157894737  ********
# -----------------------------------------------
# ********  f1_score:0.4627249357326478  ********
# -----------------------------------------------
# ********  best_score:0.605263157894737  ********
# -----------------------------------------------
# ********  f1_score:0.4652173913043478  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss95.51
# 当前的批次为： 2
# loss138.69
# 当前的批次为： 3
# loss100.42
# 当前的批次为： 4
# loss115.33
# 当前的批次为： 5
# loss129.48
# 当前的批次为： 6
# loss68.27
# 当前的批次为： 7
# loss122.43
# 当前的批次为： 8
# loss120.66
# 当前的批次为： 9
# loss161.32
# 当前的批次为： 10
# loss107.46
# 当前的批次为： 11
# loss115.51
# 当前的批次为： 12
# loss132.12
# 当前的批次为： 13
# loss128.67
# 当前的批次为： 14
# loss108.70
# 当前的批次为： 15
# loss145.05
# 当前的批次为： 16
# loss154.22
# 当前的批次为： 17
# loss114.20
# 当前的批次为： 18
# loss75.85
# 当前的批次为： 19
# loss107.61
# 当前的批次为： 20
# loss127.51
# 当前的批次为： 21
# loss109.32
# 当前的批次为： 22
# loss99.57
# 当前的批次为： 23
# loss140.49
# 当前的批次为： 24
# loss83.31
# 当前的批次为： 25
# loss100.64
# 当前的批次为： 26
# loss45.97
# -----------------------------------------------
# ********  have trained 16 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.4817518248175182  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.48039215686274506  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.4664310954063604  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.4619883040935672  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.47088607594936716  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.4763948497854077  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss97.84
# 当前的批次为： 2
# loss132.73
# 当前的批次为： 3
# loss96.21
# 当前的批次为： 4
# loss114.11
# 当前的批次为： 5
# loss120.69
# 当前的批次为： 6
# loss62.09
# 当前的批次为： 7
# loss118.40
# 当前的批次为： 8
# loss121.12
# 当前的批次为： 9
# loss159.50
# 当前的批次为： 10
# loss103.57
# 当前的批次为： 11
# loss113.21
# 当前的批次为： 12
# loss133.52
# 当前的批次为： 13
# loss120.96
# 当前的批次为： 14
# loss116.67
# 当前的批次为： 15
# loss151.20
# 当前的批次为： 16
# loss144.18
# 当前的批次为： 17
# loss108.04
# 当前的批次为： 18
# loss71.39
# 当前的批次为： 19
# loss99.80
# 当前的批次为： 20
# loss130.36
# 当前的批次为： 21
# loss110.96
# 当前的批次为： 22
# loss97.36
# 当前的批次为： 23
# loss154.54
# 当前的批次为： 24
# loss86.43
# 当前的批次为： 25
# loss97.64
# 当前的批次为： 26
# loss43.82
# -----------------------------------------------
# ********  have trained 17 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.6153846153846153  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.4822695035460993  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.4854368932038835  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.47887323943661975  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.47536231884057967  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.4837905236907731  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.48523206751054854  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss93.78
# 当前的批次为： 2
# loss110.45
# 当前的批次为： 3
# loss97.94
# 当前的批次为： 4
# loss115.80
# 当前的批次为： 5
# loss108.27
# 当前的批次为： 6
# loss58.06
# 当前的批次为： 7
# loss124.46
# 当前的批次为： 8
# loss113.77
# 当前的批次为： 9
# loss152.89
# 当前的批次为： 10
# loss105.64
# 当前的批次为： 11
# loss104.57
# 当前的批次为： 12
# loss131.52
# 当前的批次为： 13
# loss125.49
# 当前的批次为： 14
# loss97.75
# 当前的批次为： 15
# loss131.61
# 当前的批次为： 16
# loss133.31
# 当前的批次为： 17
# loss102.74
# 当前的批次为： 18
# loss72.17
# 当前的批次为： 19
# loss97.80
# 当前的批次为： 20
# loss118.52
# 当前的批次为： 21
# loss100.99
# 当前的批次为： 22
# loss95.18
# 当前的批次为： 23
# loss141.31
# 当前的批次为： 24
# loss83.68
# 当前的批次为： 25
# loss99.54
# 当前的批次为： 26
# loss41.04
# -----------------------------------------------
# ********  have trained 18 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.5035971223021583  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.5073170731707318  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.512280701754386  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.5043478260869565  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.5087281795511223  ********
# -----------------------------------------------
# ********  best_score:0.6315789473684211  ********
# -----------------------------------------------
# ********  f1_score:0.5073375262054508  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss86.54
# 当前的批次为： 2
# loss105.76
# 当前的批次为： 3
# loss86.51
# 当前的批次为： 4
# loss98.70
# 当前的批次为： 5
# loss109.10
# 当前的批次为： 6
# loss64.81
# 当前的批次为： 7
# loss101.99
# 当前的批次为： 8
# loss110.27
# 当前的批次为： 9
# loss146.06
# 当前的批次为： 10
# loss105.11
# 当前的批次为： 11
# loss93.30
# 当前的批次为： 12
# loss118.69
# 当前的批次为： 13
# loss124.49
# 当前的批次为： 14
# loss90.41
# 当前的批次为： 15
# loss134.51
# 当前的批次为： 16
# loss118.51
# 当前的批次为： 17
# loss94.41
# 当前的批次为： 18
# loss65.45
# 当前的批次为： 19
# loss92.90
# 当前的批次为： 20
# loss124.45
# 当前的批次为： 21
# loss92.13
# 当前的批次为： 22
# loss88.30
# 当前的批次为： 23
# loss132.58
# 当前的批次为： 24
# loss70.44
# 当前的批次为： 25
# loss88.23
# 当前的批次为： 26
# loss37.57
# -----------------------------------------------
# ********  have trained 19 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5405405405405406  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5308056872037914  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5292096219931272  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5284090909090909  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5294117647058824  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5300207039337475  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss78.06
# 当前的批次为： 2
# loss96.59
# 当前的批次为： 3
# loss82.83
# 当前的批次为： 4
# loss87.70
# 当前的批次为： 5
# loss104.42
# 当前的批次为： 6
# loss55.51
# 当前的批次为： 7
# loss93.87
# 当前的批次为： 8
# loss98.24
# 当前的批次为： 9
# loss142.39
# 当前的批次为： 10
# loss82.48
# 当前的批次为： 11
# loss96.76
# 当前的批次为： 12
# loss116.57
# 当前的批次为： 13
# loss116.95
# 当前的批次为： 14
# loss91.77
# 当前的批次为： 15
# loss134.83
# 当前的批次为： 16
# loss128.67
# 当前的批次为： 17
# loss89.32
# 当前的批次为： 18
# loss65.92
# 当前的批次为： 19
# loss83.68
# 当前的批次为： 20
# loss103.77
# 当前的批次为： 21
# loss86.98
# 当前的批次为： 22
# loss85.29
# 当前的批次为： 23
# loss116.62
# 当前的批次为： 24
# loss66.54
# 当前的批次为： 25
# loss91.43
# 当前的批次为： 26
# loss33.04
# -----------------------------------------------
# ********  have trained 20 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5540540540540541  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5446009389671361  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.541095890410959  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5397727272727273  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5441176470588236  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5443298969072164  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss80.47
# 当前的批次为： 2
# loss90.84
# 当前的批次为： 3
# loss76.09
# 当前的批次为： 4
# loss87.76
# 当前的批次为： 5
# loss91.35
# 当前的批次为： 6
# loss65.31
# 当前的批次为： 7
# loss104.51
# 当前的批次为： 8
# loss99.37
# 当前的批次为： 9
# loss137.14
# 当前的批次为： 10
# loss95.39
# 当前的批次为： 11
# loss89.66
# 当前的批次为： 12
# loss112.17
# 当前的批次为： 13
# loss107.92
# 当前的批次为： 14
# loss90.71
# 当前的批次为： 15
# loss139.21
# 当前的批次为： 16
# loss118.85
# 当前的批次为： 17
# loss88.58
# 当前的批次为： 18
# loss67.29
# 当前的批次为： 19
# loss78.15
# 当前的批次为： 20
# loss101.22
# 当前的批次为： 21
# loss86.44
# 当前的批次为： 22
# loss90.50
# 当前的批次为： 23
# loss123.74
# 当前的批次为： 24
# loss68.79
# 当前的批次为： 25
# loss87.99
# 当前的批次为： 26
# loss31.35
# -----------------------------------------------
# ********  have trained 21 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.6666666666666666  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5179856115107914  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5148514851485148  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5270758122743682  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5341246290801187  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5370843989769821  ********
# -----------------------------------------------
# ********  best_score:0.6829268292682926  ********
# -----------------------------------------------
# ********  f1_score:0.5333333333333334  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss74.39
# 当前的批次为： 2
# loss104.65
# 当前的批次为： 3
# loss61.61
# 当前的批次为： 4
# loss94.07
# 当前的批次为： 5
# loss98.48
# 当前的批次为： 6
# loss64.78
# 当前的批次为： 7
# loss75.94
# 当前的批次为： 8
# loss87.68
# 当前的批次为： 9
# loss132.45
# 当前的批次为： 10
# loss83.76
# 当前的批次为： 11
# loss90.74
# 当前的批次为： 12
# loss104.34
# 当前的批次为： 13
# loss102.65
# 当前的批次为： 14
# loss90.26
# 当前的批次为： 15
# loss122.55
# 当前的批次为： 16
# loss103.56
# 当前的批次为： 17
# loss76.42
# 当前的批次为： 18
# loss59.45
# 当前的批次为： 19
# loss85.99
# 当前的批次为： 20
# loss95.16
# 当前的批次为： 21
# loss85.12
# 当前的批次为： 22
# loss76.69
# 当前的批次为： 23
# loss109.74
# 当前的批次为： 24
# loss59.26
# 当前的批次为： 25
# loss76.10
# 当前的批次为： 26
# loss31.91
# -----------------------------------------------
# ********  have trained 22 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.6013071895424837  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.6  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.5993265993265994  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.5921787709497206  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.5893719806763286  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.5906313645621182  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss70.07
# 当前的批次为： 2
# loss95.23
# 当前的批次为： 3
# loss67.44
# 当前的批次为： 4
# loss72.51
# 当前的批次为： 5
# loss86.16
# 当前的批次为： 6
# loss51.79
# 当前的批次为： 7
# loss76.00
# 当前的批次为： 8
# loss88.26
# 当前的批次为： 9
# loss118.14
# 当前的批次为： 10
# loss79.00
# 当前的批次为： 11
# loss74.46
# 当前的批次为： 12
# loss113.92
# 当前的批次为： 13
# loss90.82
# 当前的批次为： 14
# loss82.20
# 当前的批次为： 15
# loss110.14
# 当前的批次为： 16
# loss97.20
# 当前的批次为： 17
# loss79.59
# 当前的批次为： 18
# loss59.05
# 当前的批次为： 19
# loss76.85
# 当前的批次为： 20
# loss96.91
# 当前的批次为： 21
# loss78.99
# 当前的批次为： 22
# loss88.37
# 当前的批次为： 23
# loss123.13
# 当前的批次为： 24
# loss53.29
# 当前的批次为： 25
# loss72.86
# 当前的批次为： 26
# loss26.26
# -----------------------------------------------
# ********  have trained 23 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.6585365853658537  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.56  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.5555555555555556  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.5597269624573378  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# -----------------------------------------------
# ********  f1_score:0.559322033898305  ********
# -----------------------------------------------
# ********  best_score:0.6987951807228916  ********
# ...
# loss10.59
# 当前的批次为： 11
# loss10.26
# 当前的批次为： 12
# loss18.13
# 当前的批次为： 13
# loss4.42
# 当前的批次为： 14
# loss10.28
# 当前的批次为： 15
# loss27.59
# 当前的批次为： 16
# loss12.33
# 当前的批次为： 17
# loss12.92
# 当前的批次为： 18
# loss14.46
# 当前的批次为： 19
# loss10.56
# 当前的批次为： 20
# loss5.60
# 当前的批次为： 21
# loss8.89
# 当前的批次为： 22
# loss14.53
# 当前的批次为： 23
# loss9.73
# 当前的批次为： 24
# loss16.48
# 当前的批次为： 25
# loss14.79
# 当前的批次为： 26
# loss4.35
# -----------------------------------------------
# ********  have trained 193 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7764705882352941  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7453416149068323  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7248908296943231  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7405063291139239  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7539267015706805  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7595505617977528  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7642585551330798  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss8.11
# 当前的批次为： 2
# loss14.38
# 当前的批次为： 3
# loss7.02
# 当前的批次为： 4
# loss14.10
# 当前的批次为： 5
# loss9.14
# 当前的批次为： 6
# loss10.53
# 当前的批次为： 7
# loss9.80
# 当前的批次为： 8
# loss11.27
# 当前的批次为： 9
# loss22.91
# 当前的批次为： 10
# loss11.15
# 当前的批次为： 11
# loss11.60
# 当前的批次为： 12
# loss15.29
# 当前的批次为： 13
# loss3.47
# 当前的批次为： 14
# loss9.68
# 当前的批次为： 15
# loss36.11
# 当前的批次为： 16
# loss13.73
# 当前的批次为： 17
# loss12.71
# 当前的批次为： 18
# loss12.88
# 当前的批次为： 19
# loss11.63
# 当前的批次为： 20
# loss7.92
# 当前的批次为： 21
# loss6.85
# 当前的批次为： 22
# loss16.95
# 当前的批次为： 23
# loss7.57
# 当前的批次为： 24
# loss15.49
# 当前的批次为： 25
# loss13.64
# 当前的批次为： 26
# loss1.45
# -----------------------------------------------
# ********  have trained 194 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.8095238095238095  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.8  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7719298245614034  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7823343848580441  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7916666666666666  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7919463087248321  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7901701323251419  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss13.24
# 当前的批次为： 2
# loss12.42
# 当前的批次为： 3
# loss7.73
# 当前的批次为： 4
# loss12.49
# 当前的批次为： 5
# loss10.76
# 当前的批次为： 6
# loss9.35
# 当前的批次为： 7
# loss9.38
# 当前的批次为： 8
# loss9.97
# 当前的批次为： 9
# loss24.38
# 当前的批次为： 10
# loss10.50
# 当前的批次为： 11
# loss9.30
# 当前的批次为： 12
# loss16.71
# 当前的批次为： 13
# loss4.53
# 当前的批次为： 14
# loss9.97
# 当前的批次为： 15
# loss24.03
# 当前的批次为： 16
# loss19.98
# 当前的批次为： 17
# loss10.13
# 当前的批次为： 18
# loss21.13
# 当前的批次为： 19
# loss8.24
# 当前的批次为： 20
# loss6.55
# 当前的批次为： 21
# loss11.46
# 当前的批次为： 22
# loss16.82
# 当前的批次为： 23
# loss7.07
# 当前的批次为： 24
# loss9.75
# 当前的批次为： 25
# loss17.29
# 当前的批次为： 26
# loss2.40
# -----------------------------------------------
# ********  have trained 195 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.8139534883720929  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.8024691358024691  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7719298245614034  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.780952380952381  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7894736842105263  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7900677200902935  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7877629063097514  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss9.50
# 当前的批次为： 2
# loss14.30
# 当前的批次为： 3
# loss7.63
# 当前的批次为： 4
# loss17.49
# 当前的批次为： 5
# loss14.19
# 当前的批次为： 6
# loss13.64
# 当前的批次为： 7
# loss13.14
# 当前的批次为： 8
# loss12.47
# 当前的批次为： 9
# loss20.06
# 当前的批次为： 10
# loss10.22
# 当前的批次为： 11
# loss10.56
# 当前的批次为： 12
# loss16.80
# 当前的批次为： 13
# loss3.60
# 当前的批次为： 14
# loss9.95
# 当前的批次为： 15
# loss27.37
# 当前的批次为： 16
# loss16.92
# 当前的批次为： 17
# loss14.83
# 当前的批次为： 18
# loss23.98
# 当前的批次为： 19
# loss9.72
# 当前的批次为： 20
# loss7.30
# 当前的批次为： 21
# loss5.94
# 当前的批次为： 22
# loss12.73
# 当前的批次为： 23
# loss16.21
# 当前的批次为： 24
# loss15.77
# 当前的批次为： 25
# loss14.95
# 当前的批次为： 26
# loss4.08
# -----------------------------------------------
# ********  have trained 196 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7816091954022989  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7804878048780488  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7586206896551724  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7725856697819314  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7763496143958868  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7849223946784922  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7804878048780488  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss7.24
# 当前的批次为： 2
# loss13.04
# 当前的批次为： 3
# loss10.22
# 当前的批次为： 4
# loss11.76
# 当前的批次为： 5
# loss17.93
# 当前的批次为： 6
# loss10.02
# 当前的批次为： 7
# loss11.97
# 当前的批次为： 8
# loss11.24
# 当前的批次为： 9
# loss23.77
# 当前的批次为： 10
# loss10.12
# 当前的批次为： 11
# loss9.52
# 当前的批次为： 12
# loss17.09
# 当前的批次为： 13
# loss4.40
# 当前的批次为： 14
# loss8.81
# 当前的批次为： 15
# loss32.20
# 当前的批次为： 16
# loss12.86
# 当前的批次为： 17
# loss10.60
# 当前的批次为： 18
# loss13.76
# 当前的批次为： 19
# loss9.89
# 当前的批次为： 20
# loss7.52
# 当前的批次为： 21
# loss6.62
# 当前的批次为： 22
# loss16.31
# 当前的批次为： 23
# loss10.06
# 当前的批次为： 24
# loss14.20
# 当前的批次为： 25
# loss13.54
# 当前的批次为： 26
# loss1.84
# -----------------------------------------------
# ********  have trained 197 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7906976744186046  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7901234567901235  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7652173913043477  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7697160883280757  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7728459530026109  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7757847533632288  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7794676806083649  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss11.39
# 当前的批次为： 2
# loss15.05
# 当前的批次为： 3
# loss5.80
# 当前的批次为： 4
# loss12.06
# 当前的批次为： 5
# loss7.75
# 当前的批次为： 6
# loss12.71
# 当前的批次为： 7
# loss9.81
# 当前的批次为： 8
# loss13.39
# 当前的批次为： 9
# loss21.98
# 当前的批次为： 10
# loss12.52
# 当前的批次为： 11
# loss7.61
# 当前的批次为： 12
# loss9.05
# 当前的批次为： 13
# loss5.16
# 当前的批次为： 14
# loss8.21
# 当前的批次为： 15
# loss27.05
# 当前的批次为： 16
# loss14.70
# 当前的批次为： 17
# loss7.11
# 当前的批次为： 18
# loss22.94
# 当前的批次为： 19
# loss10.14
# 当前的批次为： 20
# loss7.66
# 当前的批次为： 21
# loss5.57
# 当前的批次为： 22
# loss14.87
# 当前的批次为： 23
# loss9.80
# 当前的批次为： 24
# loss11.81
# 当前的批次为： 25
# loss13.40
# 当前的批次为： 26
# loss2.75
# -----------------------------------------------
# ********  have trained 198 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.8235294117647058  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.8148148148148149  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7792207792207793  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7875000000000001  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7958656330749354  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.8044444444444444  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7969924812030074  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss13.66
# 当前的批次为： 2
# loss16.03
# 当前的批次为： 3
# loss5.48
# 当前的批次为： 4
# loss9.53
# 当前的批次为： 5
# loss9.30
# 当前的批次为： 6
# loss10.93
# 当前的批次为： 7
# loss9.37
# 当前的批次为： 8
# loss13.11
# 当前的批次为： 9
# loss24.33
# 当前的批次为： 10
# loss11.22
# 当前的批次为： 11
# loss10.05
# 当前的批次为： 12
# loss11.55
# 当前的批次为： 13
# loss3.30
# 当前的批次为： 14
# loss10.12
# 当前的批次为： 15
# loss27.68
# 当前的批次为： 16
# loss11.42
# 当前的批次为： 17
# loss12.08
# 当前的批次为： 18
# loss15.09
# 当前的批次为： 19
# loss8.44
# 当前的批次为： 20
# loss6.42
# 当前的批次为： 21
# loss5.18
# 当前的批次为： 22
# loss11.76
# 当前的批次为： 23
# loss8.54
# 当前的批次为： 24
# loss17.97
# 当前的批次为： 25
# loss12.84
# 当前的批次为： 26
# loss2.48
# -----------------------------------------------
# ********  have trained 199 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.8095238095238095  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7924528301886793  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7577092511013217  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7721518987341773  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7769028871391076  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7792792792792793  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7756653992395437  ********
# -----------------------------------------------
# 当前的批次为： 1
# loss9.99
# 当前的批次为： 2
# loss9.99
# 当前的批次为： 3
# loss6.55
# 当前的批次为： 4
# loss13.98
# 当前的批次为： 5
# loss11.68
# 当前的批次为： 6
# loss9.71
# 当前的批次为： 7
# loss7.06
# 当前的批次为： 8
# loss11.19
# 当前的批次为： 9
# loss18.95
# 当前的批次为： 10
# loss10.04
# 当前的批次为： 11
# loss7.80
# 当前的批次为： 12
# loss12.20
# 当前的批次为： 13
# loss9.00
# 当前的批次为： 14
# loss11.52
# 当前的批次为： 15
# loss30.23
# 当前的批次为： 16
# loss9.72
# 当前的批次为： 17
# loss10.08
# 当前的批次为： 18
# loss18.42
# 当前的批次为： 19
# loss10.83
# 当前的批次为： 20
# loss10.64
# 当前的批次为： 21
# loss8.59
# 当前的批次为： 22
# loss16.94
# 当前的批次为： 23
# loss12.53
# 当前的批次为： 24
# loss17.64
# 当前的批次为： 25
# loss12.54
# 当前的批次为： 26
# loss3.23
# -----------------------------------------------
# ********  have trained 200 epoch!  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7951807228915663  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7924528301886793  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7577092511013217  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7643312101910829  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7684210526315789  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7692307692307693  ********
# -----------------------------------------------
# ********  best_score:0.8372093023255814  ********
# -----------------------------------------------
# ********  f1_score:0.7701149425287357  ********
# -----------------------------------------------

# %%
print(best_score)
print(len(all_pre))
# Out:
# 0.8372093023255814
# 111

# %% [markdown]
# ## 2 使用训练后的模型预测数据

# %%
# 读取数据
def read_data(file):
    all_token_list = []
    all_label_list = []

    token_list = []
    label_list = []
    with open(file, "r", encoding="utf-8") as f:
        all_data = f.read().split("\n")
    lenth_sentence_list = [] #用于存储句子的长度
    for data in all_data:
        # 但是在我重新处理的语料中，根据句号.来对句子进行划分
        if len(data) > 0:
            if data == ". O":
                # 统计一下大多数的句子的长度，太长或者太短的句子直接丢掉，不要保存在语料列表当中
                if len(token_list) > 0 and len(token_list) < 500: 
                    lenth_sentence_list.append(len(token_list))
                    all_token_list.append(token_list)
                    all_label_list.append(label_list)
                token_list = []
                label_list = []
            else:
                # print(data)
                token, lable = data.split(" ")
                token_list.append(token)
                label_list.append(lable)
    return all_token_list, all_label_list, lenth_sentence_list
dev_text, dev_label, dev_lenth_sentence_list = read_data("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/mechanical_ner/data/original_data/machine_data1/patent_1_dev.txt")
print("最长的句子为：", max(dev_lenth_sentence_list))
print("有多少条句子：", len(dev_lenth_sentence_list))
# Out:
# 最长的句子为： 482
# 有多少条句子： 7239

# %%
import os
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF

# 调用torch中bert的分词器
tokenizer = BertTokenizer.from_pretrained(os.path.join('.', 'model_bin'))

# 构建数据集
class BertDataset(Dataset):
    def __init__(self, all_text, all_label, label2idx, max_len, tokenizer, is_test=False):
        self.all_text = all_text
        self.all_label = all_label
        self.label2idx = label2idx
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.is_test = is_test

    def __getitem__(self, index):
        if self.is_test:
            self.max_len = len(self.all_label[index])

        # 按批次获得数据
        text = self.all_text[index]
        # 0到max_len的词有对应的label,后面的用padding（转换为数字张量之后就是0了）补充
        label = self.all_label[index][:self.max_len]
        
        # 这里的encode函数要做的事：
        # 对词进行编码，将词转换为在词表中对应的数字
        # 对长度大于max_length的语句进行截断（超出了max_length的直接没有了），对长度不足max_length的语句进行padding填充
        # 添加特殊的标记符
        # 返回tensor类型的张量，即将词进行编码为torch张量
        text_index = self.tokenizer.encode(text,
                                           add_special_tokens=True,
                                           max_length=self.max_len + 2,        # 加上两个左右标识符
                                           padding="max_length",
                                           truncation=True,
                                           return_tensors="pt")        # pt 返回pytorch的张量
        label_index = [0] + [self.label2idx.get(l, 1) for l in label] + [0] + [0] * (max_len - len(text))
        # 将编码后的label转换为torch张量
        label_index = torch.tensor(label_index)
        # 统一text_index和label_index的形状和维度
        return text_index.reshape(-1), label_index, len(label)

    def __len__(self):
        return self.all_text.__len__()

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from transformers import BertModel
from transformers import AdamW
from seqeval.metrics import f1_score as seqeval_f1_score
from torchcrf import CRF


batch_size = 16
max_len = max(dev_lenth_sentence_list)

dev_dataset = BertDataset(dev_text,
                          dev_label,
                          label2idx,
                          max_len,
                          tokenizer)
dev_dataloader = DataLoader(dev_dataset,
                            batch_size=batch_size,
                            shuffle=False)

print("train_dataset的数据类型为： ", type(train_dataset))
# Out:
# train_dataset的数据类型为：  <class '__main__.BertDataset'>

# %%
model.eval()
all_pre = []    # 记录所有的预测label
all_tag = []    # 记录所有的真实label
batch_index = 1
for batch_text_index, batch_label_index, batch_len in dev_dataloader:
    batch_text_index = batch_text_index.cuda()
    batch_label_index = batch_label_index.cuda()
    # 获得模型预测的结果(这里是一个批次的数据)
    pre = model.forward(batch_text_index)
    # 加载真实的label
    tag = batch_label_index.tolist()

    for p, t, l in zip(pre, tag, batch_len):
        p = p[1:1 + l]
        t = t[1:1 + l]

        p = [idx2label[i] for i in p]
        t = [idx2label[i] for i in t]

        all_pre.append(p)
        all_tag.append(t)

    batch_index = batch_index + 1

# %%
print("语料的总批次为：", batch_index)
print("label的总个数为：", len(all_pre))
print("字符的总个数为：", len(dev_text))
# Out:
# 语料的总批次为： 454
# label的总个数为： 7239
# 字符的总个数为： 7239

# %% [markdown]
# ## 3 将预测的结果转换格式并写入文件（有预处理的格式转换为一篇文章下属的实体及label的格式）

# %%
word2label_list = []
for i in range(len(dev_text)):
    word2label_dic = {}
    for j in range(len(dev_text[i])):
        word2label_dic[dev_text[i][j]] = all_pre[i][j]
    word2label_list.append(word2label_dic)
print("字符-label对的总个数为：", len(word2label_list))
# Out:
# 字符-label对的总个数为： 7239

# %%
word2label_list
# Out:
# [{'##id:360': 'O',
#   'Method': 'O',
#   'image': 'O',
#   'processing': 'O',
#   'device': 'O',
#   'computer': 'O',
#   'program': 'O',
#   'and': 'O',
#   'electronically': 'O',
#   'readable': 'O',
#   'data': 'O',
#   'carrier': 'O',
#   'for': 'O',
#   'reducing': 'B-EFA',
#   'vessel': 'O',
#   'overlap': 'B-EST',
#   'artifacts': 'I-EST',
#   'in': 'O',
#   'a': 'O',
#   'four': 'B-EST',
#   'dimensional': 'I-EST',
#   'angiography': 'O',
#   'set': 'O',
#   'Vessel': 'O',
#   'are': 'O',
#   'reduced': 'O',
#   'blood': 'O',
#   'system': 'O',
#   'of': 'O',
#   'patient': 'O',
#   'with': 'O',
#   'contrast': 'B-EST',
#   'medium': 'I-EST'},
#  {'A': 'O',
#   'three': 'O',
#   'dimensional': 'I-EST',
#   'vessel': 'O',
#   'data': 'O',
#   'set': 'O',
#   'of': 'O',
#   'the': 'O',
#   'blood': 'B-EST',
#   'system': 'O',
#   'is': 'O',
#   'reconstructed': 'O',
#   'from': 'O',
#   'two': 'O',
#   'projection': 'O',
#   'images': 'O',
#   'digital': 'O',
#   'subtraction': 'O',
#   'angiography': 'O',
#   'showing': 'O',
#   'determined': 'O',
#   'by': 'O',
#   'multiplicative': 'O',
#   'back': 'O',
#   'into': 'O',
#   'or': 'O',
#   'a': 'O',
#   'base': 'O',
#   'four': 'B-EST',
#   'derived': 'O'},
#  {'A': 'O',
#   'plausibility': 'O',
#   'check': 'O',
#   'is': 'O',
#   'performed': 'O',
#   'with': 'O',
#   'vessel': 'O',
#   'sections': 'O',
#   'displayed': 'I-EST',
#   'as': 'O',
#   'filled': 'O',
#   'contrast': 'O',
#   'medium': 'O',
#   'in': 'O',
#   'partial': 'I-EST',
#   'image': 'I-EST',
#   'data': 'O',
#   'sets': 'O',
#   'of': 'O',
#   'the': 'O',
#   'angiography': 'O',
#   'set': 'O',
#   'assigned': 'O',
#   'to': 'O',
#   'all': 'O',
#   'individual': 'O',
#   'and': 'O',
#   'different': 'O',
#   'instants': 'O',
#   'covered': 'B-EST',
#   'period': 'I-EST',
#   'are': 'O',
#   'checked': 'O',
#   'against': 'O',
#   'a': 'O',
#   'criterion': 'O',
#   'checking': 'O',
#   'for': 'O',
#   'connection': 'O',
#   'an': 'O',
#   'admissible': 'O',
#   'source': 'O',
#   'point': 'O',
#   'after': 'O',
#   'which': 'O',
#   'corrected': 'B-EST',
#   'determined': 'O',
#   'containing': 'O',
#   'only': 'O',
#   'satisfying': 'O'},
#  {'1': 'O'},
#  {'A': 'O',
#   'method': 'B-EFA',
#   'for': 'O',
#   'reducing': 'O',
#   'vessel': 'O',
#   'overlap': 'I-EST',
#   'artifacts': 'I-EST',
#   'in': 'O',
#   'a': 'O',
#   'four': 'O',
#   'dimensional': 'B-EST',
#   'angiography': 'B-EST',
#   'data': 'I-EST',
#   'set': 'O',
#   'of': 'O',
#   'recording': 'O',
#   'region': 'O',
#   'interest': 'O',
#   'blood': 'B-EST',
#   'system': 'I-EST',
#   'patient': 'B-EST',
#   'recorded': 'I-EST',
#   'with': 'O',
#   'administration': 'O',
#   'contrast': 'B-EFO',
#   'medium': 'I-EFO',
#   'wherein': 'B-EST',
#   'three': 'O',
#   'the': 'O',
#   'is': 'O',
#   'reconstructed': 'O',
#   'from': 'O',
#   'two': 'O',
#   'projection': 'B-EST',
#   'images': 'I-EST',
#   'digital': 'O',
#   'subtraction': 'O',
#   'showing': 'O',
#   'and': 'O',
#   'determined': 'O',
#   'by': 'O',
#   'multiplicative': 'B-EST',
#   'back': 'O',
#   'into': 'O',
#   'or': 'O',
#   'base': 'B-EST',
#   'derived': 'O',
#   'comprising': 'O',
#   'performing': 'I-EST',
#   'an': 'O',
#   'imaging': 'B-EFO',
#   'processing': 'I-EFO',
#   'device': 'O',
#   'plausibility': 'B-EST',
#   'check': 'O',
#   'checking': 'O',
#   'sections': 'O',
#   'displayed': 'O',
#   'as': 'O',
#   'filled': 'O',
#   'partial': 'I-EST',
#   'image': 'I-EST',
#   'sets': 'O',
#   'assigned': 'O',
#   'to': 'O',
#   'individual': 'O',
#   'different': 'B-EST',
#   'instants': 'I-EST',
#   'covered': 'O',
#   'period': 'O',
#   'against': 'O',
#   'criterion': 'O',
#   'existence': 'O',
#   'connection': 'I-EST',
#   'admissible': 'I-EST',
#   'source': 'I-EST',
#   'point': 'O',
#   'determining': 'O',
#   'corrected': 'O',
#   'that': 'O',
#   'satisfy': 'O',
#   'points': 'I-EST',
#   'are': 'O',
#   'voxels': 'O',
#   'located': 'O',
#   'at': 'O',
#   'edge': 'O',
#   'immediately': 'B-EST',
#   'preceding': 'I-EST',
#   'have': 'O',
#   'already': 'O',
#   'been': 'O',
#   'current': 'B-EST',
#   'position': 'O',
#   'administering': 'I-EFO',
#   'inside': 'O'},
#  {'2': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'an': 'O',
#   'interruption': 'O',
#   'to': 'O',
#   'the': 'O',
#   'connection': 'O',
#   'path': 'O',
#   'satisfying': 'O',
#   'artifact': 'O',
#   'criterion': 'O',
#   'is': 'O',
#   'regarded': 'O',
#   'as': 'O',
#   'contrast': 'B-EST',
#   'medium': 'I-EST',
#   'filled': 'I-EST'},
#  {'3': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '2': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'artifact': 'O',
#   'criterion': 'I-EST',
#   'uses': 'O',
#   'a': 'O',
#   'temporal': 'B-EST',
#   'correlation': 'I-EST',
#   'between': 'O',
#   'filling': 'O',
#   'on': 'O',
#   'either': 'O',
#   'side': 'O',
#   'interruption': 'O',
#   'an': 'O',
#   'evaluation': 'O',
#   'result': 'O',
#   'three': 'O',
#   'dimensional': 'O',
#   'vessel': 'O',
#   'data': 'O',
#   'set': 'O',
#   'pointing': 'O',
#   'toward': 'O',
#   'part': 'O',
#   'missing': 'O',
#   'due': 'O',
#   'to': 'O',
#   'or': 'O',
#   'threshold': 'O',
#   'value': 'O',
#   'for': 'O',
#   'maximum': 'O',
#   'length': 'O'},
#  {'4': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'an': 'O',
#   'algorithm': 'O',
#   'graph': 'O',
#   'theory': 'O',
#   'for': 'O',
#   'finding': 'O',
#   'connected': 'B-EST',
#   'components': 'I-EST',
#   'is': 'O',
#   'used': 'O',
#   'determining': 'O',
#   'the': 'O',
#   'vessel': 'B-EST',
#   'sections': 'I-EST'},
#  {'5': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'a': 'O',
#   'binary': 'O',
#   'data': 'O',
#   'set': 'O',
#   'showing': 'O',
#   'position': 'O',
#   'the': 'O',
#   'vessel': 'O',
#   'sections': 'I-EST',
#   'satisfying': 'O',
#   'plausibility': 'B-EST',
#   'check': 'O',
#   'criterion': 'O',
#   'is': 'O',
#   'determined': 'O',
#   'by': 'O',
#   'removing': 'B-EST',
#   'that': 'O',
#   'do': 'O',
#   'not': 'O',
#   'satisfy': 'O',
#   'in': 'O',
#   'work': 'O',
#   'applied': 'O',
#   'as': 'O',
#   'mask': 'O',
#   'to': 'O',
#   'temporally': 'B-EST',
#   'assigned': 'I-EST',
#   'partial': 'I-EST',
#   'image': 'O',
#   'three': 'O',
#   'dimensional': 'O',
#   'or': 'O',
#   'base': 'O'},
#  {'6': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'further': 'O',
#   'comprising': 'I-EST',
#   'interpolating': 'I-EST',
#   'prior': 'I-EST',
#   'to': 'O',
#   'performing': 'O',
#   'the': 'O',
#   'plausibility': 'O',
#   'check': 'O',
#   'and': 'O',
#   'based': 'O',
#   'on': 'O',
#   'a': 'O',
#   'standardized': 'B-EST',
#   'four': 'I-EST',
#   'dimensional': 'O',
#   'confidence': 'O',
#   'data': 'O',
#   'set': 'O',
#   'measurements': 'O',
#   'determined': 'O',
#   'from': 'O',
#   'three': 'O',
#   'vessel': 'O',
#   'for': 'O',
#   'blood': 'O',
#   'vessels': 'O',
#   'located': 'O',
#   'along': 'O',
#   'beam': 'O',
#   'back': 'O',
#   'projection': 'O',
#   'during': 'O',
#   'determination': 'O',
#   'value': 'O',
#   'voxel': 'O',
#   'partial': 'O',
#   'image': 'O',
#   'replace': 'O',
#   'reliable': 'O',
#   'values': 'O',
#   'in': 'O',
#   'sets': 'O',
#   'with': 'O',
#   'correction': 'O',
#   'interpolated': 'O',
#   'temporally': 'O',
#   'linearly': 'O',
#   'more': 'O'},
#  {'7': 'O'},
#  {'An': 'O',
#   'angiography': 'O',
#   'device': 'O',
#   'comprising': 'O',
#   'an': 'O',
#   'image': 'I-EST',
#   'processing': 'O',
#   'configured': 'O',
#   'to': 'O',
#   'determine': 'O',
#   'a': 'O',
#   'four': 'B-EST',
#   'dimensional': 'B-EST',
#   'data': 'I-EST',
#   'set': 'O',
#   'of': 'O',
#   'recording': 'O',
#   'region': 'O',
#   'interest': 'O',
#   'blood': 'B-EST',
#   'vessel': 'O',
#   'system': 'I-EST',
#   'patient': 'O',
#   'recorded': 'O',
#   'with': 'O',
#   'administration': 'O',
#   'contrast': 'B-EST',
#   'medium': 'I-EST',
#   'wherein': 'O',
#   'three': 'O',
#   'the': 'O',
#   'is': 'O',
#   'be': 'O',
#   'reconstructed': 'O',
#   'from': 'O',
#   'two': 'O',
#   'projection': 'B-EST',
#   'images': 'O',
#   'digital': 'O',
#   'subtraction': 'O',
#   'showing': 'O',
#   'and': 'O',
#   'determined': 'O',
#   'by': 'O',
#   'multiplicative': 'O',
#   'back': 'O',
#   'into': 'O',
#   'or': 'O',
#   'base': 'B-EST',
#   'derived': 'O',
#   'check': 'O',
#   'sections': 'O',
#   'displayed': 'O',
#   'as': 'O',
#   'filled': 'O',
#   'plausibility': 'O',
#   'criterion': 'O',
#   'that': 'O',
#   'checks': 'O',
#   'for': 'O',
#   'existence': 'O',
#   'connection': 'I-EST',
#   'admissible': 'O',
#   'source': 'O',
#   'point': 'O',
#   'in': 'O',
#   'partial': 'I-EST',
#   'sets': 'O',
#   'assigned': 'O',
#   'individual': 'O',
#   'different': 'O',
#   'instants': 'O',
#   'covered': 'B-EST',
#   'period': 'I-EST',
#   'corrected': 'O',
#   'containing': 'O',
#   'only': 'O',
#   'satisfying': 'O',
#   'points': 'O',
#   'are': 'O',
#   'voxels': 'O',
#   'located': 'O',
#   'at': 'O',
#   'edge': 'O',
#   'immediately': 'B-EST',
#   'preceding': 'I-EST',
#   'have': 'O',
#   'already': 'O',
#   'been': 'O',
#   'current': 'B-EST',
#   'position': 'O',
#   'administering': 'I-EST',
#   'inside': 'O'},
#  {'8': 'O'},
#  {'A': 'O',
#   'computer': 'I-EST',
#   'program': 'O',
#   'stored': 'O',
#   'on': 'O',
#   'a': 'O',
#   'non': 'B-EST',
#   'transitory': 'I-EST',
#   'readable': 'I-EST',
#   'medium': 'I-EST',
#   'that': 'O',
#   'when': 'O',
#   'executed': 'O',
#   'an': 'O',
#   'image': 'I-EST',
#   'processing': 'I-EST',
#   'device': 'O',
#   'is': 'O',
#   'configured': 'O',
#   'to': 'O',
#   'cause': 'O',
#   'the': 'O',
#   'reconstruct': 'O',
#   'three': 'O',
#   'dimensional': 'B-EST',
#   'vessel': 'O',
#   'data': 'I-EST',
#   'set': 'O',
#   'of': 'O',
#   'blood': 'B-EST',
#   'system': 'I-EST',
#   'patient': 'O',
#   'recorded': 'O',
#   'with': 'O',
#   'administration': 'O',
#   'contrast': 'B-EST',
#   'from': 'O',
#   'two': 'O',
#   'projection': 'B-EST',
#   'images': 'O',
#   'digital': 'O',
#   'subtraction': 'O',
#   'angiography': 'O',
#   'showing': 'O',
#   'and': 'O',
#   'determined': 'O',
#   'by': 'O',
#   'multiplicative': 'B-EST',
#   'back': 'O',
#   'into': 'O',
#   'or': 'O',
#   'base': 'B-EST',
#   'four': 'O',
#   'derived': 'O',
#   'perform': 'B-EFA',
#   'plausibility': 'O',
#   'check': 'O',
#   'comprising': 'O',
#   'checking': 'O',
#   'sections': 'O',
#   'displayed': 'O',
#   'as': 'O',
#   'filled': 'O',
#   'in': 'O',
#   'partial': 'I-EST',
#   'sets': 'O',
#   'assigned': 'O',
#   'individual': 'O',
#   'different': 'B-EFO',
#   'instants': 'I-EFO',
#   'covered': 'O',
#   'period': 'O',
#   'against': 'O',
#   'criterion': 'O',
#   'for': 'O',
#   'existence': 'O',
#   'connection': 'I-EST',
#   'admissible': 'I-EST',
#   'source': 'O',
#   'point': 'O',
#   'determining': 'O',
#   'corrected': 'O',
#   'satisfy': 'O',
#   'wherein': 'B-EST',
#   'points': 'O',
#   'are': 'O',
#   'voxels': 'O',
#   'located': 'O',
#   'at': 'O',
#   'edge': 'O',
#   'recording': 'O',
#   'region': 'O',
#   'immediately': 'B-EST',
#   'preceding': 'I-EST',
#   'have': 'O',
#   'already': 'O',
#   'been': 'O',
#   'current': 'B-EST',
#   'position': 'O',
#   'administering': 'O',
#   'inside': 'O'},
#  {'9': 'O'},
#  {'The': 'O',
#   'computer': 'O',
#   'program': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '8': 'O',
#   'wherein': 'O',
#   'an': 'O',
#   'interruption': 'O',
#   'to': 'O',
#   'the': 'O',
#   'connection': 'O',
#   'path': 'I-EST',
#   'satisfying': 'O',
#   'artifact': 'O',
#   'criterion': 'O',
#   'is': 'O',
#   'regarded': 'O',
#   'as': 'O',
#   'contrast': 'B-EST',
#   'medium': 'I-EST',
#   'filled': 'I-EST'},
#  {'10': 'O'},
#  {'The': 'O',
#   'computer': 'O',
#   'program': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '9': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'artifact': 'O',
#   'criterion': 'O',
#   'uses': 'O',
#   'a': 'O',
#   'temporal': 'O',
#   'correlation': 'O',
#   'between': 'O',
#   'filling': 'O',
#   'on': 'O',
#   'either': 'O',
#   'side': 'O',
#   'interruption': 'O',
#   'an': 'O',
#   'evaluation': 'O',
#   'result': 'O',
#   'three': 'O',
#   'dimensional': 'O',
#   'vessel': 'O',
#   'data': 'O',
#   'set': 'O',
#   'pointing': 'O',
#   'toward': 'O',
#   'part': 'O',
#   'missing': 'O',
#   'due': 'O',
#   'to': 'O',
#   'or': 'O',
#   'threshold': 'O',
#   'value': 'O',
#   'for': 'O',
#   'maximum': 'O',
#   'length': 'O'},
#  {'11': 'O'},
#  {'The': 'O',
#   'computer': 'O',
#   'program': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '8': 'O',
#   'wherein': 'O',
#   'an': 'O',
#   'algorithm': 'O',
#   'graph': 'O',
#   'theory': 'O',
#   'for': 'O',
#   'finding': 'O',
#   'connected': 'B-EST',
#   'components': 'I-EST',
#   'is': 'O',
#   'used': 'O',
#   'determining': 'O',
#   'the': 'O',
#   'vessel': 'B-EST',
#   'sections': 'I-EST'},
#  {'12': 'O'},
#  {'The': 'O',
#   'computer': 'O',
#   'program': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '8': 'O',
#   'wherein': 'O',
#   'a': 'O',
#   'binary': 'O',
#   'data': 'O',
#   'set': 'O',
#   'showing': 'O',
#   'position': 'O',
#   'the': 'O',
#   'vessel': 'O',
#   'sections': 'I-EST',
#   'satisfying': 'O',
#   'plausibility': 'B-EST',
#   'check': 'I-EST',
#   'criterion': 'I-EST',
#   'is': 'O',
#   'determined': 'O',
#   'by': 'O',
#   'removing': 'B-EST',
#   'that': 'O',
#   'do': 'O',
#   'not': 'O',
#   'satisfy': 'O',
#   'in': 'O',
#   'work': 'O',
#   'applied': 'O',
#   'as': 'O',
#   'mask': 'O',
#   'to': 'O',
#   'temporally': 'B-EST',
#   'assigned': 'I-EST',
#   'partial': 'I-EST',
#   'image': 'O',
#   'three': 'O',
#   'dimensional': 'O',
#   'or': 'O',
#   'base': 'O'},
#  {'13': 'O'},
#  {'The': 'O',
#   'computer': 'O',
#   'program': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '8': 'O',
#   'further': 'O',
#   'comprising': 'O',
#   'interpolating': 'O',
#   'prior': 'O',
#   'to': 'O',
#   'performing': 'O',
#   'the': 'O',
#   'plausibility': 'O',
#   'check': 'O',
#   'and': 'O',
#   'based': 'O',
#   'on': 'O',
#   'a': 'O',
#   'standardized': 'O',
#   'four': 'O',
#   'dimensional': 'O',
#   'confidence': 'O',
#   'data': 'O',
#   'set': 'O',
#   'measurements': 'O',
#   'determined': 'O',
#   'from': 'O',
#   'three': 'O',
#   'vessel': 'O',
#   'for': 'O',
#   'blood': 'O',
#   'vessels': 'O',
#   'located': 'O',
#   'along': 'O',
#   'beam': 'O',
#   'back': 'O',
#   'projection': 'O',
#   'during': 'O',
#   'determination': 'O',
#   'value': 'O',
#   'voxel': 'O',
#   'partial': 'O',
#   'image': 'O',
#   'replace': 'O',
#   'reliable': 'B-EFO',
#   'values': 'I-EFO',
#   'in': 'O',
#   'sets': 'O',
#   'with': 'O',
#   'correction': 'O',
#   'interpolated': 'I-EST',
#   'temporally': 'I-EST',
#   'linearly': 'O',
#   'more': 'O'},
#  {'14': 'O'},
#  {'A': 'O',
#   'non': 'O',
#   'transitory': 'O',
#   'electronically': 'B-EST',
#   'readable': 'I-EST',
#   'data': 'I-EST',
#   'carrier': 'I-EST',
#   'on': 'O',
#   'which': 'O',
#   'a': 'O',
#   'computer': 'B-EST',
#   'program': 'I-EST',
#   'is': 'O',
#   'stored': 'O',
#   'the': 'O',
#   'when': 'O',
#   'executed': 'O',
#   'configured': 'O',
#   'to': 'O',
#   'reconstruct': 'O',
#   'three': 'O',
#   'dimensional': 'B-EST',
#   'vessel': 'O',
#   'set': 'O',
#   'of': 'O',
#   'blood': 'B-EST',
#   'system': 'I-EST',
#   'patient': 'O',
#   'recorded': 'O',
#   'with': 'O',
#   'an': 'O',
#   'administration': 'O',
#   'contrast': 'B-EST',
#   'medium': 'I-EST',
#   'from': 'O',
#   'two': 'O',
#   'projection': 'O',
#   'images': 'O',
#   'digital': 'O',
#   'subtraction': 'O',
#   'angiography': 'B-EST',
#   'showing': 'O',
#   'and': 'O',
#   'determined': 'O',
#   'by': 'O',
#   'multiplicative': 'B-EST',
#   'back': 'O',
#   'into': 'O',
#   'or': 'O',
#   'base': 'B-EST',
#   'four': 'O',
#   'derived': 'O',
#   'perform': 'B-EFA',
#   'plausibility': 'B-EST',
#   'check': 'O',
#   'comprising': 'O',
#   'checking': 'B-EFO',
#   'sections': 'O',
#   'displayed': 'O',
#   'as': 'O',
#   'filled': 'O',
#   'in': 'O',
#   'partial': 'I-EST',
#   'image': 'I-EST',
#   'sets': 'O',
#   'assigned': 'O',
#   'individual': 'B-EFA',
#   'different': 'B-EFO',
#   'instants': 'I-EST',
#   'covered': 'O',
#   'period': 'O',
#   'against': 'O',
#   'criterion': 'O',
#   'for': 'O',
#   'existence': 'O',
#   'connection': 'I-EST',
#   'admissible': 'I-EST',
#   'source': 'O',
#   'point': 'O',
#   'determining': 'O',
#   'corrected': 'O',
#   'that': 'O',
#   'satisfy': 'O',
#   'wherein': 'B-EST',
#   'points': 'O',
#   'are': 'O',
#   'voxels': 'O',
#   'located': 'O',
#   'at': 'O',
#   'edge': 'O',
#   'recording': 'O',
#   'region': 'O',
#   'immediately': 'B-EST',
#   'preceding': 'I-EST',
#   'have': 'O',
#   'already': 'O',
#   'been': 'O',
#   'current': 'B-EST',
#   'position': 'O',
#   'administering': 'O',
#   'device': 'O',
#   'inside': 'O'},
#  {'##id:99': 'O',
#   'Coated': 'O',
#   'packaging': 'O',
#   'products': 'O',
#   'systems': 'O',
#   'and': 'O',
#   'methods': 'O',
#   'In': 'O',
#   'a': 'O',
#   'method': 'O',
#   'of': 'O',
#   'forming': 'O',
#   'coated': 'O',
#   'bag': 'O',
#   'for': 'O',
#   'pre': 'O',
#   'treating': 'O',
#   'an': 'O',
#   'item': 'O',
#   'stored': 'O',
#   'in': 'O',
#   'the': 'O',
#   'is': 'O',
#   'provided': 'O',
#   'having': 'O',
#   'sidewall': 'B-EST',
#   'extending': 'I-EST',
#   'from': 'O',
#   'closed': 'O',
#   'bottom': 'O',
#   'end': 'O',
#   'to': 'O',
#   'open': 'O',
#   'top': 'O',
#   'defining': 'O',
#   'interior': 'B-EST',
#   'surface': 'I-EST',
#   'cavity': 'B-EST'},
#  {'The': 'O',
#   'bag': 'O',
#   'is': 'O',
#   'expanded': 'O',
#   'from': 'O',
#   'a': 'O',
#   'flattened': 'B-EST',
#   'condition': 'O',
#   'to': 'O',
#   'an': 'O'},
#  {'At': 'O',
#   'least': 'O',
#   'one': 'O',
#   'adhesive': 'O',
#   'dispenser': 'O',
#   'is': 'O',
#   'inserted': 'O',
#   'through': 'O',
#   'the': 'O',
#   'open': 'O',
#   'top': 'O',
#   'end': 'O',
#   'of': 'O',
#   'bag': 'O',
#   'into': 'O',
#   'cavity': 'O'},
#  {'An': 'O',
#   'adhesive': 'O',
#   'is': 'O',
#   'applied': 'O',
#   'from': 'O',
#   'the': 'O',
#   'at': 'O',
#   'least': 'O',
#   'one': 'O',
#   'inserted': 'O',
#   'dispenser': 'O',
#   'to': 'O',
#   'form': 'O',
#   'an': 'O',
#   'coating': 'O',
#   'on': 'O',
#   'interior': 'O',
#   'surface': 'O',
#   'of': 'O',
#   'cavity': 'B-EST'},
#  {'A': 'O',
#   'particulate': 'O',
#   'dispenser': 'O',
#   'is': 'O',
#   'inserted': 'O',
#   'through': 'O',
#   'the': 'O',
#   'open': 'O',
#   'top': 'O',
#   'end': 'O',
#   'of': 'O',
#   'bag': 'O',
#   'into': 'O',
#   'cavity': 'O'},
#  {'A': 'O',
#   'particulate': 'O',
#   'is': 'O',
#   'discharged': 'O',
#   'from': 'O',
#   'the': 'O',
#   'inserted': 'B-EST',
#   'dispenser': 'I-EST',
#   'to': 'O',
#   'embed': 'O',
#   'in': 'O',
#   'adhesive': 'O',
#   'coating': 'O'},
#  {'The': 'O',
#   'adhesive': 'O',
#   'coating': 'O',
#   'is': 'O',
#   'dried': 'O',
#   'to': 'O',
#   'retain': 'O',
#   'the': 'O',
#   'embedded': 'B-EST',
#   'particulate': 'I-EST',
#   'on': 'O',
#   'interior': 'O',
#   'surface': 'O',
#   'of': 'O',
#   'sidewall': 'O'},
#  {'1': 'O'},
#  {'A': 'O',
#   'method': 'B-EST',
#   'of': 'O',
#   'forming': 'O',
#   'a': 'O',
#   'coated': 'B-EST',
#   'bag': 'O',
#   'for': 'O',
#   'pre': 'O',
#   'treating': 'O',
#   'an': 'O',
#   'item': 'O',
#   'stored': 'O',
#   'in': 'O',
#   'the': 'O',
#   'comprising': 'I-EST',
#   'providing': 'O',
#   'having': 'O',
#   'sidewall': 'B-EST',
#   'extending': 'I-EST',
#   'from': 'O',
#   'closed': 'B-EST',
#   'bottom': 'I-EST',
#   'end': 'O',
#   'to': 'O',
#   'open': 'O',
#   'top': 'O',
#   'and': 'O',
#   'defining': 'O',
#   'interior': 'B-EST',
#   'surface': 'I-EST',
#   'cavity': 'O',
#   'expanding': 'O',
#   'flattened': 'O',
#   'condition': 'I-EST',
#   'expanded': 'B-EST',
#   'inserting': 'O',
#   'at': 'O',
#   'least': 'O',
#   'one': 'O',
#   'adhesive': 'I-EST',
#   'dispenser': 'I-EST',
#   'through': 'I-EST',
#   'into': 'O',
#   'applying': 'O',
#   'inserted': 'B-EST',
#   'form': 'O',
#   'coating': 'O',
#   'on': 'O',
#   'particulate': 'O',
#   'discharging': 'O',
#   'embed': 'O',
#   'drying': 'O',
#   'retain': 'O',
#   'embedded': 'O',
#   'wherein': 'I-EST',
#   'is': 'O',
#   'first': 'B-EST',
#   'further': 'I-EST',
#   'second': 'B-EST',
#   'such': 'O',
#   'that': 'O',
#   'captured': 'O',
#   'between': 'O',
#   'coatings': 'O'},
#  {'2': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'applying': 'O',
#   'the': 'O',
#   'adhesive': 'O',
#   'comprises': 'O',
#   'spraying': 'O',
#   'a': 'O',
#   'liquid': 'O',
#   'having': 'O',
#   'viscosity': 'O',
#   'between': 'O',
#   'approximately': 'O',
#   '6': 'O',
#   'dPa': 'O',
#   'and': 'O',
#   '10': 'O'},
#  {'3': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'applying': 'O',
#   'the': 'O',
#   'adhesive': 'O',
#   'comprises': 'O',
#   'spraying': 'O',
#   'a': 'O',
#   'liquid': 'O',
#   'at': 'O',
#   'temperature': 'O',
#   'between': 'O',
#   'approximately': 'O',
#   '87°': 'O',
#   'F': 'O'},
#  {'and': 'O', 'approximately': 'O', '175°': 'O', 'F': 'O'},
#  {'4': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'applying': 'O',
#   'the': 'O',
#   'adhesive': 'O',
#   'comprises': 'O',
#   'spraying': 'O',
#   'a': 'O',
#   'liquid': 'O',
#   'at': 'O',
#   'pressure': 'O',
#   'between': 'O',
#   'approximately': 'O',
#   '200': 'O',
#   'psi': 'O',
#   'and': 'O',
#   '1300': 'O'},
#  {'5': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'applying': 'O',
#   'the': 'O',
#   'adhesive': 'O',
#   'comprises': 'O',
#   'spraying': 'O',
#   'a': 'O',
#   'liquid': 'O',
#   'at': 'O',
#   'flow': 'O',
#   'rate': 'O',
#   'between': 'O',
#   'about': 'O',
#   'g': 'O',
#   'per': 'O',
#   'second': 'O',
#   'and': 'O',
#   '2': 'O'},
#  {'6': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'expanding': 'O',
#   'the': 'O',
#   'bag': 'O',
#   'from': 'O',
#   'flattened': 'O',
#   'condition': 'O',
#   'to': 'O',
#   'expanded': 'O',
#   'comprises': 'O',
#   'applying': 'O',
#   'suction': 'O',
#   'an': 'O',
#   'outer': 'O',
#   'surface': 'O',
#   'sidewall': 'B-EST'},
#  {'7': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'drying': 'O',
#   'the': 'O',
#   'adhesive': 'O',
#   'coating': 'O',
#   'comprises': 'O',
#   'maintaining': 'O',
#   'coated': 'O',
#   'bag': 'O',
#   'at': 'O',
#   'a': 'O',
#   'maximum': 'O',
#   'temperature': 'O',
#   'up': 'O',
#   'to': 'O',
#   'approximately': 'O',
#   '160°': 'O',
#   'F': 'O'},
#  {'8': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'drying': 'O',
#   'the': 'O',
#   'adhesive': 'O',
#   'coating': 'O',
#   'comprises': 'O',
#   'applying': 'O',
#   'infrared': 'O',
#   'radiation': 'O',
#   'to': 'O',
#   'an': 'O',
#   'exterior': 'O',
#   'surface': 'O',
#   'bag': 'O'},
#  {'9': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'discharging': 'O',
#   'the': 'O',
#   'particulate': 'O',
#   'from': 'O',
#   'inserted': 'O',
#   'dispenser': 'O',
#   'comprises': 'O',
#   'at': 'O',
#   'least': 'O',
#   'one': 'O',
#   'a': 'O',
#   'seasoning': 'O',
#   'coloring': 'O',
#   'and': 'O',
#   'preservative': 'O'},
#  {'10': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'first': 'O',
#   'and': 'O',
#   'second': 'B-EST',
#   'adhesives': 'I-EST',
#   'are': 'O',
#   'substantially': 'O',
#   'same': 'B-EST',
#   'material': 'I-EST'},
#  {'11': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'first': 'O',
#   'and': 'O',
#   'second': 'O',
#   'adhesives': 'O',
#   'are': 'O',
#   'applied': 'O',
#   'at': 'O',
#   'substantially': 'O',
#   'same': 'B-EST',
#   'temperature': 'I-EST'},
#  {'12': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'first': 'O',
#   'and': 'O',
#   'second': 'O',
#   'adhesives': 'O',
#   'have': 'O',
#   'substantially': 'O',
#   'same': 'O',
#   'viscosity': 'O',
#   'when': 'O',
#   'applied': 'O'},
#  {'13': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'discharging': 'O',
#   'the': 'O',
#   'particulate': 'I-EST',
#   'comprises': 'O',
#   'a': 'O',
#   'first': 'O',
#   'further': 'O',
#   'comprising': 'O',
#   'second': 'B-EST',
#   'after': 'O',
#   'applying': 'O',
#   'adhesive': 'I-EST',
#   'such': 'O',
#   'that': 'O',
#   'is': 'O',
#   'embedded': 'O',
#   'in': 'O',
#   'coating': 'O'},
#  {'14': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '13': 'O',
#   'further': 'B-EST',
#   'comprising': 'I-EST',
#   'applying': 'O',
#   'a': 'O',
#   'third': 'O',
#   'adhesive': 'O',
#   'from': 'O',
#   'the': 'O',
#   'at': 'O',
#   'least': 'O',
#   'one': 'O',
#   'inserted': 'O',
#   'dispenser': 'O',
#   'after': 'O',
#   'discharging': 'O',
#   'second': 'O',
#   'particulate': 'O',
#   'to': 'O',
#   'form': 'O',
#   'coating': 'O',
#   'on': 'O',
#   'embedded': 'I-EST',
#   'such': 'O',
#   'that': 'O',
#   'is': 'O',
#   'captured': 'O',
#   'between': 'O',
#   'and': 'O',
#   'coatings': 'O'},
#  {'15': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'adhesive': 'B-EST',
#   'coating': 'I-EST',
#   'has': 'O',
#   'an': 'O',
#   'area': 'O',
#   'density': 'O',
#   'between': 'O',
#   'approximately': 'O',
#   '20': 'O',
#   'mg': 'O',
#   'in2': 'O',
#   'and': 'O',
#   '60': 'O'},
#  {'16': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'B-EFA',
#   '1': 'O',
#   'wherein': 'O',
#   'discharging': 'O',
#   'the': 'O',
#   'particulate': 'I-EST',
#   'comprises': 'O',
#   'a': 'O',
#   'first': 'B-EST',
#   'further': 'O',
#   'comprising': 'O',
#   'second': 'B-EST',
#   'after': 'O',
#   'to': 'O',
#   'embed': 'O',
#   'in': 'O',
#   'adhesive': 'O',
#   'coating': 'O',
#   'being': 'O',
#   'different': 'O',
#   'from': 'O'},
#  {'17': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '16': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'first': 'O',
#   'particulate': 'O',
#   'has': 'O',
#   'an': 'O',
#   'average': 'O',
#   'particle': 'O',
#   'size': 'O',
#   'that': 'O',
#   'is': 'O',
#   'at': 'O',
#   'least': 'O',
#   '100': 'O',
#   'times': 'O',
#   'second': 'B-EST',
#   'being': 'O',
#   'embedded': 'O',
#   'in': 'O',
#   'adhesive': 'O',
#   'coating': 'O',
#   'spaces': 'O',
#   'between': 'O'},
#  {'18': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'adhesive': 'O',
#   'comprises': 'O',
#   'an': 'O',
#   'edible': 'O',
#   'and': 'O',
#   'particulate': 'O'},
#  {'19': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'applying': 'O',
#   'the': 'O',
#   'adhesive': 'O',
#   'to': 'O',
#   'form': 'O',
#   'coating': 'O',
#   'comprises': 'O',
#   'spraying': 'O',
#   'an': 'O',
#   'aerated': 'O',
#   'liquid': 'O',
#   'having': 'O',
#   'gas': 'O',
#   'bubbles': 'O',
#   'trapped': 'O',
#   'throughout': 'O'},
#  {'20': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'applying': 'O',
#   'the': 'O',
#   'adhesive': 'O',
#   'to': 'O',
#   'form': 'O',
#   'coating': 'O',
#   'comprises': 'O',
#   'spraying': 'O',
#   'an': 'O',
#   'aerated': 'O',
#   'liquid': 'O',
#   'a': 'O',
#   'foamed': 'O',
#   'on': 'O',
#   'interior': 'B-EST',
#   'surface': 'I-EST',
#   'cavity': 'B-EST'},
#  {'21': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'interior': 'O',
#   'surface': 'B-EST',
#   'has': 'O',
#   'a': 'O',
#   'tension': 'I-EST',
#   'between': 'O',
#   'about': 'O',
#   '30': 'O',
#   'dynes': 'O',
#   'cm': 'O',
#   'and': 'O',
#   '38': 'O'},
#  {'##id:397': 'O',
#   'Device': 'O',
#   'for': 'O',
#   'management': 'O',
#   'of': 'O',
#   'an': 'O',
#   'open': 'O',
#   'abdomen': 'O',
#   'A': 'O',
#   'device': 'O',
#   'includes': 'O',
#   'a': 'O',
#   'belt': 'O',
#   'having': 'O',
#   'first': 'O',
#   'and': 'O',
#   'second': 'O',
#   'end': 'O',
#   'portions': 'O'},
#  {'The': 'O',
#   'belt': 'O',
#   'is': 'O',
#   'positionable': 'O',
#   'to': 'O',
#   'extend': 'B-EFA',
#   'partially': 'I-EST',
#   'around': 'O',
#   'a': 'O',
#   'patient': 'O',
#   's': 'O',
#   'torso': 'O',
#   'in': 'O',
#   'taut': 'O',
#   'configuration': 'O',
#   'with': 'O',
#   'the': 'O',
#   'end': 'O',
#   'portions': 'O',
#   'positioned': 'O',
#   'on': 'O',
#   'opposed': 'O',
#   'sides': 'O',
#   'of': 'O',
#   'an': 'O',
#   'incision': 'O',
#   'abdomen': 'O'},
#  {'A': 'O',
#   'first': 'O',
#   'connector': 'I-EST',
#   'is': 'O',
#   'at': 'O',
#   'the': 'O',
#   'end': 'O',
#   'portion': 'O',
#   'and': 'O',
#   'a': 'O',
#   'second': 'O'},
#  {'The': 'O',
#   'connectors': 'O',
#   'are': 'O',
#   'positionable': 'B-EST',
#   'adjacent': 'I-EST',
#   'each': 'O',
#   'other': 'O',
#   'on': 'O',
#   'the': 'O',
#   'opposed': 'O',
#   'sides': 'O',
#   'of': 'O',
#   'incision': 'O'},
#  {'At': 'O',
#   'least': 'O',
#   'one': 'O',
#   'cinching': 'B-EST',
#   'device': 'I-EST',
#   'is': 'O',
#   'connected': 'O',
#   'to': 'O',
#   'and': 'O',
#   'extends': 'O',
#   'between': 'O',
#   'the': 'O',
#   'connectors': 'O'},
#  {'The': 'O',
#   'cinching': 'O',
#   'device': 'B-EST',
#   'is': 'O',
#   'positionable': 'O',
#   'to': 'O',
#   'extend': 'O',
#   'over': 'O',
#   'the': 'O',
#   'incision': 'O',
#   'when': 'O',
#   'connectors': 'O',
#   'are': 'O',
#   'positioned': 'O',
#   'adjacent': 'O',
#   'each': 'O',
#   'other': 'O',
#   'on': 'O',
#   'opposed': 'O',
#   'sides': 'O',
#   'of': 'O'},
#  {'The': 'O',
#   'cinching': 'O',
#   'device': 'O',
#   'is': 'O',
#   'adjustable': 'O',
#   'to': 'O',
#   'cinch': 'O',
#   'the': 'O',
#   'end': 'B-EST',
#   'portions': 'I-EST',
#   'towards': 'O',
#   'each': 'O',
#   'other': 'O',
#   'hold': 'O',
#   'incision': 'O',
#   'in': 'O',
#   'an': 'O',
#   'at': 'O',
#   'least': 'O',
#   'partially': 'O',
#   'closed': 'O',
#   'position': 'O'},
#  {'1': 'O'},
#  {'A': 'O',
#   'device': 'I-EST',
#   'for': 'O',
#   'management': 'O',
#   'of': 'O',
#   'an': 'O',
#   'open': 'O',
#   'incision': 'O',
#   'in': 'O',
#   'a': 'O',
#   'patient': 'O',
#   'the': 'O',
#   'comprising': 'O',
#   'belt': 'B-EST',
#   'having': 'O',
#   'first': 'O',
#   'end': 'O',
#   'portion': 'O',
#   'and': 'O',
#   'opposed': 'O',
#   'second': 'O',
#   'positionable': 'I-EST',
#   'to': 'O',
#   'extend': 'O',
#   'partially': 'O',
#   'around': 'O',
#   'taut': 'B-EST',
#   'configuration': 'I-EST',
#   'with': 'O',
#   'positioned': 'O',
#   'on': 'O',
#   'sides': 'O',
#   'b': 'O',
#   'connector': 'I-EST',
#   'comprises': 'O',
#   'lock': 'O',
#   'holding': 'O',
#   'clamp': 'B-EST',
#   'adapted': 'I-EST',
#   'hold': 'O',
#   'adjacent': 'O',
#   'each': 'O',
#   'other': 'O',
#   'when': 'O',
#   'is': 'O',
#   'c': 'O',
#   'at': 'O',
#   'least': 'O',
#   'one': 'O',
#   'cinching': 'B-EST',
#   'connected': 'I-EST',
#   'extending': 'O',
#   'between': 'O',
#   'over': 'O',
#   'are': 'O',
#   'adjustable': 'I-EST',
#   'cinch': 'O',
#   'towards': 'O',
#   'closed': 'O',
#   'position': 'O'},
#  {'2': 'O'},
#  {'The': 'O',
#   'device': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'at': 'O',
#   'least': 'O',
#   'one': 'O',
#   'cinching': 'O',
#   'is': 'O',
#   'adapted': 'O',
#   'to': 'O',
#   'collectively': 'O',
#   'apply': 'O',
#   '11.36': 'O',
#   '17.9': 'O',
#   'pounds': 'O',
#   'tension': 'O',
#   'between': 'O',
#   'connectors': 'O'},
#  {'3': 'O'},
#  {'The': 'O',
#   'device': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'configured': 'O',
#   'to': 'O',
#   'manage': 'O',
#   'an': 'O',
#   'incision': 'O',
#   'in': 'O',
#   'the': 'O',
#   'abdomen': 'O',
#   'patient': 'O'},
#  {'4': 'O'},
#  {'The': 'O',
#   'device': 'O',
#   'according': 'O',
#   'to': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'clamp': 'O',
#   'comprises': 'O',
#   'a': 'O',
#   'first': 'O',
#   'plate': 'O',
#   'hingedly': 'O',
#   'connected': 'O',
#   'second': 'O',
#   'movable': 'O',
#   'between': 'O',
#   'an': 'O',
#   'open': 'O',
#   'position': 'O',
#   'and': 'O',
#   'closed': 'O'},
#  {'5': 'O'},
#  {'The': 'O',
#   'device': 'O',
#   'according': 'O',
#   'to': 'O',
#   'claim': 'O',
#   '4': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'first': 'O',
#   'belt': 'I-EST',
#   'lock': 'O',
#   'and': 'O',
#   'second': 'O',
#   'each': 'O',
#   'comprise': 'O',
#   'a': 'O',
#   'gripping': 'B-EST',
#   'mechanism': 'I-EST',
#   'for': 'O',
#   'holding': 'O',
#   'end': 'O',
#   'portion': 'O',
#   'respectively': 'O'},
#  {'6': 'O'},
#  {'The': 'O',
#   'device': 'O',
#   'according': 'O',
#   'to': 'O',
#   'claim': 'B-EFA',
#   '5': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'gripping': 'O',
#   'mechanism': 'O',
#   'comprises': 'O',
#   'a': 'O',
#   'plurality': 'O',
#   'of': 'O',
#   'spikes': 'O',
#   'extending': 'O',
#   'upwardly': 'O',
#   'from': 'O',
#   'first': 'O',
#   'plate': 'I-EST',
#   'and': 'O',
#   'openings': 'O',
#   'in': 'O',
#   'second': 'B-EST',
#   'configured': 'O',
#   'receive': 'O',
#   'when': 'O',
#   'clamp': 'O',
#   'is': 'O',
#   'closed': 'O',
#   'position': 'O'},
#  {'7': 'O'},
#  {'A': 'O',
#   'method': 'B-EST',
#   'for': 'O',
#   'management': 'O',
#   'of': 'O',
#   'an': 'O',
#   'incision': 'O',
#   'in': 'O',
#   'a': 'O',
#   'patient': 'B-EST',
#   'the': 'O',
#   'comprising': 'I-EST',
#   'positioning': 'O',
#   'belt': 'O',
#   'to': 'O',
#   'extend': 'O',
#   'partially': 'O',
#   'around': 'I-EST',
#   'from': 'O',
#   'first': 'O',
#   'position': 'I-EST',
#   'on': 'O',
#   'side': 'O',
#   'portion': 'I-EST',
#   'second': 'O',
#   'taut': 'B-EST',
#   'configuration': 'O',
#   'b': 'O',
#   'securing': 'O',
#   'connector': 'I-EST',
#   'end': 'I-EST',
#   'and': 'O',
#   'comprises': 'O',
#   'lock': 'O',
#   'holding': 'O',
#   'clamp': 'B-EST',
#   'adapted': 'O',
#   'hold': 'O',
#   'where': 'O',
#   'connectors': 'I-EST',
#   'are': 'O',
#   'connect': 'O',
#   'cinching': 'O',
#   'device': 'I-EST',
#   'c': 'O',
#   'cinched': 'B-EST',
#   'bring': 'O',
#   'towards': 'I-EST',
#   'each': 'I-EST',
#   'other': 'O',
#   'd': 'O',
#   'temporarily': 'O',
#   'at': 'O',
#   'least': 'O',
#   'closed': 'O'},
#  {'8': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '7': 'O',
#   'further': 'O',
#   'comprising': 'O',
#   'prior': 'O',
#   'to': 'O',
#   'step': 'O',
#   'c': 'O',
#   'positioning': 'O',
#   'the': 'O',
#   'first': 'O',
#   'connector': 'O',
#   'on': 'O',
#   'side': 'O',
#   'incision': 'O',
#   'and': 'O',
#   'second': 'O',
#   'adjacent': 'O'},
#  {'9': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '7': 'O',
#   'further': 'O',
#   'comprising': 'O',
#   'prior': 'O',
#   'to': 'O',
#   'step': 'O',
#   'c': 'O',
#   'configuring': 'O',
#   'a': 'O',
#   'cinching': 'O',
#   'device': 'O',
#   'between': 'O',
#   'the': 'O',
#   'first': 'O',
#   'connector': 'O',
#   'and': 'O',
#   'second': 'O',
#   'so': 'O',
#   'that': 'O',
#   'extends': 'O',
#   'over': 'O',
#   'incision': 'O'},
#  {'10': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '9': 'O',
#   'wherein': 'O',
#   'step': 'O',
#   'c': 'O',
#   'comprises': 'O',
#   'cinching': 'O',
#   'the': 'O',
#   'device': 'O'},
#  {'11': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '10': 'O',
#   'wherein': 'O',
#   'step': 'O',
#   'd': 'O',
#   'is': 'O',
#   'carried': 'O',
#   'out': 'O',
#   'automatically': 'O',
#   'upon': 'O',
#   'cinching': 'O',
#   'the': 'O',
#   'belt': 'O'},
#  {'12': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   '7': 'O',
#   'further': 'O',
#   'comprising': 'O',
#   'e': 'O',
#   'tightening': 'O',
#   'the': 'O',
#   'belt': 'O',
#   'periodically': 'O'},
#  {'13': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '7': 'O',
#   'wherein': 'O',
#   'step': 'O',
#   'c': 'O',
#   'comprises': 'O',
#   'applying': 'O',
#   '11.36': 'O',
#   'to': 'O',
#   '17.9': 'O',
#   'pounds': 'O',
#   'tension': 'O',
#   'between': 'O',
#   'the': 'O',
#   'connectors': 'O'},
#  {'14': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '13': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'incision': 'O',
#   'is': 'O',
#   'in': 'O',
#   'abdomen': 'O',
#   'patient': 'O'},
#  {'15': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '14': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'force': 'B-EST',
#   'exerted': 'I-EST',
#   'on': 'O',
#   'abdominal': 'O',
#   'wall': 'O',
#   'patient': 'B-EST',
#   'provokes': 'I-EST',
#   'an': 'O',
#   'overall': 'O',
#   'increase': 'O',
#   'in': 'O',
#   'intra': 'O',
#   'pressure': 'O'},
#  {'16': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '7': 'O',
#   'comprising': 'O',
#   'bringing': 'O',
#   'the': 'O',
#   'edges': 'O',
#   'incision': 'O',
#   'together': 'O',
#   'to': 'O',
#   'meet': 'O'},
#  {'17': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'according': 'O',
#   'to': 'O',
#   'claim': 'O',
#   '7': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'clamp': 'O',
#   'comprises': 'O',
#   'a': 'O',
#   'first': 'O',
#   'plate': 'O',
#   'hingedly': 'O',
#   'connected': 'O',
#   'second': 'O',
#   'movable': 'O',
#   'between': 'O',
#   'an': 'O',
#   'open': 'O',
#   'position': 'O',
#   'and': 'O',
#   'closed': 'O'},
#  {'18': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'according': 'O',
#   'to': 'O',
#   'claim': 'O',
#   '17': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'first': 'O',
#   'belt': 'I-EST',
#   'lock': 'O',
#   'and': 'O',
#   'second': 'O',
#   'each': 'O',
#   'comprise': 'O',
#   'a': 'O',
#   'gripping': 'B-EST',
#   'mechanism': 'I-EST',
#   'for': 'O',
#   'holding': 'O',
#   'end': 'O',
#   'portion': 'O',
#   'respectively': 'O'},
#  {'19': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'according': 'O',
#   'to': 'O',
#   'claim': 'O',
#   '18': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'gripping': 'O',
#   'mechanism': 'O',
#   'comprises': 'O',
#   'a': 'O',
#   'plurality': 'O',
#   'of': 'O',
#   'spikes': 'O',
#   'extending': 'O',
#   'upwardly': 'O',
#   'from': 'O',
#   'first': 'O',
#   'plate': 'I-EST',
#   'and': 'O',
#   'openings': 'O',
#   'in': 'O',
#   'second': 'B-EST',
#   'configured': 'O',
#   'receive': 'O',
#   'when': 'O',
#   'clamp': 'O',
#   'is': 'O',
#   'closed': 'O',
#   'position': 'O'},
#  {'20': 'O'},
#  {'A': 'O',
#   'kit': 'O',
#   'of': 'O',
#   'parts': 'O',
#   'for': 'O',
#   'a': 'O',
#   'device': 'I-EST',
#   'management': 'O',
#   'an': 'O',
#   'open': 'O',
#   'incision': 'O',
#   'in': 'O',
#   'patient': 'O',
#   'the': 'O',
#   'comprising': 'O',
#   'belt': 'B-EST',
#   'having': 'O',
#   'first': 'B-EST',
#   'end': 'O',
#   'portion': 'O',
#   'and': 'O',
#   'opposed': 'O',
#   'second': 'O',
#   'positionable': 'O',
#   'to': 'O',
#   'extend': 'O',
#   'partially': 'O',
#   'around': 'O',
#   'taut': 'O',
#   'configuration': 'O',
#   'with': 'O',
#   'positioned': 'I-EST',
#   'on': 'O',
#   'sides': 'O',
#   'b': 'O',
#   'connector': 'I-EST',
#   'comprises': 'O',
#   'lock': 'O',
#   'holding': 'O',
#   'clamp': 'B-EST',
#   'adapted': 'I-EST',
#   'hold': 'O',
#   'adjacent': 'O',
#   'each': 'O',
#   'other': 'O',
#   'wherein': 'I-EST',
#   'is': 'O',
#   'be': 'O',
#   'connected': 'O',
#   'c': 'O',
#   'at': 'O',
#   'least': 'O',
#   'one': 'O',
#   'cinching': 'B-EST',
#   'connectors': 'O',
#   'configured': 'I-EST',
#   'over': 'O',
#   'when': 'O',
#   'are': 'O',
#   'being': 'I-EST',
#   'adjustable': 'I-EST',
#   'cinch': 'O',
#   'towards': 'O',
#   'closed': 'O'},
#  {'21': 'O'},
#  {'The': 'O',
#   'kit': 'O',
#   'of': 'O',
#   'parts': 'O',
#   'claim': 'O',
#   '20': 'O',
#   'wherein': 'O',
#   'any': 'O',
#   'one': 'O',
#   'components': 'O',
#   'a': 'O',
#   'b': 'O',
#   'or': 'O',
#   'c': 'O',
#   'is': 'O',
#   'provided': 'O',
#   'unassembled': 'O',
#   'from': 'O',
#   'others': 'O',
#   'the': 'O'},
#  {'22': 'O'},
#  {'The': 'O',
#   'kit': 'O',
#   'of': 'O',
#   'parts': 'O',
#   'claim': 'O',
#   '20': 'O',
#   'wherein': 'O',
#   'any': 'O',
#   'one': 'O',
#   'components': 'O',
#   'a': 'O',
#   'b': 'O',
#   'or': 'O',
#   'c': 'O',
#   'is': 'O',
#   'provided': 'O',
#   'assembled': 'O',
#   'to': 'O',
#   'others': 'O',
#   'the': 'O'},
#  {'23': 'O'},
#  {'The': 'O',
#   'kit': 'O',
#   'of': 'O',
#   'parts': 'O',
#   'claim': 'O',
#   '20': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'cinching': 'O',
#   'device': 'O',
#   'is': 'O',
#   'adapted': 'O',
#   'to': 'O',
#   'apply': 'O',
#   '11.36': 'O',
#   '17.9': 'O',
#   'pounds': 'O',
#   'tension': 'O',
#   'between': 'O',
#   'connectors': 'O'},
#  {'24': 'O'},
#  {'The': 'O',
#   'kit': 'O',
#   'of': 'O',
#   'parts': 'O',
#   'claim': 'O',
#   '20': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'assembled': 'O',
#   'device': 'O',
#   'is': 'O',
#   'configured': 'O',
#   'to': 'O',
#   'manage': 'O',
#   'an': 'O',
#   'incision': 'O',
#   'in': 'O',
#   'abdomen': 'O',
#   'patient': 'O'},
#  {'25': 'O'},
#  {'The': 'O',
#   'kit': 'O',
#   'according': 'O',
#   'to': 'O',
#   'claim': 'O',
#   '20': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'clamp': 'O',
#   'comprises': 'O',
#   'a': 'O',
#   'first': 'B-EST',
#   'plate': 'O',
#   'hingedly': 'O',
#   'connected': 'O',
#   'second': 'O',
#   'movable': 'O',
#   'between': 'O',
#   'an': 'O',
#   'open': 'O',
#   'position': 'I-EST',
#   'and': 'O',
#   'closed': 'B-EST'},
#  {'26': 'O'},
#  {'The': 'O',
#   'kit': 'O',
#   'according': 'O',
#   'to': 'O',
#   'claim': 'O',
#   '25': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'first': 'O',
#   'belt': 'I-EST',
#   'lock': 'O',
#   'and': 'O',
#   'second': 'O',
#   'each': 'O',
#   'comprise': 'O',
#   'a': 'O',
#   'gripping': 'B-EST',
#   'mechanism': 'I-EST',
#   'for': 'O',
#   'holding': 'O',
#   'end': 'O',
#   'portion': 'O',
#   'respectively': 'O'},
#  {'27': 'O'},
#  {'The': 'O',
#   'kit': 'O',
#   'according': 'O',
#   'to': 'O',
#   'claim': 'B-EFA',
#   '26': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'gripping': 'B-EST',
#   'mechanism': 'I-EST',
#   'comprises': 'O',
#   'a': 'O',
#   'plurality': 'O',
#   'of': 'O',
#   'spikes': 'O',
#   'extending': 'O',
#   'upwardly': 'O',
#   'from': 'O',
#   'first': 'O',
#   'plate': 'I-EST',
#   'and': 'O',
#   'openings': 'O',
#   'in': 'O',
#   'second': 'B-EST',
#   'configured': 'O',
#   'receive': 'O',
#   'when': 'O',
#   'clamp': 'O',
#   'is': 'O',
#   'closed': 'O',
#   'position': 'O'},
#  {'##id:262': 'O',
#   'Photomedical': 'O',
#   'treatment': 'B-EST',
#   'system': 'O',
#   'and': 'O',
#   'method': 'O',
#   'with': 'O',
#   'a': 'O',
#   'virtual': 'O',
#   'aiming': 'O',
#   'device': 'O',
#   'A': 'O',
#   'photomedical': 'O',
#   'for': 'O',
#   'treating': 'O',
#   'or': 'O',
#   'diagnosing': 'O',
#   'patient': 'O',
#   's': 'O',
#   'eye': 'O',
#   'that': 'O',
#   'includes': 'O',
#   'first': 'O',
#   'light': 'O',
#   'source': 'O',
#   'producing': 'O',
#   'scanning': 'O',
#   'deflecting': 'O',
#   'the': 'O',
#   'to': 'O',
#   'produce': 'O',
#   'pattern': 'O',
#   'of': 'O',
#   'on': 'O',
#   'viewing': 'O',
#   'element': 'O',
#   'positioned': 'O',
#   'view': 'O',
#   'by': 'O',
#   'user': 'O',
#   'physician': 'O',
#   'an': 'O',
#   'alignment': 'O',
#   'aligned': 'O',
#   'optically': 'O',
#   'indicating': 'O',
#   'through': 'O',
#   'location': 'O',
#   'which': 'O',
#   'will': 'O',
#   'be': 'O',
#   'located': 'O',
#   'but': 'O',
#   'without': 'O',
#   'projecting': 'O',
#   'any': 'O',
#   'onto': 'O'},
#  {'1': 'O'},
#  {'A': 'O',
#   'photomedical': 'O',
#   'system': 'O',
#   'for': 'O',
#   'treating': 'O',
#   'or': 'O',
#   'diagnosing': 'O',
#   'a': 'O',
#   'patient': 'B-EST',
#   's': 'O',
#   'eye': 'O',
#   'the': 'O',
#   'comprising': 'O',
#   'first': 'B-EST',
#   'light': 'I-EST',
#   'source': 'O',
#   'configured': 'O',
#   'to': 'O',
#   'generate': 'O',
#   'treatment': 'O',
#   'second': 'B-EST',
#   'alignment': 'I-EST',
#   'scanning': 'B-EST',
#   'device': 'I-EST',
#   'receive': 'O',
#   'from': 'O',
#   'and': 'O',
#   'project': 'O',
#   'pattern': 'O',
#   'of': 'O',
#   'on': 'O',
#   'viewing': 'O',
#   'element': 'O',
#   'positioned': 'I-EST',
#   'provide': 'O',
#   'view': 'O',
#   'an': 'O',
#   'electronic': 'O',
#   'display': 'O',
#   'information': 'O',
#   'wherein': 'O',
#   'optical': 'B-EST',
#   'path': 'I-EST',
#   'does': 'O',
#   'not': 'O',
#   'overlap': 'O',
#   'with': 'O',
#   'controller': 'B-EST',
#   'communicatively': 'I-EST',
#   'coupled': 'I-EST',
#   'is': 'O',
#   'cause': 'O',
#   'region': 'O',
#   'projected': 'O',
#   'indicates': 'I-EST',
#   'which': 'O'},
#  {'2': 'O'},
#  {'The': 'O',
#   'system': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'viewing': 'O',
#   'element': 'O',
#   'comprises': 'O',
#   'a': 'O',
#   'lens': 'O'},
#  {'3': 'O'},
#  {'The': 'O',
#   'system': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'viewing': 'O',
#   'element': 'O',
#   'comprises': 'O',
#   'an': 'O',
#   'image': 'O',
#   'collection': 'O',
#   'device': 'O',
#   'coupled': 'O',
#   'to': 'O',
#   'a': 'O',
#   'display': 'O'},
#  {'4': 'O'},
#  {'The': 'O',
#   'system': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'controller': 'O',
#   'has': 'O',
#   'an': 'O',
#   'input': 'O',
#   'device': 'O',
#   'configured': 'O',
#   'to': 'O',
#   'control': 'O',
#   'scanning': 'O',
#   'adjust': 'O',
#   'a': 'O',
#   'size': 'O',
#   'shape': 'O',
#   'and': 'O',
#   'or': 'O',
#   'arrangement': 'O',
#   'treatment': 'O',
#   'pattern': 'I-EST',
#   'light': 'O',
#   'on': 'O',
#   'eye': 'O'},
#  {'5': 'O'},
#  {'The': 'O',
#   'system': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'alignment': 'O',
#   'pattern': 'O',
#   'and': 'O',
#   'information': 'O',
#   'are': 'O',
#   'generated': 'O',
#   'by': 'O',
#   'passing': 'O',
#   'light': 'O',
#   'through': 'O',
#   'electronic': 'O',
#   'display': 'O'},
#  {'6': 'O'},
#  {'The': 'O',
#   'system': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '5': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'electronic': 'O',
#   'display': 'O',
#   'includes': 'O',
#   'an': 'O',
#   'optical': 'O',
#   'pattern': 'O',
#   'as': 'O',
#   'alignment': 'O',
#   'light': 'O',
#   'passes': 'O',
#   'through': 'O',
#   'element': 'O'},
#  {'7': 'O'},
#  {'The': 'O',
#   'system': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'projected': 'O',
#   'alignment': 'I-EST',
#   'pattern': 'I-EST',
#   'outlines': 'O',
#   'on': 'O',
#   'view': 'O',
#   'eye': 'O',
#   'a': 'O',
#   'perimeter': 'O',
#   'region': 'O',
#   'which': 'O',
#   'treatment': 'B-EST',
#   'is': 'O'},
#  {'8': 'O'},
#  {'The': 'O',
#   'system': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'further': 'O',
#   'comprising': 'O',
#   'a': 'O',
#   'magnification': 'B-EST',
#   'device': 'I-EST',
#   'configured': 'O',
#   'to': 'O',
#   'adjustably': 'O',
#   'magnify': 'O',
#   'the': 'O',
#   'view': 'O',
#   'eye': 'O',
#   'as': 'O',
#   'viewed': 'O',
#   'through': 'O',
#   'viewing': 'B-EST',
#   'element': 'I-EST'},
#  {'9': 'O'},
#  {'The': 'O',
#   'system': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '8': 'O',
#   'further': 'O',
#   'comprising': 'O',
#   'an': 'O',
#   'infinity': 'O',
#   'corrected': 'O',
#   'objective': 'O',
#   'lens': 'O',
#   'situated': 'O',
#   'between': 'O',
#   'the': 'O',
#   'magnification': 'O',
#   'device': 'O',
#   'and': 'O',
#   'scanning': 'O'},
#  {'10': 'O'},
#  {'The': 'O',
#   'system': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'electronic': 'O',
#   'display': 'O',
#   'and': 'O',
#   'second': 'O',
#   'light': 'O',
#   'source': 'O',
#   'are': 'O',
#   'integrally': 'O',
#   'formed': 'O',
#   'together': 'O'},
#  {'11': 'O'},
#  {'The': 'O',
#   'system': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'alignment': 'O',
#   'light': 'O',
#   'is': 'O',
#   'a': 'O',
#   'single': 'O',
#   'color': 'O'},
#  {'12': 'O'},
#  {'The': 'O',
#   'system': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '11': 'O',
#   'further': 'O',
#   'comprising': 'O',
#   'a': 'O',
#   'mirror': 'O',
#   'configured': 'O',
#   'to': 'O',
#   'direct': 'O',
#   'the': 'O',
#   'treatment': 'O',
#   'light': 'O',
#   'toward': 'O',
#   'eye': 'O',
#   'and': 'O',
#   'alignment': 'O',
#   'viewing': 'O',
#   'element': 'O',
#   'wherein': 'O',
#   'is': 'O',
#   'photopically': 'O',
#   'balanced': 'O',
#   'dichroic': 'O',
#   'optical': 'O',
#   'having': 'O',
#   'transmission': 'B-EST',
#   'property': 'I-EST',
#   'that': 'O',
#   'matched': 'O',
#   'wavelength': 'O',
#   'range': 'O'},
#  {'13': 'O'},
#  {'A': 'O',
#   'method': 'O',
#   'for': 'O',
#   'performing': 'O',
#   'a': 'O',
#   'photomedical': 'O',
#   'treatment': 'O',
#   'or': 'O',
#   'diagnosis': 'O',
#   'of': 'O',
#   'patient': 'O',
#   's': 'O',
#   'eye': 'O',
#   'using': 'O',
#   'system': 'O',
#   'comprising': 'O',
#   'first': 'B-EST',
#   'light': 'I-EST',
#   'source': 'O',
#   'second': 'B-EST',
#   'scanning': 'B-EST',
#   'device': 'I-EST',
#   'viewing': 'O',
#   'element': 'O',
#   'an': 'O',
#   'electronic': 'O',
#   'display': 'O',
#   'and': 'O',
#   'controller': 'O',
#   'communicatively': 'O',
#   'coupled': 'O',
#   'to': 'O',
#   'the': 'O',
#   'generating': 'O',
#   'wherein': 'O',
#   'is': 'O',
#   'configured': 'O',
#   'receive': 'O',
#   'from': 'O',
#   'project': 'O',
#   'pattern': 'O',
#   'on': 'O',
#   'alignment': 'O',
#   'information': 'O',
#   'optical': 'B-EST',
#   'path': 'I-EST',
#   'does': 'O',
#   'not': 'O',
#   'overlap': 'O',
#   'with': 'O',
#   'providing': 'O',
#   'view': 'O',
#   'causing': 'O',
#   'region': 'O',
#   'projected': 'O',
#   'indicates': 'I-EST',
#   'which': 'O'},
#  {'14': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '13': 'O',
#   'wherein': 'O',
#   'projecting': 'O',
#   'the': 'O',
#   'alignment': 'O',
#   'pattern': 'O',
#   'comprises': 'O',
#   'passing': 'O',
#   'light': 'O',
#   'through': 'O',
#   'electronic': 'O',
#   'display': 'O',
#   'having': 'O',
#   'an': 'O',
#   'optical': 'O'},
#  {'15': 'O'},
#  {'The': 'O',
#   'method': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '13': 'O',
#   'further': 'O',
#   'comprising': 'O',
#   'adjusting': 'O',
#   'a': 'O',
#   'magnification': 'O',
#   'level': 'O',
#   'the': 'O',
#   'provided': 'B-EST',
#   'view': 'I-EST',
#   'eye': 'O',
#   'through': 'O',
#   'viewing': 'O',
#   'element': 'O'},
#  {'16': 'O'},
#  {'A': 'O',
#   'photomedical': 'B-EST',
#   'system': 'O',
#   'for': 'O',
#   'treating': 'O',
#   'or': 'O',
#   'diagnosing': 'O',
#   'a': 'O',
#   'patient': 'O',
#   's': 'O',
#   'eye': 'O',
#   'the': 'O',
#   'comprising': 'O',
#   'treatment': 'O',
#   'light': 'O',
#   'source': 'O',
#   'scanning': 'O',
#   'device': 'O',
#   'configured': 'O',
#   'to': 'O',
#   'receive': 'O',
#   'from': 'O',
#   'and': 'O',
#   'project': 'O',
#   'pattern': 'O',
#   'of': 'O',
#   'on': 'O',
#   'viewing': 'O',
#   'element': 'O',
#   'an': 'O',
#   'image': 'O',
#   'alignment': 'B-EST',
#   'electronic': 'O',
#   'display': 'O',
#   'optical': 'I-EST',
#   'indication': 'I-EST',
#   'information': 'O',
#   'wherein': 'O',
#   'is': 'O',
#   'not': 'O',
#   'onto': 'O',
#   'controller': 'O',
# ...
#   'upper': 'B-EST',
#   'attachment': 'O',
#   'assembly': 'I-EFO',
#   'having': 'O',
#   'cuff': 'I-EFO',
#   'with': 'O',
#   'medial': 'O',
#   'strut': 'O',
#   'and': 'O',
#   'lateral': 'O',
#   'extending': 'B-EST',
#   'therefrom': 'I-EST',
#   'a': 'O',
#   'lower': 'O',
#   'said': 'O',
#   'struts': 'O',
#   'configured': 'O',
#   'to': 'O',
#   'be': 'O',
#   'connected': 'O',
#   'proximate': 'O',
#   'user': 'O',
#   's': 'O',
#   'by': 'O',
#   'associated': 'B-EFO',
#   'hinge': 'I-EFO',
#   'rotatable': 'O',
#   'about': 'O',
#   'first': 'O',
#   'rotation': 'O',
#   'point': 'O',
#   'second': 'B-EST',
#   'the': 'O',
#   'third': 'I-EST',
#   'fourth': 'O',
#   'wherein': 'O',
#   'at': 'O',
#   'least': 'O',
#   'one': 'O',
#   'of': 'O',
#   'or': 'O',
#   'mechanism': 'O',
#   'dynamically': 'I-EFO',
#   'altering': 'O',
#   'length': 'O',
#   'respect': 'O',
#   'points': 'O',
#   'in': 'O',
#   'upon': 'O',
#   'flexion': 'O',
#   'assemblies': 'O',
#   'between': 'O',
#   'flexed': 'B-EST',
#   'position': 'O',
#   'extended': 'O',
#   'buck': 'O',
#   'directly': 'O',
#   'pivot': 'O',
#   'pin': 'O',
#   'saddle': 'O',
#   'interface': 'O',
#   'channel': 'O',
#   'receiving': 'O',
#   'for': 'O',
#   'reciprocal': 'O',
#   'motion': 'O',
#   'through': 'O',
#   'range': 'O',
#   'from': 'O',
#   'contracted': 'O',
#   'roller': 'O',
#   'fixed': 'O',
#   'offset': 'I-EST',
#   'ramp': 'O',
#   'on': 'O',
#   'periphery': 'O',
#   'contacting': 'O',
#   'during': 'O',
#   'urge': 'O'},
#  {'2': 'O'},
#  {'The': 'O',
#   'knee': 'O',
#   'brace': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'at': 'O',
#   'least': 'O',
#   'a': 'O',
#   'second': 'O',
#   'one': 'O',
#   'said': 'O',
#   'upper': 'O',
#   'medial': 'O',
#   'strut': 'O',
#   'lateral': 'O',
#   'lower': 'O',
#   'or': 'O',
#   'has': 'O',
#   'mechanism': 'O',
#   'to': 'O',
#   'non': 'O',
#   'dynamically': 'O',
#   'adjust': 'O',
#   'the': 'O',
#   'length': 'O'},
#  {'3': 'O'},
#  {'The': 'O',
#   'knee': 'O',
#   'brace': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '2': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'second': 'O',
#   'mechanism': 'I-EST',
#   'comprises': 'O',
#   'a': 'O',
#   'buck': 'I-EST',
#   'connected': 'I-EST',
#   'to': 'O',
#   'rotation': 'O',
#   'pin': 'O',
#   'at': 'O',
#   'an': 'O',
#   'associated': 'O',
#   'one': 'O',
#   'first': 'O',
#   'third': 'O',
#   'or': 'O',
#   'fourth': 'O',
#   'point': 'O',
#   'saddle': 'O',
#   'interface': 'I-EST',
#   'in': 'O',
#   'least': 'O',
#   'said': 'O',
#   'upper': 'B-EFO',
#   'medial': 'I-EFO',
#   'strut': 'I-EFO',
#   'lateral': 'B-EFO',
#   'lower': 'O',
#   'and': 'O',
#   'having': 'O',
#   'channel': 'O',
#   'receiving': 'O',
#   'for': 'O',
#   'adjustable': 'B-EFA',
#   'motion': 'B-EFO',
#   'through': 'O',
#   'range': 'O',
#   'from': 'O',
#   'retracted': 'O',
#   'position': 'I-EST',
#   'extended': 'B-EST',
#   'threaded': 'O',
#   'rod': 'B-EST',
#   'received': 'O',
#   'bore': 'O',
#   'rotatable': 'I-EST',
#   'by': 'O',
#   'adjustment': 'B-EST',
#   'knob': 'I-EST',
#   'extend': 'O',
#   'retract': 'O'},
#  {'4': 'O'},
#  {'The': 'O',
#   'knee': 'O',
#   'brace': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '3': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'second': 'O',
#   'saddle': 'I-EST',
#   'is': 'O',
#   'attached': 'O',
#   'to': 'O',
#   'interface': 'I-EST',
#   'in': 'O',
#   'at': 'O',
#   'least': 'O',
#   'one': 'O',
#   'said': 'O',
#   'upper': 'O',
#   'medial': 'O',
#   'strut': 'O',
#   'lateral': 'O',
#   'lower': 'O',
#   'or': 'O',
#   'by': 'O',
#   'a': 'O',
#   'hinge': 'O'},
#  {'5': 'O'},
#  {'The': 'O',
#   'knee': 'O',
#   'brace': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'said': 'O',
#   'saddle': 'O',
#   'periphery': 'O',
#   'has': 'O',
#   'the': 'O',
#   'ramp': 'O',
#   'and': 'O',
#   'roller': 'O',
#   'is': 'O',
#   'fixed': 'O',
#   'in': 'O',
#   'associated': 'O',
#   'medial': 'O',
#   'or': 'O',
#   'lateral': 'O',
#   'hinge': 'O',
#   'assembly': 'O'},
#  {'6': 'O'},
#  {'The': 'O',
#   'knee': 'O',
#   'brace': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '5': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'roller': 'B-EST',
#   'is': 'O',
#   'adjustable': 'O',
#   'to': 'O',
#   'change': 'O',
#   'a': 'O',
#   'length': 'O',
#   'between': 'O',
#   'contracted': 'O',
#   'and': 'O',
#   'extended': 'O',
#   'positions': 'O',
#   'buck': 'O',
#   'saddle': 'O'},
#  {'7': 'O'},
#  {'The': 'O',
#   'knee': 'O',
#   'brace': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '5': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'saddle': 'O',
#   'is': 'O',
#   'attached': 'O',
#   'to': 'O',
#   'interface': 'O',
#   'in': 'O',
#   'at': 'O',
#   'least': 'O',
#   'one': 'O',
#   'said': 'O',
#   'upper': 'O',
#   'medial': 'O',
#   'strut': 'O',
#   'lateral': 'O',
#   'lower': 'O',
#   'or': 'O',
#   'by': 'O',
#   'a': 'O',
#   'hinge': 'O'},
#  {'8': 'O'},
#  {'The': 'O',
#   'knee': 'O',
#   'brace': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'further': 'O',
#   'comprising': 'O',
#   'an': 'O',
#   'upper': 'O',
#   'medial': 'O',
#   'pad': 'O',
#   'attached': 'O',
#   'to': 'O',
#   'the': 'O',
#   'strut': 'O',
#   'proximate': 'O',
#   'cuff': 'O',
#   'said': 'O',
#   'angularly': 'O',
#   'compliant': 'O',
#   'with': 'O',
#   'respect': 'O'},
#  {'9': 'O'},
#  {'The': 'O',
#   'knee': 'O',
#   'brace': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'further': 'O',
#   'comprising': 'O',
#   'a': 'O',
#   'lower': 'O',
#   'medial': 'O',
#   'pad': 'O',
#   'attached': 'O',
#   'to': 'O',
#   'the': 'O',
#   'strut': 'O',
#   'proximate': 'O',
#   'cuff': 'O',
#   'said': 'O',
#   'angularly': 'O',
#   'compliant': 'O',
#   'with': 'O',
#   'respect': 'O'},
#  {'10': 'O'},
#  {'A': 'O',
#   'knee': 'O',
#   'brace': 'B-EFA',
#   'comprising': 'O',
#   'an': 'O',
#   'upper': 'O',
#   'attachment': 'O',
#   'assembly': 'O',
#   'having': 'O',
#   'cuff': 'O',
#   'with': 'O',
#   'medial': 'O',
#   'strut': 'I-EST',
#   'extending': 'I-EFO',
#   'therefrom': 'O',
#   'a': 'O',
#   'lower': 'O',
#   'said': 'O',
#   'and': 'O',
#   'struts': 'I-EST',
#   'configured': 'I-EST',
#   'to': 'O',
#   'be': 'O',
#   'connected': 'O',
#   'proximate': 'O',
#   'user': 'O',
#   's': 'O',
#   'by': 'O',
#   'associated': 'O',
#   'hinge': 'O',
#   'rotatable': 'I-EST',
#   'about': 'O',
#   'first': 'O',
#   'rotation': 'O',
#   'point': 'O',
#   'in': 'O',
#   'the': 'O',
#   'second': 'O',
#   'wherein': 'B-EFO',
#   'includes': 'O',
#   'mechanism': 'O',
#   'dynamically': 'O',
#   'altering': 'O',
#   'length': 'O',
#   'of': 'O',
#   'respect': 'O',
#   'upon': 'I-EFO',
#   'flexion': 'O',
#   'assemblies': 'O',
#   'between': 'O',
#   'flexed': 'O',
#   'position': 'O',
#   'extended': 'O',
#   'buck': 'B-EST',
#   'directly': 'O',
#   'pivot': 'O',
#   'pin': 'O',
#   'at': 'O',
#   'saddle': 'O',
#   'interface': 'O',
#   'channel': 'O',
#   'receiving': 'O',
#   'for': 'O',
#   'reciprocal': 'O',
#   'motion': 'O',
#   'through': 'O',
#   'range': 'O',
#   'from': 'O',
#   'contracted': 'O',
#   'roller': 'O',
#   'fixed': 'O',
#   'ramp': 'O',
#   'on': 'O',
#   'periphery': 'O',
#   'contacting': 'O',
#   'during': 'O',
#   'urge': 'O'},
#  {'11': 'O'},
#  {'The': 'O',
#   'knee': 'O',
#   'brace': 'O',
#   'as': 'O',
#   'defined': 'O',
#   'in': 'O',
#   'claim': 'O',
#   '10': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'upper': 'B-EST',
#   'cuff': 'O',
#   'has': 'O',
#   'an': 'O',
#   'lateral': 'I-EST',
#   'strut': 'I-EST',
#   'attached': 'O',
#   'thereto': 'I-EST',
#   'and': 'O',
#   'lower': 'O',
#   'a': 'O',
#   'said': 'O',
#   'medial': 'O',
#   'rotatable': 'I-EST',
#   'about': 'O',
#   'second': 'B-EST',
#   'rotation': 'I-EST',
#   'point': 'O',
#   'hinge': 'O',
#   'assembly': 'O',
#   'struts': 'O',
#   'configured': 'O',
#   'to': 'O',
#   'be': 'O',
#   'connected': 'I-EST',
#   'proximate': 'O',
#   'user': 'O',
#   's': 'O',
#   'by': 'O',
#   'associated': 'O',
#   'third': 'B-EST',
#   'fourth': 'O',
#   'mechanism': 'I-EST',
#   'non': 'O',
#   'dynamically': 'O',
#   'adjust': 'O',
#   'length': 'O',
#   'of': 'O',
#   'comprising': 'O',
#   'buck': 'I-EST',
#   'pin': 'O',
#   'at': 'O',
#   'saddle': 'I-EST',
#   'interface': 'I-EST',
#   'having': 'O',
#   'channel': 'O',
#   'receiving': 'O',
#   'for': 'O',
#   'adjustable': 'O',
#   'motion': 'O',
#   'through': 'O',
#   'range': 'B-EST',
#   'from': 'O',
#   'retracted': 'B-EST',
#   'position': 'O',
#   'extended': 'O',
#   'threaded': 'O',
#   'rod': 'B-EST',
#   'received': 'O',
#   'bore': 'O',
#   'adjustment': 'B-EST',
#   'knob': 'I-EST',
#   'extend': 'O',
#   'or': 'O',
#   'retract': 'O'},
#  {'##id:986': 'O',
#   'Method': 'O',
#   'of': 'O',
#   'liquid': 'O',
#   'filter': 'B-EST',
#   'wetting': 'O',
#   'A': 'O',
#   'process': 'O',
#   'is': 'O',
#   'disclosed': 'O',
#   'for': 'O',
#   'a': 'O',
#   'cartridge': 'I-EST',
#   'used': 'O',
#   'to': 'O',
#   'treat': 'O',
#   'solvent': 'O',
#   'in': 'O',
#   'semiconductor': 'O',
#   'manufacture': 'O'},
#  {'In': 'O',
#   'the': 'O',
#   'process': 'O',
#   'a': 'O',
#   'filter': 'B-EST',
#   'cartridge': 'I-EST',
#   'having': 'O',
#   'void': 'O',
#   'spaces': 'O',
#   'wherein': 'O',
#   'contain': 'O',
#   'residual': 'O',
#   'gas': 'I-EST',
#   'from': 'O',
#   'manufacturing': 'O',
#   'used': 'O',
#   'to': 'O',
#   'make': 'O',
#   'is': 'O',
#   'connected': 'O',
#   'source': 'O',
#   'of': 'O',
#   'purging': 'B-EST'},
#  {'The': 'O',
#   'purging': 'O',
#   'gas': 'I-EST',
#   'is': 'O',
#   'flowed': 'O',
#   'through': 'O',
#   'the': 'O',
#   'filter': 'B-EST',
#   'cartridge': 'I-EST',
#   'to': 'O',
#   'at': 'O',
#   'least': 'O',
#   'partially': 'O',
#   'displace': 'O',
#   'a': 'O',
#   'portion': 'O',
#   'of': 'O',
#   'residual': 'B-EST',
#   'from': 'O',
#   'manufacturing': 'O',
#   'process': 'O',
#   'used': 'O',
#   'make': 'O'},
#  {'Next': 'O',
#   'liquid': 'B-EST',
#   'solvent': 'I-EST',
#   'is': 'O',
#   'pumped': 'O',
#   'through': 'O',
#   'the': 'O',
#   'filter': 'O',
#   'cartridge': 'O',
#   'so': 'O',
#   'that': 'O',
#   'purging': 'O',
#   'gas': 'O',
#   'dissolves': 'O',
#   'into': 'O',
#   'and': 'O',
#   'to': 'O',
#   'at': 'O',
#   'least': 'O',
#   'partially': 'O',
#   'fill': 'O',
#   'void': 'O',
#   'spaces': 'O',
#   'thereby': 'O',
#   'wet': 'O',
#   'out': 'O',
#   'with': 'O'},
#  {'1': 'O'},
#  {'A': 'O',
#   'process': 'O',
#   'for': 'O',
#   'wetting': 'B-EFA',
#   'a': 'O',
#   'filter': 'B-EST',
#   'cartridge': 'I-EST',
#   'used': 'O',
#   'to': 'O',
#   'treat': 'B-EFA',
#   'liquid': 'O',
#   'solvent': 'O',
#   'in': 'I-EFO',
#   'semiconductor': 'I-EFO',
#   'manufacture': 'I-EFO',
#   'comprising': 'I-EFO',
#   'providing': 'I-EFO',
#   'having': 'I-EFO',
#   'void': 'O',
#   'spaces': 'O',
#   'wherein': 'I-EFO',
#   'the': 'O',
#   'contain': 'I-EFO',
#   'residual': 'O',
#   'gas': 'O',
#   'from': 'O',
#   'manufacturing': 'O',
#   'make': 'O',
#   'flowing': 'I-EFO',
#   'purging': 'O',
#   'through': 'O',
#   'at': 'O',
#   'least': 'O',
#   'partially': 'O',
#   'displace': 'O',
#   'portion': 'O',
#   'of': 'O',
#   'and': 'O',
#   'thereafter': 'O',
#   'pumping': 'O',
#   'so': 'O',
#   'that': 'O',
#   'dissolves': 'O',
#   'into': 'O',
#   'fill': 'O'},
#  {'2': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'purging': 'O',
#   'gas': 'O',
#   'is': 'O',
#   'an': 'O',
#   'organic': 'O',
#   'nonpolar': 'O',
#   'having': 'O',
#   'one': 'O',
#   'or': 'O',
#   'more': 'O',
#   'carbon': 'O',
#   'atoms': 'O'},
#  {'3': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'purging': 'B-EST',
#   'gas': 'O',
#   'is': 'O',
#   'flowed': 'O',
#   'through': 'O',
#   'filter': 'B-EST',
#   'cartridge': 'I-EST',
#   'until': 'O',
#   'at': 'O',
#   'least': 'O',
#   '50': 'O',
#   'percent': 'O',
#   'residual': 'O',
#   'has': 'O',
#   'been': 'O',
#   'displaced': 'O'},
#  {'4': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'liquid': 'O',
#   'solvent': 'O',
#   'is': 'O',
#   'flowed': 'O',
#   'through': 'O',
#   'filter': 'B-EST',
#   'cartridge': 'I-EST',
#   'at': 'O',
#   'a': 'O',
#   'rate': 'O',
#   '0.1': 'O',
#   'to': 'O',
#   '12': 'O',
#   'L': 'O',
#   'min': 'O'},
#  {'5': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'purging': 'B-EST',
#   'gas': 'I-EST',
#   'is': 'O',
#   'flowed': 'O',
#   'through': 'O',
#   'filter': 'B-EST',
#   'cartridge': 'I-EST',
#   'at': 'O',
#   'a': 'O',
#   'temperature': 'O',
#   'from': 'O',
#   '10': 'O',
#   'to': 'O',
#   '50': 'O',
#   'degrees': 'O',
#   'Centigrade': 'O'},
#  {'6': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'filter': 'O',
#   'in': 'O',
#   'cartridge': 'O',
#   'is': 'O',
#   'made': 'O',
#   'nylon': 'O',
#   'or': 'O',
#   'polytetrafluoroethylene': 'O'},
#  {'7': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'reduces': 'O',
#   'time': 'O',
#   'to': 'O',
#   'fully': 'O',
#   'wet': 'O',
#   'out': 'O',
#   'filter': 'O',
#   'cartridge': 'O',
#   'with': 'O',
#   'liquid': 'O',
#   'solvent': 'O',
#   'as': 'O',
#   'compared': 'O',
#   'a': 'O',
#   'where': 'O',
#   'is': 'O',
#   'pumped': 'O',
#   'through': 'O',
#   'without': 'O',
#   'previously': 'O',
#   'flowing': 'O',
#   'purging': 'O',
#   'gas': 'O'},
#  {'8': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'liquid': 'B-EST',
#   'solvent': 'I-EST',
#   'is': 'O',
#   'a': 'O',
#   'photoresist': 'O',
#   'fluid': 'O',
#   'which': 'O',
#   'flowed': 'O',
#   'through': 'O',
#   'filter': 'B-EST',
#   'cartridge': 'I-EST',
#   'until': 'O',
#   'no': 'O',
#   'bubbles': 'O',
#   'exit': 'O'},
#  {'9': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'liquid': 'O',
#   'solvent': 'O',
#   'is': 'O',
#   'an': 'O',
#   'aqueous': 'O',
#   'or': 'O',
#   'alcohol': 'O'},
#  {'10': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'purging': 'O',
#   'gas': 'O',
#   'is': 'O',
#   'a': 'O',
#   'nonpolar': 'O',
#   'organic': 'O'},
#  {'11': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'purging': 'O',
#   'gas': 'O',
#   'is': 'O',
#   'carbon': 'O',
#   'dioxide': 'O',
#   'ammonia': 'O',
#   'or': 'O',
#   'a': 'O',
#   'volatile': 'B-EST',
#   'amine': 'I-EST'},
#  {'12': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'purging': 'O',
#   'gas': 'O',
#   'is': 'O',
#   'methane': 'O',
#   'ethane': 'O',
#   'propane': 'O',
#   'butane': 'O',
#   'or': 'O',
#   'a': 'O',
#   'fluorinated': 'O',
#   'ethylene': 'O'},
#  {'13': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'liquid': 'O',
#   'solvent': 'O',
#   'is': 'O',
#   'a': 'O',
#   'photoresist': 'O',
#   'fluid': 'O'},
#  {'14': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'liquid': 'B-EST',
#   'solvent': 'I-EST',
#   'flows': 'O',
#   'through': 'O',
#   'filter': 'O',
#   'cartridge': 'O',
#   'until': 'O',
#   'no': 'O',
#   'bubbles': 'O',
#   'exit': 'O'},
#  {'15': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'purging': 'O',
#   'gas': 'O',
#   'has': 'O',
#   'a': 'O',
#   'purity': 'O',
#   'at': 'O',
#   'least': 'O',
#   '99': 'O',
#   'percent': 'O'},
#  {'16': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'filter': 'B-EST',
#   'cartridge': 'I-EST',
#   'is': 'O',
#   'disconnected': 'O',
#   'from': 'O',
#   'a': 'O',
#   'source': 'O',
#   'liquid': 'O',
#   'solvent': 'O',
#   'after': 'O',
#   'has': 'O',
#   'wetted': 'O',
#   'out': 'O'},
#  {'17': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'purging': 'O',
#   'gas': 'O',
#   'is': 'O',
#   'ethane': 'O',
#   'propane': 'O',
#   'butane': 'O',
#   'or': 'O',
#   'a': 'O',
#   'combination': 'B-EST',
#   'thereof': 'I-EST'},
#  {'18': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'purging': 'O',
#   'gas': 'O',
#   'is': 'O',
#   'tetrafluoroethane': 'O',
#   'tetrafluoromethane': 'O',
#   'difluroethane': 'O',
#   'or': 'O',
#   'a': 'O',
#   'combination': 'B-EST',
#   'thereof': 'I-EST'},
#  {'19': 'O'},
#  {'The': 'O',
#   'process': 'O',
#   'of': 'O',
#   'claim': 'O',
#   '1': 'O',
#   'wherein': 'O',
#   'the': 'O',
#   'filter': 'O',
#   'cartridge': 'O',
#   'is': 'O',
#   'connected': 'O',
#   'to': 'O',
#   'a': 'O',
#   'source': 'O',
#   'purging': 'O',
#   'gas': 'O',
#   'prior': 'O',
#   'flowing': 'O',
#   'through': 'O'},
#  {'20': 'O'},
#  ...]

# %%
with open("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/mechanical_ner/data/result_data/1.txt", "w", encoding="utf-8") as file:
    for i in range(len(word2label_list)):
        for key, value in word2label_list[i].items():
            file.write(f"{key} {value}\n")
        file.write(". O\n")

# %% [markdown]
# ## 4 将预测的结果转换格式（有预处理的格式转换为一篇文章下属的实体及label的格式）

# %%
def parse_predict_results(file_path):
    """
    Parse results from predicted file.
    """
    with open(file_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
    id2results = {}
    category = ""
    category_set = set()
    for line in lines:
        try:
            category = line.split(' ')[1].split('-')[1].strip()
        except:
            pass
        if category in ('EFA', 'EFO', 'EST', 'EEF'):
            category_set.add(category)

    cur_id = ""
    extracted_cnt = 0
    category = ""
    for line in lines:
        if line.startswith('##id:'):
            new_id = line[5:].split(" ")[0].strip()
            if cur_id != new_id:
                if extracted_cnt > 0 :
                    id2results[cur_id] = result_dict
                result_dict = {}
                for category in category_set:
                    result_dict[category] = set()
                cur_id = new_id
                extracted_cnt += 1
            label_word = ''

        else:
            label = line.split(' ')[1].strip()
            if line.split(' ')[0].startswith('##'):
                token = line.split(' ')[0][2:]
            else:
                token = line.split(' ')[0]
            if (label == 'O') or (len(label) == 0):
                if len(label_word) != 0:
                    result_dict[category].add(label_word)
                    category = ""
                    label_word = ""
            elif label.startswith('B-'):
                if len(label_word) != 0:
                    result_dict[category].add(label_word)
                    category = ""
                label_word = token
                category = label.split('-')[1].strip()
            elif label.startswith('I-'):
                if len(category) > 0:
                    label_word += " " + token
    id2results[cur_id] = result_dict
    return id2results

# %%
doc_word_dict = parse_predict_results("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/mechanical_ner/data/result_data/1.txt")

# %%
doc_word_dict
# Out:
# {'360': {'EST': {'angiography',
#    'angiography data',
#    'base',
#    'blood',
#    'blood system',
#    'computer program',
#    'connected components',
#    'contrast',
#    'contrast medium',
#    'contrast medium filled',
#    'corrected',
#    'covered period',
#    'current',
#    'different instants',
#    'dimensional',
#    'dimensional data',
#    'electronically readable data carrier',
#    'four',
#    'four dimensional',
#    'immediately preceding',
#    'multiplicative',
#    'non transitory readable medium',
#    'overlap artifacts',
#    'patient recorded',
#    'plausibility',
#    'plausibility check criterion',
#    'projection',
#    'projection images',
#    'removing',
#    'standardized four',
#    'temporal correlation',
#    'temporally assigned partial',
#    'vessel sections',
#    'wherein'},
#   'EFO': {'checking',
#    'contrast medium',
#    'different instants',
#    'imaging processing',
#    'reliable values'},
#   'EFA': {'individual', 'method', 'perform', 'reducing'}},
#  '99': {'EST': {'adhesive coating',
#    'cavity',
#    'closed bottom',
#    'coated',
#    'embedded particulate',
#    'expanded',
#    'first',
#    'first further',
#    'flattened',
#    'further comprising',
#    'inserted',
#    'inserted dispenser',
#    'interior surface',
#    'method',
#    'same material',
#    'same temperature',
#    'second',
#    'second adhesives',
#    'sidewall',
#    'sidewall extending',
#    'surface'},
#   'EFO': set(),
#   'EFA': {'claim'}},
#  '397': {'EST': {'belt',
#    'cinched',
#    'cinching',
#    'cinching connected',
#    'cinching device',
#    'clamp',
#    'clamp adapted',
#    'closed',
#    'device',
#    'end portions',
#    'first',
#    'force exerted',
#    'gripping mechanism',
#    'method',
#    'patient',
#    'patient provokes',
#    'positionable adjacent',
#    'second',
#    'taut',
#    'taut configuration'},
#   'EFO': set(),
#   'EFA': {'claim', 'extend partially'}},
#  '262': {'EST': {'alignment',
#    'claim',
#    'controller',
#    'controller communicatively coupled',
#    'first light',
#    'magnification device',
#    'optical path',
#    'patient',
#    'photomedical',
#    'projected alignment',
#    'provided view',
#    'scanning',
#    'scanning device',
#    'second',
#    'second alignment',
#    'transmission property',
#    'treatment',
#    'viewing element',
#    'wavelength range'},
#   'EFO': set(),
#   'EFA': set()},
#  '593': {'EST': {'M2',
#    'acid',
#    'amount ranging',
#    'carboxylic acid',
#    'cationic counterion',
#    'chemical oxidizing',
#    'compounds',
#    'divalent',
#    'dyeing',
#    'hydrocarbon based',
#    'hydrogen peroxide generating',
#    'hydroxyl',
#    'keratin',
#    'linear',
#    'organic',
#    'organic titanium salt',
#    'pyrrolyl',
#    'saturated',
#    'unsaturated',
#    'wherein'},
#   'EFO': {'C2 alkenyl ix cycloalkyl',
#    'N',
#    'Rb Rc Rd',
#    'adjacent',
#    'alkyl',
#    'anthocyanidins anthocyanins',
#    'aromatic hydrocarbon based',
#    'benzene naphthalene tetrahydronaphthalene indane indene anthracene phenanthrene isoindole indoline isoindoline benzofuran dihydrobenzofuran chroman isochroman chromene isochromene quinoline tetrahydroquinoline',
#    'chain allyl ether unsaturated',
#    'chemical oxidizing agents',
#    'compounds',
#    'compounds according',
#    'fatty',
#    'keratin fibers',
#    'methylpropane sulfonic AMPS®',
#    'proanthocyanins tannic acid ellagic',
#    'xiv xv xvi heterocyclic'},
#   'EFA': {'Hair',
#    'amino vii linear',
#    'anthocyans hydroxybenzoates flavones hydroxystilbenes',
#    'aromatic',
#    'branched',
#    'dyeing',
#    'flavanols',
#    'oxyalkylenated alcohol amphiphilic',
#    'those',
#    'viii'}},
#  '999': {'EST': {'circularly oriented',
#    'cylindrical draft',
#    'cylindrical draft tube',
#    'external',
#    'following types',
#    'reactor allows',
#    'tubular filters',
#    'tubular filters arranged'},
#   'EFO': {'internal'},
#   'EFA': {' Ammoximation'}},
#  '659': {'EST': {'following sequences', 'oligodeoxy', 'oligodeoxy nucleotide'},
#   'EFO': {'tumor growth'},
#   'EFA': {'inhibiting'}},
#  '662': {'EST': {'aqueous solution',
#    'based substance',
#    'bioactive material',
#    'composition',
#    'method',
#    'plant'},
#   'EFO': {'inactivate'},
#   'EFA': set()},
#  '151': {'EST': {'bottom surface',
#    'compressed',
#    'first cleat',
#    'first resilient',
#    'footwear according',
#    'footwear comprising',
#    'forefoot',
#    'forward',
#    'ground',
#    'longitudinal axis',
#    'outer',
#    'second cleat',
#    'shaft away',
#    'sole plate',
#    'terminal'},
#   'EFO': set(),
#   'EFA': set()},
#  '988': {'EST': {'above described',
#    'communicating',
#    'differential',
#    'differential pressure',
#    'dopant',
#    'etching mask',
#    'etching mask which',
#    'film forming material',
#    'filter medium',
#    'following general',
#    'isocyanate',
#    'linear',
#    'method according',
#    'monovalent organic',
#    'porous membrane',
#    'purification',
#    'resin layer',
#    'semiconductor substrate',
#    'silanol group',
#    'silicon compound',
#    'silicon compound containing',
#    'silicon compound containing liquid',
#    'silylating'},
#   'EFO': {'etching mask',
#    'fluorine',
#    'forming material',
#    'imide porous membrane having',
#    'silylating'},
#   'EFA': {'Purification method',
#    'forming',
#    'hydrolysis',
#    'imprinting',
#    'permeate',
#    'producing',
#    'purifying'}},
#  '113': {'EST': {'Measured',
#    'alert based',
#    'battery',
#    'battery section',
#    'cartomizer',
#    'control',
#    'control circuit',
#    'each',
#    'electrical resistance',
#    'electrically end respectively',
#    'electronic vaping',
#    'first',
#    'first color',
#    'first electrical lead',
#    'first probe',
#    'first value',
#    'fluid',
#    'fluid transport',
#    'fluid transport structure',
#    'heating coil',
#    'liquid supply',
#    'measured',
#    'memory',
#    'respective ends',
#    'second',
#    'second probe',
#    'third portion',
#    'vapor precursor',
#    'vaporizer driver',
#    'wick'},
#   'EFO': {'method An'},
#   'EFA': {'includes', 'measuring', 'perform'}},
#  '755': {'EST': {'blood',
#    'distal',
#    'electrical',
#    'electrical conductor',
#    'interior',
#    'interior bore',
#    'longitudinal axis',
#    'outflow cannula',
#    'proximal end attached',
#    'pump housing',
#    'sensor mounted',
#    'transverse wall',
#    'ultrasonic',
#    'velocity'},
#   'EFO': {'VAD A', 'assist device'},
#   'EFA': {'intraventricular', 'ventricular'}},
#  '501': {'EST': {'approximate',
#    'combinations thereof',
#    'diameter',
#    'haptic members',
#    'optical body',
#    'phakic refractive',
#    'phakic refractive lens',
#    'posterior',
#    'raised ring',
#    'refractive lens'},
#   'EFO': set(),
#   'EFA': {'comprises', 'correcting'}},
#  '438': {'EST': {'abrasion device',
#    'actuator magnets',
#    'distal tip',
#    'method',
#    'microchannel extending',
#    'negative pressure',
#    'rotational motion independently',
#    'spaced apart',
#    'spaced apart flexible',
#    'spiral shape'},
#   'EFO': set(),
#   'EFA': set()},
#  '996': {'EST': {'Siemens',
#    'improvement comprising',
#    'offgas collector',
#    'offgas ring',
#    'problems associated',
#    'reaction gas',
#    'reaction gas ring',
#    'segments which'},
#   'EFO': {'apart therefrom', 'improvement'},
#   'EFA': {'claim', 'spaced', 'supplying fastened'}},
#  '447': {'EST': {'bone',
#    'deflectable portion',
#    'deflection',
#    'effective length',
#    'elongate cavity',
#    'epiphysiodesis',
#    'female linkage',
#    'first',
#    'first fixation',
#    'fixation element',
#    'growth',
#    'growth plate',
#    'longitudinal axis arm being disposed',
#    'male',
#    'male sliding',
#    'plate',
#    'preset load',
#    'ratchet arm',
#    'ratchet atm',
#    'ratcheting mechanism',
#    'slider band'},
#   'EFO': {'first', 'sliding'},
#   'EFA': {'Ratcheting epiphysiodesis'}},
#  '56': {'EST': {'commodity plant product',
#    'hybrid',
#    'inbred',
#    'method',
#    'plant seed',
#    'second',
#    'seeds plants',
#    'single locus',
#    'soybean variety 01072245',
#    'synthetic cultivation medium'},
#   'EFO': {'herbicide tolerance'},
#   'EFA': {'producing'}},
#  '906': {'EST': {'HMD',
#    'camera',
#    'capture',
#    'communications device',
#    'computer',
#    'controller',
#    'depth camera',
#    'exchanging',
#    'exchanging data',
#    'exterior',
#    'exterior housing',
#    'head',
#    'illuminating elements',
#    'inner side',
#    'screen configuring',
#    'view',
#    'view port',
#    'viewer coupled',
#    'viewing module',
#    'virtual reality',
#    'virtual reality scene'},
#   'EFO': set(),
#   'EFA': {' mounted', 'operating'}},
#  '305': {'EST': {'approaching',
#    'device',
#    'distance between',
#    'first',
#    'first appendage',
#    'first data',
#    'first gait',
#    'first proximity',
#    'first proximity sensor',
#    'gait',
#    'gait pattern',
#    'heel strike',
#    'incoming',
#    'independent variable',
#    'laser',
#    'management computing',
#    'predicted upcoming',
#    'predicting',
#    'predicting comprises',
#    'providing',
#    'proximity sensor',
#    'same',
#    'second',
#    'second gait cycle',
#    'signal',
#    'subject',
#    'transitory computer',
#    'transitory computer readable'},
#   'EFO': {'approaching',
#    'computer readable medium having stored thereon instructions',
#    'instructions stored',
#    'method',
#    'models',
#    'periodic',
#    'programmed',
#    'steps'},
#   'EFA': {'established',
#    'established models predicting',
#    'execute',
#    'perform',
#    'simultaneously',
#    'transitory'}},
#  '963': {'EST': {'baffle plate thereto',
#    'circumferential',
#    'entire length inlet',
#    'filter',
#    'filter mechanism',
#    'first',
#    'first casing',
#    'inner wall',
#    'intake',
#    'matters adhering',
#    'movable blade',
#    'move',
#    'moveable',
#    'present invention',
#    'pump',
#    'radial',
#    'second casing',
#    'turbulent flow',
#    'turning',
#    'working fluid'},
#   'EFO': set(),
#   'EFA': {' mechanism'}},
#  '792': {'EST': {'U shape',
#    'apex',
#    'biasing force',
#    'diaphragm',
#    'diaphragm arranged',
#    'extends',
#    'first arm extending',
#    'housing',
#    'position adjacent',
#    'protrusion',
#    'resilient material',
#    'second',
#    'second arm',
#    'spring'},
#   'EFO': {'valve element', 'valve element biased closed'},
#   'EFA': {'inhalable'}},
#  '187': {'EST': {'actuator',
#    'deployed extends',
#    'first',
#    'inner',
#    'power module',
#    'second',
#    'second plate',
#    'second proximate',
#    'selectively urging',
#    'stowed',
#    'stowed configuration',
#    'substantially perpendicularly'},
#   'EFO': {'deployed', 'further including each'},
#   'EFA': {'claim'}},
#  '914': {'EST': {'being distinct',
#    'camera',
#    'client',
#    'graphics displayed',
#    'identifying',
#    'majority',
#    'occurrence time',
#    'recipient being distinct',
#    'rendered',
#    'rendered video',
#    'replication',
#    'server then',
#    'video stream',
#    'wherein'},
#   'EFO': {'bandwidth', 'efficient', 'efficient remote'},
#   'EFA': {'claim', 'executing'}},
#  '19': {'EST': {'agricultural',
#    'agricultural product distribution system comprising',
#    'air source',
#    'controller',
#    'electrically',
#    'equivalent pressure',
#    'fan configured',
#    'first',
#    'first fan',
#    'first flow regulating device',
#    'first input indicative number openers fluidly coupled primary',
#    'first input indicative number outlets fluidly coupled',
#    'operator',
#    'processor',
#    'product distribution',
#    'second',
#    'second determining'},
#   'EFO': set(),
#   'EFA': {' motors', 'claim'}},
#  '741': {'EST': {'amorphous calcium', 'selenium doped'},
#   'EFO': {'selenium doped hydroxyapatite'},
#   'EFA': {'preparing'}},
#  '550': {'EST': {'adjustment knob',
#    'associated hinge',
#    'buck',
#    'extended',
#    'extending therefrom',
#    'flexed',
#    'lateral',
#    'range',
#    'retracted',
#    'rod',
#    'roller',
#    'second',
#    'second rotation',
#    'third',
#    'upper'},
#   'EFO': {'associated hinge',
#    'lateral',
#    'motion',
#    'upper medial strut',
#    'wherein'},
#   'EFA': {' adjustable', 'adjustable', 'brace'}},
#  '986': {'EST': {'combination thereof',
#    'filter',
#    'filter cartridge',
#    'liquid solvent',
#    'purging',
#    'purging gas',
#    'residual',
#    'volatile amine'},
#   'EFO': set(),
#   'EFA': {'treat', 'wetting'}},
#  '926': {'EST': {'collision signal',
#    'electronic which communicates',
#    'first lighthouse base',
#    'first physical',
#    'first physical object',
#    'first virtual',
#    'initial distance',
#    'interactive processing method comprising',
#    'memory',
#    'method',
#    'overlapping',
#    'overlapping region',
#    'second',
#    'second different',
#    'second physical',
#    'storage medium',
#    'transitory computer readable'},
#   'EFO': {'programs further comprises'},
#   'EFA': set()},
#  '121': {'EST': {'aerosol generating',
#    'air inlet',
#    'capsule',
#    'central passageway',
#    'cover extends',
#    'heating',
#    'liquid storage',
#    'liquid transfer',
#    'second',
#    'vapor generating',
#    'vaporizing unit'},
#   'EFO': set(),
#   'EFA': {'contain'}},
#  '843': {'EST': {'amplitude',
#    'cardiac',
#    'collected',
#    'control',
#    'control circuit',
#    'evoked response',
#    'evoked response amplitude',
#    'first associated',
#    'first command',
#    'initial evoked',
#    'maximum desirable',
#    'microprocessor',
#    'operational',
#    'pacing',
#    'predetermined maximum desirable',
#    'responses thereto',
#    'threshold',
#    'warning',
#    'warning signal'},
#   'EFO': {'control circuit further',
#    'each',
#    'evoked response',
#    'further comprises means',
#    'maximum desirable',
#    'periodic',
#    'responses thereto'},
#   'EFA': {' pacing',
#    'claim',
#    'collecting',
#    'corresponding',
#    'defining',
#    'detecting',
#    'predetermined',
#    'setting',
#    'triggering'}},
#  '749': {'EST': {'present invention'}, 'EFO': set(), 'EFA': set()},
#  '627': {'EST': {'AT1R blocker',
#    'CCR2',
#    'CCR2 inhibitor',
#    'MCP mediated',
#    'affinity potency',
#    'combined',
#    'comprising administering',
#    'dosage',
#    'fibrotic disorders',
#    'inverse',
#    'negative allosteric',
#    'subject concurrently',
#    'treatment'},
#   'EFO': {'RS504393 MLN 1202 INCB8696 MK 0812 CCX140 PF 4136309 RS102895',
#    'allosteric',
#    'blocker AT1R',
#    'chemokine',
#    'kidney',
#    'nephropathy',
#    'pharmaceutically acceptable salt thereof',
#    'therapy The invention',
#    'treating kidney'},
#   'EFA': {'direct antagonists inverse agonists negative',
#    'indirect',
#    'propagermanium'}},
#  '564': {'EST': {'Blowout Percent',
#    'Blowout Percent Leakage',
#    'Efficiency Factor',
#    'crotch',
#    'disposable absorbent',
#    'disposable article',
#    'elastic',
#    'elastomeric nonwoven',
#    'first region',
#    'first waist',
#    'first waist region',
#    'gasketing',
#    'inboard',
#    'inboard lateral',
#    'inner',
#    'inner cuff',
#    'laterally',
#    'leg',
#    'leg gasketing',
#    'material',
#    'outboard',
#    'outer folded edge',
#    'second',
#    'waist element',
#    'waist gasketing',
#    'waist gasketing element'},
#   'EFO': set(),
#   'EFA': set()},
#  '230': {'EST': {'cabinet',
#    'collected urine',
#    'disc',
#    'mechanical lever assembly',
#    'media mixture',
#    'vanity wings'},
#   'EFO': {'auger comprises', 'collected urine', 'dispenser'},
#   'EFA': set()},
#  '979': {'EST': {'any claim',
#    'carbon dioxide',
#    'epoxidation catalyst',
#    'epoxidation reactor',
#    'guard bed',
#    'guard bed material',
#    'support material',
#    'treated recycle',
#    'vinyl impurity'},
#   'EFO': {'gaseous containing', 'recycle gas', 'treated'},
#   'EFA': {'claim', 'removing'}},
#  '359': {'EST': {'bone',
#    'calcium',
#    'calcium surface',
#    'calcium surface structure',
#    'corresponding location',
#    'fidelity measure',
#    'first',
#    'first value',
#    'hard plaque',
#    'hard plaque texture',
#    'inhomogeneous spatial',
#    'local neighborhood',
#    'maximum probability',
#    'penalty',
#    'plaque structures',
#    'regularized map',
#    'second',
#    'segmentation unit',
#    'spectral',
#    'volumetric',
#    'voxel'},
#   'EFO': {'computed',
#    'computed tomography',
#    'maximum',
#    'probability',
#    'spectral',
#    'tomography'},
#   'EFA': {' value', 'processing', 'receiving'}},
#  '292': {'EST': {'ADC measurement variations',
#    'acquisition able',
#    'collected',
#    'diffusion weighted magnetic',
#    'diffusion weighted magnetic resonance images',
#    'histogram',
#    'magnetic resonance images',
#    'parallel imaging',
#    'total',
#    'tumor recurrence',
#    'variation CV',
#    '“diffusion'},
#   'EFO': {'ADC measurement variations',
#    'CV measurements',
#    'apparent',
#    'apparent diffusion coefficient',
#    'approximating',
#    'artifacts calculating',
#    'coefficient',
#    'collecting wise calculated',
#    'current',
#    'estimating apparent diffusion',
#    'mapping',
#    'resolve',
#    'resolve apparent',
#    'subject',
#    'tumor imaging'},
#   'EFA': {' reproducibility',
#    'acquired',
#    'approximating',
#    'claim',
#    'coefficient',
#    'diffusion weighted',
#    'eddy',
#    'mapping',
#    'motion',
#    'quickly',
#    'resolve',
#    'tissue',
#    'variation'}},
#  '645': {'EST': {'Afatinib dimaleate',
#    'core weight',
#    'differential scanning',
#    'endothermic peaks',
#    'lubricated',
#    'pharmaceutically acceptable'},
#   'EFO': set(),
#   'EFA': {'claim', 'manufacturing'}},
#  '887': {'EST': {'entire',
#    'handle region thereof',
#    'hollow golf',
#    'increase frictional',
#    'internal surface',
#    'longitudinal sleeve',
#    'lower',
#    'medial',
#    'medial portion',
#    'method',
#    'outer',
#    'radially extending',
#    'ratchet',
#    'relaxed configuration until',
#    'second movement',
#    'secured',
#    'shaft'},
#   'EFO': set(),
#   'EFA': {' movement', 'attaching'}},
#  '437': {'EST': {'biasing',
#    'biasing mechanism',
#    'coupling mechanism',
#    'distal',
#    'expanded',
#    'fifth',
#    'fine',
#    'fine needle',
#    'first slot',
#    'fourth',
#    'housing',
#    'inner',
#    'inner tubular',
#    'longitudinal slot',
#    'method',
#    'outer',
#    'outer tubular',
#    'plurality',
#    'projection',
#    'proximal end',
#    'rod coupled',
#    'second',
#    'second distance',
#    'third',
#    'third distance'},
#   'EFO': set(),
#   'EFA': {' medical procedures A device', 'claim', 'fine needle aspiration'}},
#  '198': {'EST': {'axis affixed',
#    'camera part',
#    'changes determining',
#    'control',
#    'determined',
#    'display apparatus',
#    'first',
#    'first rotation direction',
#    'horizontal',
#    'image',
#    'isolation',
#    'location angle',
#    'location angle based',
#    'maximum value',
#    'method according',
#    'mirror display',
#    'mirror display apparatus',
#    'operation',
#    'same',
#    'second',
#    'stationary support part',
#    'steps',
#    'user',
#    'user located'},
#   'EFO': set(),
#   'EFA': set()},
#  '214': {'EST': {'brewing',
#    'brewing position',
#    'cap',
#    'coffee',
#    'coffee capsule',
#    'first abutment block',
#    'fixing plate',
#    'fourth',
#    'frame body',
#    'front',
#    'holding seat',
#    'inlet tube assembly',
#    'lateral walls',
#    'mechanism further',
#    'micro switch',
#    'operating',
#    'pin',
#    'reloading mechanisms',
#    'reloading position',
#    'restoring spring',
#    'sealing ring',
#    'second'},
#   'EFO': set(),
#   'EFA': set()},
#  '605': {'EST': {'methacrylic acid', 'processing aid', 'shell according'},
#   'EFO': set(),
#   'EFA': set()},
#  '240': {'EST': {'air',
#    'combined',
#    'controller',
#    'exterior surface',
#    'hydraulic circuit',
#    'liquid',
#    'liquid supply',
#    'nozzle',
#    'sprayers includes',
#    'tubular spray',
#    'wash'},
#   'EFO': {'discretely directable sprayer', 'liquid'},
#   'EFA': {'claim', 'comprising', 'dishwasher', 'spray', 'supply'}},
#  '982': {'EST': {'CHA CDO',
#    'catalytic material',
#    'molecular sieve',
#    'second',
#    'substrate'},
#   'EFO': {'CHA CON DDR ERI FAU FER GON IFR IFW IFY IHW IMF IRN IRY IS V ITE ITG ITN ITR ITW IWR IWS IWV IWW JOZ LTA LTF MEL MEP MFI MRE MSE MTF MTN MTT MTW MVY MWW NON NSI RRO RSN RTE RTH RUT RWR SEW SFE SFF SFG SFH SFN SFS SFV SGT SOD SSF SSO',
#    'SSY STF',
#    'STO STT',
#    'SVR SW TON TUN UOS UOV',
#    'exhaust gas produced',
#    'platinum Pt',
#    'substrate'},
#   'EFA': {' emission A', 'AEI', 'CFI', 'treating'}},
#  '688': {'EST': {'CAR comprises',
#    'FKBP12 variant',
#    'amino acid',
#    'caspase',
#    'multimeric ligand',
#    'multimeric ligand inducer',
#    'multimerization',
#    'therapeutic',
#    'therapeutic cells',
#    'therapeutically effective'},
#   'EFO': {'ID NO',
#    'amino',
#    'chimeric',
#    'chimeric protein',
#    'chimeric protein comprising',
#    'nucleic acid'},
#   'EFA': {'encodes', 'treating'}},
#  '324': {'EST': {'Bayesian',
#    'ECG',
#    'accelerometer',
#    'accelerometer configured',
#    'constituent',
#    'constituent bands',
#    'constituent frequency bands',
#    'electrical',
#    'electrical activity',
#    'filter bank',
#    'first',
#    'first electrode',
#    'higher level',
#    'intensive',
#    'machine learning',
#    'memory',
#    'method',
#    'modules',
#    'motor accelerometry',
#    'neural',
#    'neural activity',
#    'neuro cardiological',
#    'outer surface',
#    'output signal',
#    'plurality',
#    'post acute',
#    'post acute stroke',
#    'predefined',
#    'processor',
#    'radial artery permitting',
#    'second',
#    'second electrode',
#    'wearable device',
#    'wherein steps'},
#   'EFO': {'motor', 'neuro cardiological', 'neuro cardiological disorders'},
#   'EFA': {'monitoring'}},
#  '216': {'EST': {'alcoholic',
#    'apparatus',
#    'bag cup',
#    'beverage pod',
#    'biodegradable material',
#    'decadienal',
#    'disposable',
#    'first',
#    'first compartment',
#    'first flavor',
#    'group',
#    'lid portion',
#    'piercing tearing',
#    'predetermined',
#    'predetermined amount',
#    'resulting single',
#    'second',
#    'second consisting',
#    'water'},
#   'EFO': {'astringent',
#    'diethoxyethane trans cinnamate glycerol glucose fructose L proline',
#    'methylbutanal',
#    'methylpropanal furaneol ethylfuraneol',
#    'methylpropanoate octanoate hexanoate',
#    'methylpropanoic butanoic',
#    'octanoic acid',
#    'phenolic medicinal seventh',
#    'proline saccharose potassium magnesium calcium tannic aconitic',
#    'seasoning fatty sixth',
#    'smoky coconut woody fifth',
#    'sour',
#    'which impart aromas tastes'},
#   'EFA': {'cooked',
#    'diethoxyethane trans cinnamate whiskey lactone',
#    'fruity fourth',
#    'making',
#    'methylpropanoic butanoic',
#    'methylpropanol methylbutanal',
#    'myrcene',
#    'oak',
#    'phenylethyl',
#    'phenylethyl acetate linalool acetaldehyde'}},
#  '739': {'EST': {'abluminal surface',
#    'acellular tissue',
#    'adhesive',
#    'basement membrane',
#    'dermal matrix',
#    'first longitudinal',
#    'second',
#    'second longitudinal',
#    'single',
#    'tubular wall'},
#   'EFO': set(),
#   'EFA': {' comprising'}},
#  '539': {'EST': {'base',
#    'direction between groups',
#    'first spiral body',
#    'flat plate',
#    'horizontal section',
#    'medical linear',
#    'medical linear member',
#    'oval shape',
#    'plurality',
#    'predetermined length',
#    'production method',
#    'second',
#    'short diameter',
#    'spirally',
#    'winding',
#    'wires'},
#   'EFO': set(),
#   'EFA': set()},
#  '259': {'EST': {'apparatus',
#    'bright spot',
#    'camera',
#    'caregiver uses',
#    'cylindrical barrel',
#    'elongated',
#    'eye',
#    'memory',
#    'outer housing',
#    'processor',
#    'second configured',
#    'upper half'},
#   'EFO': set(),
#   'EFA': {' An'}},
#  '333': {'EST': {'current',
#    'electronic signal',
#    'electronic signal configured',
#    'energy requirements',
#    'equipment device',
#    'equipment device oxygenation',
#    'first',
#    'first portion',
#    'intermittent activity',
#    'output',
#    'previous',
#    'processor',
#    'same',
#    'same rate',
#    'second',
#    'third',
#    'tissue',
#    'updated estimated'},
#   'EFO': set(),
#   'EFA': set()},
#  '942': {'EST': {'air guide',
#    'axial passageway',
#    'axial passageway therethrough',
#    'bubble',
#    'circular',
#    'closed geometrically',
#    'closed geometrically shaped',
#    'closed geometrically shaped outer shell',
#    'electric motor',
#    'exterior thereof',
#    'housing',
#    'impeller',
#    'impeller rotatingly',
#    'inner air',
#    'inner circular',
#    'leading edge',
#    'liquid',
#    'outer shell',
#    'peripheral',
#    'peripheral outlet',
#    'peripheral outlet ring affixed',
#    'plenum',
#    'shaped outer shell',
#    'trough'},
#   'EFO': {'bubble fan', 'spaced fins'},
#   'EFA': {'Bladeless bubble', 'claim', 'closely', 'drawing', 'receiving'}},
#  '98': {'EST': {'bacterial biomass',
#    'bottom surface',
#    'bounded tank',
#    'bounded tank water',
#    'concentrated microbial',
#    'constituent microbes',
#    'creating movement',
#    'growth',
#    'harvested plant',
#    'inlet',
#    'intermediary',
#    'least partially submerged',
#    'lower',
#    'microbial',
#    'upper end',
#    'upper fluid',
#    'wherein excess',
#    'wood chips'},
#   'EFO': set(),
#   'EFA': set()},
#  '587': {'EST': {'digestive organ',
#    'distal',
#    'forceps',
#    'grasping',
#    'grasping sections disposed',
#    'linear',
#    'manner',
#    'outer peripheral',
#    'outer peripheral surface',
#    'protrudes laterally',
#    'region',
#    'ring portion',
#    'site',
#    'tube'},
#   'EFO': set(),
#   'EFA': set()},
#  '439': {'EST': {'adjuster',
#    'adjustment means',
#    'attachment peg',
#    'external',
#    'first',
#    'first housing',
#    'fourth',
#    'locked position',
#    'second',
#    'second ball joint',
#    'second sub',
#    'socket',
#    'sub strut',
#    'third',
#    'threaded bolt',
#    'threaded collar',
#    'threaded shaft'},
#   'EFO': {'position relative'},
#   'EFA': {' A dynamic', 'claim'}},
#  '190': {'EST': {'bedding thereof',
#    'differential',
#    'flame retardant',
#    'knitting pattern',
#    'knitting textile cylinder',
#    'mattress',
#    'mattress foundations',
#    'tubular form',
#    'unitarily',
#    'width'},
#   'EFO': {'concentrations yielding',
#    'knitted fire barrier fabric',
#    'knitted fire barrier fabrics',
#    'material',
#    'retardant yarns',
#    'retardant yarns defining',
#    'tubular unitarily'},
#   'EFA': {'Differentially', 'assembling', 'example', 'forming', 'knitted'}},
#  '797': {'EST': {'airflow',
#    'airflow generator',
#    'apparatus comprising removing',
#    'bacterial filter',
#    'bacterial filter extend',
#    'cartridge',
#    'cartridge within',
#    'cavity',
#    'cavity comprises slidable',
#    'cavity configured',
#    'controller electrically coupled',
#    'exhalation comprises',
#    'exhalation phase',
#    'exhalation valve',
#    'first',
#    'first gas',
#    'first gas flow',
#    'first junction',
#    'gas flow',
#    'gaseous flow',
#    'housing',
#    'housing configured',
#    'humidifier',
#    'patient interface',
#    'patient interface connection',
#    'prepared',
#    'pressure sensor',
#    'removable',
#    'removable cartridge',
#    'second',
#    'second junction',
#    'second treatment',
#    'used cartridge'},
#   'EFO': {'airflow', 'cross contamination', 'through', 'unfiltered'},
#   'EFA': {'claim', 'preventing', 'traveling'}},
#  '691': {'EST': {'antigenic',
#    'carrier molecules',
#    'glacial acetic acid',
#    'micellar',
#    'mixed',
#    'organic',
#    'polypeptide vaccine',
#    'vacuum rotary evaporator'},
#   'EFO': set(),
#   'EFA': {'preparing'}},
#  '952': {'EST': {'displaced',
#    'extending',
#    'filler',
#    'filler inserted',
#    'filter',
#    'inserting filler',
#    'interior',
#    'mixture thereof',
#    'primary chamber',
#    'secondary',
#    'side walls',
#    'top wall',
#    'underdrain'},
#   'EFO': set(),
#   'EFA': set()},
#  '686': {'EST': {'mutant Htt',
#    'nucleic acid',
#    'nucleic acid molecule',
#    'promoter'},
#   'EFO': {'exogenous', 'huntingtin mediated'},
#   'EFA': {'Mutant', 'decreasing'}},
#  '916': {'EST': {'acceleration',
#    'computer readable storage',
#    'computer system',
#    'control point',
#    'course',
#    'current position',
#    'direction',
#    'display',
#    'during',
#    'during gameplay',
#    'first vector',
#    'forward',
#    'game',
#    'game program',
#    'generated',
#    'hardware processor',
#    'instruction inputted',
#    'medium configured',
#    'object',
#    'operated',
#    'position',
#    'processing',
#    'relative position',
#    'screen',
#    'second',
#    'second vector',
#    'virtual'},
#   'EFO': set(),
#   'EFA': {' apparatus A forward'}},
#  '83': {'EST': {'A', 'genera Agropyron'},
#   'EFO': {'disease pressure', 'pythium'},
#   'EFA': {' phytopathogenic diseases', 'moderate'}},
#  '588': {'EST': {'1',
#    '1.5',
#    'X',
#    'abrasive powder',
#    'alkyl',
#    'binder',
#    'butylene',
#    'cationic bactericide triclosan',
#    'foam liquid',
#    'foam liquid composition',
#    'mass',
#    'nonionic',
#    'sugar alcohol which'},
#   'EFO': {'following components', 'propylene'},
#   'EFA': {' The present invention', 'glycerin'}},
#  '392': {'EST': {'displayed firing',
#    'end effector',
#    'firing member',
#    'first jaw',
#    'measured',
#    'memory coupled storing',
#    'motor',
#    'pressure applied',
#    'processor',
#    'second',
#    'staple cartridge',
#    'threshold',
#    'tissue',
#    'tissue grasped',
#    'which'},
#   'EFO': set(),
#   'EFA': {'instrument'}},
#  '229': {'EST': {'foldable element',
#    'lateral sections',
#    'potty',
#    'stiff',
#    'support',
#    'support element'},
#   'EFO': {'arched bodies', 'discrete sub elements'},
#   'EFA': {' element', 'round'}},
#  '719': {'EST': {'Br I methanesulfonate ethanesulfonate',
#    'C1',
#    'Cl Br',
#    'C═O',
#    'C═S',
#    'F Cl',
#    'R1',
#    'R4',
#    'R8',
#    'Rs0',
#    'Rs1',
#    'S',
#    'S R3',
#    'alkyl',
#    'alkyl methyl ethyl',
#    'alkynyl',
#    'anesthetic',
#    'azido',
#    'chronic pain',
#    'conjugate',
#    'following A1',
#    'following steps',
#    'group',
#    'group consisting',
#    'iNHCO',
#    'linking',
#    'linking position',
#    'linking position between',
#    'maleate',
#    'prolonged analgesic effect',
#    'quaternary ammonium',
#    'quaternary ammonium salt',
#    'structures shown below',
#    'wherein',
#    'wherein R10'},
#   'EFO': {'I'},
#   'EFA': {' method thereof',
#    'Br methanesulfonate ethanesulfonate benzenesulfonate citrate lactate succinate fumarate glutamate salicylate'}},
#  '488': {'EST': {'diagnostic',
#    'dimensional scanner',
#    'first',
#    'first dental',
#    'first scanner',
#    'image data',
#    'navigation elements',
#    'perpendicular axes',
#    'relative',
#    'scanner',
#    'three dimensional'},
#   'EFO': set(),
#   'EFA': {' locations'}},
#  '487': {'EST': {'abutment',
#    'bottom end',
#    'circumferential',
#    'conical',
#    'dental',
#    'external',
#    'external part',
#    'imaging',
#    'imaging device',
#    'implant',
#    'larger diameter',
#    'lower',
#    'lower portion',
#    'neck',
#    'neck portion',
#    'outer surface',
#    'screw',
#    'slope',
#    'substantially',
#    'substantially circumferential',
#    'substantially radial',
#    'upper'},
#   'EFO': set(),
#   'EFA': set()},
#  '945': {'EST': {'19.0° C',
#    'CH2F2 HFC',
#    'adding',
#    'being 1.11',
#    'contaminated',
#    'converting',
#    'crystal',
#    'crystal structure',
#    'first stage',
#    'gas hydrate',
#    'guest molecule',
#    'heavy',
#    'light',
#    'liquid',
#    'second',
#    'steps',
#    'tritiated',
#    'tritiated water',
#    'yet keeping'},
#   'EFO': set(),
#   'EFA': set()},
#  '383': {'EST': {'arc shaped profile',
#    'bend',
#    'bent',
#    'bottom surface',
#    'deflect laterally',
#    'degrees',
#    'distal',
#    'distal region',
#    'elongate body',
#    'extend laterally',
#    'extended',
#    'fixed relative',
#    'knee meniscus',
#    'lower',
#    'lower jaw',
#    'move',
#    'proximal end',
#    'retracted configuration',
#    'retracted position',
#    'rounded',
#    'straight line',
#    'suture passer',
#    'tissue penetrator',
#    'tissue penetrator housed',
#    'tissue penetrator laterally',
#    'upper',
#    'upper jaw'},
#   'EFO': {'passer'},
#   'EFA': {'claim'}},
#  '148': {'EST': {'arcuate',
#    'arcuate segment',
#    'bladder',
#    'chamber',
#    'chamber extending continuously',
#    'chamber including',
#    'claim',
#    'continuously defining portion',
#    'different material',
#    'entirely',
#    'extending',
#    'first',
#    'first cushion',
#    'first terminal end',
#    'first top cushion',
#    'fluid communication',
#    'forefoot',
#    'ground engaging',
#    'ground engaging surface',
#    'having',
#    'heel',
#    'heel region',
#    'interior',
#    'interior cushion',
#    'interior outsole',
#    'lateral',
#    'medial side',
#    'mid foot',
#    'opening cushion',
#    'opposite',
#    'peripheral',
#    'peripheral outsole',
#    'second',
#    'second bottom',
#    'second portion',
#    'second spaced',
#    'second spaced apart',
#    'separated',
#    'sole structure',
#    'web area',
#    'width'},
#   'EFO': set(),
#   'EFA': {' A'}},
#  '794': {'EST': {'alert message',
#    'breathable gas',
#    'communications device',
#    'comprising accessing',
#    'control parameter',
#    'controller',
#    'controller comprises',
#    'detectable condition',
#    'input',
#    'memory',
#    'monitoring sessions',
#    'patient interface',
#    'performed',
#    'physician based',
#    'potential relapse',
#    'question addresses',
#    'respiratory insufficiency An such',
#    'second question',
#    'subsequent',
#    'subsequent alert',
#    'user'},
#   'EFO': {'above atmospheric',
#    'apparatus',
#    'method',
#    'monitor provides',
#    'patient interface'},
#   'EFA': {'claim', 'evaluating', 'monitoring', 'treating'}},
#  '350': {'EST': {'X',
#    'circuitry',
#    'comparison',
#    'corrected',
#    'detected',
#    'detection signal',
#    'detector',
#    'determined',
#    'device according',
#    'first predetermined',
#    'processing circuitry',
#    'reference',
#    'second',
#    'subject'},
#   'EFO': {'device according',
#    'device comprising processing circuitry configured'},
#   'EFA': {'acquisition'}},
#  '596': {'EST': {'C6 hydrocarbon',
#    'O S',
#    'R3',
#    'amino C4 aminoalkyl interrupted',
#    'amount ranging',
#    'carbonyl CO R2 which',
#    'heteroatom',
#    'integer ranging',
#    'optionally',
#    'proviso'},
#   'EFO': {'C1',
#    'C3 C40 cycloalkyl C30 aromatic hydroxyl thiol aryl',
#    'C30 aromatic hydroxyl thiol aryl',
#    'C40 cycloalkyl',
#    'C6 hydrocarbon based chain',
#    'NH2',
#    'R being C20',
#    'cyclic',
#    'groups',
#    'groups chosen',
#    'linear',
#    'saturated',
#    'silicon atoms',
#    'thereof',
#    'wherein',
#    'wherein R1'},
#   'EFA': {' substance The invention',
#    'NHR',
#    'acyclic',
#    'amine',
#    'different',
#    'each represent',
#    'following amine NH2',
#    'formula',
#    'identical',
#    'unsaturated'}},
#  '777': {'EST': {'avoiding displacement',
#    'container',
#    'delivery device',
#    'delivery member',
#    'distally',
#    'elongated',
#    'fixed position',
#    'flexible retaining',
#    'guide track',
#    'locking mechanism',
#    'longitudinal',
#    'medical',
#    'opposite',
#    'outer circumferential',
#    'resilient portion',
#    'resilient structure',
#    'tubular body'},
#   'EFO': set(),
#   'EFA': set()},
#  '772': {'EST': {'activated',
#    'aperture through',
#    'device according',
#    'distal',
#    'elongate member',
#    'entire distal',
#    'first width',
#    'frustoconical segment',
#    'indentation',
#    'internal',
#    'needle',
#    'needle guard',
#    'needle shaft passes',
#    'outer surface',
#    'proximal',
#    'proximal section of',
#    'ready',
#    'reduced being less',
#    'resilient arm',
#    'second',
#    'through passage extending ends'},
#   'EFO': {'device according'},
#   'EFA': {'safety'}},
#  '80': {'EST': {'2 keto',
#    'aqueous saline',
#    'aqueous solution',
#    'composition comprises',
#    'increasing salt tolerance',
#    'plant',
#    'plant substrate',
#    'salt stress',
#    'solution comprises',
#    'untreated',
#    'wherein salt tolerance'},
#   'EFO': {'EC',
#    'aci reductone dioxygenase mtnK kinase metK encloding',
#    'dehydratase mtnC',
#    'enolase phosphatase mtnD ykrZ encodiong',
#    'methylthioribulose',
#    'spermidine',
#    'tyrB',
#    'wide spectrum aminotransferase mtnA MtnA methylthioribose'},
#   'EFA': {'3.2.2.16',
#    'claim',
#    'cultivating',
#    'increasing',
#    'mtnN',
#    'provides'}},
#  '282': {'EST': {'algorithms',
#    'algorithms algorithm',
#    'alone',
#    'amplitude variation curve',
#    'biometric',
#    'fast Fourier transforming',
#    'first',
#    'first algorithm',
#    'first algorithm corresponding',
#    'frequency spectrum',
#    'intervals',
#    'memory',
#    'peaks valleys',
#    'physiological',
#    'pulse wave',
#    'rest',
#    'second being different',
#    'subject'},
#   'EFO': {'biometric sensors'},
#   'EFA': {' sensors', 'controlling'}},
#  '416': {'EST': {'apparatus',
#    'displacement values',
#    'displacing',
#    'displacing means',
#    'displaying means',
#    'focal point',
#    'orthogonal secant planes',
#    'recorded',
#    'remote',
#    'screen',
#    'ultrasound',
#    'ultrasound probe',
#    'virtual images which'},
#   'EFO': set(),
#   'EFA': set()},
#  '957': {'EST': {'actuator',
#    'actuator attached distally distal',
#    'bypass',
#    'bypass valve',
#    'bypass valve actuator',
#    'cartridge',
#    'cartridge housing',
#    'clip',
#    'configured such',
#    'elongated rod',
#    'extending',
#    'filter',
#    'filter cartridge',
#    'first cylindrical',
#    'second',
#    'surrounding exterior',
#    'valve'},
#   'EFO': set(),
#   'EFA': {' A', 'comprises'}},
#  '306': {'EST': {'action recognition',
#    'character',
#    'characteristic vector',
#    'inner side',
#    'light sensing',
#    'movable part',
#    'muscular variation module',
#    'processing',
#    'recognition module',
#    'second beam',
#    'wearable device'},
#   'EFO': {'gyro'},
#   'EFA': {' recognition', 'claim'}},
#  '142': {'EST': {'blank',
#    'coolant',
#    'cuboid',
#    'foot orthotic',
#    'heated orthotic',
#    'longitudinal axis',
#    'medial longitudinal arch',
#    'neutral position',
#    'orthotic template',
#    'outer lower',
#    'outside',
#    'patient',
#    'prepared',
#    'upper'},
#   'EFO': {'orthotic', 'outer', 'template'},
#   'EFA': {'blank', 'forming', 'preparing', 'providing'}},
#  '582': {'EST': {'administration methods',
#    'cylindrical sidewalls',
#    'protective material',
#    'syringe'},
#   'EFO': {'package sufficiently'},
#   'EFA': set()},
#  '391': {'EST': {'clip',
#    'compressive',
#    'dispensing',
#    'elongated',
#    'formation rear',
#    'jaw clenching pressure',
#    'loop portion',
#    'lumen',
#    'minor',
#    'resilient material',
#    'second',
#    'shoulders respectively',
#    'solid shoulder',
#    'spring biased',
#    'surgery clip'},
#   'EFO': set(),
#   'EFA': set()},
#  '59': {'EST': {'apparatus',
#    'first',
#    'first mount',
#    'first pig',
#    'first trough',
#    'floor slats',
#    'fluid supply',
#    'frame such',
#    'front',
#    'horizontal portion',
#    'longitudinally spaced apart',
#    'nipple ports',
#    'rear',
#    'rescue feeder',
#    'restraining portion',
#    'retaining portion',
#    'rooting protector',
#    'rung portions',
#    'second',
#    'semi cylindrical',
#    'trough',
#    'waterer',
#    'waterer apparatus'},
#   'EFO': {'fallback'},
#   'EFA': {'reintegrating'}},
#  '223': {'EST': {'being hingedly attached',
#    'closed',
#    'combustion products',
#    'continuous',
#    'cooking',
#    'cooking chamber',
#    'door flap',
#    'entrance pathway',
#    'entrance pathway extending horizontally',
#    'entrance pathway horizontally',
#    'first extending',
#    'front',
#    'grate',
#    'grill combination',
#    'handle joined',
#    'heated air',
#    'height greater',
#    'hinge',
#    'items insertable',
#    'maximum thickness',
#    'peripheral edge',
#    'pizza',
#    'planar portion',
#    'rear',
#    'second',
#    'substantially',
#    'substantially enclosed chamber',
#    'upper edge'},
#   'EFO': set(),
#   'EFA': {' hingedly'}},
#  '431': {'EST': {'annular',
#    'annular edge',
#    'body',
#    'catheter',
#    'catheter body',
#    'circumferentially around',
#    'cutting',
#    'cutting element',
#    'deployment mechanism',
#    'distal',
#    'drive shaft',
#    'elongate',
#    'elongate configured',
#    'external thread',
#    'handle',
#    'helical',
#    'imparting relative',
#    'internal',
#    'longitudinal',
#    'longitudinal axis',
#    'method',
#    'operatively connected',
#    'opposite',
#    'proximal engagement',
#    'proximally facing cup',
#    'recess',
#    'removed',
#    'removed material',
#    'removed tissue',
#    'removing',
#    'removing tissue',
#    'retracted',
#    'retracted position',
#    'rotatable',
#    'selectively imparting relative',
#    'shearing member'},
#   'EFO': set(),
#   'EFA': {' A'}},
#  '975': {'EST': {'first',
#    'merging adapted',
#    'mixed fluid',
#    'recirculation',
#    'second fluid',
#    'separation header',
#    'separation header circulation',
#    'separation portion',
#    'supply',
#    'switching',
#    'tank',
#    'transfer'},
#   'EFO': {'mixed fluid', 'respective', 'separated', 'transfer'},
#   'EFA': {'Component transfer', 'component device A', 'flowing'}},
#  '567': {'EST': {'blade operatively',
#    'driven element',
#    'housing',
#    'operator during',
#    'output shaft further',
#    'substantially orthogonal'},
#   'EFO': {'driven', 'teeth thereon element'},
#   'EFA': set()},
#  '649': {'EST': {'anticancer adjuvant', 'compound', 'following Formula'},
#   'EFO': {'K',
#    'cancer',
#    'mitochondria mediated activity',
#    'pharmaceutical composition',
#    'treating'},
#   'EFA': {'Anticancer', 'enhancing', 'increasing', 'treating'}},
#  '42': {'EST': {'aquatic',
#    'aquatic plant',
#    'aquatic plant culture',
#    'bottom wall',
#    'cartridge',
#    'compartment',
#    'compartment configured',
#    'control unit',
#    'customize contents',
#    'distributing aquatic plant',
#    'extractor',
#    'harvesting aquatic',
#    'processor',
#    'sensors',
#    'server',
#    'subsequent',
#    'walls'},
#   'EFO': {'central processing',
#    'fertilizer stock solution',
#    'growth conditions',
#    'substances housed'},
#   'EFA': {'cultivating', 'receiving'}},
#  '77': {'EST': {'aqueous solution containing',
#    'microcapsule suspension',
#    'pH adjuster',
#    'pesticide',
#    'polyanionic',
#    'spray',
#    'weight',
#    'whole amount'},
#   'EFO': {'aqueous solution'},
#   'EFA': {'Microcapsule', 'releasing'}},
#  '118': {'EST': {'ejection head',
#    'fluid reservoir',
#    'heating element',
#    'heating element located',
#    'interwoven',
#    'interwoven wire',
#    'vaporization device A'},
#   'EFO': set(),
#   'EFA': set()},
#  '804': {'EST': {'activating',
#    'actuator',
#    'actuator switches',
#    'anesthetic',
#    'anesthetic administration',
#    'controller comprises',
#    'first',
#    'flow devices',
#    'group consisting',
#    'infusion',
#    'local reservoir',
#    'pushbutton',
#    'regional',
#    'regional anesthesia',
#    'second backward',
#    'slide',
#    'third',
#    'tube',
#    'volume displacement'},
#   'EFO': {'actuator switches',
#    'actuator switches operate',
#    'infusion',
#    'regional needle'},
#   'EFA': {'generating', 'performing'}},
#  '373': {'EST': {'decision',
#    'doctor respectively',
#    'first',
#    'first medical image',
#    'first needle',
#    'freeze display',
#    'monitor',
#    'operator pressed',
#    'past',
#    'predetermined events concerning operations',
#    'processing circuitry',
#    'processing circuitry executes',
#    'second',
#    'second medical',
#    'second needle',
#    'three dimensional',
#    'ultrasonic',
#    'updated'},
#   'EFO': {'desired'},
#   'EFA': {'claim'}},
#  '737': {'EST': {'3D scaffold',
#    'cell',
#    'composition',
#    'hydrogel',
#    'mixture',
#    'pH',
#    'silk fibroin'},
#   'EFO': {'3D scaffold'},
#   'EFA': set()},
#  '271': {'EST': {'camera',
#    'feedback',
#    'first',
#    'infrared fluorescence',
#    'molecular',
#    'optical acquisition',
#    'second switcher',
#    'signal',
#    'signal acquisition'},
#   'EFO': {'timing'},
#   'EFA': {' module configured', 'claim'}},
#  '540': {'EST': {'braded tubular',
#    'braided portion',
#    'braided wires',
#    'cover member',
#    'covered',
#    'covered portion',
#    'crocheted',
#    'first end region',
#    'single crocheted wire',
#    'single wire',
#    'stent',
#    'uncovered',
#    'uncovered portion'},
#   'EFO': {'body lumen',
#    'medical device',
#    'medical device comprising',
#    'tissue ingrowth therein'},
#   'EFA': {' portion', 'allowing', 'implantable', 'limit', 'remove'}},
#  '813': {'EST': {'catheter',
#    'clamped',
#    'clamping element',
#    'cutting',
#    'first',
#    'first blade',
#    'first blade positioned between',
#    'further comprising',
#    'handle outside',
#    'proximal end',
#    'receiving channel',
#    'sheath',
#    'stopping element',
#    'tubular section'},
#   'EFO': {'allow passage', 'catheter therein', 'clamp', 'cutting', 'method'},
#   'EFA': {' device', 'claim', 'introducer', 'releasably', 'using'}},
#  '377': {'EST': {'accessible such',
#    'adjacent',
#    'adjacent spinous',
#    'cannula dilator',
#    'decompression procedure',
#    'dilation',
#    'distal',
#    'elongate',
#    'first',
#    'first assembly',
#    'first dilator',
#    'first instrument',
#    'further comprising',
#    'handle',
#    'instrument',
#    'instrument cannula',
#    'instrument cannula passageway',
#    'introducer dilator',
#    'locked configuration',
#    'main body',
#    'mechanically coupling',
#    'outer instruments',
#    'passing',
#    'proximal',
#    'respective',
#    'second',
#    'second inner',
#    'second inner instrument',
#    'second movable',
#    'spinal decompression',
#    'treatment site',
#    'unlocked',
#    'unlocked away'},
#   'EFO': {'adjacent spinous processes',
#    'dilating anatomical features',
#    'same A method'},
#   'EFA': {'claim', 'position', 'sequentially'}},
#  '780': {'EST': {'actuateable release',
#    'coupling',
#    'dose',
#    'dose dial',
#    'drug delivery',
#    'first phase',
#    'first position',
#    'housing',
#    'housing assembly',
#    'lock element',
#    'method',
#    'power reservoir',
#    'primary',
#    'primary assembly',
#    'primary drive',
#    'rotationally',
#    'second',
#    'second coupled',
#    'secondary',
#    'secondary lead'},
#   'EFO': {'device'},
#   'EFA': {' mechanism', 'claim', 'driving lead', 'screw'}},
#  '208': {'EST': {'100',
#    'bacilli',
#    'bonding agent',
#    'heating takes',
#    'period',
#    'premixed composition',
#    'range',
#    'surface',
#    'surface either',
#    'temperature'},
#   'EFO': {'environment'},
#   'EFA': set()},
#  '55': {'EST': {'backcross',
#    'commodity plant',
#    'desired trait',
#    'different',
#    'hybrid',
#    'inbred',
#    'method',
#    'mutagenized',
#    'second',
#    'single locus',
#    'soybean cultivar 75052534',
#    'soybean cultivars lines',
#    'transgenic'},
#   'EFO': {'cultivar 75052534'},
#   'EFA': {'introducing', 'producing'}},
#  '372': {'EST': {'absolute',
#    'certain angle',
#    'coefficients based',
#    'coefficients using',
#    'diagnostic apparatus',
#    'different',
#    'first',
#    'piece based',
#    'pieces',
#    'processing circuitry',
#    'received signals',
#    'separately',
#    'signal',
#    'spatial',
#    'ultrasound',
#    'values'},
#   'EFO': {'apparatus comprising processing circuitry configured',
#    'calculation',
#    'method An',
#    'method comprising',
#    'multiplication',
#    'ultrasound'},
#   'EFA': {'Ultrasound diagnostic', 'diagnostic', 'imaging'}},
#  '263': {'EST': {'adjuster mechanism',
#    'centering portion',
#    'computer readable memory',
#    'facial',
#    'first',
#    'lateral',
#    'processing',
#    'processing unit',
#    'statistical'},
#   'EFO': {'centering portion'},
#   'EFA': {' rest'}},
#  '863': {'EST': {'Active Venting',
#    'active venting',
#    'detachable venting system',
#    'exhalation cycle',
#    'exhaled',
#    'first attachment',
#    'housing',
#    'mask adapted',
#    'membrane opens',
#    'membrane prevents',
#    'membrane seat',
#    'relative closed',
#    'respiratory device',
#    'second',
#    'supporting pillars extending',
#    'unidirectional',
#    'unidirectional valve',
#    'valve during exhalation',
#    'venting'},
#   'EFO': {'warm moist exhaled'},
#   'EFA': set()},
#  '641': {'EST': {'analgesic compound',
#    'formulae',
#    'invention relates',
#    'opioid agonist compound'},
#   'EFO': set(),
#   'EFA': set()},
#  '633': {'EST': {'oral dosage', 'therapeutically effective'},
#   'EFO': {'method'},
#   'EFA': set()},
#  '727': {'EST': {'certain controlled chemical',
#    'group consisting',
#    'modified',
#    'phospholipid layer',
#    'synthetic',
#    'targeting moiety'},
#   'EFO': {'discoidal phospholipid layer', 'scavenger receptors'},
#   'EFA': {' A', 'macrophage'}},
#  '256': {'EST': {'data',
#    'dental prosthesis',
#    'different',
#    'method',
#    'patient',
#    'scanned concurrently',
#    'tray',
#    'tray part',
#    'tray parts',
#    'upper'},
#   'EFO': {'dental prosthesis', 'rigid'},
#   'EFA': {'claim', 'producing'}},
#  '351': {'EST': {'control device',
#    'control mode',
#    'external',
#    'external synchronizing',
#    'predetermined amount',
#    'radiation',
#    'subject',
#    'synchronizing'},
#   'EFO': {'detecting elements aligned'},
#   'EFA': set()},
#  '330': {'EST': {'Euclidian distance',
#    'analysis',
#    'analysis unit',
#    'body',
#    'body part',
#    'camera configured',
#    'cardiac activity extraction',
#    'cardiac activity signal using remote',
#    'computer processors',
#    'decision',
#    'determined',
#    'fundamental frequency',
#    'heart',
#    'input',
#    'input unit',
#    'measurement',
#    'method',
#    'monitor device',
#    'monitoring',
#    'motion',
#    'predetermined threshold',
#    'received',
#    'second',
#    'similarity measure',
# ...
#    'flow modifying',
#    'higher',
#    'impeller',
#    'impeller housing',
#    'inner',
#    'leading',
#    'longitudinal axis',
#    'lumen extending',
#    'second',
#    'second number',
#    'smaller diameter',
#    'trailing edge'},
#   'EFO': set(),
#   'EFA': {'claim'}},
#  '460': {'EST': {'ablation',
#    'ablation electrodes',
#    'catheter',
#    'distal node',
#    'dual node',
#    'dual node multiray',
#    'electrode assembly',
#    'elongated body',
#    'expanded configuration',
#    'longitudinal axis',
#    'node multiray electrode',
#    'outer',
#    'proximal',
#    'proximal multiray',
#    'relative distance',
#    'stent'},
#   'EFO': set(),
#   'EFA': set()},
#  '476': {'EST': {'activation switch',
#    'audible',
#    'blocking element',
#    'compartment 48',
#    'detection',
#    'device',
#    'invention relates',
#    'keying',
#    'medical waste products',
#    'medicament',
#    'medicament which',
#    'monitoring unit',
#    'operably',
#    'outer',
#    'safe container',
#    'second',
#    'second locking'},
#   'EFO': {'specific'},
#   'EFA': {'claim', 'handling'}},
#  '427': {'EST': {'assistance apparatus',
#    'assistance apparatus method',
#    'blood vessel',
#    'boundary surface',
#    'computer readable',
#    'cutting',
#    'cutting surface',
#    'direction orthogonal',
#    'excision',
#    'first',
#    'first distance map',
#    'first width',
#    'inner',
#    'input',
#    'input specifying depth',
#    'inside',
#    'lower',
#    'manner',
#    'neighborhood',
#    'neighborhood region',
#    'organ',
#    'outer',
#    'outer edge',
#    'partial',
#    'portion',
#    'process further',
#    'processor',
#    'ratio',
#    'respective',
#    'second',
#    'specified',
#    'surgery assistance',
#    'three dimensional'},
#   'EFO': set(),
#   'EFA': set()},
#  '566': {'EST': {'absorbent',
#    'absorbent article',
#    'being',
#    'core insert',
#    'core insert being',
#    'depression',
#    'detachable',
#    'disposable',
#    'elastic loop',
#    'elasticated receptacle',
#    'elasticated receptacle formed',
#    'inner',
#    'inner providing',
#    'outer',
#    'outer shell',
#    'outwardly directed',
#    'protruding',
#    'protruding outwardly relative forming',
#    'protuberance projecting',
#    'removable',
#    'retaining structure',
#    'retaining structure formed',
#    'reusable',
#    'second',
#    'single',
#    'surface further',
#    'wherein'},
#   'EFO': {'absorbent assembly',
#    'disposable',
#    'portion',
#    'protruding portion',
#    'receptacle conformed'},
#   'EFA': {' disposable assembly', 'detachable'}},
#  '862': {'EST': {'circuit breathing',
#    'closed',
#    'closed breathing',
#    'closed breathing circuit',
#    'closed circuit',
#    'closed circuit breathing',
#    'connection',
#    'connection module',
#    'empty',
#    'filter',
#    'filter module',
#    'first',
#    'first element',
#    'maintenance',
#    'positive locking',
#    'regenerating cartridge',
#    'second'},
#   'EFO': {'additional fluid inlet',
#    'additional fluid inlet through',
#    'modules'},
#   'EFA': {'Connection module', 'maintaining'}},
#  '954': {'EST': {'abutment position',
#    'another while isolated',
#    'axial',
#    'backwashed',
#    'communication',
#    'discharge',
#    'drain',
#    'during filtration',
#    'filter element',
#    'filtered',
#    'filtering apparatus',
#    'flow',
#    'flow therethrough',
#    'fluid',
#    'holes',
#    'internal spaces',
#    'opening',
#    'outer',
#    'parallel',
#    'removal brush',
#    'stopper',
#    'trapped',
#    'trapped object',
#    'tubular',
#    'tubular shape',
#    'unfiltered',
#    'unfiltered chamber filled',
#    'which'},
#   'EFO': set(),
#   'EFA': set()},
#  '815': {'EST': {'L connector',
#    'device',
#    'diaphragm',
#    'diaphragm interposed',
#    'diaphragm permits',
#    'first',
#    'first closed',
#    'first terminal',
#    'grinding chamber',
#    'grinding teeth',
#    'input apparatus',
#    'mortar',
#    'mouth',
#    'nasal',
#    'positive',
#    'positive pressure',
#    'reservoir container',
#    'second',
#    'second open',
#    'second terminal',
#    'sino',
#    'sino nasal',
#    'tube'},
#   'EFO': {'medically beneficial substance',
#    'nasal rinse delivery',
#    'solution'},
#   'EFA': {'Sino', 'accurately apply', 'delivering'}},
#  '120': {'EST': {'aerosol',
#    'aerosolizable materials',
#    'aerosolization zone substantially',
#    'air',
#    'article comprising',
#    'composition',
#    'connecting',
#    'distal',
#    'first',
#    'first reservoir',
#    'first transport',
#    'first transport element',
#    'first unit',
#    'heater positioned',
#    'mouthpiece',
#    'nicotine solution',
#    'opening',
#    'opposing proximate',
#    'portion',
#    'proximate end',
#    'second',
#    'second separate',
#    'second unit',
#    'shell'},
#   'EFO': set(),
#   'EFA': {' delivery'}},
#  '311': {'EST': {'arrangement',
#    'deposit ink',
#    'detector',
#    'detectors',
#    'dispenser',
#    'dispenser coupled',
#    'eighth',
#    'either side',
#    'extended',
#    'exterior surface',
#    'fifth',
#    'fifth sixth',
#    'fifth sixth seventh',
#    'first',
#    'first distance',
#    'fourth',
#    'fourth distance',
#    'housing',
#    'housing comprising',
#    'housing plurality',
#    'light sources',
#    'line',
#    'line separated',
#    'ninth distance',
#    'oximeter',
#    'oximeter probe contained',
#    'oxygen saturation based',
#    'plurality',
#    'probe face',
#    'processor',
#    'purlicue',
#    'radiation emitted',
#    'reflectance data',
#    'reflectance data received',
#    'saturation value',
#    'second',
#    'second coupled',
#    'second distance',
#    'seventh',
#    'single',
#    'single housing',
#    'sources',
#    'third',
#    'third side',
#    'thumb',
#    'tissue'},
#   'EFO': {'similar ink sources'},
#   'EFA': {'Tissue'}},
#  '987': {'EST': {'building blocks',
#    'correlation',
#    'effective structure',
#    'equation',
#    'fractal aggregate model',
#    'fractal dimension',
#    'intensity difference',
#    'least squares',
#    'nanoporous ceramic',
#    'polydispersity ratio',
#    'scattering length',
#    'selective',
#    'small angle',
#    'small angle scattering'},
#   'EFO': set(),
#   'EFA': {' include incorporation', 'R S'}},
#  '44': {'EST': {'attachment formation',
#    'corresponding longitudinally',
#    'corresponding single',
#    'downwardly projecting',
#    'external attachment formation',
#    'first',
#    'first holder',
#    'first plant',
#    'flow communication',
#    'fluid communication',
#    'inlet',
#    'intake',
#    'intake closure',
#    'liquid',
#    'longitudinal',
#    'longitudinally extending',
#    'nutrient',
#    'outer circumference',
#    'outlet',
#    'partially closed enclosure',
#    'plant',
#    'plant holder',
#    'plant holder mouth',
#    'plant holders',
#    'plant holders defined',
#    'plant holders extending',
#    'planters',
#    'planting',
#    'planting insert shaped',
#    'rows',
#    'rows being provided',
#    'second',
#    'seeding clip'},
#   'EFO': {'liquid'},
#   'EFA': {' longitudinally'}},
#  '529': {'EST': {'arcuate configuration',
#    'articulating',
#    'articulating member',
#    'average pore',
#    'front',
#    'inner',
#    'inner perimeter',
#    'integral',
#    'interior',
#    'intervertebral',
#    'linear strut extending',
#    'lower',
#    'outer perimeter',
#    'porous',
#    'porous structures',
#    'side walls',
#    'slot',
#    'solid rim',
#    'solid support',
#    'spaced apart',
#    'spaced apart wall',
#    'threaded tool',
#    'upper surface',
#    'vertebrae',
#    'walls'},
#   'EFO': set(),
#   'EFA': {' surface'}},
#  '203': {'EST': {'V shaped configuration',
#    'aforementioned',
#    'arcuate',
#    'central',
#    'connected relative',
#    'curve extends',
#    'extension',
#    'fill material received',
#    'first',
#    'headpiece',
#    'optional connection',
#    'second',
#    'second increase',
#    'substantially',
#    'third being'},
#   'EFO': set(),
#   'EFA': {' pod'}},
#  '451': {'EST': {'deflectable',
#    'distal',
#    'group consisting',
#    'lumen',
#    'precursor feedstock',
#    'reactive oxygen',
#    'selectively reactive',
#    'tissue formation'},
#   'EFO': set(),
#   'EFA': {'claim', 'includes', 'treating'}},
#  '805': {'EST': {'actuator',
#    'failure factor',
#    'first',
#    'freely attachable',
#    'sensor'},
#   'EFO': {'assistance apparatus comprising', 'assistance method comprising'},
#   'EFA': {'Sleep assistance apparatus sleep system', 'moment', 'rapid'}},
#  '417': {'EST': {'barrel extending',
#    'barrel further',
#    'closed',
#    'disinfectant',
#    'first longitudinal',
#    'first open',
#    'respect',
#    'response',
#    'second',
#    'spreading',
#    'tines',
#    'tissues',
#    'tubular member'},
#   'EFO': set(),
#   'EFA': {'claim'}},
#  '162': {'EST': {'UV LED',
#    'UV LED module',
#    'chamber',
#    'cone reflectors',
#    'control',
#    'control module',
#    'curved edge',
#    'exchangeable',
#    'exchangeable battery',
#    'exchangeable holder',
#    'first positioning',
#    'handle further',
#    'jack strip',
#    'outer housing',
#    'plurality notch',
#    'present invention',
#    'screw',
#    'second',
#    'slide track',
#    'slide track configured',
#    'sliding element',
#    'supporting frame',
#    'tenon'},
#   'EFO': {'UV LED',
#    'chamber',
#    'external',
#    'outer housing',
#    'portable',
#    'present invention provides comprising',
#    'slidable lid',
#    'supporting frame'},
#   'EFA': {'Exchangeable battery photocuring device',
#    'The',
#    'least',
#    'walls',
#    'wherein'}},
#  '34': {'EST': {'baler',
#    'blade assemblies',
#    'exposed plates',
#    'first',
#    'foreign',
#    'foreign substance',
#    'foreign substance inflow prevention cover',
#    'front',
#    'hay',
#    'hollow pipe',
#    'inside',
#    'intermediate',
#    'margin',
#    'margin portion',
#    'opening',
#    'opposite ends',
#    'opposite margin',
#    'outer circumferential',
#    'outer diameter',
#    'outside',
#    'outside plate',
#    'picked',
#    'roll forming',
#    'rotary',
#    'second',
#    'sharp',
#    'through holes'},
#   'EFO': set(),
#   'EFA': {' A', 'claim'}},
#  '702': {'EST': {'allergen compositions',
#    'mixed',
#    'mixed allergen composition',
#    'pharmaceutically acceptable',
#    'same'},
#   'EFO': {'soy', 'weight'},
#   'EFA': {' Mixed allergen'}},
#  '991': {'EST': {'hexaiodo substituted',
#    'nanoporous',
#    'nanoporous membrane graphene'},
#   'EFO': set(),
#   'EFA': {'comprising', 'depositing'}},
#  '64': {'EST': {'feeder configured',
#    'intake portion',
#    'interactive fetching',
#    'interactive fetching device',
#    'launch',
#    'launch defined',
#    'launch distance',
#    'launch opening',
#    'launch portion',
#    'location',
#    'location prior',
#    'opening using gravity',
#    'planar surface disposed',
#    'predetermined',
#    'preset',
#    'preset distance',
#    'projectile',
#    'retaining location',
#    'second projectile',
#    'sensor',
#    'shell',
#    'wheels rotated'},
#   'EFO': {'interactive fetching'},
#   'EFA': set()},
#  '590': {'EST': {'M2 cationic counterion',
#    'Rb Rc Rd',
#    'amount ranging',
#    'atoms',
#    'based',
#    'carboxylic acid',
#    'chemical oxidizing',
#    'compounds',
#    'hydroxyl',
#    'keratin',
#    'organic',
#    'organic titanium salt',
#    'pyrrolyl',
#    'saturated',
#    'thereof',
#    'titanium',
#    'unsaturated'},
#   'EFO': {'C1 C6',
#    'C2 alkenyl ix cycloalkyl',
#    'acid',
#    'adjacent',
#    'alkyl',
#    'anthocyanidins anthocyanins',
#    'aromatic hydrocarbon',
#    'aromatic hydrocarbon based',
#    'associative anionic amphoteric',
#    'benzene naphthalene tetrahydronaphthalene indane indene anthracene phenanthrene isoindole indoline isoindoline benzofuran dihydrobenzofuran chroman isochroman chromene isochromene quinoline tetrahydroquinoline',
#    'cellulose based polysaccharide',
#    'cellulose polysaccharide',
#    'compounds',
#    'ethylenediamines',
#    'glycol derivatives aromatic',
#    'hydrocarbon',
#    'hydroxides',
#    'monovalent group',
#    'particular',
#    'proanthocyanins tannic acid ellagic',
#    'silicates vii amino acids',
#    'xiv xv xvi heterocyclic'},
#   'EFA': {'Hair',
#    'amino vii linear',
#    'anthocyans hydroxybenzoates flavones hydroxystilbenes',
#    'aromatic',
#    'branched',
#    'dye',
#    'dyeing',
#    'flavanols',
#    'hydrogen',
#    'monovalent group',
#    'organic',
#    'oxypropylenated',
#    'propylene',
#    'viii'}},
#  '469': {'EST': {'camera',
#    'commands',
#    'computing device',
#    'contra lateral',
#    'distal',
#    'executable instructions',
#    'first',
#    'first branch',
#    'first location',
#    'generate',
#    'image received',
#    'location',
#    'location sensors',
#    'location sensors Provided',
#    'luminal',
#    'luminal network',
#    'medium',
#    'memory',
#    'model',
#    'processor configured',
#    'processors',
#    'processors computer',
#    'registration',
#    'registration between',
#    'registration route',
#    'second',
#    'thereon',
#    'threshold distance'},
#   'EFO': {'computer readable'},
#   'EFA': {'claim', 'track', 'transitory'}},
#  '675': {'EST': {'additional pharmaceutical', 'condition', 'optical'},
#   'EFO': {'peptide D TRP AIB'},
#   'EFA': set()},
#  '738': {'EST': set(), 'EFO': {'calcium'}, 'EFA': {' solution'}},
#  '317': {'EST': {'circular buffers falls',
#    'device',
#    'particular',
#    'predetermined',
#    'processors analyze',
#    'second',
#    'signal causes',
#    'third circular buffers falls'},
#   'EFO': set(),
#   'EFA': set()},
#  '776': {'EST': {'angled support',
#    'annular gap',
#    'annular proximal',
#    'audible',
#    'audible tactile',
#    'biased',
#    'brightness',
#    'completely',
#    'cover',
#    'delay plunger rod assembly',
#    'delivery',
#    'delivery device comprising',
#    'device',
#    'distal',
#    'distal plunger configured',
#    'distally extending',
#    'drive',
#    'drive mechanism',
#    'engaging',
#    'expanded plastic enclosed air',
#    'extension part',
#    'first resilient',
#    'following',
#    'holding extension',
#    'inner',
#    'interactively connected',
#    'longitudinally',
#    'longitudinally extending',
#    'longitudinally inward',
#    'movable',
#    'partially',
#    'pen',
#    'pre tensioned',
#    'predetermined distance',
#    'proximal',
#    'radially inwardly extending protrusion',
#    'releasing',
#    'remaining force',
#    'resilient tongue',
#    'signal generating',
#    'support members',
#    'tactile',
#    'through hole such',
#    'tubular',
#    'tubular extension',
#    'viscous fluid'},
#   'EFO': {'elongated U shaped', 'proximal'},
#   'EFA': set()},
#  '894': {'EST': {'appendage',
#    'athletic',
#    'athletic activity',
#    'athletic sensor data comprising receiving',
#    'base unit',
#    'first',
#    'first athlete',
#    'first sensor',
#    'group consisting',
#    'individual',
#    'performance measuring',
#    'processors',
#    'processors further',
#    'second',
#    'third',
#    'wireless communications'},
#   'EFO': set(),
#   'EFA': {' tests'}},
#  '868': {'EST': {'agent',
#    'circuit',
#    'comprehensive',
#    'diesel exhaust reservoir',
#    'fire',
#    'fire suppressing',
#    'fuel',
#    'fuel tank',
#    'maintenance',
#    'monitor fluid',
#    'primary reducer',
#    'processing circuit',
#    'readiness score based',
#    'suppressing',
#    'water',
#    'whether'},
#   'EFO': {'incident comprising'},
#   'EFA': {' tank'}},
#  '730': {'EST': {'UV',
#    'UV LEDs',
#    'beam angle',
#    'different sides',
#    'diode LED',
#    'first',
#    'first UV',
#    'fluid',
#    'housing',
#    'inner',
#    'inner surface',
#    'inner wall',
#    'internal space',
#    'light reflecting',
#    'location between',
#    'second',
#    'second UV',
#    'sterilizing',
#    'sterilizing element',
#    'sterilizing element includes'},
#   'EFO': {'UV', 'sterilization'},
#   'EFA': {'Fluid sterilizer'}},
#  '765': {'EST': {'actual',
#    'air detector',
#    'controller',
#    'device controlled',
#    'first',
#    'first signal',
#    'leak',
#    'leak sensor',
#    'pressure',
#    'processor',
#    'second',
#    'suspected',
#    'suspected leak'},
#   'EFO': {'fluid'},
#   'EFA': {'performing'}},
#  '50': {'EST': {'desired',
#    'desired trait',
#    'different',
#    'hybrid corn',
#    'hybrid maize variety',
#    'isogenic progeny',
#    'method',
#    'plant',
#    'second',
#    'second maize',
#    'seed',
#    'single locus conversion',
#    'transgene confers',
#    'varieties'},
#   'EFO': {'Accession Numbers', 'hybrid maize', 'inbred'},
#   'EFA': {'producing'}},
#  '504': {'EST': {'another',
#    'distal anchor',
#    'distal anchors',
#    'entire length',
#    'expandable frame',
#    'extends proximally body',
#    'first cross',
#    'native mitral',
#    'proximal anchoring',
#    'proximal anchoring portion',
#    'second',
#    'second bases'},
#   'EFO': set(),
#   'EFA': set()}}

# %% [markdown]
# ## 5.将最终格式写入csv文件，这里包括了文章和关键词实体，以及文章和关键词实体之间的关系

# %%
import json
with open("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/mechanical_ner/data/original_data/id和标题的对应关系.jsonl", "r", encoding="utf-8") as file:
    for line in file:
        id2doc_dict = json.loads(line)
print("文章的篇数为：", len(id2doc_dict))

# 获得 id2doc_dict中的所有键，也就是所有的文章id
id_list = list(id2doc_dict.keys())

with open("/ssd01/Codes/PersonalCodes/ZhangXianpeng/graduation_design/mechanical_ner/data/data_to_neo4j/1.txt", "w", encoding="utf-8") as file:
    file.write("文章,BEN,LABEL\n")
    for key, value in doc_word_dict.items():
        id = key
        for i in range(len(id_list)):
            if id == id_list[i][5:]:
                title = id2doc_dict[id_list[i]]
                print(title)
        try:
            # BEN的实体类别是集合
            BEN_set = value["EFA"]
            for ele in BEN_set:
                file.write(title)
                file.write(",")
                file.write(ele)
                file.write(",")
                file.write("has_EFA")
                file.write("\n")
        except:
            continue
# Out:
# 文章的篇数为： 1000
# Method, image processing device, computer program and electronically readable data carrier for reducing vessel overlap artifacts in a four-dimensional angiography data set
# Coated packaging products, systems and methods
# Device for management of an open abdomen
# Photomedical treatment system and method with a virtual aiming device
# Hair dyeing process using at least one dye, a titanium salt and an anionic thickening polymer
# Ammoximation reactor for cyclohexanone oxime production
# Oligodeoxy nucleotide for preparing drugs for inhibiting tumor growth and application thereof
# Increasing the half-life of hydrogen peroxide in an ingestible composition
# Article of footwear with self-cleaning cleats
# Purification method for purifying liquid, purification method for purifying silicon compound-containing liquid, method for producing silylating agent liquid, film forming material or diffusing agent composition, filter medium and filter device
# Method for measuring a vapor precursor level in a cartomizer of an electronic vaping device and/or an electronic vaping device configured to perform the method
# Integrated sensors for intraventricular VAD
# Self-centering phakic refractive lenses with parachute design
# Fluid skin treatment systems and methods
# Gas distributor for a Siemens reactor
# Ratcheting epiphysiodesis plate
# Soybean variety 01072245
# Head mounted display
# Method and system for monitoring terrain and gait and predicting upcoming terrain
# Filter mechanism
# Inhaler
# Corner chair assembly
# Method of using cloud infrastructure and virtualization for bandwidth-efficient remote video streaming of software application operation by executing computer-executable instructions stored on a non-transitory computer-readable medium
# Independently controlled meter rollers and air conveyance components system and method
# Selenium-doped hydroxyapatite and preparation method thereof
# Knee brace with adjustable strut length and dynamic strut lengthening
# Method of liquid filter wetting
# Method, device, and non-transitory computer readable storage medium for interaction to event in virtual space
# Airflow in aerosol generating system with mouthpiece
# Methods for setting cardiac pacing parameters in relatively high efficiency pacing systems
# Pimple puller
# Combination therapy
# Absorbent article with waist gasketing element and leg cuffs
# Self-contained cabinet urinal systems
# Processes and systems for removing a vinyl iodide impurity from a recycle gas stream in the production of ethylene oxide
# Bone and hard plaque segmentation in spectral CT
# Diffusion reproducibility evaluation and measurement (DREAM)-MRI imaging methods
# Pharmaceutical compositions comprising Afatinib
# Removable and reattachable golf club grip
# Device and methods for precise control of medical procedures
# Mirror display apparatus and the operation method thereof
# Coffee brewer
# Aqueous dispersions of controlled release polymers and shells and capsules thereof
# Dishwasher with combined liquid and air sprayers
# Oxidation catalyst for treating a natural gas emission
# Methods for inducing partial apoptosis using caspase polypeptides
# System and method for identification of neuro-cardiological disturbances
# Disposable beverage pod and apparatus for making a beverage
# Vascular grafts derived from acellular tissue matrices
# Production method for medical linear member
# Retinal image capturing
# Activity monitoring device with assessment of exercise intensity
# Bladeless bubble fan
# Process and method for optimizing production of food and feed
# Medical tube, and medical tube set
# Dynamic strut for fixation constructs
# Differentially knitted fire barrier fabrics, and mattresses, mattress foundations, and upholstered furniture articles employing same
# System and method for preventing cross-contamination in flow generation systems
# Micellar polypeptide vaccine having pegylated phospholipids as carrier
# Grout support installation method for filter underdrain system
# Mutant huntingtin-mediated protein dysfunction
# Game program and game apparatus
# Method of controlling phytopathogenic diseases on turfgrass
# Liquid composition for oral cavity contained in foam-discharging container
# Powered surgical instrument with parameter-based firing rate
# Foldable potty
# Conjugate of polyethylene glycol and anesthetic, and preparation method thereof
# Methods and apparatus for digital imaging of dental models
# Conical connection for a dental implant
# Method for separating tritiated water from light water contaminated by the tritiated water
# Suture passers adapted for use in constrained regions
# Airbag for article of footwear
# Methods and apparatus for monitoring and treating respiratory insufficiency
# Data acquisition device, X-ray CT apparatus, and nuclear medicine diagnostic apparatus
# Composition comprising a combination of particular alkoxysilanes and a fatty substance
# Container holder assembly
# Needle guard
# Compositions and methods for increasing salt tolerance in plants
# Apparatus and method for determining a health parameter of a subject
# Method and apparatus for locating and visualizing a target in relation to a focal point of a treatment system
# Filter cartridge
# Action recognition system and method thereof
# Castless stance corrected prostetic and method of forming same
# Mixing/administration syringe devices, protective packaging and methods of protecting syringe handlers
# Spring-closing endoscopic clip where the spring action can also reverse the clip prior anytime before full ejection
# Pig rescue feeder and waterer
# Hinged-lid cooking grill for cooking pizza and the like
# Tissue-removing catheter with ball and socket deployment mechanism
# Component transfer processing method and component transfer processing device
# Orthopedic cast removal apparatus
# Anticancer adjuvant containing panaxadiol ginsenocide compound
# Systems and methods for cultivating and distributing aquatic organisms
# Microcapsule suspension
# Heater for a vaporization device
# Device for performing regional anesthesia
# Medical image diagnostic apparatus and medical image processing apparatus
# Sophorolipid mediated accelerated gelation of silk fibroin
# Handheld molecular imaging navigation system
# Implantable medical device with reduced migration capabilities
# Sheath device for inserting a catheter
# Spinal nerve decompression systems, dilation systems, and methods of using the same
# Dispense mechanism for a drug delivery device and drug delivery device
# Article and method for controlling odors from odoriferous nitrogen-containing compounds
# Soybean cultivar 75052534
# Ultrasound diagnostic apparatus and ultrasound imaging method
# System and controlling method thereof for performing measurements of an eye
# Respiratory device with unidirectional valve for attaching active venting system
# Compositions, dosage forms, and co-administration of an opioid agonist compound and an analgesic compound
# Dosing regimens for the treatment of lysosomal storage diseases using pharmacological chaperones
# Methods and compositions for targeted imaging
# Scanable tray for producing a dental prosthesis
# Radiation image capturing system
# Device, system and method for detecting apnoea of a subject
# Flavor modifying composition, uses thereof and products comprising the same
# Induction-based aerosol delivery device
# System and method to detect significant arrhythmic events through a photoplethysmogram (PPG) and accelerometer
# Method for determining a weight of a payload for a utility vehicle
# Impulse noise management
# Device for preparing beverages, provided with a storage tank
# System and method for monitoring motor recovery in a post acute stroke treatment
# Device for getting rid of undesirable animals
# Dialysis system and method for pumping and valving according to flow schedule
# Methods of synthesis and/or purification of diaminophenothiazinium compounds
# Honeycomb filter
# Spinning top and spinning top production method
# Collagen construct and method for producing the collagen construct
# Tree segregation and protection system
# Charco-resis implant, alignment instrument, system and method of use
# Droplet delivery device for delivery of fluids to the pulmonary system and methods of use
# Systems and methods for preclinical models of metastases
# Apparatus for removing protein-bound toxins from blood plasma
# Medical stopcock, kit comprising such a stopcock, and method for preparing a mixture or an emulsion
# Method and system for interpreting activity of a person on a flexible mat of a trampoline
# Universal joint implant for shoulder
# Blender with vertically movable blades
# Liquid preparation for contact lenses comprising hydrolyzed hyaluronic acid derivative and cationic bactericide
# Absorbent article with waist gasketing element and leg cuffs
# Self-rescue anti choking implements
# Maize inbred PH40ZZ
# Double-joint sickle knife for endoscopy therapy
# External agent for treating hyperhidrosis
# Method of repairing cartilage defects
# Intravascular treatment of vascular occlusion and associated devices, systems, and methods
# Surgical instrument
# Fishing lure with blade arrangement
# Autoinjector
# Reactor comprising radially placed cooling plates and methods of using same
# Apparatus for detecting a substance in a rod shaped article of the tobacco industry
# Electrosurgical device with disposable shaft having modular subassembly
# Telescopic post for a table
# Ultrasonic device, ultrasonic probe, electronic equipment, and ultrasonic image device
# Compositions and methods of Rit1 inhibition
# Micro-adjustable telescoping arms for orthopedic braces
# Breast pump container assemblies
# Patch
# Pegylated lipid nanoparticle with bioactive lipophilic compound
# Systems and methods for planning and controlling the rotation of a multileaf collimator for arc therapy
# Dual vacuum device for medical fixture placement including for thoracoscopic left ventricular lead placement
# Medical device coating with a biocompatible layer
# Composite containing poly(glycerol sebacate) filler
# Divergence detection of a shoe bite line
# Footwear sole assembly with insert plate and nonlinear bending stiffness
# Tip for lead extraction device
# Systems and methods for match-3 strategic adventure games
# Stand-alone ALIF spine implants
# Filter device
# Catheter pump assembly including a stator
# Dual node multiray electrode catheter
# Device for handling medical waste products
# Surgery assistance apparatus, method and program
# Disposable absorbent core and disposable absorbent assembly including same, and method of making same
# Connection module, maintenance device and method for maintaining a closed-circuit breathing apparatus
# Filter element and filtering apparatus
# Sino-nasal rinse delivery device with agitation, flow-control and integrated medication management system
# Reservoir and heater system for controllable delivery of multiple aerosolizable materials in an electronic smoking article
# Tissue oximetry probe with tissue marking feature
# Nanoporous ceramic membranes, membrane structures, and related methods
# Hyrdoponics
# Intervertebral spinal implant
# Multiple pod pillow system
# System and method for sinus surgery
# Sleep assistance apparatus, sleep assistance system, and sleep assistance method
# Frenulum spreader
# Exchangeable-battery photocuring device, an exchangeable-battery photocuring device with a slidable lid, and a portable battery photocuring device with a slidable lid
# Rotor apparatus for baler
# Mixed allergen compositions and methods for using the same
# Nanoporous graphene membranes
# Pet exercise and entertainment device
# Hair dyeing process using at least one direct and/or natural dye, a titanium salt, a cellulose-based polysaccharide and optionally a particular organic solvent
# Systems and methods for registration of location sensors
# Methods for the treatment of glaucoma and age-related macular degeneratiion by a peptide D-TRP-AIB
# Collagen biomaterials
# Cognitive event predictor
# Medicament delivery device
# Athleticism rating and performance measuring system
# Response vehicle systems and methods
# Fluid sterilizer and associated connecting device
# Medical device leak sensing devices, methods and systems
# Hybrid corn variety 13921291
# Replacement heart valve
